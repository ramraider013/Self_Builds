# %% [markdown]
# # Title

# %% [markdown]
# ## Purpose
#
# *
# *
# *

# %% [markdown]
# ## References

# %% [markdown]
# 1. author1, article1, journal1, year1, url1
# 2. author2, article2, journal2, year2, url2

# %% [markdown]
# ## Library_Import

# %%
    # Data manipulation
import numpy as np
from bs4 import BeautifulSoup as bs
import pandas as pd
import pandas_datareader
from pandas_datareader import data as wb

    # Visualizations
import matplotlib as plt
# %matplotlib inline
import chart_studio.plotly as py
import plotly
import plotly.tools as tls
import plotly.graph_objs as go
import plotly.offline as ply
plotly.offline.init_notebook_mode(connected=True)

    # Cufflinks binds Plotly directly to pandas dataframes.
import cufflinks as cf
cf.go_offline(connected=True)
cf.set_config_file(theme='white')

    # IMPORT API FUNCTIONS
import quandl
import yfinance as yf
from yahoofinancials import YahooFinancials
import requests
import alpha_vantage
from alpha_vantage.timeseries import TimeSeries
import iexfinance
from iexfinance.stocks import Stock
from iexfinance.stocks import get_historical_data
from iexfinance.stocks import get_historical_intraday
from iexfinance.refdata import get_symbols
from iexfinance.data_apis import get_data_points
from iexfinance.data_apis import get_time_series
from iexfinance.altdata import get_social_sentiment
from iexfinance.altdata import get_ceo_compensation

    # MISC LIB IMPORTS
import jupytemplate
import locale
from datetime import date, datetime
from nsepy import get_history
import os
import time
import csv
import json
from patsy import dmatrices

    # lOCAL LIBRARY IMPORT
import jupytemplate
print(jupytemplate.get_template_path())
import sys
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %% [markdown]
# # Data_Import
# We retrieve all the required data for the analysis.

# %% [markdown]
# ##  Authentication

# %%
quandl.ApiConfig.api_key="dbyBuiq4bczbbuz9bA4t"

https://www.quandl.com/api/v3/datatables/SHARADAR/SF1.csv?
    ticker=AAPL&api_key=dbyBuiq4bczbbuz9bA4t

# %% [markdown]
# ## TICKER

# %%
quandl.get_table('SHARADAR/SF1', ticker='AAPL')
# Out:
#      ticker dimension calendardate    datekey reportperiod lastupdated  \
# None
# 0      AAPL       MRY   2018-12-31 2018-09-29   2018-09-29  2020-01-29
# 1      AAPL       MRY   2017-12-31 2017-09-30   2017-09-30  2020-01-29
# 2      AAPL       MRY   2016-12-31 2016-09-24   2016-09-24  2020-01-29
# 3      AAPL       MRY   2015-12-31 2015-09-26   2015-09-26  2020-01-29
# 4      AAPL       MRY   2014-12-31 2014-09-27   2014-09-27  2020-01-29
# 5      AAPL       MRY   2013-12-31 2013-09-28   2013-09-28  2020-01-29
# 6      AAPL       MRY   2012-12-31 2012-09-29   2012-09-29  2020-01-29
# 7      AAPL       MRY   2011-12-31 2011-09-24   2011-09-24  2020-01-29
#
#           accoci        assets     assetsavg       assetsc  ...   sharesbas  \
# None                                                        ...
# 0    -3454000000  365725000000  372304500000  131339000000  ...  4829926000
# 1     -150000000  375319000000  346541250000  128645000000  ...  5165228000
# ...

# %% [markdown]
# ## Dimension
# * https://www.quandl.com/api/v3/datatables/SHARADAR/SF1.csv?dimension=MRY&ticker=AAPL&api_key=dbyBuiq4bczbbuz9bA4t

# %%
quandl.get_table('SHARADAR/SF1', dimension='MRY', ticker='AAPL')
# Out:
#      ticker dimension calendardate    datekey reportperiod lastupdated  \
# * https://www.quandl.com/api/v3/datatables/SHARADAR/SF1.csv?ticker=AAPL&calendardate.gte=2013-12-31&api_key=dbyBuiq4bczbbuz9bA4t

# %%
quandl.get_table('SHARADAR/SF1', calendardate={'gte':'2013-12-31'},
                 ticker='AAPL')
# Out:
#      ticker dimension calendardate    datekey reportperiod lastupdated  \
# None
# 0      AAPL       MRY   2018-12-31 2018-09-29   2018-09-29  2020-01-29
# 1      AAPL       MRY   2017-12-31 2017-09-30   2017-09-30  2020-01-29
# 2      AAPL       MRY   2016-12-31 2016-09-24   2016-09-24  2020-01-29
# 3      AAPL       MRY   2015-12-31 2015-09-26   2015-09-26  2020-01-29
# 4      AAPL       MRY   2014-12-31 2014-09-27   2014-09-27  2020-01-29
# 5      AAPL       MRY   2013-12-31 2013-09-28   2013-09-28  2020-01-29
#
#           accoci        assets     assetsavg       assetsc  ...   sharesbas  \
# None                                                        ...
# 0    -3454000000  365725000000  372304500000  131339000000  ...  4829926000
# 1     -150000000  375319000000  346541250000  128645000000  ...  5165228000
# 2      634000000  321686000000  306462250000  106869000000  ...  5388443000
# 3     -345000000  290345000000  271646000000   89378000000  ...  5702722000
# ...

# %% [markdown]
# ## Indicators
# * https://www.quandl.com/api/v3/datatables/SHARADAR/SF1.csv?ticker=AAPL&qopts.columns=ticker,dimension,datekey,revenue&api_key=dbyBuiq4bczbbuz9bA4t

# %%
quandl.get_table('SHARADAR/SF1', 
                 qopts={"columns":['ticker' ,'dimension','datekey',
                                   'revenue']}, ticker='AAPL')
# Out:
#      ticker dimension    datekey       revenue
# None
# 0      AAPL       MRY 2018-09-29  265595000000
# 1      AAPL       MRY 2017-09-30  229234000000
# 2      AAPL       MRY 2016-09-24  215639000000
# 3      AAPL       MRY 2015-09-26  233715000000
# 4      AAPL       MRY 2014-09-27  182795000000
# 5      AAPL       MRY 2013-09-28  170910000000
# 6      AAPL       MRY 2012-09-29  156508000000
# 7      AAPL       MRY 2011-09-24  108249000000

# %% [markdown]
# ## More than 10,000 Rows of Data
# * in browser
# https://www.quandl.com/api/v3/datatables/SHARADAR/SF1?qopts.export=true&api_key=dbyBuiq4bczbbuz9bA4t
# * out of browser
# https://www.quandl.com/api/v3/datatables/SHARADAR/SF1.csv?qopts.export=true&api_key=dbyBuiq4bczbbuz9bA4t

# %%
quandl.get_table('SHARADAR/SF1', 
                 calendardate={'gte':'2017-09-01','lte':'2018-01-10'},
                 paginate=True)
# Out:
#      ticker dimension calendardate    datekey reportperiod lastupdated  \
# None
# 0       XOM       MRY   2017-12-31 2017-12-31   2017-12-31  2020-02-26
# 1       WMT       MRY   2017-12-31 2018-01-31   2018-01-31  2019-12-04
# 2        VZ       MRY   2017-12-31 2017-12-31   2017-12-31  2020-02-21
# 3         V       MRY   2017-12-31 2017-09-30   2017-09-30  2020-02-01
# 4       UTX       MRY   2017-12-31 2017-12-31   2017-12-31  2020-02-06
# 5       UNH       MRY   2017-12-31 2017-12-31   2017-12-31  2020-02-15
# 6      TSLA       MRY   2017-12-31 2017-12-31   2017-12-31  2020-02-14
# 7       TRV       MRY   2017-12-31 2017-12-31   2017-12-31  2020-02-13
# Out:
#      ticker       date eventcodes
# None
# 0      AAPL 2020-02-27         57
# 1      AAPL 2020-02-18      71|91
# 2      AAPL 2020-02-14         34
# 3      AAPL 2020-02-12         34
# 4      AAPL 2020-02-10         34
# ...     ...        ...        ...
# 219    AAPL 1999-02-05         34
# 220    AAPL 1999-01-07         34
# 221    AAPL 1998-12-23         51
# 222    AAPL 1998-08-10         34
# 223    AAPL 1998-01-08         21
#
# [224 rows x 3 columns]

# %% [markdown]
# ## Events by Date
# https://www.quandl.com/api/v3/datatables/SHARADAR/EVENTS.csv?date=2016-04-18&api_key=dbyBuiq4bczbbuz9bA4t

# %%
quandl.get_table('SHARADAR/EVENTS', date='2016-04-18')
# Out:
#      ticker       date eventcodes
# None
# 0       IBM 2016-04-18         22
# 1       JPM 2016-04-18      81|91

# %% [markdown]
# ## Ticker Metadata
# https://www.quandl.com/api/v3/datatables/SHARADAR/TICKERS.csv?table=SF1&ticker=AAPL&api_key=dbyBuiq4bczbbuz9bA4t

# %%
quandl.get_table('SHARADAR/TICKERS', table='SF1', ticker='AAPL')
# Out:
#      table  permaticker ticker       name exchange isdelisted  category  \
# None
# 0      SF1       199059   AAPL  Apple Inc   NASDAQ          N  Domestic
#
#          cusips  siccode      sicsector  ... currency           location  \
# None                                     ...
# 0     037833100     3571  Manufacturing  ...      USD  California; U.S.A
#
#      lastupdated firstadded firstpricedate lastpricedate firstquarter  \
# None
# 0     2020-01-29 2014-09-24     1986-01-01    2020-03-06   1996-09-30
#
#      lastquarter                                         secfilings  \
# None
# 0     2019-12-31  https://www.sec.gov/cgi-bin/browse-edgar?actio...
#
#                companysite
# None
# 0     http://www.apple.com
#
# [1 rows x 28 columns]

# %% [markdown]
# ## Indicator Descriptions by Table
# https://www.quandl.com/api/v3/datatables/SHARADAR/INDICATORS.csv?table=SF1&api_key=dbyBuiq4bczbbuz9bA4t

# %%
quandl.get_table('SHARADAR/INDICATORS', table='SF1')
# Out:
#      table     indicator isfilter isprimarykey  \
# None
# 0      SF1       revenue        N            N
# 1      SF1           cor        N            N
# 2      SF1          sgna        N            N
# 3      SF1           rnd        N            N
# 4      SF1          opex        N            N
# ...    ...           ...      ...          ...
# 106    SF1     dimension        Y            Y
# 107    SF1  calendardate        Y            N
# 108    SF1       datekey        N            Y
# 109    SF1  reportperiod        N            Y
# 110    SF1   lastupdated        Y            N
#
#                                            title  \
# None
# 0                                       Revenues
# 1                                Cost of Revenue
# 2     Selling General and Administrative Expense
# 3               Research and Development Expense
# 4                             Operating Expenses
# ...                                          ...
# ...

# %% [markdown]
# ## Indicator Descriptions by Indicator
# https://www.quandl.com/api/v3/datatables/SHARADAR/INDICATORS.csv?indicator=revenue&api_key=dbyBuiq4bczbbuz9bA4t

# %%
quandl.get_table('SHARADAR/INDICATORS', indicator='revenue')
# Out:
#      table indicator isfilter isprimarykey     title  \
# None
# 0      SF1   revenue        N            N  Revenues
#
#                                             description  unittype
# None
# 0     [Income Statement] Amount of Revenue recognize...  currency

# %% [markdown]
# # Test_Section

# %%
import numpy as np
import pandas as pd
import pyexcel
import statsmodels.api as stat
import statsmodels.tsa.stattools as ts
import quandl
from quantrautil import get_quantinsti_api_key

quandl.ApiConfig.api_key="dbyBuiq4bczbbuz9bA4t"

data = []
headers = ['Date','commodity1','commodity2','zscore','signal','status',
           'buy price','sell price','mtm','pnl','Cointegration test']

data.append(headers)
threshold = 1.75
start=80
end=90
prev_status = ""
mtm = ""
prev_sell_price = ""
sell_price = ""
prev_buy_price = ""
buy_price = ""
SL = -10000
TP = 20000
N=5000
M=5000

data1 = quandl.get("CHRIS/MCX_AL1", start_date="2014-04-01", 
                   end_date="2016-07-01", api_key=key)

data2 = quandl.get("CHRIS/MCX_PB1", start_date="2014-04-01", 
                   end_date="2016-07-01", api_key=key)

data1 = data1.dropna()
data2 = data2.dropna()

data1['key']=data1.index
data2['key']=data2.index

result = pd.merge(data1, data2, on='key', left_index=True,
                  right_index=False)

data1 = result[['Open_x','High_x','Low_x','Close_x','Volume_x']]
data2 = result[['Open_y','High_y','Low_y','Close_y','Volume_y']]

data1.columns = ['Open','High','Low','Close','Volume']

data2.columns = ['Open','High','Low','Close','Volume']

def cointegration_test(x, y):
    result = stat.OLS(x['Close'], y['Close']).fit()
    return ts.adfuller(result.resid)

def zscore_cal(data1,data2,start,end):
    s1 = pd.Series(data1['Close'][start:end])
    s2 = pd.Series(data2['Close'][start:end])

    mvavg_old = np.mean(np.log(s1) - np.log(s2))

    std_old = np.std(np.log(s1) - np.log(s2))
    
    current_spread = np.log(data1['Close'][end])- np.log(data2['Close'][end])

    zscore = (current_spread - mvavg_old)/std_old if std_old > 0 else 0

    return zscore

def signal_cal(zscore,threshold,adftest):
    if zscore > threshold and adftest == 'Yes':
        signal = 'SELL' 

    elif zscore < -threshold and adftest == 'Yes':
        signal = 'BUY'

    else:
        signal = ''
    return signal

def status_cal(prev_status,mtm,SL,TP,signal,adftest):
    if prev_status in ["","SL","TP","CB"]:
        status = signal
    else:
        if adftest == "No":
            status = "CB"
        else:
            if mtm == "":
                status = ""
            else:
                if mtm<SL:
                    status="SL"
                else:
                    if mtm>TP:
                        status="TP"
                    else:
                        status = prev_status

    return status

def buy_price_cal(prev_status,prev_buy_price,buy_price,
                  signal,status,data1, data2,end):
    if status == prev_status:
        buy_price = prev_buy_price
    else:
        if status in ["SL","TP","CB",""]:
            buy_price = ""
        else:
            if signal == "BUY":
                buy_price = data1['Close'][end]
            else:
                if signal == "SELL":
                    buy_price = data2['Close'][end]
                else:
                    buy_price = ""

    return buy_price

def sell_price_cal(prev_status,prev_sell_price,
                   sell_price,signal,status, data1,data2,end):
    if status == prev_status:
        sell_price = prev_sell_price
    else:
        if status in ["SL","TP","CB",""]:
            sell_price = ""
        else:
            if signal == "BUY":
                sell_price = data2['Close'][end]
            else:
                if signal == "SELL":
                    sell_price = data1['Close'][end]
                else:
                    sell_price = ""

    return sell_price

def mtm_cal(data1,data2,prev_status,prev_sell_price,
            prev_buy_price,M,N,end):
    if prev_status == "BUY":
        mtm = (prev_sell_price-data2['Close'][end])*M+(data1['Close'][end]-prev_buy_price)*N if prev_buy_price else 0
    else:
        if prev_status == "SELL":
            mtm =(prev_sell_price-data1['Close'][end])*N+(data2['Close'][end]-prev_buy_price)*M if prev_buy_price else 0
        else:
            mtm = ""

    return mtm

def strategy(data1,data2,threshold,start,end,
             prev_status,mtm,prev_sell_price,sell_price,
             prev_buy_price,buy_price,SL,TP,M,N):
    pnl = 0
    i = 0
    for row in data1[90:].iterrows():
        
        d1 = data1[i:90+i]
        d2 = data2[i:90+i]
        c_t = cointegration_test(d1, d2)
        if c_t[0] <= c_t[4]['10%'] and c_t[1] <= 0.1:
            adftest = "Yes"
        else:
            adftest = "No"
        
        zscore = zscore_cal(data1,data2,start,end)
        signal = signal_cal(zscore,threshold,adftest)
        mtm = mtm_cal(data1,data2,prev_status,
                      prev_sell_price,prev_buy_price,M,N,end)
        status = status_cal(prev_status,mtm,SL,TP,signal,adftest)
        buy_price = buy_price_cal(prev_status,prev_buy_price,
                                  buy_price,signal,status,data1,data2,end)
        sell_price = sell_price_cal(prev_status,
                                    prev_sell_price,sell_price,
                                    signal,status,data1,data2,end)

        pnl = (pnl + mtm) if status in ['TP','SL','CB'] else pnl

# %%
import statsmodels.api as sm
df=sm.datasets.macrodata.load_pandas().data
df
# Out:
#        year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 0    1959.0      1.0   2710.349    1707.4   286.898   470.045   1886.9
# 1    1959.0      2.0   2778.801    1733.7   310.859   481.301   1919.7
# 2    1959.0      3.0   2775.488    1751.8   289.226   491.260   1916.4
# 3    1959.0      4.0   2785.204    1753.7   299.356   484.052   1931.3
# 4    1960.0      1.0   2847.699    1770.5   331.722   462.199   1955.5
# ..      ...      ...        ...       ...       ...       ...      ...
# 198  2008.0      3.0  13324.600    9267.7  1990.693   991.551   9838.3
# 199  2008.0      4.0  13141.920    9195.3  1857.661  1007.273   9920.4
# 200  2009.0      1.0  12925.410    9209.2  1558.494   996.287   9926.4
# 201  2009.0      2.0  12901.504    9189.0  1456.678  1023.528  10077.5
# 202  2009.0      3.0  12990.341    9256.0  1486.398  1044.088  10040.6
#
#          cpi      m1  tbilrate  unemp      pop  infl  realint
# ...

# %%
index=sm.tsa.datetools.dates_from_range('1959Q1','2009Q3')
df.index=index
df
# Out:
#               year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 1959-03-31  1959.0      1.0   2710.349    1707.4   286.898   470.045   1886.9
# 1959-06-30  1959.0      2.0   2778.801    1733.7   310.859   481.301   1919.7
# 1959-09-30  1959.0      3.0   2775.488    1751.8   289.226   491.260   1916.4
# 1959-12-31  1959.0      4.0   2785.204    1753.7   299.356   484.052   1931.3
# 1960-03-31  1960.0      1.0   2847.699    1770.5   331.722   462.199   1955.5
# ...            ...      ...        ...       ...       ...       ...      ...
# 2008-09-30  2008.0      3.0  13324.600    9267.7  1990.693   991.551   9838.3
# 2008-12-31  2008.0      4.0  13141.920    9195.3  1857.661  1007.273   9920.4
# 2009-03-31  2009.0      1.0  12925.410    9209.2  1558.494   996.287   9926.4
# 2009-06-30  2009.0      2.0  12901.504    9189.0  1456.678  1023.528  10077.5
# 2009-09-30  2009.0      3.0  12990.341    9256.0  1486.398  1044.088  10040.6
#
# ...

# %%
import pandas as pd
import pandas_datareader as pdr

start=pd.to_datetime('2015-01-01')
end=pd.to_datetime('2020-01-01')

# %%
ticker=['AAPL', 'CSCO','IBM','AMZN']

data = pdr.get_data_yahoo(ticker, start="2017-01-01", end="2020-03-06")
data=data['Adj Close']
data
# Out:
# Symbols           AAPL       CSCO         IBM         AMZN
# Date
# 2017-01-03  110.691154  27.626755  145.416626   753.669983
# 2017-01-04  110.567276  27.462530  147.217041   757.179993
# 2017-01-05  111.129562  27.526394  146.729950   780.450012
# 2017-01-06  112.368469  27.581137  147.451843   795.989990
# 2017-01-09  113.397697  27.535517  145.816681   796.919983
# ...                ...        ...         ...          ...
# 2020-03-02  298.809998  41.169998  134.300003  1953.949951
# 2020-03-03  289.320007  40.040001  128.899994  1908.989990
# 2020-03-04  302.739990  41.389999  134.220001  1975.829956
# 2020-03-05  292.920013  39.570000  129.550003  1924.030029
# 2020-03-06  289.029999  39.680000  127.730003  1901.089966
#
# [799 rows x 4 columns]

# %%
data
# Out:
# Date
# 2017-01-03 00:00:00                                               753.67
# 2017-01-04 00:00:00                                               757.18
# 2017-01-05 00:00:00                                               780.45
# 2017-01-06 00:00:00                                               795.99
# 2017-01-09 00:00:00                                               796.92
#                                              ...
# 2020-03-04 00:00:00                                              1975.83
# 2020-03-05 00:00:00                                              1924.03
# 2020-03-06 00:00:00                                              1901.09
# Normalized_R           Symbols         AAPL      CSCO       IBM      ...
# Nominal R              Date
# 2017-01-03 00:00:00                      ...
# Name: AMZN, Length: 801, dtype: object

# %% [markdown]
# # New_Tricks

# %% [markdown]
# ## Tricks_One

# %% [markdown]
# ## Tricks_Two

# %% [markdown]
# ## Tricks_Three

# %% [markdown]
# # SECTION_HEADDER_1

# %% [markdown]
# ## Concept_1_One

# %% [markdown]
# ## Concept_1_Two

# %% [markdown]
# ## Concept_1_Three

# %% [markdown]
# # SECTION_HEADDER_3

# %% [markdown]
# ## Concept_2_One

# %% [markdown]
# ### Aspect_2_One

# %% [markdown]
# ### Aspect_2_Two

# %% [markdown]
# ### Aspect_2_Three

# %% [markdown]
# ## Concept_2_Two

# %% [markdown]
# ### Aspect_2_One

# %% [markdown]
# ### Aspect_2_Two

# %% [markdown]
# ### Aspect_2_Three

# %% [markdown]
# ## Concept_2_Three

# %% [markdown]
# ### Aspect_2_One

# %% [markdown]
# ### Aspect_2_Two

# %% [markdown]
# ### Aspect_2_Three

# %% [markdown]
# # SECTION_HEADDER_3

# %% [markdown]
# ## Concept_3_One

# %% [markdown]
# ### Aspect_3_One

# %% [markdown]
# ### Aspect_3_Two

# %% [markdown]
# ### Aspect_3_Three

# %% [markdown]
# ## Concept_3_Two

# %% [markdown]
# ### Aspect_3_One

# %% [markdown]
# ### Aspect_3_Two

# %% [markdown]
# ### Aspect_3_Three

# %% [markdown]
# ## Concept_3_Three

# %% [markdown]
# ### Aspect_3_One

# %% [markdown]
# ### Aspect_3_Two

# %% [markdown]
# ### Aspect_3_Three
