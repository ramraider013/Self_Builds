# %% [markdown]
# # TITLE: RESOURCE GUIDE:

# %% [markdown]
# ## Module & Library Import

# %%
    # 1 Data manipulation
import numpy as np
from bs4 import BeautifulSoup as bs
import pandas as pd
import pandas_datareader as pdr
from pandas_datareader import data as wb
    # 7 Options for pandas
pd.options.display.max_columns = 50
pd.options.display.max_rows = 30

    # 11 Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline
    # 14 More Visualizations
import chart_studio.plotly as py
import plotly
import plotly.tools as tls
import plotly.graph_objs as go
import plotly.offline as ply
plotly.offline.init_notebook_mode(connected=True)
    # 21 Cufflinks binds Plotly directly to pandas dataframes.
import cufflinks as cf
cf.go_offline(connected=True)
cf.set_config_file(theme='white')
 
    # 26 IMPORT API FUNCTIONS
import quandl
import yfinance as yf
from yahoofinancials import YahooFinancials
import requests
import alpha_vantage
from alpha_vantage.timeseries import TimeSeries

import iexfinance
from iexfinance.stocks import Stock
from iexfinance.stocks import get_historical_data
from iexfinance.stocks import get_historical_intraday
from iexfinance.refdata import get_symbols
from iexfinance.data_apis import get_data_points
from iexfinance.data_apis import get_time_series
from iexfinance.altdata import get_social_sentiment
from iexfinance.altdata import get_ceo_compensation

    # 44 MISC LIB IMPORTS
import locale
from datetime import date, datetime
from nsepy import get_history
import os
import time
import csv
import json
from patsy import dmatrices

    # 54
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Local library import
# We import all the required local libraries libraries

# %%
# Include local library paths
import sys

    # uncomment and fill to import local libraries
    
# sys.path.append('path/to/local/lib') 
# Import local libraries

# %% [markdown]
# ## References
#
# * import jupytemplate
# * print(jupytemplate.get_template_path())

# %% [markdown]
# # GENERAL TRICKS:
#
# ## Format Outputs
# * ADD COMMAS TO NUMBERS

# %%
    # ADD COMMAS TO NUMBERS\

value=100000000000000000
    
print('$'+f'{value:,}')


print('ANNUAL_NON-DIVERSIFIABLE RISK = ' + f'{value:%}')
# Out:
# $100,000,000,000,000,000
# ANNUAL_NON-DIVERSIFIABLE RISK = 10000000000000000000.000000%

# %% [markdown]
# # Data import
# * We retrieve all the required data for the analysis.
#
# ## save data

# %%
data.to_csv(r'C:\Users\gordo\Programming\Data_Bank\New_bank\_'+stocks+'.csv')
            
data.to_excel(r'C:\Users\gordo\Programming\Data_Bank\New_bank\_'+stocks+'.xlsx')

# %% [markdown]
# ## NASDAQ

# %%
# Get the list of all available equity symbols from Nasdaq.

    # Returns nasdaq_tickers – 
        # DataFrame with company tickers, names, and other properties.
    # Return type pandas.DataFrame

pdr.nasdaq_trader.get_nasdaq_symbols(retry_count=3, timeout=30,pause=None)
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAAU             True                       Perth Mint Physical Gold ETF
# AACG             True  ATA Creativity Global - American Depositary Sh...
# AADR             True                AdvisorShares Dorsey Wright ADR ETF
# ...               ...                                                ...
# ZXYZ.A           True                 Nasdaq Symbology Test Common Stock
# ZXZZT            True                                  NASDAQ TEST STOCK
# ZYME             True                       Zymeworks Inc. Common Shares
# ZYNE             True       Zynerba Pharmaceuticals, Inc. - Common Stock
# ZYXI             True                         Zynex, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# A                     N                  False           100.0       False
# AA                    N                  False           100.0       False
# AAAU                  P                   True           100.0       False
# AACG                  Q               G  False           100.0       False
# AADR                  P                   True           100.0       False
# ...                 ...             ...    ...             ...         ...
# ZXYZ.A                Q               Q  False           100.0        True
# ZXZZT                 Q               G  False           100.0        True
# ZYME                  N                  False           100.0       False
# ZYNE                  Q               G  False           100.0       False
# ZYXI                  Q               S  False           100.0       False
#
#        Financial Status CQS Symbol NASDAQ Symbol  NextShares
# Symbol
# A                   NaN          A             A       False
# AA                  NaN         AA            AA       False
# AAAU                NaN       AAAU          AAAU       False
# AACG                  N        NaN          AACG       False
# AADR                NaN       AADR          AADR       False
# ...                 ...        ...           ...         ...
# ZXYZ.A                N        NaN        ZXYZ.A       False
# ZXZZT                 N        NaN         ZXZZT       False
# ZYME                NaN       ZYME          ZYME       False
# ZYNE                  N        NaN          ZYNE       False
# ZYXI                  N        NaN          ZYXI       False
#
# [8903 rows x 11 columns]

# %% [markdown]
# ## INTRINO

# %%
import intrinio_sdk
import pandas as pd

intrinio_sdk.ApiClient().configuration.api_key['api_key'] = '{OjdlOTlkZjdkODk3MDY0YzkzMWMxZDM0NjIyZTMyZTYw}' 
security_api = intrinio_sdk.SecurityApi()

# %%
r = security_api.get_security_stock_prices(identifier='AAPL',
                                           start_date='2019-01-01',
                                           end_date='2020-12-31',
                                           frequency='daily',
                                           page_size=10000)
r
# Out:
# {'next_page': None,
#  'security': {'code': 'EQS',
#               'company_id': 'com_NX6GzO',
#               'composite_figi': 'BBG000B9XRY4',
#               'composite_ticker': 'AAPL:US',
#               'currency': 'USD',
#               'figi': 'BBG000B9Y5X2',
#               'id': 'sec_agjrgj',
#               'name': 'Apple Inc',
#               'share_class_figi': 'BBG001S5N8V8',
#               'ticker': 'AAPL'},
#  'stock_prices': [{'adj_close': 292.92,
#                    'adj_high': 299.55,
#                    'adj_low': 291.41,
#                    'adj_open': 295.52,
#                    'adj_volume': 46893219.0,
#                    'close': 292.92,
#                    'date': datetime.date(2020, 3, 5),
#                    'frequency': 'daily',
#                    'high': 299.55,
#                    'intraperiod': False,
#                    'low': 291.41,
#                    'open': 295.52,
#                    'volume': 46893219.0},
#                   {'adj_close': 302.74,
#                    'adj_high': 303.4,
#                    'adj_low': 293.13,
#                    'adj_open': 296.44,
#                    'adj_volume': 54794568.0,
#                    'close': 302.74,
#                    'date': datetime.date(2020, 3, 4),
#                    'frequency': 'daily',
#                    'high': 303.4,
#                    'intraperiod': False,
#                    'low': 293.13,
#                    'open': 296.44,
#                    'volume': 54794568.0},
#                   {'adj_close': 289.32,
#                    'adj_high': 304.0,
#                    'adj_low': 285.8,
#                    'adj_open': 303.67,
#                    'adj_volume': 79868852.0,
#                    'close': 289.32,
#                    'date': datetime.date(2020, 3, 3),
#                    'frequency': 'daily',
#                    'high': 304.0,
#                    'intraperiod': False,
#                    'low': 285.8,
#                    'open': 303.67,
#                    'volume': 79868852.0},
#                   {'adj_close': 298.81,
#                    'adj_high': 301.44,
#                    'adj_low': 277.72,
#                    'adj_open': 282.28,
#                    'adj_volume': 85349339.0,
#                    'close': 298.81,
#                    'date': datetime.date(2020, 3, 2),
#                    'frequency': 'daily',
#                    'high': 301.44,
#                    'intraperiod': False,
#                    'low': 277.72,
#                    'open': 282.28,
#                    'volume': 85349339.0},
#                   {'adj_close': 273.36,
#                    'adj_high': 278.41,
#                    'adj_low': 256.37,
#                    'adj_open': 257.26,
#                    'adj_volume': 106721230.0,
#                    'close': 273.36,
#                    'date': datetime.date(2020, 2, 28),
#                    'frequency': 'daily',
#                    'high': 278.41,
#                    'intraperiod': False,
#                    'low': 256.37,
#                    'open': 257.26,
#                    'volume': 106721230.0},
#                   {'adj_close': 273.52,
#                    'adj_high': 286.0,
#                    'adj_low': 272.96,
#                    'adj_open': 281.1,
#                    'adj_volume': 80151381.0,
#                    'close': 273.52,
#                    'date': datetime.date(2020, 2, 27),
#                    'frequency': 'daily',
#                    'high': 286.0,
#                    'intraperiod': False,
#                    'low': 272.96,
#                    'open': 281.1,
#                    'volume': 80151381.0},
#                   {'adj_close': 292.65,
#                    'adj_high': 297.88,
#                    'adj_low': 286.5,
#                    'adj_open': 286.53,
#                    'adj_volume': 49678431.0,
#                    'close': 292.65,
#                    'date': datetime.date(2020, 2, 26),
#                    'frequency': 'daily',
#                    'high': 297.88,
#                    'intraperiod': False,
#                    'low': 286.5,
#                    'open': 286.53,
#                    'volume': 49678431.0},
#                   {'adj_close': 288.08,
#                    'adj_high': 302.53,
#                    'adj_low': 286.13,
#                    'adj_open': 300.95,
#                    'adj_volume': 57668364.0,
#                    'close': 288.08,
#                    'date': datetime.date(2020, 2, 25),
#                    'frequency': 'daily',
#                    'high': 302.53,
#                    'intraperiod': False,
#                    'low': 286.13,
#                    'open': 300.95,
#                    'volume': 57668364.0},
#                   {'adj_close': 298.18,
#                    'adj_high': 304.18,
#                    'adj_low': 289.23,
#                    'adj_open': 297.26,
#                    'adj_volume': 55548828.0,
#                    'close': 298.18,
#                    'date': datetime.date(2020, 2, 24),
#                    'frequency': 'daily',
#                    'high': 304.18,
#                    'intraperiod': False,
#                    'low': 289.23,
#                    'open': 297.26,
#                    'volume': 55548828.0},
#                   {'adj_close': 313.05,
#                    'adj_high': 320.45,
#                    'adj_low': 310.5,
#                    'adj_open': 318.62,
#                    'adj_volume': 32426415.0,
#                    'close': 313.05,
#                    'date': datetime.date(2020, 2, 21),
#                    'frequency': 'daily',
#                    'high': 320.45,
#                    'intraperiod': False,
#                    'low': 310.5,
#                    'open': 318.62,
#                    'volume': 32426415.0},
#                   {'adj_close': 320.3,
#                    'adj_high': 324.65,
#                    'adj_low': 318.21,
#                    'adj_open': 322.63,
#                    'adj_volume': 25141489.0,
#                    'close': 320.3,
#                    'date': datetime.date(2020, 2, 20),
#                    'frequency': 'daily',
#                    'high': 324.65,
#                    'intraperiod': False,
#                    'low': 318.21,
#                    'open': 322.63,
#                    'volume': 25141489.0},
#                   {'adj_close': 323.62,
#                    'adj_high': 324.57,
#                    'adj_low': 320.0,
#                    'adj_open': 320.0,
#                    'adj_volume': 23495991.0,
#                    'close': 323.62,
#                    'date': datetime.date(2020, 2, 19),
#                    'frequency': 'daily',
#                    'high': 324.57,
#                    'intraperiod': False,
#                    'low': 320.0,
#                    'open': 320.0,
#                    'volume': 23495991.0},
#                   {'adj_close': 319.0,
#                    'adj_high': 319.75,
#                    'adj_low': 314.61,
#                    'adj_open': 315.36,
#                    'adj_volume': 38190545.0,
#                    'close': 319.0,
#                    'date': datetime.date(2020, 2, 18),
#                    'frequency': 'daily',
#                    'high': 319.75,
#                    'intraperiod': False,
#                    'low': 314.61,
#                    'open': 315.36,
#                    'volume': 38190545.0},
#                   {'adj_close': 324.95,
#                    'adj_high': 325.98,
#                    'adj_low': 322.85,
#                    'adj_open': 324.74,
#                    'adj_volume': 20028447.0,
#                    'close': 324.95,
#                    'date': datetime.date(2020, 2, 14),
#                    'frequency': 'daily',
#                    'high': 325.98,
#                    'intraperiod': False,
#                    'low': 322.85,
#                    'open': 324.74,
#                    'volume': 20028447.0},
#                   {'adj_close': 324.87,
#                    'adj_high': 326.22,
#                    'adj_low': 323.35,
#                    'adj_open': 324.19,
#                    'adj_volume': 23686892.0,
#                    'close': 324.87,
#                    'date': datetime.date(2020, 2, 13),
#                    'frequency': 'daily',
#                    'high': 326.22,
#                    'intraperiod': False,
#                    'low': 323.35,
#                    'open': 324.19,
#                    'volume': 23686892.0},
#                   {'adj_close': 327.2,
#                    'adj_high': 327.22,
#                    'adj_low': 321.47,
#                    'adj_open': 321.47,
#                    'adj_volume': 28432573.0,
#                    'close': 327.2,
#                    'date': datetime.date(2020, 2, 12),
#                    'frequency': 'daily',
#                    'high': 327.22,
#                    'intraperiod': False,
#                    'low': 321.47,
#                    'open': 321.47,
#                    'volume': 28432573.0},
#                   {'adj_close': 319.61,
#                    'adj_high': 323.9,
#                    'adj_low': 318.71,
#                    'adj_open': 323.6,
#                    'adj_volume': 23580780.0,
#                    'close': 319.61,
#                    'date': datetime.date(2020, 2, 11),
#                    'frequency': 'daily',
#                    'high': 323.9,
#                    'intraperiod': False,
#                    'low': 318.71,
#                    'open': 323.6,
#                    'volume': 23580780.0},
#                   {'adj_close': 321.55,
#                    'adj_high': 321.55,
#                    'adj_low': 313.85,
#                    'adj_open': 314.18,
#                    'adj_volume': 27337215.0,
#                    'close': 321.55,
#                    'date': datetime.date(2020, 2, 10),
#                    'frequency': 'daily',
#                    'high': 321.55,
#                    'intraperiod': False,
#                    'low': 313.85,
#                    'open': 314.18,
#                    'volume': 27337215.0},
#                   {'adj_close': 320.03,
#                    'adj_high': 323.4,
#                    'adj_low': 318.0,
#                    'adj_open': 322.37,
#                    'adj_volume': 29421012.0,
#                    'close': 320.03,
#                    'date': datetime.date(2020, 2, 7),
#                    'frequency': 'daily',
#                    'high': 323.4,
#                    'intraperiod': False,
#                    'low': 318.0,
#                    'open': 322.37,
#                    'volume': 29421012.0},
#                   {'adj_close': 324.44,
#                    'adj_high': 324.449976322991,
#                    'adj_low': 319.506508754343,
#                    'adj_open': 321.806250730297,
#                    'adj_volume': 26356385.0,
#                    'close': 325.21,
#                    'date': datetime.date(2020, 2, 6),
#                    'frequency': 'daily',
#                    'high': 325.22,
#                    'intraperiod': False,
#                    'low': 320.2648,
#                    'open': 322.57,
#                    'volume': 26356385.0},
#                   {'adj_close': 320.688902555272,
#                    'adj_high': 323.991065465392,
#                    'adj_low': 318.194821807447,
#                    'adj_open': 322.754001414471,
#                    'adj_volume': 29706718.0,
#                    'close': 321.45,
#                    'date': datetime.date(2020, 2, 5),
#                    'frequency': 'daily',
#                    'high': 324.76,
#                    'intraperiod': False,
#                    'low': 318.95,
#                    'open': 323.52,
#                    'volume': 29706718.0},
#                   {'adj_close': 318.095058577535,
#                    'adj_high': 318.883188093847,
#                    'adj_low': 312.891907321423,
#                    'adj_open': 314.563440238615,
#                    'adj_volume': 34154134.0,
#                    'close': 318.85,
#                    'date': datetime.date(2020, 2, 4),
#                    'frequency': 'daily',
#                    'high': 319.64,
#                    'intraperiod': False,
#                    'low': 313.6345,
#                    'open': 315.31,
#                    'volume': 34154134.0},
#                   {'adj_close': 307.929185449402,
#                    'adj_high': 312.747749454199,
#                    'adj_low': 301.504433443006,
#                    'adj_open': 303.579508625196,
#                    'adj_volume': 43496401.0,
#                    'close': 308.66,
#                    'date': datetime.date(2020, 2, 3),
#                    'frequency': 'daily',
#                    'high': 313.49,
#                    'intraperiod': False,
#                    'low': 302.22,
#                    'open': 304.3,
#                    'volume': 43496401.0},
#                   {'adj_close': 308.777172903662,
#                    'adj_high': 321.915990283202,
#                    'adj_low': 307.560061498724,
#                    'adj_open': 320.170133759724,
#                    'adj_volume': 49897096.0,
#                    'close': 309.51,
#                    'date': datetime.date(2020, 1, 31),
#                    'frequency': 'daily',
#                    'high': 322.68,
#                    'intraperiod': False,
#                    'low': 308.29,
#                    'open': 320.93,
#                    'volume': 49897096.0},
#                   {'adj_close': 323.103172719166,
#                    'adj_high': 323.322651824975,
#                    'adj_low': 317.995295347622,
#                    'adj_open': 319.784548876111,
#                    'adj_volume': 31685808.0,
#                    'close': 323.87,
#                    'date': datetime.date(2020, 1, 30),
#                    'frequency': 'daily',
#                    'high': 324.09,
#                    'intraperiod': False,
#                    'low': 318.75,
#                    'open': 320.5435,
#                    'volume': 31685808.0},
#                   {'adj_close': 323.572059899757,
#                    'adj_high': 327.073749269703,
#                    'adj_low': 320.619068294333,
#                    'adj_open': 323.681799452661,
#                    'adj_volume': 54149928.0,
#                    'close': 324.34,
#                    'date': datetime.date(2020, 1, 29),
#                    'frequency': 'daily',
#                    'high': 327.85,
#                    'intraperiod': False,
#                    'low': 321.38,
#                    'open': 324.45,
#                    'volume': 54149928.0},
#                   {'adj_close': 316.937805110544,
#                    'adj_high': 317.646124042926,
#                    'adj_low': 311.45082746533,
#                    'adj_open': 311.859856707973,
#                    'adj_volume': 40558486.0,
#                    'close': 317.69,
#                    'date': datetime.date(2020, 1, 28),
#                    'frequency': 'daily',
#                    'high': 318.4,
#                    'intraperiod': False,
#                    'low': 312.19,
#                    'open': 312.6,
#                    'volume': 40558486.0},
#                   {'adj_close': 308.21849881615,
#                    'adj_high': 311.031821899696,
#                    'adj_low': 304.158135358691,
#                    'adj_open': 309.325870668184,
#                    'adj_volume': 40485005.0,
#                    'close': 308.95,
#                    'date': datetime.date(2020, 1, 27),
#                    'frequency': 'daily',
#                    'high': 311.77,
#                    'intraperiod': False,
#                    'low': 304.88,
#                    'open': 310.06,
#                    'volume': 40485005.0},
#                   {'adj_close': 317.556337136004,
#                    'adj_high': 322.564451277636,
#                    'adj_low': 316.767010460933,
#                    'adj_open': 319.491743796316,
#                    'adj_volume': 36634380.0,
#                    'close': 318.31,
#                    'date': datetime.date(2020, 1, 24),
#                    'frequency': 'daily',
#                    'high': 323.33,
#                    'intraperiod': False,
#                    'low': 317.5188,
#                    'open': 320.25,
#                    'volume': 36634380.0},
#                   {'adj_close': 318.474158851204,
#                    'adj_high': 318.803377509917,
#                    'adj_low': 314.902635220319,
#                    'adj_open': 317.167260539344,
#                    'adj_volume': 26117993.0,
#                    'close': 319.23,
#                    'date': datetime.date(2020, 1, 23),
#                    'frequency': 'daily',
#                    'high': 319.56,
#                    'intraperiod': False,
#                    'low': 315.65,
#                    'open': 317.92,
#                    'volume': 26117993.0},
#                   {'adj_close': 316.947781433535,
#                    'adj_high': 319.232359398542,
#                    'adj_low': 316.558704836875,
#                    'adj_open': 317.825697856769,
#                    'adj_volume': 25458115.0,
#                    'close': 317.7,
#                    'date': datetime.date(2020, 1, 22),
#                    'frequency': 'daily',
#                    'high': 319.99,
#                    'intraperiod': False,
#                    'low': 317.31,
#                    'open': 318.58,
#                    'volume': 25458115.0},
#                   {'adj_close': 315.820456935519,
#                    'adj_high': 318.264656068387,
#                    'adj_low': 315.251806525015,
#                    'adj_open': 316.438988960979,
#                    'adj_volume': 27710814.0,
#                    'close': 316.57,
#                    'date': datetime.date(2020, 1, 21),
#                    'frequency': 'daily',
#                    'high': 319.02,
#                    'intraperiod': False,
#                    'low': 316.0,
#                    'open': 317.19,
#                    'volume': 27710814.0},
#                   {'adj_close': 317.975342701639,
#                    'adj_high': 317.98531902463,
#                    'adj_low': 314.254174225885,
#                    'adj_open': 315.52116724578,
#                    'adj_volume': 34454117.0,
#                    'close': 318.73,
#                    'date': datetime.date(2020, 1, 17),
#                    'frequency': 'daily',
#                    'high': 318.74,
#                    'intraperiod': False,
#                    'low': 315.0,
#                    'open': 316.27,
#                    'volume': 34454117.0},
#                   {'adj_close': 314.493605977676,
#                    'adj_high': 314.952516835276,
#                    'adj_low': 311.351064235417,
#                    'adj_open': 312.847512684112,
#                    'adj_volume': 27207254.0,
#                    'close': 315.24,
#                    'date': datetime.date(2020, 1, 16),
#                    'frequency': 'daily',
#                    'high': 315.7,
#                    'intraperiod': False,
#                    'low': 312.09,
#                    'open': 313.59,
#                    'volume': 27207254.0},
#                   {'adj_close': 310.60284001107,
#                    'adj_high': 314.75299037545,
#                    'adj_low': 308.817078195627,
#                    'adj_open': 311.111632483626,
#                    'adj_volume': 30480882.0,
#                    'close': 311.34,
#                    'date': datetime.date(2020, 1, 15),
#                    'frequency': 'daily',
#                    'high': 315.5,
#                    'intraperiod': False,
#                    'low': 309.55,
#                    'open': 311.85,
#                    'volume': 30480882.0},
#                   {'adj_close': 311.939667291904,
#                    'adj_high': 316.818089234648,
#                    'adj_low': 311.430874819347,
#                    'adj_open': 315.950149134405,
#                    'adj_volume': 40653457.0,
#                    'close': 312.68,
#                    'date': datetime.date(2020, 1, 14),
#                    'frequency': 'daily',
#                    'high': 317.57,
#                    'intraperiod': False,
#                    'low': 312.17,
#                    'open': 316.7,
#                    'volume': 40653457.0},
#                   {'adj_close': 316.209533532179,
#                    'adj_high': 316.319273085083,
#                    'adj_low': 310.413289874235,
#                    'adj_open': 310.902129700809,
#                    'adj_volume': 30521722.0,
#                    'close': 316.96,
#                    'date': datetime.date(2020, 1, 13),
#                    'frequency': 'daily',
#                    'high': 317.07,
#                    'intraperiod': False,
#                    'low': 311.15,
#                    'open': 311.64,
#                    'volume': 30521722.0},
#                   {'adj_close': 309.595231388949,
#                    'adj_high': 311.929690968912,
#                    'adj_low': 307.520156206759,
#                    'adj_open': 309.864592109714,
#                    'adj_volume': 35217272.0,
#                    'close': 310.33,
#                    'date': datetime.date(2020, 1, 10),
#                    'frequency': 'daily',
#                    'high': 312.67,
#                    'intraperiod': False,
#                    'low': 308.25,
#                    'open': 310.6,
#                    'volume': 35217272.0},
#                   {'adj_close': 308.896888779558,
#                    'adj_high': 309.694994618862,
#                    'adj_low': 305.475009993543,
#                    'adj_open': 306.507559423142,
#                    'adj_volume': 42621542.0,
#                    'close': 309.63,
#                    'date': datetime.date(2020, 1, 9),
#                    'frequency': 'daily',
#                    'high': 310.43,
#                    'intraperiod': False,
#                    'low': 306.2,
#                    'open': 307.235,
#                    'volume': 42621542.0},
#                   {'adj_close': 302.472136773162,
#                    'adj_high': 303.719077383844,
#                    'adj_low': 296.452423480213,
#                    'adj_open': 296.456414009409,
#                    'adj_volume': 33090946.0,
#                    'close': 303.19,
#                    'date': datetime.date(2020, 1, 8),
#                    'frequency': 'daily',
#                    'high': 304.4399,
#                    'intraperiod': False,
#                    'low': 297.156,
#                    'open': 297.16,
#                    'volume': 33090946.0},
#                   {'adj_close': 297.683501737339,
#                    'adj_high': 300.187558808155,
#                    'adj_low': 296.775656345131,
#                    'adj_open': 299.130068571077,
#                    'adj_volume': 27877655.0,
#                    'close': 298.39,
#                    'date': datetime.date(2020, 1, 7),
#                    'frequency': 'daily',
#                    'high': 300.9,
#                    'intraperiod': False,
#                    'low': 297.48,
#                    'open': 299.84,
#                    'volume': 27877655.0},
#                   {'adj_close': 299.090163279112,
#                    'adj_high': 299.249784446973,
#                    'adj_low': 292.056855570247,
#                    'adj_open': 293.094393161342,
#                    'adj_volume': 29644644.0,
#                    'close': 299.8,
#                    'date': datetime.date(2020, 1, 6),
#                    'frequency': 'daily',
#                    'high': 299.96,
#                    'intraperiod': False,
#                    'low': 292.75,
#                    'open': 293.79,
#                    'volume': 29644644.0},
#                   {'adj_close': 296.725774730174,
#                    'adj_high': 299.868316472433,
#                    'adj_low': 295.797976691984,
#                    'adj_open': 296.446437686418,
#                    'adj_volume': 36633878.0,
#                    'close': 297.43,
#                    'date': datetime.date(2020, 1, 3),
#                    'frequency': 'daily',
#                    'high': 300.58,
#                    'intraperiod': False,
#                    'low': 296.5,
#                    'open': 297.15,
#                    'volume': 36633878.0},
#                   {'adj_close': 299.638861043633,
#                    'adj_high': 299.888269118416,
#                    'adj_low': 294.491078380124,
#                    'adj_open': 295.53859229421,
#                    'adj_volume': 33911864.0,
#                    'close': 300.35,
#                    'date': datetime.date(2020, 1, 2),
#                    'frequency': 'daily',
#                    'high': 300.6,
#                    'intraperiod': False,
#                    'low': 295.19,
#                    'open': 296.24,
#                    'volume': 33911864.0},
#                   {'adj_close': 292.954724639464,
#                    'adj_high': 292.984653608438,
#                    'adj_low': 288.834503244058,
#                    'adj_open': 289.243532486701,
#                    'adj_volume': 25247625.0,
#                    'close': 293.65,
#                    'date': datetime.date(2019, 12, 31),
#                    'frequency': 'daily',
#                    'high': 293.68,
#                    'intraperiod': False,
#                    'low': 289.52,
#                    'open': 289.93,
#                    'volume': 25247625.0},
#                   {'adj_close': 290.829767842317,
#                    'adj_high': 291.996997632299,
#                    'adj_low': 284.5446843578,
#                    'adj_open': 288.77464530611,
#                    'adj_volume': 36059614.0,
#                    'close': 291.52,
#                    'date': datetime.date(2019, 12, 30),
#                    'frequency': 'daily',
#                    'high': 292.69,
#                    'intraperiod': False,
#                    'low': 285.22,
#                    'open': 289.46,
#                    'volume': 36059614.0},
#                   {'adj_close': 289.113840287814,
#                    'adj_high': 293.273966975185,
#                    'adj_low': 287.437818025276,
#                    'adj_open': 290.430714922665,
#                    'adj_volume': 36592936.0,
#                    'close': 289.8,
#                    'date': datetime.date(2019, 12, 27),
#                    'frequency': 'daily',
#                    'high': 293.97,
#                    'intraperiod': False,
#                    'low': 288.12,
#                    'open': 291.12,
#                    'volume': 36592936.0},
#                   {'adj_close': 289.223579840718,
#                    'adj_high': 289.293414101657,
#                    'adj_low': 284.025915562252,
#                    'adj_open': 284.145631438148,
#                    'adj_volume': 23334004.0,
#                    'close': 289.91,
#                    'date': datetime.date(2019, 12, 26),
#                    'frequency': 'daily',
#                    'high': 289.98,
#                    'intraperiod': False,
#                    'low': 284.7,
#                    'open': 284.82,
#                    'volume': 23334004.0},
#                   {'adj_close': 283.596933673626,
#                    'adj_high': 284.215465699087,
#                    'adj_low': 282.249830780111,
#                    'adj_open': 284.015939239261,
#                    'adj_volume': 12119714.0,
#                    'close': 284.27,
#                    'date': datetime.date(2019, 12, 24),
#                    'frequency': 'daily',
#                    'high': 284.89,
#                    'intraperiod': False,
#                    'low': 282.9197,
#                    'open': 284.69,
#                    'volume': 12119714.0},
#                   {'adj_close': 283.327572952861,
#                    'adj_high': 283.576981027644,
#                    'adj_low': 279.709659420067,
#                    'adj_open': 279.865788874881,
#                    'adj_volume': 24677883.0,
#                    'close': 284.0,
#                    'date': datetime.date(2019, 12, 23),
#                    'frequency': 'daily',
#                    'high': 284.25,
#                    'intraperiod': False,
#                    'low': 280.3735,
#                    'open': 280.53,
#                    'volume': 24677883.0},
#                   {'adj_close': 278.778369668829,
#                    'adj_high': 281.980769349036,
#                    'adj_low': 277.900453245595,
#                    'adj_open': 281.561763783401,
#                    'adj_volume': 69032743.0,
#                    'close': 279.44,
#                    'date': datetime.date(2019, 12, 20),
#                    'frequency': 'daily',
#                    'high': 282.65,
#                    'intraperiod': False,
#                    'low': 278.56,
#                    'open': 282.23,
#                    'volume': 69032743.0},
#                   {'adj_close': 279.356996402325,
#                    'adj_high': 280.514249869315,
#                    'adj_low': 278.289529842256,
#                    'adj_open': 278.838227606777,
#                    'adj_volume': 24626947.0,
#                    'close': 280.02,
#                    'date': datetime.date(2019, 12, 19),
#                    'frequency': 'daily',
#                    'high': 281.18,
#                    'intraperiod': False,
#                    'low': 278.95,
#                    'open': 279.5,
#                    'volume': 24626947.0},
#                   {'adj_close': 279.077659358568,
#                    'adj_high': 281.232545124689,
#                    'adj_low': 278.459127333108,
#                    'adj_open': 279.137517296516,
#                    'adj_volume': 29024687.0,
#                    'close': 279.74,
#                    'date': datetime.date(2019, 12, 18),
#                    'frequency': 'daily',
#                    'high': 281.9,
#                    'intraperiod': False,
#                    'low': 279.12,
#                    'open': 279.8,
#                    'volume': 29024687.0},
#                   {'adj_close': 279.746072998985,
#                    'adj_high': 281.102852925802,
#                    'adj_low': 278.139884997386,
#                    'adj_open': 278.908061867716,
#                    'adj_volume': 28575798.0,
#                    'close': 280.41,
#                    'date': datetime.date(2019, 12, 17),
#                    'frequency': 'daily',
#                    'high': 281.77,
#                    'intraperiod': False,
#                    'low': 278.8,
#                    'open': 279.57,
#                    'volume': 28575798.0},
#                   {'adj_close': 279.197375234464,
#                    'adj_high': 280.125173272655,
#                    'adj_low': 276.32419421297,
#                    'adj_open': 276.344146858953,
#                    'adj_volume': 32081105.0,
#                    'close': 279.86,
#                    'date': datetime.date(2019, 12, 16),
#                    'frequency': 'daily',
#                    'high': 280.79,
#                    'intraperiod': False,
#                    'low': 276.98,
#                    'open': 277.0,
#                    'volume': 32081105.0},
#                   {'adj_close': 274.498527105563,
#                    'adj_high': 274.648171950432,
#                    'adj_low': 270.288518803235,
#                    'adj_open': 270.817263921774,
#                    'adj_volume': 33432806.0,
#                    'close': 275.15,
#                    'date': datetime.date(2019, 12, 13),
#                    'frequency': 'daily',
#                    'high': 275.3,
#                    'intraperiod': False,
#                    'low': 270.93,
#                    'open': 271.46,
#                    'volume': 33432806.0},
#                   {'adj_close': 270.817263921774,
#                    'adj_high': 271.914559687587,
#                    'adj_low': 266.688063835675,
#                    'adj_open': 267.145977060976,
#                    'adj_volume': 34437042.0,
#                    'close': 271.46,
#                    'date': datetime.date(2019, 12, 12),
#                    'frequency': 'daily',
#                    'high': 272.5599,
#                    'intraperiod': False,
#                    'low': 267.321,
#                    'open': 267.78,
#                    'volume': 34437042.0},
#                   {'adj_close': 270.128897635374,
#                    'adj_high': 270.458116294087,
#                    'adj_low': 267.864272316349,
#                    'adj_open': 268.17353832908,
#                    'adj_volume': 19723391.0,
#                    'close': 270.77,
#                    'date': datetime.date(2019, 12, 11),
#                    'frequency': 'daily',
#                    'high': 271.1,
#                    'intraperiod': False,
#                    'low': 268.5,
#                    'open': 268.81,
#                    'volume': 19723391.0},
#                   {'adj_close': 267.844319670367,
#                    'adj_high': 269.430555025983,
#                    'adj_low': 265.230523046647,
#                    'adj_open': 267.964035546262,
#                    'adj_volume': 22632383.0,
#                    'close': 268.48,
#                    'date': datetime.date(2019, 12, 10),
#                    'frequency': 'daily',
#                    'high': 270.07,
#                    'intraperiod': False,
#                    'low': 265.86,
#                    'open': 268.6,
#                    'volume': 22632383.0},
#                   {'adj_close': 266.288013283724,
#                    'adj_high': 270.158826604348,
#                    'adj_low': 264.282772362474,
#                    'adj_open': 269.360720765044,
#                    'adj_volume': 32182645.0,
#                    'close': 266.92,
#                    'date': datetime.date(2019, 12, 9),
#                    'frequency': 'daily',
#                    'high': 270.8,
#                    'intraperiod': False,
#                    'low': 264.91,
#                    'open': 270.0,
#                    'volume': 32182645.0},
#                   {'adj_close': 270.069039697426,
#                    'adj_high': 270.358353064174,
#                    'adj_low': 266.667113557394,
#                    'adj_open': 266.846687371237,
#                    'adj_volume': 26547493.0,
#                    'close': 270.71,
#                    'date': datetime.date(2019, 12, 6),
#                    'frequency': 'daily',
#                    'high': 271.0,
#                    'intraperiod': False,
#                    'low': 267.3,
#                    'open': 267.48,
#                    'volume': 26547493.0},
#                   {'adj_close': 264.95118600289,
#                    'adj_high': 265.260452015621,
#                    'adj_low': 262.107933950371,
#                    'adj_open': 263.165424187448,
#                    'adj_volume': 18661343.0,
#                    'close': 265.58,
#                    'date': datetime.date(2019, 12, 5),
#                    'frequency': 'daily',
#                    'high': 265.89,
#                    'intraperiod': False,
#                    'low': 262.73,
#                    'open': 263.79,
#                    'volume': 18661343.0},
#                   {'adj_close': 261.120277974232,
#                    'adj_high': 262.686560683866,
#                    'adj_low': 260.062787737154,
#                    'adj_open': 260.451864333815,
#                    'adj_volume': 16810388.0,
#                    'close': 261.74,
#                    'date': datetime.date(2019, 12, 4),
#                    'frequency': 'daily',
#                    'high': 263.31,
#                    'intraperiod': False,
#                    'low': 260.68,
#                    'open': 261.07,
#                    'volume': 16810388.0},
#                   {'adj_close': 258.835700009225,
#                    'adj_high': 258.915510593155,
#                    'adj_low': 255.683181943975,
#                    'adj_open': 257.698399188217,
#                    'adj_volume': 29377268.0,
#                    'close': 259.45,
#                    'date': datetime.date(2019, 12, 3),
#                    'frequency': 'daily',
#                    'high': 259.53,
#                    'intraperiod': False,
#                    'low': 256.29,
#                    'open': 258.31,
#                    'volume': 29377268.0},
#                   {'adj_close': 263.534548138126,
#                    'adj_high': 267.614864241567,
#                    'adj_low': 262.826229205744,
#                    'adj_open': 266.63718458842,
#                    'adj_volume': 23693550.0,
#                    'close': 264.16,
#                    'date': datetime.date(2019, 12, 2),
#                    'frequency': 'daily',
#                    'high': 268.25,
#                    'intraperiod': False,
#                    'low': 263.45,
#                    'open': 267.27,
#                    'volume': 23693550.0},
#                   {'adj_close': 266.617231942437,
#                    'adj_high': 267.365456166785,
#                    'adj_low': 265.270428338612,
#                    'adj_open': 265.968770948003,
#                    'adj_volume': 11654363.0,
#                    'close': 267.25,
#                    'date': datetime.date(2019, 11, 29),
#                    'frequency': 'daily',
#                    'high': 268.0,
#                    'intraperiod': False,
#                    'low': 265.9,
#                    'open': 266.6,
#                    'volume': 11654363.0},
#                   {'adj_close': 267.205834998924,
#                    'adj_high': 267.345503520802,
#                    'adj_low': 264.681825282125,
#                    'adj_open': 264.95118600289,
#                    'adj_volume': 16386122.0,
#                    'close': 267.84,
#                    'date': datetime.date(2019, 11, 27),
#                    'frequency': 'daily',
#                    'high': 267.98,
#                    'intraperiod': False,
#                    'low': 265.31,
#                    'open': 265.58,
#                    'volume': 16386122.0},
#                   {'adj_close': 263.664240337013,
#                    'adj_high': 266.527445035516,
#                    'adj_low': 261.878478521571,
#                    'adj_open': 266.307965929707,
#                    'adj_volume': 26334882.0,
#                    'close': 264.29,
#                    'date': datetime.date(2019, 11, 26),
#                    'frequency': 'daily',
#                    'high': 267.16,
#                    'intraperiod': False,
#                    'low': 262.5,
#                    'open': 266.94,
#                    'volume': 26334882.0},
#                   {'adj_close': 265.739315519203,
#                    'adj_high': 265.809149780142,
#                    'adj_low': 261.898431167553,
#                    'adj_open': 262.087981304388,
#                    'adj_volume': 21029517.0,
#                    'close': 266.37,
#                    'date': datetime.date(2019, 11, 25),
#                    'frequency': 'daily',
#                    'high': 266.44,
#                    'intraperiod': False,
#                    'low': 262.52,
#                    'open': 262.71,
#                    'volume': 21029517.0},
#                   {'adj_close': 261.160183266197,
#                    'adj_high': 262.556868484979,
#                    'adj_low': 260.222408905015,
#                    'adj_open': 261.968265428492,
#                    'adj_volume': 16331263.0,
#                    'close': 261.78,
#                    'date': datetime.date(2019, 11, 22),
#                    'frequency': 'daily',
#                    'high': 263.18,
#                    'intraperiod': False,
#                    'low': 260.84,
#                    'open': 262.59,
#                    'volume': 16331263.0},
#                   {'adj_close': 261.389638694997,
#                    'adj_high': 263.379915131761,
#                    'adj_low': 260.561603886719,
#                    'adj_open': 263.065660957535,
#                    'adj_volume': 30348778.0,
#                    'close': 262.01,
#                    'date': datetime.date(2019, 11, 21),
#                    'frequency': 'daily',
#                    'high': 264.005,
#                    'intraperiod': False,
#                    'low': 261.18,
#                    'open': 263.69,
#                    'volume': 30348778.0},
#                   {'adj_close': 262.56684480797,
#                    'adj_high': 265.452995049353,
#                    'adj_low': 259.783450693398,
#                    'adj_open': 264.911280710925,
#                    'adj_volume': 26609919.0,
#                    'close': 263.19,
#                    'date': datetime.date(2019, 11, 20),
#                    'frequency': 'daily',
#                    'high': 266.083,
#                    'intraperiod': False,
#                    'low': 260.4,
#                    'open': 265.54,
#                    'volume': 26609919.0},
#                   {'adj_close': 265.659504935273,
#                    'adj_high': 267.365456166785,
#                    'adj_low': 264.764229710034,
#                    'adj_open': 267.265692936872,
#                    'adj_volume': 19069597.0,
#                    'close': 266.29,
#                    'date': datetime.date(2019, 11, 19),
#                    'frequency': 'daily',
#                    'high': 268.0,
#                    'intraperiod': False,
#                    'low': 265.3926,
#                    'open': 267.9,
#                    'volume': 19069597.0},
#                   {'adj_close': 266.467587097568,
#                    'adj_high': 266.796805756281,
#                    'adj_low': 263.604382399065,
#                    'adj_open': 265.170665108699,
#                    'adj_volume': 21700897.0,
#                    'close': 267.1,
#                    'date': datetime.date(2019, 11, 18),
#                    'frequency': 'daily',
#                    'high': 267.43,
#                    'intraperiod': False,
#                    'low': 264.23,
#                    'open': 265.8,
#                    'volume': 21700897.0},
#                   {'adj_close': 265.130759816734,
#                    'adj_high': 265.150712462716,
#                    'adj_low': 262.387270994127,
#                    'adj_open': 263.055684634544,
#                    'adj_volume': 25093666.0,
#                    'close': 265.76,
#                    'date': datetime.date(2019, 11, 15),
#                    'frequency': 'daily',
#                    'high': 265.78,
#                    'intraperiod': False,
#                    'low': 263.01,
#                    'open': 263.68,
#                    'volume': 25093666.0},
#                   {'adj_close': 262.018147043449,
#                    'adj_high': 264.2528433935,
#                    'adj_low': 261.479425601919,
#                    'adj_open': 263.125518895483,
#                    'adj_volume': 22395556.0,
#                    'close': 262.64,
#                    'date': datetime.date(2019, 11, 14),
#                    'frequency': 'daily',
#                    'high': 264.88,
#                    'intraperiod': False,
#                    'low': 262.1,
#                    'open': 263.75,
#                    'volume': 22395556.0},
#                   {'adj_close': 263.843814150856,
#                    'adj_high': 264.153080163587,
#                    'adj_low': 260.451864333815,
#                    'adj_open': 260.511722271763,
#                    'adj_volume': 25817593.0,
#                    'close': 264.47,
#                    'date': datetime.date(2019, 11, 13),
#                    'frequency': 'daily',
#                    'high': 264.78,
#                    'intraperiod': False,
#                    'low': 261.07,
#                    'open': 261.13,
#                    'volume': 25817593.0},
#                   {'adj_close': 261.339757080041,
#                    'adj_high': 262.167791888318,
#                    'adj_low': 260.302219488946,
#                    'adj_open': 260.930727837397,
#                    'adj_volume': 21847226.0,
#                    'close': 261.96,
#                    'date': datetime.date(2019, 11, 12),
#                    'frequency': 'daily',
#                    'high': 262.79,
#                    'intraperiod': False,
#                    'low': 260.92,
#                    'open': 261.55,
#                    'volume': 21847226.0},
#                   {'adj_close': 261.579188831832,
#                    'adj_high': 261.848549552597,
#                    'adj_low': 257.668470219243,
#                    'adj_open': 257.688422865226,
#                    'adj_volume': 20507459.0,
#                    'close': 262.2,
#                    'date': datetime.date(2019, 11, 11),
#                    'frequency': 'daily',
#                    'high': 262.47,
#                    'intraperiod': False,
#                    'low': 258.28,
#                    'open': 258.3,
#                    'volume': 20507459.0},
#                   {'adj_close': 259.524066295624,
#                    'adj_high': 259.823355985363,
#                    'adj_low': 256.241856031487,
#                    'adj_open': 258.077499461886,
#                    'adj_volume': 17520495.0,
#                    'close': 260.14,
#                    'date': datetime.date(2019, 11, 8),
#                    'frequency': 'daily',
#                    'high': 260.44,
#                    'intraperiod': False,
#                    'low': 256.85,
#                    'open': 258.69,
#                    'volume': 17520495.0},
#                   {'adj_close': 258.815747363242,
#                    'adj_high': 259.733569078442,
#                    'adj_low': 257.498872728391,
#                    'adj_open': 258.127381076843,
#                    'adj_volume': 23735083.0,
#                    'close': 259.43,
#                    'date': datetime.date(2019, 11, 7),
#                    'frequency': 'daily',
#                    'high': 260.35,
#                    'intraperiod': False,
#                    'low': 258.11,
#                    'open': 258.74,
#                    'volume': 23735083.0},
#                   {'adj_close': 255.862755757818,
#                    'adj_high': 256.111417276009,
#                    'adj_low': 253.997794371386,
#                    'adj_open': 255.395272103619,
#                    'adj_volume': 18966124.0,
#                    'close': 257.24,
#                    'date': datetime.date(2019, 11, 6),
#                    'frequency': 'daily',
#                    'high': 257.49,
#                    'intraperiod': False,
#                    'low': 255.365,
#                    'open': 256.77,
#                    'volume': 18966124.0},
#                   {'adj_close': 255.753344689814,
#                    'adj_high': 256.807669526944,
#                    'adj_low': 254.947681370875,
#                    'adj_open': 255.673773003993,
#                    'adj_volume': 19974427.0,
#                    'close': 257.13,
#                    'date': datetime.date(2019, 11, 5),
#                    'frequency': 'daily',
#                    'high': 258.19,
#                    'intraperiod': False,
#                    'low': 256.32,
#                    'open': 257.05,
#                    'volume': 19974427.0},
#                   {'adj_close': 256.121363736737,
#                    'adj_high': 256.46451663184,
#                    'adj_low': 254.012714062477,
#                    'adj_open': 255.952273904367,
#                    'adj_volume': 25817952.0,
#                    'close': 257.5,
#                    'date': datetime.date(2019, 11, 4),
#                    'frequency': 'daily',
#                    'high': 257.845,
#                    'intraperiod': False,
#                    'low': 255.38,
#                    'open': 257.33,
#                    'volume': 25817952.0},
#                   {'adj_close': 254.450358334493,
#                    'adj_high': 254.559769402497,
#                    'adj_low': 247.826015489885,
#                    'adj_open': 248.203980997535,
#                    'adj_volume': 37781334.0,
#                    'close': 255.82,
#                    'date': datetime.date(2019, 11, 1),
#                    'frequency': 'daily',
#                    'high': 255.93,
#                    'intraperiod': False,
#                    'low': 249.16,
#                    'open': 249.54,
#                    'volume': 37781334.0},
#                   {'adj_close': 247.428157060779,
#                    'adj_high': 247.835961950612,
#                    'adj_low': 235.989727223993,
#                    'adj_open': 245.916295030178,
#                    'adj_volume': 34790520.0,
#                    'close': 248.76,
#                    'date': datetime.date(2019, 10, 31),
#                    'frequency': 'daily',
#                    'high': 249.17,
#                    'intraperiod': False,
#                    'low': 237.26,
#                    'open': 247.24,
#                    'volume': 34790520.0},
#                   {'adj_close': 241.957603660577,
#                    'adj_high': 243.986681649016,
#                    'adj_low': 239.918579211411,
#                    'adj_open': 243.449572769723,
#                    'adj_volume': 31130522.0,
# ...
#                    'close': 170.89,
#                    'date': datetime.date(2019, 2, 12),
#                    'frequency': 'daily',
#                    'high': 171.0,
#                    'intraperiod': False,
#                    'low': 169.7,
#                    'open': 170.1,
#                    'volume': 22283523.0},
#                   {'adj_close': 167.240971785291,
#                    'adj_high': 168.99797426288,
#                    'adj_low': 167.063297377445,
#                    'adj_open': 168.840041455905,
#                    'adj_volume': 20993425.0,
#                    'close': 169.43,
#                    'date': datetime.date(2019, 2, 11),
#                    'frequency': 'daily',
#                    'high': 171.21,
#                    'intraperiod': False,
#                    'low': 169.25,
#                    'open': 171.05,
#                    'volume': 20993425.0},
#                   {'adj_close': 168.208310228008,
#                    'adj_high': 168.455080238906,
#                    'adj_low': 166.244020941266,
#                    'adj_open': 166.806656566112,
#                    'adj_volume': 23819966.0,
#                    'close': 170.41,
#                    'date': datetime.date(2019, 2, 8),
#                    'frequency': 'daily',
#                    'high': 170.66,
#                    'intraperiod': False,
#                    'low': 168.42,
#                    'open': 168.99,
#                    'volume': 23819966.0},
#                   {'adj_close': 168.010894219291,
#                    'adj_high': 170.959488361433,
#                    'adj_low': 167.421175390862,
#                    'adj_open': 169.4458767018,
#                    'adj_volume': 31741690.0,
#                    'close': 170.94,
#                    'date': datetime.date(2019, 2, 7),
#                    'frequency': 'daily',
#                    'high': 173.94,
#                    'intraperiod': False,
#                    'low': 170.34,
#                    'open': 172.4,
#                    'volume': 31741690.0},
#                   {'adj_close': 171.254347775648,
#                    'adj_high': 172.561557845331,
#                    'adj_low': 169.891212703735,
#                    'adj_open': 171.657322308407,
#                    'adj_volume': 28239591.0,
#                    'close': 174.24,
#                    'date': datetime.date(2019, 2, 6),
#                    'frequency': 'daily',
#                    'high': 175.57,
#                    'intraperiod': False,
#                    'low': 172.8531,
#                    'open': 174.65,
#                    'volume': 28239591.0},
#                   {'adj_close': 171.195375892805,
#                    'adj_high': 172.079954135448,
#                    'adj_low': 169.396831752569,
#                    'adj_open': 169.897994470262,
#                    'adj_volume': 36101628.0,
#                    'close': 174.18,
#                    'date': datetime.date(2019, 2, 5),
#                    'frequency': 'daily',
#                    'high': 175.08,
#                    'intraperiod': False,
#                    'low': 172.3501,
#                    'open': 172.86,
#                    'volume': 36101628.0},
#                   {'adj_close': 168.315582280645,
#                    'adj_high': 168.713642489835,
#                    'adj_low': 164.413609365877,
#                    'adj_open': 164.541381778703,
#                    'adj_volume': 31495582.0,
#                    'close': 171.25,
#                    'date': datetime.date(2019, 2, 4),
#                    'frequency': 'daily',
#                    'high': 171.655,
#                    'intraperiod': False,
#                    'low': 167.28,
#                    'open': 167.41,
#                    'volume': 31495582.0},
#                   {'adj_close': 163.6666321832,
#                    'adj_high': 166.084479379757,
#                    'adj_low': 163.086742001912,
#                    'adj_open': 164.099092657381,
#                    'adj_volume': 32668138.0,
#                    'close': 166.52,
#                    'date': datetime.date(2019, 2, 1),
#                    'frequency': 'daily',
#                    'high': 168.98,
#                    'intraperiod': False,
#                    'low': 165.93,
#                    'open': 166.96,
#                    'volume': 32668138.0},
#                   {'adj_close': 163.588003006077,
#                    'adj_high': 166.104136674038,
#                    'adj_low': 161.740217343667,
#                    'adj_open': 163.263657650441,
#                    'adj_volume': 40739649.0,
#                    'close': 166.44,
#                    'date': datetime.date(2019, 1, 31),
#                    'frequency': 'daily',
#                    'high': 169.0,
#                    'intraperiod': False,
#                    'low': 164.56,
#                    'open': 166.11,
#                    'volume': 40739649.0},
#                   {'adj_close': 162.41839399636,
#                    'adj_high': 163.302972239003,
#                    'adj_low': 157.484413131841,
#                    'adj_open': 160.452664568265,
#                    'adj_volume': 61109780.0,
#                    'close': 165.25,
#                    'date': datetime.date(2019, 1, 30),
#                    'frequency': 'daily',
#                    'high': 166.15,
#                    'intraperiod': False,
#                    'low': 160.23,
#                    'open': 163.25,
#                    'volume': 61109780.0},
#                   {'adj_close': 152.029513968877,
#                    'adj_high': 155.420397232341,
#                    'adj_low': 151.46928108187,
#                    'adj_open': 153.572611569932,
#                    'adj_volume': 41587239.0,
#                    'close': 154.68,
#                    'date': datetime.date(2019, 1, 29),
#                    'frequency': 'daily',
#                    'high': 158.13,
#                    'intraperiod': False,
#                    'low': 154.11,
#                    'open': 156.25,
#                    'volume': 41587239.0},
#                   {'adj_close': 153.621754805634,
#                    'adj_high': 153.651240747056,
#                    'adj_low': 151.026991960549,
#                    'adj_open': 153.12049380147,
#                    'adj_volume': 26192058.0,
#                    'close': 156.3,
#                    'date': datetime.date(2019, 1, 28),
#                    'frequency': 'daily',
#                    'high': 156.33,
#                    'intraperiod': False,
#                    'low': 153.66,
#                    'open': 155.79,
#                    'volume': 26192058.0},
#                   {'adj_close': 155.056737288144,
#                    'adj_high': 155.420397232341,
#                    'adj_low': 151.67568267182,
#                    'adj_open': 152.815805740115,
#                    'adj_volume': 33547893.0,
#                    'close': 157.76,
#                    'date': datetime.date(2019, 1, 25),
#                    'frequency': 'daily',
#                    'high': 158.13,
#                    'intraperiod': False,
#                    'low': 154.32,
#                    'open': 155.48,
#                    'volume': 33547893.0},
#                   {'adj_close': 150.083441835063,
#                    'adj_high': 151.832941026068,
#                    'adj_low': 149.139891709577,
#                    'adj_open': 151.46928108187,
#                    'adj_volume': 25441549.0,
#                    'close': 152.7,
#                    'date': datetime.date(2019, 1, 24),
#                    'frequency': 'daily',
#                    'high': 154.48,
#                    'intraperiod': False,
#                    'low': 151.74,
#                    'open': 154.11,
#                    'volume': 25441549.0},
#                   {'adj_close': 151.282536786201,
#                    'adj_high': 152.481631737339,
#                    'adj_low': 149.100577121016,
#                    'adj_open': 151.508595670432,
#                    'adj_volume': 23130570.0,
#                    'close': 153.92,
#                    'date': datetime.date(2019, 1, 23),
#                    'frequency': 'daily',
#                    'high': 155.14,
#                    'intraperiod': False,
#                    'low': 151.7,
#                    'open': 154.15,
#                    'volume': 23130570.0},
#                   {'adj_close': 150.673160663492,
#                    'adj_high': 154.044386632675,
#                    'adj_low': 150.004812657939,
#                    'adj_open': 153.72986992418,
#                    'adj_volume': 30393970.0,
#                    'close': 153.3,
#                    'date': datetime.date(2019, 1, 22),
#                    'frequency': 'daily',
#                    'high': 156.73,
#                    'intraperiod': False,
#                    'low': 152.62,
#                    'open': 156.41,
#                    'volume': 30393970.0},
#                   {'adj_close': 154.132844456939,
#                    'adj_high': 155.174681053829,
#                    'adj_low': 153.307827815968,
#                    'adj_open': 154.801192462491,
#                    'adj_volume': 33751023.0,
#                    'close': 156.82,
#                    'date': datetime.date(2019, 1, 18),
#                    'frequency': 'daily',
#                    'high': 157.88,
#                    'intraperiod': False,
#                    'low': 155.9806,
#                    'open': 157.5,
#                    'volume': 33751023.0},
#                   {'adj_close': 153.189294331453,
#                    'adj_high': 154.958450816739,
#                    'adj_low': 150.63384607493,
#                    'adj_open': 151.557738906134,
#                    'adj_volume': 29821160.0,
#                    'close': 155.86,
#                    'date': datetime.date(2019, 1, 17),
#                    'frequency': 'daily',
#                    'high': 157.66,
#                    'intraperiod': False,
#                    'low': 153.26,
#                    'open': 154.2,
#                    'volume': 29821160.0},
#                   {'adj_close': 152.28505879453,
#                    'adj_high': 153.208951625734,
#                    'adj_low': 150.378301249277,
#                    'adj_open': 150.456930426401,
#                    'adj_volume': 30569706.0,
#                    'close': 154.94,
#                    'date': datetime.date(2019, 1, 16),
#                    'frequency': 'daily',
#                    'high': 155.88,
#                    'intraperiod': False,
#                    'low': 153.0,
#                    'open': 153.08,
#                    'volume': 30569706.0},
#                   {'adj_close': 150.447101779261,
#                    'adj_high': 150.761618487756,
#                    'adj_low': 147.478850342837,
#                    'adj_open': 147.695080579928,
#                    'adj_volume': 28710324.0,
#                    'close': 153.07,
#                    'date': datetime.date(2019, 1, 15),
#                    'frequency': 'daily',
#                    'high': 153.39,
#                    'intraperiod': False,
#                    'low': 150.05,
#                    'open': 150.27,
#                    'volume': 28710324.0},
#                   {'adj_close': 147.429707107135,
#                    'adj_high': 148.677945293975,
#                    'adj_low': 146.663072630178,
#                    'adj_open': 148.265142114075,
#                    'adj_volume': 32439186.0,
#                    'close': 150.0,
#                    'date': datetime.date(2019, 1, 14),
#                    'frequency': 'daily',
#                    'high': 151.27,
#                    'intraperiod': False,
#                    'low': 149.22,
#                    'open': 150.85,
#                    'volume': 32439186.0},
#                   {'adj_close': 149.680467302304,
#                    'adj_high': 151.066306549111,
#                    'adj_low': 148.913832825346,
#                    'adj_open': 150.260357483592,
#                    'adj_volume': 27023241.0,
#                    'close': 152.29,
#                    'date': datetime.date(2019, 1, 11),
#                    'frequency': 'daily',
#                    'high': 153.7,
#                    'intraperiod': False,
#                    'low': 151.51,
#                    'open': 152.88,
#                    'volume': 27023241.0},
#                   {'adj_close': 151.164593020515,
#                    'adj_high': 151.331680021904,
#                    'adj_low': 148.274970761216,
#                    'adj_open': 149.886868892254,
#                    'adj_volume': 35780670.0,
#                    'close': 153.8,
#                    'date': datetime.date(2019, 1, 10),
#                    'frequency': 'daily',
#                    'high': 153.97,
#                    'intraperiod': False,
#                    'low': 150.86,
#                    'open': 152.5,
#                    'volume': 35780670.0},
#                   {'adj_close': 150.682989310632,
#                    'adj_high': 151.88208426177,
#                    'adj_low': 147.066047162937,
#                    'adj_open': 148.697602588256,
#                    'adj_volume': 45099081.0,
#                    'close': 153.31,
#                    'date': datetime.date(2019, 1, 9),
#                    'frequency': 'daily',
#                    'high': 154.53,
#                    'intraperiod': False,
#                    'low': 149.63,
#                    'open': 151.29,
#                    'volume': 45099081.0},
#                   {'adj_close': 148.16685564267,
#                    'adj_high': 149.218520886701,
#                    'adj_low': 145.975067330344,
#                    'adj_open': 146.997246632954,
#                    'adj_volume': 41025314.0,
#                    'close': 150.75,
#                    'date': datetime.date(2019, 1, 8),
#                    'frequency': 'daily',
#                    'high': 151.82,
#                    'intraperiod': False,
#                    'low': 148.52,
#                    'open': 149.56,
#                    'volume': 41025314.0},
#                   {'adj_close': 145.395177149056,
#                    'adj_high': 146.279755391699,
#                    'adj_low': 143.39996177954,
#                    'adj_open': 146.151982978873,
#                    'adj_volume': 54777764.0,
#                    'close': 147.93,
#                    'date': datetime.date(2019, 1, 7),
#                    'frequency': 'daily',
#                    'high': 148.83,
#                    'intraperiod': False,
#                    'low': 145.9,
#                    'open': 148.7,
#                    'volume': 54777764.0},
#                   {'adj_close': 145.719522504692,
#                    'adj_high': 146.004454985294,
#                    'adj_low': 141.33594588004,
#                    'adj_open': 142.053437121295,
#                    'adj_volume': 58607070.0,
#                    'close': 148.26,
#                    'date': datetime.date(2019, 1, 4),
#                    'frequency': 'daily',
#                    'high': 148.5499,
#                    'intraperiod': False,
#                    'low': 143.8,
#                    'open': 144.53,
#                    'volume': 58607070.0},
#                   {'adj_close': 139.753533690423,
#                    'adj_high': 143.223046131011,
#                    'adj_low': 139.566789394754,
#                    'adj_open': 141.512861528568,
#                    'adj_volume': 91312195.0,
#                    'close': 142.19,
#                    'date': datetime.date(2019, 1, 3),
#                    'frequency': 'daily',
#                    'high': 145.72,
#                    'intraperiod': False,
#                    'low': 142.0,
#                    'open': 143.98,
#                    'volume': 91312195.0},
#                   {'adj_close': 155.213995642391,
#                    'adj_high': 156.128059826456,
#                    'adj_low': 151.587224847556,
#                    'adj_open': 152.235915558827,
#                    'adj_volume': 37039737.0,
#                    'close': 157.92,
#                    'date': datetime.date(2019, 1, 2),
#                    'frequency': 'daily',
#                    'high': 158.85,
#                    'intraperiod': False,
#                    'low': 154.23,
#                    'open': 154.89,
#                    'volume': 37039737.0}]}

# %%
response_list = [x.to_dict() for x in r.stock_prices]
df_intrinio = pd.DataFrame(response_list).sort_values('date')
df_intrinio.set_index('date', inplace=True)

# %% [markdown]
# ## quandl
# Quandl has many data sources to get different types of data. However, some are free and some are paid. Wiki is the free data source of Quandl to get the data of the end of the day prices of 3000+ US equities.
#
# It is curated by Quandl community and also provides information about the dividends and split.
#
# To get the stock market data, you need to first install the quandl module if it is not already installed using the pip command as shown below.
#
# ####  Advantages
# It is free of cost Has split and dividend-adjusted stock market data
#
# #### Disadvantages
# Only available till 27-March-2018

# %% [markdown]
# ### cookbook

# %%
import pandas as pd
import quandl

QUANDL_KEY = 'dbyBuiq4bczbbuz9bA4t'
quandl.ApiConfig.api_key = QUANDL_KEY

df_quandl = quandl.get(dataset='WIKI/AAPL',
                       start_date='2000-01-01',
                       end_date='2010-12-31',api_key=QUANDL_KEY)

df_quandl
# Out:
#                 Open    High     Low   Close     Volume  Ex-Dividend  \
# Date
# 2000-01-03  104.8700  112.50  101.69  111.94  4783900.0          0.0
# 2000-01-04  108.2500  110.62  101.19  102.50  4574800.0          0.0
# 2000-01-05  103.7500  110.56  103.00  104.00  6949300.0          0.0
# 2000-01-06  106.1200  107.00   95.00   95.00  6856900.0          0.0
# 2000-01-07   96.5000  101.00   95.50   99.50  4113700.0          0.0
# ...              ...     ...     ...     ...        ...          ...
# 2010-12-27  322.8519  325.44  321.52  324.68  8922000.0          0.0
# 2010-12-28  325.9102  326.66  325.06  325.47  6283000.0          0.0
# 2010-12-29  326.2200  326.45  325.10  325.29  5826400.0          0.0
# 2010-12-30  325.4800  325.51  323.05  323.66  5624800.0          0.0
# 2010-12-31  322.9500  323.48  321.31  322.56  6911000.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2000-01-03          1.0   3.369314   3.614454   3.267146    3.596463
# 2000-01-04          1.0   3.477908   3.554053   3.251081    3.293170
# 2000-01-05          1.0   3.333330   3.552125   3.309234    3.341362
# 2000-01-06          1.0   3.409475   3.437748   3.052206    3.052206
# 2000-01-07          1.0   3.100399   3.244977   3.068270    3.196784
# ...                 ...        ...        ...        ...         ...
# 2010-12-27          1.0  41.490969  41.823576  41.319801   41.725905
# 2010-12-28          1.0  41.884003  41.980363  41.774741   41.827431
# 2010-12-29          1.0  41.923817  41.953375  41.779881   41.804299
# 2010-12-30          1.0  41.828716  41.832572  41.516428   41.594821
# 2010-12-31          1.0  41.503576  41.571689  41.292813   41.453456
#
#             Adj. Volume
# Date
# 2000-01-03  133949200.0
# 2000-01-04  128094400.0
# 2000-01-05  194580400.0
# 2000-01-06  191993200.0
# 2000-01-07  115183600.0
# ...                 ...
# 2010-12-27   62454000.0
# 2010-12-28   43981000.0
# 2010-12-29   40784800.0
# 2010-12-30   39373600.0
# 2010-12-31   48377000.0
#
# [2767 rows x 12 columns]

# %% [markdown]
# ### other data pulls

# %%
QUANDL_API_KEY = 'dbyBuiq4bczbbuz9bA4t'

# Set the start and end date
start_date = '1990-01-01'
end_date = '2018-03-01'

# Set the ticker name
ticker = 'AMZN'

# Feth the data
data = quandl.get('WIKI/'+ticker, start_date=start_date,
                  end_date=end_date, api_key=QUANDL_API_KEY)

# Print the first 5 rows of the dataframe
data.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1997-05-16  22.38  23.75  20.50  20.75  1225000.0          0.0          1.0
# 1997-05-19  20.50  21.25  19.50  20.50   508900.0          0.0          1.0
# 1997-05-20  20.75  21.00  19.63  19.63   455600.0          0.0          1.0
# 1997-05-21  19.25  19.75  16.50  17.13  1571100.0          0.0          1.0
# 1997-05-22  17.25  17.38  15.75  16.75   981400.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1997-05-16   1.865000   1.979167  1.708333    1.729167   14700000.0
# 1997-05-19   1.708333   1.770833  1.625000    1.708333    6106800.0
# 1997-05-20   1.729167   1.750000  1.635833    1.635833    5467200.0
# 1997-05-21   1.604167   1.645833  1.375000    1.427500   18853200.0
# 1997-05-22   1.437500   1.448333  1.312500    1.395833   11776800.0

# %%
# Define the figure size for the plot
plt.figure(figsize=(10, 7))

# Plot the adjusted close price
data['Adj. Close'].plot()

# Define the label for the title of the figure
plt.title("Adjusted Close Price of %s" % ticker, fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %% [markdown]
# ### multi security pull

# %%
# Define the ticker list
tickers_list = ['AAPL', 'IBM', 'MSFT', 'WMT']

# Import pandas
data = pd.DataFrame(columns=tickers_list)

# Feth the data
for ticker in tickers_list:
    data[ticker] = quandl.get('WIKI/' + ticker, start_date=start_date,
                              end_date=end_date, api_key=QUANDL_API_KEY)['Adj. Close']

# Print first 5 rows of the data
data.head()
# Out:
#                 AAPL        IBM      MSFT       WMT
# Date
# 1990-01-02  1.118093  14.138144  0.410278  4.054211
# 1990-01-03  1.125597  14.263656  0.412590  4.054211
# 1990-01-04  1.129499  14.426678  0.424702  4.033561
# 1990-01-05  1.133101  14.390611  0.414300  3.990541
# 1990-01-08  1.140605  14.480057  0.420680  4.043886

# %%
# Plot all the close prices
data.plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Adjusted Close Price", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
pdr.quandl.QuandlReader(['AAPL', 'IBM', 'MSFT', 'WMT'], start=None, end=None,
                       retry_count=3, pause=0.1,
                       session=None,chunksize=25,
                       api_key='dbyBuiq4bczbbuz9bA4t')

# %%
# Returns DataFrame of historical stock prices from symbol, 
    # over date range, start to end.

pdr.quandl.QuandlReader(['AAPL', 'IBM', 'MSFT', 'WMT'], start=None, end=None,
                       retry_count=3, pause=0.1, session=None,
                       chunksize=25, api_key='dbyBuiq4bczbbuz9bA4t')

# %% [markdown]
# ### main pulls

# %%
# QUANDL API FIXED-PARAMETERS

quandl.ApiConfig.api_key = 'VpYKj-e3pTXsUxQBMcto'


start_date=('2018-1-1')
end_date=('2020-1-1')

# %%
# SPECIFIC_DATE

SPECIFIC_DATE=quandl.get('FINRA/FORF_TLLTD', start_date='2018-06-22', end_date='2018-06-22',api_key='dbyBuiq4bczbbuz9bA4t'
)
SPECIFIC_DATE
# Out:
#             ShortVolume  ShortExemptVolume  TotalVolume
# Date
# 2018-06-22        541.0                0.0        574.0

# %%
# FILTER BY DATE_RANGE

DATE_RANGE=quandl.get('FINRA/FORF_TLLTD', start_date='2018-06-14', end_date='2018-06-22',api_key='dbyBuiq4bczbbuz9bA4t'
)
DATE_RANGE
# Out:
#             ShortVolume  ShortExemptVolume  TotalVolume
# Date
# 2018-06-14        166.0                0.0        332.0
# 2018-06-21        666.0                0.0        666.0
# 2018-06-22        541.0                0.0        574.0

# %%
# RETRIEVE Two_Columns

Two_Columns=quandl.get('FINRA/FORF_TLLTD', start_date=start_date, end_date=end_date,
                       column_index='1',api_key='dbyBuiq4bczbbuz9bA4t')
Two_Columns
# Out:
#             ShortVolume
# Date
# 2018-06-13       1426.0
# 2018-06-14        166.0
# 2018-06-21        666.0
# 2018-06-22        541.0

# %%
# RETRIEVE UNFILTERED TIME-SERIES

UNFILTERED=quandl.get('FINRA/FORF_TLLTD')
UNFILTERED
# Out:
#             ShortVolume  ShortExemptVolume  TotalVolume
# Date
# 2018-06-13       1426.0                0.0       1428.0
# 2018-06-14        166.0                0.0        332.0
# 2018-06-21        666.0                0.0        666.0
# 2018-06-22        541.0                0.0        574.0

# %% [markdown]
# ### (ZEFR)
# * Zacks Expanded Fundamental Ratios

# %%
# Exp Ratio F1 (Exp_Ratio_F1)

Exp_Ratio_F1 = quandl.get_table("ZACKS/RF1", paginate=True)
Exp_Ratio_F1
# Out:
#      ticker m_ticker        comp_name  fye per_type per_end_date exchange  \
# None
# 0      AAPL     AAPL        APPLE INC    9        A   2019-12-31     NSDQ
# 1       AXP      AXP  AMER EXPRESS CO   12        A   2019-12-31     NYSE
# 2        BA       BA        BOEING CO   12        A   2019-12-31     NYSE
# 3       CAT      CTR  CATERPILLAR INC   12        A   2019-12-31     NYSE
# 4      CSCO     CSCO    CISCO SYSTEMS    7        A   2020-01-31     NSDQ
# 5       CVX       SD     CHEVRON CORP   12        A   2019-12-31     NYSE
# 6        DD      DOW  DUPONT DE NEMRS   12        A   2019-12-31     NYSE
# 7       DIS      DIS      DISNEY WALT    9        A   2019-12-31     NYSE
# 8        GE       GE    GENL ELECTRIC   12        A   2019-12-31     NYSE
# 9        GS      GS&    GOLDMAN SACHS   12        A   2019-12-31     NYSE
# 10       HD     HOMD       HOME DEPOT    1        A   2020-01-31     NYSE
# 11      IBM      IBM    INTL BUS MACH   12        A   2019-12-31     NYSE
# 12     INTC      ITL       INTEL CORP   12        A   2019-12-31     NSDQ
# 13      JNJ      JNJ  JOHNSON & JOHNS   12        A   2019-12-31     NYSE
# 14      JPM      CHL   JPMORGAN CHASE   12        A   2019-12-31     NYSE
# 15       KO       KO     COCA COLA CO   12        A   2019-12-31     NYSE
# 16      MCD      MCD   MCDONALDS CORP   12        A   2019-12-31     NYSE
# 17      MMM      MMM            3M CO   12        A   2019-12-31     NYSE
# 18      MRK      MRK   MERCK & CO INC   12        A   2019-12-31     NYSE
# 19     MSFT     MSFT   MICROSOFT CORP    6        A   2019-12-31     NSDQ
# 20      NKE     NIKE       NIKE INC-B    5        A   2020-02-29     NYSE
# 21      PFE      PFE       PFIZER INC   12        A   2019-12-31     NYSE
# 22       PG       PG  PROCTER & GAMBL    6        A   2019-12-31     NYSE
# 23      TRV      SPM    TRAVELERS COS   12        A   2019-12-31     NYSE
# 24      UNH     UNIH  UNITEDHEALTH GP   12        A   2019-12-31     NYSE
# 25      UTX       UA   UTD TECHS CORP   12        A   2019-12-31     NYSE
# 26        V     VISA       VISA INC-A    9        A   2019-12-31     NYSE
# 27       VZ      BEL     VERIZON COMM   12        A   2019-12-31     NYSE
# 28      WMT      WMS      WALMART INC    1        A   2020-01-31     NYSE
# 29      XOM        J  EXXON MOBIL CRP   12        A   2019-12-31     NYSE
#
#       zacksecon  zacksglob  zacksmind  zacksxind com_adr_cd  5ymrevttm  \
# None
# 0            10         45         31        199        COM  234351.50
# 1            13         40         48         69        COM   38897.00
# 2            11         20         38          2        COM   94901.00
# 3             7         20         26         95        COM   49362.00
# 4            10         45         31        198        COM   49288.50
# 5            12         10         44        132        COM  146290.50
# 6             6         15         19         34        COM   46376.50
# 7             2         50         10        208        COM   55668.00
# 8             9         20         30         48        COM  123573.00
# 9            13         40         50         62        COM   34159.00
# 10            3         25         14         25        COM   98292.00
# 11           10         45         31        203        COM   79987.50
# 12           10         45         33        241        COM   61896.50
# 13            4         35         15        225        COM   73975.50
# 14           13         40         46        204        COM  110831.50
# 15            1         30          2         20        COM   38084.50
# 16            3         25         13        160        COM   23843.85
# 17            9         20         30         48        COM   31344.00
# 18            4         35         15        225        COM   40185.50
# 19           10         45         32         44        COM   98297.50
# 20            2         25          1        173        COM   34546.00
# 21            4         35         15        225        COM   52572.00
# 22            1         30          5        174        COM   66890.50
# 23           13         40         49         89        COM   28462.00
# 24            4         35         16        108        COM  194618.50
# 25            9         20         30         48        COM   58462.00
# 26           16         45         59        282        COM   18061.00
# 27           10         50         37        238        COM  129881.00
# 28            3         30         13        167        COM  492512.00
# 29           12         10         44        132        COM  266910.00
#
#        5ymnebt  5ymnebta     5ymcf   5ymfcf      5ymbv   5ymtliab  5ymcapex  \
# None
# 0     64957.00  76511.00  62976.00  58570.5  126709.50   219265.5   12200.5
# 1      9812.46  10862.96   6512.50   9444.5   21130.00   146657.0    1325.5
# 2      8674.93  10571.93   7412.50   8509.0     762.00    91967.5    1949.0
# 3      5543.08   8874.08   5372.50   4554.0   15132.50    63222.0    1807.5
# 4     13074.68  15347.68  12217.50  12842.5   59270.00    61074.5     933.5
# 5     11190.00  30501.00  29375.50   3926.0  152473.00   107230.0   14364.5
# 6      5915.40   9108.20   7770.00   3240.0   35572.50    51786.0    2561.0
# 7     12757.77  15440.27  11915.50   7914.0   48653.00    45657.0    4436.0
# 8     21297.90  25670.21    739.00   4155.0   75972.00   284450.5    2686.5
# 9     11614.32  12840.32   8989.00  -2360.5   75702.00   827188.0    2516.5
# 10    14239.00  16260.00  10518.00   9265.5    3048.50    42442.5    1758.0
# 11    15827.50  20339.00  15658.50  13783.5   17750.50   102119.0    3122.0
# 12    18735.15  26590.65  20372.50  11953.0   68822.00    53441.0   10981.0
# 13    23788.50  28215.00  19756.50  19436.0   69109.50    81282.0     688.5
# 14    46252.00  52159.00  31812.50  19290.0  229964.00  2304691.5       0.0
# 15    11111.00  12662.50   8242.00   6741.5   22120.50    67003.0    1811.5
# 16     8754.11  10161.01   6524.35   4353.4   -2736.15    35411.5    1900.6
# 17     7139.97   8633.97   6379.50   5155.0   11254.00    22799.0    1379.0
# 18    13515.50  19331.50  11263.00   8325.0   39105.50    54961.5    1708.0
# 19    29915.00  40648.41  29164.50  31640.5   81400.50   162854.0    8905.0
# 20     4689.00   5407.50   4546.00   3387.0   12079.00    11975.5    1087.0
# 21    18570.50  24271.00  15288.00  13670.0   63657.50   101302.0    1936.0
# 22    14280.62  17195.00  12858.00  11964.0   53854.50    66957.5    2888.5
# 23     3768.50   8854.00   7803.00   3927.5   23945.50    79281.5      76.0
# 24    14437.50  16625.50  10529.00  10969.0   46323.00    92941.5    1846.5
# 25     8770.90  10999.30   7907.00   4894.0   31814.50    64649.5    1845.5
# 26    13045.00  14184.50  10353.00   8376.5   28581.50    33098.5     658.0
# 27    27433.10  44493.60  32981.00  16646.0   27606.00   224523.5   16953.5
# 28    23321.52  33534.84  23784.50  18126.5   79306.50   125041.0   10265.5
# 29    16782.50  36873.00  35893.00   9605.5  187518.00   160333.5   20491.5
#
#       5ymdepam    5ymcash  5ymnetdeb   5ymtotd  5ymernret  ...  10ymroe  \
# None                                                       ...
# 0      10768.0    69062.5    69240.0  108169.5      75.80  ...     0.38
# 1       1171.5    26694.5    25201.5   52600.5      79.76  ...     0.27
# 2       2009.0     9813.5     2357.0   10907.0      57.13  ...     0.80
# 3       3027.5     7839.0    29111.0   37151.0      36.95  ...     0.20
# 4       2232.5    59741.0    13817.0   21524.0      52.82  ...     0.16
# 5      19384.0     8663.0    29098.5   38533.5      31.78  ...     0.12
# 6       3417.0     7170.5    15024.0   21041.5      19.03  ...     0.11
# 7       2772.5     4395.5    17302.5   21387.5      75.37  ...     0.16
# 8       5727.0    83765.0    89157.5  133165.5     115.83  ...     0.10
# 9       1144.5   417372.5    87371.0  205361.5      78.74  ...     0.10
# 10      2021.0     3373.5    21535.5   25232.5      56.33  ...     0.39
# 11      4475.0    11236.5    34051.0   45591.5      52.43  ...     0.71
# 12      8634.0    14604.5    23102.0   27745.0      60.84  ...     0.21
# 13      4426.5    19525.5     9383.0   26797.0      43.99  ...     0.22
# 14      5907.0  1019579.5  -318674.0  303057.5      65.86  ...     0.10
# 15      1451.5    20811.0    23826.0   32065.5       5.80  ...     0.26
# 16      1521.9     2402.3    25957.8   28489.6      39.39  ...     0.35
# 17      1484.0     2898.5    10057.0   12055.0      46.57  ...     0.31
# 18      4674.5    11282.5    15034.5   22753.5      12.49  ...     0.12
# 19     10430.0   131944.0    67435.0   78719.0      48.01  ...     0.29
# 20       720.5     5326.5     -582.5    3473.5      70.52  ...     0.25
# 21      6042.0    17082.0    29811.0   32370.0      26.38  ...     0.13
# 22      2917.5    13254.0    24758.5   31205.5      30.53  ...     0.17
# 23      4901.0     4999.5     6169.0    6558.0      71.36  ...     0.12
# 24      2162.5    14907.0    15984.5   27026.0      71.94  ...     0.18
# 25      2064.5     7156.5    17353.5   26943.0      57.61  ...     0.18
# 26      2314.0    12428.5     7443.0   16536.0      62.58  ...     0.20
# 27     16435.0     2950.0   111000.0  113665.0      38.30  ...     0.29
# 28     10436.5     7699.0    36605.5   49473.0      54.49  ...     0.19
# 29     18972.0     4281.0    18861.5   22593.5      22.79  ...     0.17
#
#       5ymroic  10ymroic  5ymrote  10ymrote  5ymeb_sh  10ymeb_sh  5ymebt_sh  \
# None
# 0       21.00     21.54    44.01     40.33     12.50      10.52      14.45
# 1        6.05      5.52    26.15     26.53     10.22       9.26      11.44
# 2       20.13     17.34   -98.59    -98.17     11.30       8.80      14.23
# 3        1.40      4.92    32.70     42.32      7.19       9.87      12.37
# 4        6.44      8.10    29.36     28.83      2.45       2.06       2.90
# 5        0.43      5.75     6.05     12.10      5.49      12.68      16.75
# 6        1.05      3.71    64.01     82.03      8.89       9.29      16.18
# 7       10.92      9.32    72.92     59.30      8.55       6.18      10.15
# 8       -4.51      1.24    30.98     32.33      0.77       1.87       1.51
# 9        2.40      2.70    10.26     11.08     28.35      25.13      30.99
# 10      16.87     14.56   104.72     30.48     12.05       8.12      13.76
# 11      10.90     17.13   -49.30    -67.50     12.95      14.10      17.86
# 12       9.42     10.04    28.90     28.14      3.53       2.93       5.16
# 13       7.38      7.75    63.28     63.11      6.97       6.60       8.99
# 14       3.37      3.27    15.05     15.17     12.92       9.95      14.57
# 15       0.75      3.96   159.25    113.38      2.00       2.04       2.40
# 16       6.80      8.58   -68.38     43.03     10.83       8.55      12.64
# 17      10.83     12.21  -201.94     52.57     11.37      10.77      13.83
# 18       1.18      1.18   105.05     59.06      2.75       2.64       4.78
# 19       8.79     11.82    52.16     49.00      3.86       3.26       5.05
# 20      19.19     16.70    32.19     26.48      2.72       2.35       3.16
# 21       2.41      2.91   -47.60    -63.31      2.18       2.17       3.14
# 22       4.04      4.99   -66.59    -59.78      4.98       5.02       6.05
# 23       6.56      7.17    14.26     14.21     14.15      12.62      32.11
# 24       9.46     10.43   -76.23    -73.01     14.20      10.88      16.39
# 25       5.68      7.55   -40.03    -40.03     10.00       9.65      12.85
# 26      15.95     13.90   -52.64    107.17      4.99       3.17       5.59
# 27       4.21      2.73   -17.20    -17.87      6.63       5.30      10.73
# 28       6.06      7.74    22.19     26.46      7.31       7.43      10.63
# 29       1.88      9.55     9.02     16.52      4.67       8.90       9.17
#
#       10ymebt_sh  5ymintcof  10ymintcop  5ymintcop  10ymintcof  5ymcpx_rv  \
# None
# 0          12.00        NaN         NaN        NaN         NaN       5.20
# 1          10.36       3.98        3.52       8.45        7.11       3.45
# 2          11.45      15.52       10.31      29.95       19.33       2.14
# 3          14.52       2.30        3.23       5.84        5.68       3.52
# 4           2.51      13.87       13.59      18.31       18.87       1.89
# 5          21.02        NaN         NaN        NaN         NaN      10.72
# 6          16.66       5.04        2.81       7.39        6.15       7.17
# 7           8.07      26.28       20.77      32.08       25.79       7.56
# 8           2.68      -0.12        0.93       1.42        2.30       2.21
# 9          27.94        NaN         NaN        NaN         NaN       7.36
# 10          9.48       8.31        7.64      10.88       10.74       1.79
# 11         18.53      18.70       32.00      26.24       37.51       3.79
# 12          4.51        NaN         NaN        NaN         NaN      17.74
# 13          8.17      22.51       23.78      25.99       30.75       0.97
# 14         11.28       2.61        2.30       2.07        3.03       0.00
# 15          2.45       7.92       13.96      10.56       13.71       4.76
# 16         10.17       5.72        7.84       7.15       11.38       7.93
# 17         13.09        NaN         NaN        NaN         NaN       4.53
# 18          4.86        NaN         NaN        NaN         NaN       4.28
# 19          3.92      11.40       29.72      19.59       46.82       9.27
# 20          2.71      86.95       87.18     117.32      117.32       3.10
# 21          3.18        NaN         NaN        NaN         NaN       3.68
# 22          6.07      17.60       15.08      27.82       22.89       4.39
# 23         29.72       7.82        8.06      11.04       10.09       0.26
# 24         12.41       8.27        8.57      11.90       11.40       0.95
# 25         12.21       5.01        5.93       6.31        8.08       2.98
# 26          4.53      18.35         NaN      20.97         NaN       3.46
# 27          9.78       3.34        2.92       6.91        7.57      13.39
# 28         10.58       5.62        6.38      12.00       11.26       2.03
# 29         12.07      29.50       57.22      48.74      101.10       7.78
#
#       10ymcpx_rv  5ymrecturn  10ymrectrn  5ymrecsls  10ymrecrev  5ymsga_sls  \
# None
# 0           4.97        8.74        9.34      11.45       10.71        6.55
# 1           3.25        0.32        0.32     312.58      312.58       74.50
# 2           2.15        9.20       10.26      10.88        9.75        3.97
# 3           4.48        3.01        3.11      33.21       32.17       14.82
# 4           2.37       10.57       10.32       9.46        9.69       24.06
# 5          11.10        9.98       10.61      10.02        9.43       17.28
# 6           4.43        4.98        5.60      20.16       17.87        9.06
# 7           7.41        6.01        6.32      16.64       15.82       15.98
# 8           3.05        2.95        0.80      33.88      126.86       12.62
# 9           3.73        0.39        0.38     254.10      259.84       52.56
# 10          1.69       48.37       50.24       2.07        1.99       18.13
# 11          3.51        8.32        9.32      12.02       10.73       25.02
# 12         19.14       12.67       14.17       7.89        7.06       13.33
# 13          2.12        5.90        6.08      16.94       16.45       29.05
# 14          0.00        0.12        0.12     850.16      804.47       57.80
# 15          5.13        9.52        9.21      10.51       10.86       40.07
# 16          9.48       16.66       21.49       6.01        4.65        9.70
# 17          4.53        6.48        6.91      15.43       14.47       20.54
# 18          3.81        5.86        5.87      17.08       17.03       25.06
# 19          6.49        6.19        5.92      16.17       16.90       20.58
# 20          2.95        9.46        8.86      10.63       11.50       32.13
# 21          2.51        5.73        5.21      17.44       19.20       29.46
# 22          4.10       13.69       13.10       7.31        7.63       28.71
# 23          0.26        1.34        1.25      74.65       79.69       29.03
# 24          0.95       12.33       14.22       8.11        7.03       15.05
# 25          2.85        5.07        5.26      19.73       19.01        8.75
# 26          3.56        6.63        7.16      15.09       13.97       32.70
# 27         13.73        6.87        9.47      14.58       10.56       23.28
# 28          2.39       90.68       89.29       1.10        1.12       20.81
# 29          7.13         NaN         NaN       0.00        0.00        4.13
#
#       10ymsgarev  5ymtdta  10ymtdta  5ymtd_eq  10ymtdeq
# None
# 0           6.50    29.10     13.99     74.65     27.69
# 1          74.50    30.28     35.41    254.93    274.04
# 2           4.20    11.19     11.43    191.83    215.38
# 3          12.84    46.91     45.94    241.50    242.84
# 4          24.87    18.69     17.84     42.23     33.46
# 5          14.52    14.74      9.98     24.68     16.95
# 6           5.24    24.03     26.39     58.33     73.57
# 7          14.89    22.85     20.05     44.32     36.52
# 8          15.00    37.04     42.83    188.51    211.67
# 9          53.02    22.25     19.91    228.50    233.74
# 10         19.40    53.60     39.68    365.02    115.35
# 11         24.38    37.22     35.47    269.22    240.77
# 12         14.99    21.88     15.05     39.24     24.14
# 13         29.97    17.37     10.97     35.63     20.25
# 14         67.76    12.17     12.18    122.81    132.89
# 15         39.15    36.42     23.89    148.76     69.21
# 16          8.51    84.73     41.90   -564.23     86.87
# 17         20.57    35.13     21.65    104.44     45.76
# 18         26.88    24.08     19.99     57.13     42.15
# 19         24.44    31.42     14.91     89.27     28.27
# 20         31.68    14.83      6.61     28.34     10.91
# 21         29.61    19.12     18.38     47.59     42.73
# 22         31.18    25.41     24.43     56.12     50.50
# 23         28.97     6.35      6.22     27.06     26.32
# 24         15.22    20.62     18.33     62.43     47.48
# 25          9.32    27.18     24.30     83.51     72.20
# 26         35.46    23.88      0.14     49.05      0.19
# 27         24.35    44.94     43.34    449.79    210.93
# 28         19.48    24.73     27.07     61.18     69.72
# 29          3.90     6.38      4.52     11.58      9.03
#
# [30 rows x 186 columns]

# %%
# Exp Ratio F160 
# Exp_Ratio_F160

Exp_Ratio_F160= quandl.get_table("ZACKS/RF160", paginate=True)
Exp_Ratio_F160
# Out:
#      ticker m_ticker        comp_name  fye per_type per_end_date exchange  \
# None
# 0      AAPL     AAPL        APPLE INC    9        A   2018-12-31     NSDQ
# 1      AAPL     AAPL        APPLE INC    9        A   2018-09-30     NSDQ
# 2      AAPL     AAPL        APPLE INC    9        A   2018-06-30     NSDQ
# 3      AAPL     AAPL        APPLE INC    9        A   2018-03-31     NSDQ
# 4       AXP      AXP  AMER EXPRESS CO   12        A   2018-12-31     NYSE
# ...     ...      ...              ...  ...      ...          ...      ...
# 115     WMT      WMS      WALMART INC    1        A   2018-01-31     NYSE
# 116     XOM        J  EXXON MOBIL CRP   12        A   2018-12-31     NYSE
# 117     XOM        J  EXXON MOBIL CRP   12        A   2018-09-30     NYSE
# 118     XOM        J  EXXON MOBIL CRP   12        A   2018-06-30     NYSE
# 119     XOM        J  EXXON MOBIL CRP   12        A   2018-03-31     NYSE
#
#       zacksecon  zacksglob  zacksmind  zacksxind com_adr_cd  revenuettm  \
# None
# 0            10         45         31        199        COM    261612.0
# 1            10         45         31        199        COM    265595.0
# 2            10         45         31        199        COM    255274.0
# 3            10         45         31        199        COM    247417.0
# 4            13         40         48         69        COM     43281.0
# ...         ...        ...        ...        ...        ...         ...
# 115           3         30         13        167        COM    500343.0
# 116          12         10         44        132        COM    290212.0
# 117          12         10         44        132        COM    284832.0
# 118          12         10         44        132        COM    274392.0
# 119          12         10         44        132        COM    263767.0
#
#       nebitttm  nebitdattm  cashflow      fcf  bookvalue  totalliab    capex  \
# None
# 0     67970.00    79523.00   70984.0  61973.0   117892.0   255827.0  13858.0
# 1     70898.00    81801.00   70434.0  64121.0   107147.0   258578.0  13313.0
# 2     67900.00    78533.00   66753.0  59430.0   114949.0   234248.0  14137.0
# 3     66056.00    76378.00   63640.0  54295.0   126878.0   240624.0  13147.0
# 4      9249.00    10542.00    8214.0   7620.0    22290.0   166312.0   1310.0
# ...        ...         ...       ...      ...        ...        ...      ...
# 115   23175.97    33704.97   20391.0  18664.0    80822.0   123700.0   9673.0
# 116   30262.00    49007.00   39585.0  16440.0   198528.0   147668.0  19574.0
# 117   20104.00    39663.00   42779.0  16837.0   196831.0   157797.0  17981.0
# 118   16441.00    36222.00   40731.0  13555.0   193533.0   155257.0  17690.0
# 119   14107.00    33951.00   40194.0  14551.0   194911.0   153915.0  15861.0
#
#       depamort  cash&equiv  netdebt  totaldebt  earnreten  ...  daysslsinv  \
# None                                                       ...
# 0      11553.0     86427.0  69959.0   114730.0      77.07  ...       12.72
# 1      10903.0     66301.0  88570.0   114483.0      77.51  ...       12.25
# 2      10633.0     70970.0  82629.0   114600.0      76.51  ...       13.24
# 3      10322.0     87940.0  76781.0   121840.0      75.73  ...       12.00
# 4       1293.0     27445.0  31144.0    58423.0      82.16  ...         NaN
# ...        ...         ...      ...        ...        ...  ...         ...
# 115    10529.0      6756.0  32284.0    45820.0      37.96  ...       44.17
# 116    18745.0      3042.0  17496.0    20538.0      34.37  ...       30.04
# 117    19559.0      5669.0  14955.0    20624.0      41.99  ...       29.44
# 118    19781.0      3430.0  17290.0    20720.0      36.71  ...       30.24
# 119    19844.0      4125.0  16656.0    20781.0      35.87  ...       30.76
#
#       fcfmargin     ebit  gwinptc   ebitda  ebitmrg  ebitdamrg  opermrg  \
# None
# 0         23.69  67970.0     0.00  79523.0    25.98      30.40    25.98
# 1         24.14  70898.0     1.64  81801.0    26.69      30.80    26.69
# 2         23.28  67900.0     3.11  78533.0    26.60      30.76    26.60
# 3         21.94  66056.0     4.53  76378.0    26.70      30.87    26.70
# 4         17.61   9778.0     0.00  11071.0    22.59      25.58    22.59
# ...         ...      ...      ...      ...      ...        ...      ...
# 115        3.73  19776.0    22.88  30305.0     3.95       6.06     4.08
# 116        5.66  29853.0     0.00  48598.0    10.29      16.75    11.11
# 117        5.91  24752.0     0.00  44311.0     8.69      15.56     9.41
# 118        4.94  21089.0     0.00  40870.0     7.69      14.89     8.38
# 119        5.52  18755.0     0.00  38599.0     7.11      14.63     7.71
#
#       td_ebitda  nd_ebitda   roa    roc   roe   roic   rote  ebit_sh  \
# None
# 0          1.44       0.88  0.16  27.90  0.51  21.50  50.92    14.24
# 1          1.40       1.08  0.16  26.90  0.49  20.85  49.49    14.63
# 2          1.46       1.05  0.15  24.51  0.43  18.76  44.89    13.78
# 3          1.60       1.01  0.14  23.03  0.40  17.44  41.87    13.03
# 4          5.28       2.81  0.04   9.04  0.33   7.43  32.86    11.48
# ...         ...        ...   ...    ...   ...    ...    ...      ...
# 115        1.29       1.07  0.05   8.34  0.13   3.16  16.25     6.64
# 116        0.42       0.36  0.06   9.62  0.11   3.31  10.64     6.99
# 117        0.47       0.34  0.07  10.72  0.12   4.50  11.91     5.80
# 118        0.51       0.42  0.06   9.71  0.11   3.56  10.85     4.94
# 119        0.54       0.43  0.06   9.47  0.11   3.40  10.65     4.39
#
#       ebitda_sh  intcovcop  intcovopcf  cpxptrev  recvturn  recvptrev  \
# None
# 0         16.66        NaN         NaN      5.30      7.77      12.88
# 1         16.87        NaN         NaN      5.01      7.15      13.99
# 2         15.94        NaN         NaN      5.54      7.54      13.26
# 3         15.07        NaN         NaN      5.31      7.52      13.30
# 4         12.99       4.16        5.39      3.03      0.32     312.53
# ...         ...        ...         ...       ...       ...        ...
# 115       10.18       4.23       12.16      1.93     90.45       1.11
# 116       11.38      27.21       47.02      6.74       NaN       0.00
# 117       10.37      31.51       47.24      6.31       NaN       0.00
# 118        9.57      32.33       48.22      6.45       NaN       0.00
# 119        9.04      30.88       46.15      6.01       NaN       0.00
#
#       sgaptrev  tdbt_asst  td_equity
# None
# 0         6.60      31.98      99.74
# 1         6.29      31.78      96.76
# 2         6.39      31.66      91.95
# 3         6.46      31.33      87.76
# 4        74.43      29.91     263.57
# ...        ...        ...        ...
# 115      21.29      23.06      59.70
# 116       3.96       5.91      10.55
# 117       4.07       6.18      11.10
# 118       4.13       6.50      11.76
# 119       4.13       6.82      12.40
#
# [120 rows x 99 columns]

# %% [markdown]
# ###  - Z_A_R
# * Zacks Analyst Revisions

# %%
    # Zacks Earnings Estimate Revisions
        # Z_Earning_Est_Rev

Z_Earning_Est_Rev = quandl.get_table("ZACKS/EREV", paginate=True)
Z_Earning_Est_Rev
# Out:
#      m_ticker ticker        comp_name                  comp_name_2 exchange  \
# None
# 0        AAPL   AAPL        APPLE INC                   Apple Inc.     NSDQ
# 1        AAPL   AAPL        APPLE INC                   Apple Inc.     NSDQ
# 2        AAPL   AAPL        APPLE INC                   Apple Inc.     NSDQ
# 3        AAPL   AAPL        APPLE INC                   Apple Inc.     NSDQ
# 4        AAPL   AAPL        APPLE INC                   Apple Inc.     NSDQ
# ...       ...    ...              ...                          ...      ...
# 146       BEL     VZ     VERIZON COMM  Verizon Communications Inc.     NYSE
# 147       BEL     VZ     VERIZON COMM  Verizon Communications Inc.     NYSE
# 148       BEL     VZ     VERIZON COMM  Verizon Communications Inc.     NYSE
# 149       BEL     VZ     VERIZON COMM  Verizon Communications Inc.     NYSE
# 150         J    XOM  EXXON MOBIL CRP      Exxon Mobil Corporation     NYSE
#
#      currency_code per_end_date per_type per_code  per_fisc_year  \
# None
# 0              USD   2020-09-30        A     None           2020
# 1              USD   2021-09-30        A     None           2021
# 2              USD   2020-03-31        Q     None           2020
# 3              USD   2020-06-30        Q     None           2020
# 4              USD   2020-09-30        Q     None           2020
# ...            ...          ...      ...      ...            ...
# 146            USD   2021-03-31        Q     None           2021
# 147            USD   2021-06-30        Q     None           2021
# 148            USD   2021-09-30        Q     None           2021
# 149            USD   2021-12-31        Q     None           2021
# 150            USD   2020-12-31        A     None           2020
#
#       per_fisc_qtr  per_cal_year  per_cal_qtr rev_type rev_type_desc  \
# None
# 0                4          2020            3        E           EPS
# 1                4          2021            3        E           EPS
# 2                2          2020            1        E           EPS
# 3                3          2020            2        E           EPS
# 4                4          2020            3        E           EPS
# ...            ...           ...          ...      ...           ...
# 146              1          2021            1        E           EPS
# 147              2          2021            2        E           EPS
# 148              3          2021            3        E           EPS
# 149              4          2021            4        E           EPS
# 150              4          2020            4        E           EPS
#
#           broker_name analyst_name eps_rev_date  eps_rev_est  \
# None
# 0     OPPENHEIMER HLD   A Uerkwitz   2020-03-01        12.85
# 1     OPPENHEIMER HLD   A Uerkwitz   2020-03-01        15.83
# 2     OPPENHEIMER HLD   A Uerkwitz   2020-03-01         2.41
# 3     OPPENHEIMER HLD   A Uerkwitz   2020-03-01         2.17
# 4     OPPENHEIMER HLD   A Uerkwitz   2020-03-01         3.24
# ...               ...          ...          ...          ...
# 146              None         None   2020-02-24         1.31
# 147              None         None   2020-02-24         1.38
# 148              None         None   2020-02-24         1.29
# 149              None         None   2020-02-24         1.11
# 150     PIPER SANDLER       R TODD   2020-03-02         4.43
#
#      eps_rev_date_prev  eps_rev_est_prev
# None
# 0           2020-01-28             13.61
# 1           2020-01-28             15.05
# 2           2020-01-28              2.93
# 3           2020-01-28              2.31
# 4           2020-01-28              3.34
# ...                ...               ...
# 146                NaT               NaN
# 147                NaT               NaN
# 148                NaT               NaN
# 149                NaT               NaN
# 150         2020-01-23              4.42
#
# [151 rows x 21 columns]

# %% [markdown]
# ### Zacks Sales Surprises

# %%
# Zacks Master Table
    # Z_Master

Z_Master = quandl.get_table("ZACKS/MT", paginate=True)
Z_Master
# Out:
#      m_ticker ticker        comp_name  \
# None
# 0        AAPL   AAPL        APPLE INC
# 1         AXP    AXP  AMER EXPRESS CO
# 2          BA     BA        BOEING CO
# 3         CTR    CAT  CATERPILLAR INC
# 4        CSCO   CSCO    CISCO SYSTEMS
# 5          SD    CVX     CHEVRON CORP
# 6         DOW     DD  DUPONT DE NEMRS
# 7         DIS    DIS      DISNEY WALT
# 8          GE     GE    GENL ELECTRIC
# 9         GS&     GS    GOLDMAN SACHS
# 10       HOMD     HD       HOME DEPOT
# 11        IBM    IBM    INTL BUS MACH
# 12        ITL   INTC       INTEL CORP
# 13        JNJ    JNJ  JOHNSON & JOHNS
# 14        CHL    JPM   JPMORGAN CHASE
# 15         KO     KO     COCA COLA CO
# 16        MCD    MCD   MCDONALDS CORP
# 17        MMM    MMM            3M CO
# 18        MRK    MRK   MERCK & CO INC
# 19       MSFT   MSFT   MICROSOFT CORP
# 20       NIKE    NKE       NIKE INC-B
# 21        PFE    PFE       PFIZER INC
# 22         PG     PG  PROCTER & GAMBL
# 23        SPM    TRV    TRAVELERS COS
# 24       UNIH    UNH  UNITEDHEALTH GP
# 25         UA    UTX   UTD TECHS CORP
# 26       VISA      V       VISA INC-A
# 27        BEL     VZ     VERIZON COMM
# 28        WMS    WMT      WALMART INC
# 29          J    XOM  EXXON MOBIL CRP
#
#                                       comp_name_2 exchange currency_code  \
# None
# 0                                      Apple Inc.     NSDQ           USD
# 1                        American Express Company     NYSE           USD
# 2                              The Boeing Company     NYSE           USD
# 3                                Caterpillar Inc.     NYSE           USD
# 4                             Cisco Systems, Inc.     NSDQ           USD
# 5                             Chevron Corporation     NYSE           USD
# 6                         DuPont de Nemours, Inc.     NYSE           USD
# 7                         The Walt Disney Company     NYSE           USD
# 8                        General Electric Company     NYSE           USD
# 9                   The Goldman Sachs Group, Inc.     NYSE           USD
# 10                           The Home Depot, Inc.     NYSE           USD
# 11    International Business Machines Corporation     NYSE           USD
# 12                              Intel Corporation     NSDQ           USD
# 13                              Johnson & Johnson     NYSE           USD
# 14                           JPMorgan Chase & Co.     NYSE           USD
# 15                        Coca-Cola Company (The)     NYSE           USD
# 16                         McDonald's Corporation     NYSE           USD
# 17                                     3M Company     NYSE           USD
# 18                              Merck & Co., Inc.     NYSE           USD
# 19                          Microsoft Corporation     NSDQ           USD
# 20                                     NIKE, Inc.     NYSE           USD
# 21                                    Pfizer Inc.     NYSE           USD
# 22                 Procter & Gamble Company (The)     NYSE           USD
# 23                  The Travelers Companies, Inc.     NYSE           USD
# 24                UnitedHealth Group Incorporated     NYSE           USD
# 25                United Technologies Corporation     NYSE           USD
# 26                                      Visa Inc.     NYSE           USD
# 27                    Verizon Communications Inc.     NYSE           USD
# 28                                   Walmart Inc.     NYSE           USD
# 29                        Exxon Mobil Corporation     NYSE           USD
#
#      ticker_type active_ticker_flag                             comp_url  \
# None
# 0              S                  Y                 http://www.apple.com
# 1              S                  Y       http://www.americanexpress.com
# 2              S                  Y                http://www.boeing.com
# 3              S                  Y           http://www.caterpillar.com
# 4              S                  Y                 http://www.cisco.com
# 5              S                  Y               http://www.chevron.com
# 6              S                  Y                http://www.dupont.com
# 7              S                  Y  http://www.thewaltdisneycompany.com
# 8              S                  Y                    http://www.ge.com
# 9              S                  Y          http://www.goldmansachs.com
# 10             S                  Y             http://www.homedepot.com
# 11             S                  Y                   http://www.ibm.com
# 12             S                  Y                 http://www.intel.com
# 13             S                  Y                   http://www.jnj.com
# 14             S                  Y         http://www.jpmorganchase.com
# 15             S                  Y      http://www.coca-colacompany.com
# 16             S                  Y              corporate.mcdonalds.com
# 17             S                  Y                    http://www.3m.com
# 18             S                  Y                 http://www.merck.com
# 19             S                  Y             http://www.microsoft.com
# 20             S                  Y                  http://www.nike.com
# 21             S                  Y                http://www.pfizer.com
# 22             S                  Y                    https://us.pg.com
# 23             S                  Y             http://www.travelers.com
# 24             S                  Y     http://www.unitedhealthgroup.com
# 25             S                  Y                   http://www.utc.com
# 26             S                  Y                  http://usa.visa.com
# 27             S                  Y               http://www.verizon.com
# 28             S                  Y         http://www.stock.walmart.com
# 29             S                  Y      http://corporate.exxonmobil.com
#
#       sic_4_code                                         sic_4_desc  \
# None
# 0           3571                               Electronic computers
# 1           6199                  Nondepository credit institutions
# 2           3721                                           Aircraft
# 3           3531                             Construction machinery
# 4           3576                        Computer & office equipment
# 5           2911                                 Petroleum refining
# 6           2821                        Plastics materials & resins
# 7           4841              Cable & other pay television services
# 8           3600  Electronic, electrical equipment & components,...
# 9           6211                         Security brokers & dealers
# 10          5211                  Lumber & other building materials
# 11          3570                        Computer & office equipment
# 12          3674                   Semiconductors & related devices
# 13          2834                        Pharmaceutical preparations
# 14          6021                          National commercial banks
# 15          2080                                          Beverages
# 16          5812                                      Eating places
# 17          3841                     Surgical & medical instruments
# 18          2834                        Pharmaceutical preparations
# 19          7372                               Prepackaged software
# 20          3021                         Rubber & plastics footwear
# 21          2834                        Pharmaceutical preparations
# 22          2840  Soap, detergents, & cleaning preparations; per...
# 23          6331                 Fire, marine, & casualty insurance
# 24          6324                   Hospital & medical service plans
# 25          3724                    Aircraft engines & engine parts
# 26          7389        Business services, not elsewhere classified
# 27          4813              Telephone communication, except radio
# 28          5331                                     Variety stores
# 29          2911                                 Petroleum refining
#
#       zacks_x_ind_code                zacks_x_ind_desc  zacks_x_sector_code  \
# None
# 0                  199                       COMP-MINI                   10
# 1                   69                   FIN-MISC SVCS                   13
# 2                    2                  AEROSP/DEFENSE                   11
# 3                   95                  MACH-CONST/MNG                    7
# 4                  198                   COMP-NETWORKS                   10
# 5                  132                  OIL-INTL INTGD                   12
# 6                   34                  CHEM-DIVERSIFD                    6
# 7                  208                   MEDIA CONGLOM                    2
# 8                   48                 DIVERSIFIED OPS                    9
# 9                   62                 FIN-INVEST BKRS                   13
# 10                  25                 BLDG PRD-RT/WHL                    3
# 11                 203                 COMP-INTEGT SYS                   10
# 12                 241                    SEMI-GENERAL                   10
# 13                 225                Large Cap Pharma                    4
# 14                 204                 BANKS-MJR REGNL                   13
# 15                  20                  BEVERAGES-SOFT                    1
# 16                 160                 RETAIL-RESTRNTS                    3
# 17                  48                 DIVERSIFIED OPS                    9
# 18                 225                Large Cap Pharma                    4
# 19                  44                   COMP-SOFTWARE                   10
# 20                 173                 SHOES&REL APPRL                    2
# 21                 225                Large Cap Pharma                    4
# 22                 174                 SOAP&CLNG PREPS                    1
# 23                  89                 INS-PROP&CASLTY                   13
# 24                 108                         MED-HMO                    4
# 25                  48                 DIVERSIFIED OPS                    9
# 26                 282  Financial Transaction Services                   16
# 27                 238               Wireless National                   10
# 28                 167                 RETAIL-SUPERMKT                    3
# 29                 132                  OIL-INTL INTGD                   12
#
#              zacks_x_sector_desc  zacks_m_ind_code       zacks_m_ind_desc  \
# None
# 0        Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 1                        Finance                48                FINANCE
# 2                      Aerospace                38      AEROSPACE/DEFENSE
# 3            Industrial Products                26              MACHINERY
# 4        Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 5                    Oils/Energy                44         OIL-INTEGRATED
# 6                Basic Materials                19              CHEMICALS
# 7         Consumer Discretionary                10                  MEDIA
# 8     Multi-Sector Conglomerates                30          CONGLOMERATES
# 9                        Finance                50       INVEST BKRS/MGMT
# 10              Retail/Wholesale                14      NONFOOD RETAIL/WH
# 11       Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 12       Computer and Technology                33          ELECTRON-SEMI
# 13                       Medical                15                  DRUGS
# 14                       Finance                46            BANKS-MAJOR
# 15              Consumer Staples                 2              BEVERAGES
# 16              Retail/Wholesale                13      FOOD/DRUG-RTL/WHL
# 17    Multi-Sector Conglomerates                30          CONGLOMERATES
# 18                       Medical                15                  DRUGS
# 19       Computer and Technology                32     COMPUTER SOFT/SERV
# 20        Consumer Discretionary                 1                APPAREL
# 21                       Medical                15                  DRUGS
# 22              Consumer Staples                 5        SOAPS/COSMETICS
# 23                       Finance                49              INSURANCE
# 24                       Medical                16           MEDICAL CARE
# 25    Multi-Sector Conglomerates                30          CONGLOMERATES
# 26             Business Services                59      BUSINESS SERVICES
# 27       Computer and Technology                37          TELECOMM SVCS
# 28              Retail/Wholesale                13      FOOD/DRUG-RTL/WHL
# 29                   Oils/Energy                44         OIL-INTEGRATED
#
#       per_end_month_nbr mr_split_date  mr_split_factor    comp_cik  \
# None
# 0                     9    2014-06-09             7.00  0000320193
# 1                    12    2000-05-11             3.00  0000004962
# 2                    12    1997-06-09             2.00  0000012927
# 3                    12    2005-07-14             2.00  0000018230
# 4                     7    2000-03-23             2.00  0000858877
# 5                    12    2004-09-13             2.00  0000093410
# 6                    12    2019-06-03             0.33  0001666700
# 7                     9    1998-07-10             3.00  0001744489
# 8                    12    2000-05-08             3.00  0000040545
# 9                    12           NaT              NaN  0000886982
# 10                    1    1999-12-31             1.50  0000354950
# 11                   12    1999-05-27             2.00  0000051143
# 12                   12    2000-07-31             2.00  0000050863
# 13                   12    2001-06-13             2.00  0000200406
# 14                   12    2000-06-12             1.50  0000019617
# 15                   12    2012-08-13             2.00  0000021344
# 16                   12    1999-03-08             2.00  0000063908
# 17                   12    2003-09-30             2.00  0000066740
# 18                   12    1999-02-17             2.00  0000310158
# 19                    6    2003-02-18             2.00  0000789019
# 20                    5    2015-12-24             2.00  0000320187
# 21                   12    1999-07-01             3.00  0000078003
# 22                    6    2004-06-21             2.00  0000080424
# 23                   12    1998-05-12             2.00  0000086312
# 24                   12    2005-05-31             2.00  0000731766
# 25                   12    2005-06-13             2.00  0000101829
# 26                    9    2015-03-19             4.00  0001403161
# 27                   12    1998-06-30             2.00  0000732712
# 28                    1    1999-04-20             2.00  0000104169
# 29                   12    2001-07-19             2.00  0000034088
#
#      country_code   country_name  comp_type optionable_flag sp500_member_flag  \
# None
# 0              US  UNITED STATES          1               Y                 Y
# 1              US  UNITED STATES          2               Y                 Y
# 2              US  UNITED STATES          1               Y                 Y
# 3              US  UNITED STATES          1               Y                 Y
# 4              US  UNITED STATES          1               Y                 Y
# 5              US  UNITED STATES          1               Y                 Y
# 6              US  UNITED STATES          1               Y                 Y
# 7              US  UNITED STATES          1               Y                 Y
# 8              US  UNITED STATES          1               Y                 Y
# 9              US  UNITED STATES         10               Y                 Y
# 10             US  UNITED STATES          1               Y                 Y
# 11             US  UNITED STATES          1               Y                 Y
# 12             US  UNITED STATES          1               Y                 Y
# 13             US  UNITED STATES          1               Y                 Y
# 14             US  UNITED STATES          2               Y                 Y
# 15             US  UNITED STATES          1               Y                 Y
# 16             US  UNITED STATES          1               Y                 Y
# 17             US  UNITED STATES          1               Y                 Y
# 18             US  UNITED STATES          1               Y                 Y
# 19             US  UNITED STATES          1               Y                 Y
# 20             US  UNITED STATES          1               Y                 Y
# 21             US  UNITED STATES          1               Y                 Y
# 22             US  UNITED STATES          1               Y                 Y
# 23             US  UNITED STATES          7               Y                 Y
# 24             US  UNITED STATES          1               Y                 Y
# 25             US  UNITED STATES          1               Y                 Y
# 26             US  UNITED STATES          1               Y                 Y
# 27             US  UNITED STATES          6               Y                 Y
# 28             US  UNITED STATES          1               Y                 Y
# 29             US  UNITED STATES          1               Y                 Y
#
#      asset_type
# None
# 0           COM
# 1           COM
# 2           COM
# 3           COM
# 4           COM
# 5           COM
# 6           COM
# 7           COM
# 8           COM
# 9           COM
# 10          COM
# 11          COM
# 12          COM
# 13          COM
# 14          COM
# 15          COM
# 16          COM
# 17          COM
# 18          COM
# 19          COM
# 20          COM
# 21          COM
# 22          COM
# 23          COM
# 24          COM
# 25          COM
# 26          COM
# 27          COM
# 28          COM
# 29          COM

# %%
# Zacks Sales Surprises
    # Z_Sales

Z_Sales = quandl.get_table("ZACKS/SS", paginate=True)
Z_Sales
# Out:
#      m_ticker ticker        comp_name comp_name_2 exchange currency_code  \
# None
# 0        AAPL   AAPL        APPLE INC        None     NSDQ           USD
# 1        AAPL   AAPL        APPLE INC        None     NSDQ           USD
# 2        AAPL   AAPL        APPLE INC        None     NSDQ           USD
# 3        AAPL   AAPL        APPLE INC        None     NSDQ           USD
# 4         AXP    AXP  AMER EXPRESS CO        None     NYSE           USD
# ...       ...    ...              ...         ...      ...           ...
# 115       WMS    WMT      WALMART INC        None     NYSE           USD
# 116         J    XOM  EXXON MOBIL CRP        None     NYSE           USD
# 117         J    XOM  EXXON MOBIL CRP        None     NYSE           USD
# 118         J    XOM  EXXON MOBIL CRP        None     NYSE           USD
# 119         J    XOM  EXXON MOBIL CRP        None     NYSE           USD
#
#      per_end_date per_type per_code  per_fisc_year  per_fisc_qtr  \
# None
# 0      2018-03-31        Q     None           2018             2
# 1      2018-06-30        Q     None           2018             3
# 2      2018-09-30        Q     None           2018             4
# 3      2018-12-31        Q     None           2019             1
# 4      2018-03-31        Q     None           2018             1
# ...           ...      ...      ...            ...           ...
# 115    2018-10-31        Q     None           2019             3
# 116    2018-03-31        Q     None           2018             1
# 117    2018-06-30        Q     None           2018             2
# 118    2018-09-30        Q     None           2018             3
# 119    2018-12-31        Q     None           2018             4
#
#       per_cal_year  per_cal_qtr act_rpt_date last_rev_date  sales_act  \
# None
# 0             2018            1   2018-05-01    2018-04-30    61137.0
# 1             2018            2   2018-07-31    2018-05-02    53265.0
# 2             2018            3   2018-11-01    2018-10-29    62900.0
# 3             2018            4   2019-01-29    2019-01-28    84310.0
# 4             2018            1   2018-04-18    2018-04-17     9718.0
# ...            ...          ...          ...           ...        ...
# 115           2018            4   2018-11-15    2018-11-13   124894.0
# 116           2018            1   2018-04-27    2018-04-24    68211.0
# 117           2018            2   2018-07-27    2018-07-20    73501.0
# 118           2018            3   2018-11-02    2018-10-15    76605.0
# 119           2018            4   2019-02-01    2019-01-13    71895.0
#
#       sales_act_zacks_adj  sales_mean_est  sales_amt_diff_surp  \
# None
# 0                 61137.0        61104.77                32.23
# 1                 53265.0        52367.89               897.11
# 2                 62900.0        61492.30              1407.70
# 3                 84310.0        84071.09               238.91
# 4                  9718.0         9214.39               503.61
# ...                   ...             ...                  ...
# 115              124894.0       124856.10                37.90
# 116               68211.0        66069.73              2141.27
# 117               73501.0        70252.09              3248.91
# 118               76605.0        72454.92              4150.08
# 119               71895.0        74176.77             -2281.77
#
#       sales_pct_diff_surp  sales_cnt_est  sales_std_dev_est act_rpt_time  \
# None
# 0                    0.05              8             593.77        16:30
# 1                    1.71              8             324.76        16:30
# 2                    2.29             10             775.78        16:30
# 3                    0.28              9             224.33        16:30
# 4                    5.47              7             455.36         None
# ...                   ...            ...                ...          ...
# 115                  0.03              6            1012.75        07:02
# 116                  3.24              4            7067.44        08:00
# 117                  4.63              3            1808.86        08:00
# 118                  5.73              3            3710.30        08:00
# 119                 -3.08              3            3871.88        08:00
#
#      act_rpt_code        act_rpt_desc
# None
# 0             AMC  AFTER MARKET CLOSE
# 1             AMC  AFTER MARKET CLOSE
# 2             AMC  AFTER MARKET CLOSE
# 3             AMC  AFTER MARKET CLOSE
# 4            None                None
# ...           ...                 ...
# 115           BTO     BEFORE THE OPEN
# 116           BTO     BEFORE THE OPEN
# 117           BTO     BEFORE THE OPEN
# 118           BTO     BEFORE THE OPEN
# 119           BTO     BEFORE THE OPEN
#
# [120 rows x 25 columns]

# %% [markdown]
# ### Zacks Fundamentals Collection C

# %%
# Zacks Master Table
    # Z_Master_c
    
Z_Master_c=data = quandl.get_table("ZACKS/MT", paginate=True)
Z_Master_c
# Out:
#      m_ticker ticker        comp_name  \
# None
# 0        AAPL   AAPL        APPLE INC
# 1         AXP    AXP  AMER EXPRESS CO
# 2          BA     BA        BOEING CO
# 3         CTR    CAT  CATERPILLAR INC
# 4        CSCO   CSCO    CISCO SYSTEMS
# 5          SD    CVX     CHEVRON CORP
# 6         DOW     DD  DUPONT DE NEMRS
# 7         DIS    DIS      DISNEY WALT
# 8          GE     GE    GENL ELECTRIC
# 9         GS&     GS    GOLDMAN SACHS
# 10       HOMD     HD       HOME DEPOT
# 11        IBM    IBM    INTL BUS MACH
# 12        ITL   INTC       INTEL CORP
# 13        JNJ    JNJ  JOHNSON & JOHNS
# 14        CHL    JPM   JPMORGAN CHASE
# 15         KO     KO     COCA COLA CO
# 16        MCD    MCD   MCDONALDS CORP
# 17        MMM    MMM            3M CO
# 18        MRK    MRK   MERCK & CO INC
# 19       MSFT   MSFT   MICROSOFT CORP
# 20       NIKE    NKE       NIKE INC-B
# 21        PFE    PFE       PFIZER INC
# 22         PG     PG  PROCTER & GAMBL
# 23        SPM    TRV    TRAVELERS COS
# 24       UNIH    UNH  UNITEDHEALTH GP
# 25         UA    UTX   UTD TECHS CORP
# 26       VISA      V       VISA INC-A
# 27        BEL     VZ     VERIZON COMM
# 28        WMS    WMT      WALMART INC
# 29          J    XOM  EXXON MOBIL CRP
#
#                                       comp_name_2 exchange currency_code  \
# None
# 0                                      Apple Inc.     NSDQ           USD
# 1                        American Express Company     NYSE           USD
# 2                              The Boeing Company     NYSE           USD
# 3                                Caterpillar Inc.     NYSE           USD
# 4                             Cisco Systems, Inc.     NSDQ           USD
# 5                             Chevron Corporation     NYSE           USD
# 6                         DuPont de Nemours, Inc.     NYSE           USD
# 7                         The Walt Disney Company     NYSE           USD
# 8                        General Electric Company     NYSE           USD
# 9                   The Goldman Sachs Group, Inc.     NYSE           USD
# 10                           The Home Depot, Inc.     NYSE           USD
# 11    International Business Machines Corporation     NYSE           USD
# 12                              Intel Corporation     NSDQ           USD
# 13                              Johnson & Johnson     NYSE           USD
# 14                           JPMorgan Chase & Co.     NYSE           USD
# 15                        Coca-Cola Company (The)     NYSE           USD
# 16                         McDonald's Corporation     NYSE           USD
# 17                                     3M Company     NYSE           USD
# 18                              Merck & Co., Inc.     NYSE           USD
# 19                          Microsoft Corporation     NSDQ           USD
# 20                                     NIKE, Inc.     NYSE           USD
# 21                                    Pfizer Inc.     NYSE           USD
# 22                 Procter & Gamble Company (The)     NYSE           USD
# 23                  The Travelers Companies, Inc.     NYSE           USD
# 24                UnitedHealth Group Incorporated     NYSE           USD
# 25                United Technologies Corporation     NYSE           USD
# 26                                      Visa Inc.     NYSE           USD
# 27                    Verizon Communications Inc.     NYSE           USD
# 28                                   Walmart Inc.     NYSE           USD
# 29                        Exxon Mobil Corporation     NYSE           USD
#
#      ticker_type active_ticker_flag                             comp_url  \
# None
# 0              S                  Y                 http://www.apple.com
# 1              S                  Y       http://www.americanexpress.com
# 2              S                  Y                http://www.boeing.com
# 3              S                  Y           http://www.caterpillar.com
# 4              S                  Y                 http://www.cisco.com
# 5              S                  Y               http://www.chevron.com
# 6              S                  Y                http://www.dupont.com
# 7              S                  Y  http://www.thewaltdisneycompany.com
# 8              S                  Y                    http://www.ge.com
# 9              S                  Y          http://www.goldmansachs.com
# 10             S                  Y             http://www.homedepot.com
# 11             S                  Y                   http://www.ibm.com
# 12             S                  Y                 http://www.intel.com
# 13             S                  Y                   http://www.jnj.com
# 14             S                  Y         http://www.jpmorganchase.com
# 15             S                  Y      http://www.coca-colacompany.com
# 16             S                  Y              corporate.mcdonalds.com
# 17             S                  Y                    http://www.3m.com
# 18             S                  Y                 http://www.merck.com
# 19             S                  Y             http://www.microsoft.com
# 20             S                  Y                  http://www.nike.com
# 21             S                  Y                http://www.pfizer.com
# 22             S                  Y                    https://us.pg.com
# 23             S                  Y             http://www.travelers.com
# 24             S                  Y     http://www.unitedhealthgroup.com
# 25             S                  Y                   http://www.utc.com
# 26             S                  Y                  http://usa.visa.com
# 27             S                  Y               http://www.verizon.com
# 28             S                  Y         http://www.stock.walmart.com
# 29             S                  Y      http://corporate.exxonmobil.com
#
#       sic_4_code                                         sic_4_desc  \
# None
# 0           3571                               Electronic computers
# 1           6199                  Nondepository credit institutions
# 2           3721                                           Aircraft
# 3           3531                             Construction machinery
# 4           3576                        Computer & office equipment
# 5           2911                                 Petroleum refining
# 6           2821                        Plastics materials & resins
# 7           4841              Cable & other pay television services
# 8           3600  Electronic, electrical equipment & components,...
# 9           6211                         Security brokers & dealers
# 10          5211                  Lumber & other building materials
# 11          3570                        Computer & office equipment
# 12          3674                   Semiconductors & related devices
# 13          2834                        Pharmaceutical preparations
# 14          6021                          National commercial banks
# 15          2080                                          Beverages
# 16          5812                                      Eating places
# 17          3841                     Surgical & medical instruments
# 18          2834                        Pharmaceutical preparations
# 19          7372                               Prepackaged software
# 20          3021                         Rubber & plastics footwear
# 21          2834                        Pharmaceutical preparations
# 22          2840  Soap, detergents, & cleaning preparations; per...
# 23          6331                 Fire, marine, & casualty insurance
# 24          6324                   Hospital & medical service plans
# 25          3724                    Aircraft engines & engine parts
# 26          7389        Business services, not elsewhere classified
# 27          4813              Telephone communication, except radio
# 28          5331                                     Variety stores
# 29          2911                                 Petroleum refining
#
#       zacks_x_ind_code                zacks_x_ind_desc  zacks_x_sector_code  \
# None
# 0                  199                       COMP-MINI                   10
# 1                   69                   FIN-MISC SVCS                   13
# 2                    2                  AEROSP/DEFENSE                   11
# 3                   95                  MACH-CONST/MNG                    7
# 4                  198                   COMP-NETWORKS                   10
# 5                  132                  OIL-INTL INTGD                   12
# 6                   34                  CHEM-DIVERSIFD                    6
# 7                  208                   MEDIA CONGLOM                    2
# 8                   48                 DIVERSIFIED OPS                    9
# 9                   62                 FIN-INVEST BKRS                   13
# 10                  25                 BLDG PRD-RT/WHL                    3
# 11                 203                 COMP-INTEGT SYS                   10
# 12                 241                    SEMI-GENERAL                   10
# 13                 225                Large Cap Pharma                    4
# 14                 204                 BANKS-MJR REGNL                   13
# 15                  20                  BEVERAGES-SOFT                    1
# 16                 160                 RETAIL-RESTRNTS                    3
# 17                  48                 DIVERSIFIED OPS                    9
# 18                 225                Large Cap Pharma                    4
# 19                  44                   COMP-SOFTWARE                   10
# 20                 173                 SHOES&REL APPRL                    2
# 21                 225                Large Cap Pharma                    4
# 22                 174                 SOAP&CLNG PREPS                    1
# 23                  89                 INS-PROP&CASLTY                   13
# 24                 108                         MED-HMO                    4
# 25                  48                 DIVERSIFIED OPS                    9
# 26                 282  Financial Transaction Services                   16
# 27                 238               Wireless National                   10
# 28                 167                 RETAIL-SUPERMKT                    3
# 29                 132                  OIL-INTL INTGD                   12
#
#              zacks_x_sector_desc  zacks_m_ind_code       zacks_m_ind_desc  \
# None
# 0        Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 1                        Finance                48                FINANCE
# 2                      Aerospace                38      AEROSPACE/DEFENSE
# 3            Industrial Products                26              MACHINERY
# 4        Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 5                    Oils/Energy                44         OIL-INTEGRATED
# 6                Basic Materials                19              CHEMICALS
# 7         Consumer Discretionary                10                  MEDIA
# 8     Multi-Sector Conglomerates                30          CONGLOMERATES
# 9                        Finance                50       INVEST BKRS/MGMT
# 10              Retail/Wholesale                14      NONFOOD RETAIL/WH
# 11       Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 12       Computer and Technology                33          ELECTRON-SEMI
# 13                       Medical                15                  DRUGS
# 14                       Finance                46            BANKS-MAJOR
# 15              Consumer Staples                 2              BEVERAGES
# 16              Retail/Wholesale                13      FOOD/DRUG-RTL/WHL
# 17    Multi-Sector Conglomerates                30          CONGLOMERATES
# 18                       Medical                15                  DRUGS
# 19       Computer and Technology                32     COMPUTER SOFT/SERV
# 20        Consumer Discretionary                 1                APPAREL
# 21                       Medical                15                  DRUGS
# 22              Consumer Staples                 5        SOAPS/COSMETICS
# 23                       Finance                49              INSURANCE
# 24                       Medical                16           MEDICAL CARE
# 25    Multi-Sector Conglomerates                30          CONGLOMERATES
# 26             Business Services                59      BUSINESS SERVICES
# 27       Computer and Technology                37          TELECOMM SVCS
# 28              Retail/Wholesale                13      FOOD/DRUG-RTL/WHL
# 29                   Oils/Energy                44         OIL-INTEGRATED
#
#       per_end_month_nbr mr_split_date  mr_split_factor    comp_cik  \
# None
# 0                     9    2014-06-09             7.00  0000320193
# 1                    12    2000-05-11             3.00  0000004962
# 2                    12    1997-06-09             2.00  0000012927
# 3                    12    2005-07-14             2.00  0000018230
# 4                     7    2000-03-23             2.00  0000858877
# 5                    12    2004-09-13             2.00  0000093410
# 6                    12    2019-06-03             0.33  0001666700
# 7                     9    1998-07-10             3.00  0001744489
# 8                    12    2000-05-08             3.00  0000040545
# 9                    12           NaT              NaN  0000886982
# 10                    1    1999-12-31             1.50  0000354950
# 11                   12    1999-05-27             2.00  0000051143
# 12                   12    2000-07-31             2.00  0000050863
# 13                   12    2001-06-13             2.00  0000200406
# 14                   12    2000-06-12             1.50  0000019617
# 15                   12    2012-08-13             2.00  0000021344
# 16                   12    1999-03-08             2.00  0000063908
# 17                   12    2003-09-30             2.00  0000066740
# 18                   12    1999-02-17             2.00  0000310158
# 19                    6    2003-02-18             2.00  0000789019
# 20                    5    2015-12-24             2.00  0000320187
# 21                   12    1999-07-01             3.00  0000078003
# 22                    6    2004-06-21             2.00  0000080424
# 23                   12    1998-05-12             2.00  0000086312
# 24                   12    2005-05-31             2.00  0000731766
# 25                   12    2005-06-13             2.00  0000101829
# 26                    9    2015-03-19             4.00  0001403161
# 27                   12    1998-06-30             2.00  0000732712
# 28                    1    1999-04-20             2.00  0000104169
# 29                   12    2001-07-19             2.00  0000034088
#
#      country_code   country_name  comp_type optionable_flag sp500_member_flag  \
# None
# 0              US  UNITED STATES          1               Y                 Y
# 1              US  UNITED STATES          2               Y                 Y
# 2              US  UNITED STATES          1               Y                 Y
# 3              US  UNITED STATES          1               Y                 Y
# 4              US  UNITED STATES          1               Y                 Y
# 5              US  UNITED STATES          1               Y                 Y
# 6              US  UNITED STATES          1               Y                 Y
# 7              US  UNITED STATES          1               Y                 Y
# 8              US  UNITED STATES          1               Y                 Y
# 9              US  UNITED STATES         10               Y                 Y
# 10             US  UNITED STATES          1               Y                 Y
# 11             US  UNITED STATES          1               Y                 Y
# 12             US  UNITED STATES          1               Y                 Y
# 13             US  UNITED STATES          1               Y                 Y
# 14             US  UNITED STATES          2               Y                 Y
# 15             US  UNITED STATES          1               Y                 Y
# 16             US  UNITED STATES          1               Y                 Y
# 17             US  UNITED STATES          1               Y                 Y
# 18             US  UNITED STATES          1               Y                 Y
# 19             US  UNITED STATES          1               Y                 Y
# 20             US  UNITED STATES          1               Y                 Y
# 21             US  UNITED STATES          1               Y                 Y
# 22             US  UNITED STATES          1               Y                 Y
# 23             US  UNITED STATES          7               Y                 Y
# 24             US  UNITED STATES          1               Y                 Y
# 25             US  UNITED STATES          1               Y                 Y
# 26             US  UNITED STATES          1               Y                 Y
# 27             US  UNITED STATES          6               Y                 Y
# 28             US  UNITED STATES          1               Y                 Y
# 29             US  UNITED STATES          1               Y                 Y
#
#      asset_type
# None
# 0           COM
# 1           COM
# 2           COM
# 3           COM
# 4           COM
# 5           COM
# 6           COM
# 7           COM
# 8           COM
# 9           COM
# 10          COM
# 11          COM
# 12          COM
# 13          COM
# 14          COM
# 15          COM
# 16          COM
# 17          COM
# 18          COM
# 19          COM
# 20          COM
# 21          COM
# 22          COM
# 23          COM
# 24          COM
# 25          COM
# 26          COM
# 27          COM
# 28          COM
# 29          COM

# %%
# Zacks Fundamental Ratios
    # Z_Fund_Ratio_c
    
Z_Fund_Ratio_c=quandl.get_table("ZACKS/FR", paginate=True)
Z_Fund_Ratio_c
# Out:
#      m_ticker ticker        comp_name              comp_name_2 exchange  \
# None
# 0        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 1        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 2        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 3        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 4        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# ...       ...    ...              ...                      ...      ...
# 145         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 146         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 147         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 148         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 149         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
#
#      currency_code per_end_date per_type per_code  per_fisc_year  \
# None
# 0              USD   2018-09-30        A     None           2018
# 1              USD   2018-03-31        Q     None           2018
# 2              USD   2018-06-30        Q     None           2018
# 3              USD   2018-09-30        Q     None           2018
# 4              USD   2018-12-31        Q     None           2019
# ...            ...          ...      ...      ...            ...
# 145            USD   2018-12-31        A     None           2018
# 146            USD   2018-03-31        Q     None           2018
# 147            USD   2018-06-30        Q     None           2018
# 148            USD   2018-09-30        Q     None           2018
# 149            USD   2018-12-31        Q     None           2018
#
#       per_fisc_qtr  per_cal_year  per_cal_qtr  form_7_type  curr_ratio  \
# None
# 0                4          2018            3            7      1.1329
# 1                2          2018            1            7      1.4560
# 2                3          2018            2            7      1.3073
# 3                4          2018            3            7      1.1329
# 4                1          2018            4            7      1.3006
# ...            ...           ...          ...          ...         ...
# 145              4          2018            4            7      0.8396
# 146              1          2018            1            7      0.8012
# 147              2          2018            2            7      0.8096
# 148              3          2018            3            7      0.8267
# 149              4          2018            4            7      0.8396
#
#       non_perform_asset_tot_loan  loan_loss_reserve  lterm_debt_cap  \
# None
# 0                            NaN                NaN          0.4666
# 1                            NaN                NaN          0.4441
# 2                            NaN                NaN          0.4580
# 3                            NaN                NaN          0.4666
# 4                            NaN                NaN          0.4410
# ...                          ...                ...             ...
# 145                          NaN                NaN          0.0938
# 146                          NaN                NaN          0.0963
# 147                          NaN                NaN          0.0967
# 148                          NaN                NaN          0.0948
# 149                          NaN                NaN          0.0938
#
#       tot_debt_tot_equity  gross_margin  oper_profit_margin  ebit_margin  \
# None
# 0                  1.0685       38.3437             26.6940      26.6940
# 1                  0.9603       38.3107             25.9974      25.9974
# 2                  0.9970       38.3385             23.6778      23.6778
# 3                  1.0685       38.2894             25.6248      25.6248
# 4                  0.9732       37.9919             27.6907      27.6907
# ...                   ...           ...                 ...          ...
# 145                0.1904       22.2923             10.6657      10.9296
# 146                0.2084       22.4084             10.6141      10.9132
# 147                0.2130       20.2460              8.8597       9.0597
# 148                0.2034       22.7518             11.8530      12.1141
# 149                0.1904       23.7847             11.2956      11.5947
#
#       ebitda_margin  pretax_profit_margin  profit_margin  free_cash_flow  \
# None
# 0           30.7992               27.4489        22.4142         64121.0
# 1               NaN               26.4455        22.6082         36418.0
# 2               NaN               24.9395        21.6258         47639.0
# 3               NaN               26.1065        22.4563         64121.0
# 4               NaN               28.3549        23.6805         23335.0
# ...             ...                   ...            ...             ...
# 145         17.3887               10.6657         7.1810         16440.0
# 146             NaN               10.6141         6.8171          5170.0
# 147             NaN                8.8597         5.3741          8023.0
# 148             NaN               11.8530         8.1457         13927.0
# 149             NaN               11.2956         8.3455         16440.0
#
#       loss_ratio  exp_ratio  comb_ratio  asset_turn  invty_turn  rcv_turn  \
# None
# 0            NaN        NaN         NaN      0.7262     41.3943    5.4209
# 1            NaN        NaN         NaN      0.1664      4.9223    2.7284
# 2            NaN        NaN         NaN      0.1525      5.5330    2.0201
# 3            NaN        NaN         NaN      0.1720      9.8119    1.2838
# 4            NaN        NaN         NaN      0.2256     10.4810    2.2798
# ...          ...        ...         ...         ...         ...       ...
# 145          NaN        NaN         NaN      0.8383     11.8956       NaN
# 146          NaN        NaN         NaN      0.1955      2.9325       NaN
# 147          NaN        NaN         NaN      0.2107      3.1716       NaN
# 148          NaN        NaN         NaN      0.2160      3.1542       NaN
# 149          NaN        NaN         NaN      0.2077      2.8903       NaN
#
#       day_sale_rcv  ret_equity  ret_tang_equity  ret_asset  ret_invst  \
# None
# 0          67.3325     55.5601          55.5601    16.2775    29.6348
# 1          32.9869     10.8939          10.8939     3.7611     6.0559
# 2          44.5514     10.0210          10.0210     3.2987     5.4315
# 3          70.1041     13.1828          13.1828     3.8622     7.0315
# 4          39.4768     16.9350          16.9350     5.3422     9.4674
# ...            ...         ...              ...        ...        ...
# 145            NaN     10.7899          10.7899     6.1875     9.7783
# 146            NaN      2.4539           2.4539     1.3712     2.2175
# 147            NaN      2.0596           2.0596     1.1428     1.8604
# 148            NaN      3.2749           3.2749     1.8177     2.9643
# 149            NaN      3.1260           3.1260     1.7926     2.8329
#
#       free_cash_flow_per_share  book_val_per_share  oper_cash_flow_per_share
# None
# 0                      12.8239             22.5336                   15.4865
# 1                       7.1852             25.6668                    8.5672
# 2                       9.6697             23.7355                   11.7547
# 3                      12.8239             22.5336                   15.4865
# 4                       4.8887             24.9254                    5.5916
# ...                        ...                 ...                       ...
# 145                     3.8501             46.8558                    8.4342
# 146                     1.2108             46.0347                    1.9951
# 147                     1.8785             45.7093                    3.8162
# 148                     3.2608             46.4882                    6.4170
# 149                     3.8501             46.8558                    8.4342
#
# [150 rows x 40 columns]

# %%
# Zacks Fundamentals Expanded
    # Z_Fund_Exp_C
    
Z_Fund_Exp_C=quandl.get_table("ZACKS/FE", paginate=True)
Z_Fund_Exp_C
# Out:
#      m_ticker ticker        comp_name              comp_name_2 exchange  \
# None
# 0        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 1        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 2        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 3        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 4        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# ...       ...    ...              ...                      ...      ...
# 145         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 146         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 147         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 148         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 149         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
#
#      currency_code per_end_date per_type per_code  per_fisc_year  \
# None
# 0              USD   2018-09-30        A     None           2018
# 1              USD   2018-03-31        Q     None           2018
# 2              USD   2018-06-30        Q     None           2018
# 3              USD   2018-09-30        Q     None           2018
# 4              USD   2018-12-31        Q     None           2019
# ...            ...          ...      ...      ...            ...
# 145            USD   2018-12-31        A     None           2018
# 146            USD   2018-03-31        Q     None           2018
# 147            USD   2018-06-30        Q     None           2018
# 148            USD   2018-09-30        Q     None           2018
# 149            USD   2018-12-31        Q     None           2018
#
#       per_fisc_qtr  per_cal_year  per_cal_qtr filing_type  comp_type acct_std  \
# None
# 0                4          2018            3        10-K          1     None
# 1                2          2018            1        10-Q          1     None
# 2                3          2018            2        10-Q          1     None
# 3                4          2018            3        10-Q          1     None
# 4                1          2018            4        10-Q          1     None
# ...            ...           ...          ...         ...        ...      ...
# 145              4          2018            4        10-K          1     None
# 146              1          2018            1        10-Q          1     None
# 147              2          2018            2        10-Q          1     None
# 148              3          2018            3        10-Q          1     None
# 149              4          2018            4        10-Q          1     None
#
#      exchange_rate_bal exchange_rate_income_stmt exchange_rate_income_type  \
# None
# 0                 None                      None                      None
# 1                 None                      None                      None
# 2                 None                      None                      None
# 3                 None                      None                      None
# 4                 None                      None                      None
# ...                ...                       ...                       ...
# 145               None                      None                      None
# 146               None                      None                      None
# 147               None                      None                      None
# 148               None                      None                      None
# 149               None                      None                      None
#
#      exchange_rate_comp_rpt  zacks_sector_code  zacks_x_ind_code  \
# None
# 0                      None                 10               199
# 1                      None                 10               199
# 2                      None                 10               199
# 3                      None                 10               199
# 4                      None                 10               199
# ...                     ...                ...               ...
# 145                    None                 12               132
# 146                    None                 12               132
# 147                    None                 12               132
# 148                    None                 12               132
# 149                    None                 12               132
#
#       zacks_metrics_ind_code  fye_month  form_5_type  ...  \
# None                                                  ...
# 0                          9          9            5  ...
# 1                          9          9            5  ...
# 2                          9          9            5  ...
# 3                          9          9            5  ...
# 4                          9          9            5  ...
# ...                      ...        ...          ...  ...
# 145                       21         12            5  ...
# 146                       21         12            5  ...
# 147                       21         12            5  ...
# 148                       21         12            5  ...
# 149                       21         12            5  ...
#
#      net_pref_equity_issued_repurch net_tot_equity_issued_repurch  \
# None
# 0                               NaN                      -72069.0
# 1                               NaN                      -32524.0
# 2                               NaN                      -53306.0
# 3                               NaN                      -72069.0
# 4                               NaN                       -8796.0
# ...                             ...                           ...
# 145                             NaN                        -626.0
# 146                             NaN                        -427.0
# 147                             NaN                        -429.0
# 148                             NaN                        -430.0
# 149                             NaN                        -626.0
#
#      comm_stock_div_paid pref_stock_div_paid tot_comm_pref_stock_div_paid  \
# None
# 0               -13712.0                None                     -13712.0
# 1                -6529.0                None                      -6529.0
# 2               -10182.0                None                     -10182.0
# 3               -13712.0                None                     -13712.0
# 4                -3568.0                None                      -3568.0
# ...                  ...                 ...                          ...
# 145             -14041.0                None                     -14041.0
# 146              -3334.0                None                      -3334.0
# 147              -6928.0                None                      -6928.0
# 148             -10488.0                None                     -10488.0
# 149             -14041.0                None                     -14041.0
#
#      fin_activity_other cash_flow_fin_activity fgn_exchange_rate_adj  \
# None
# 0               -2527.0               -87876.0                   NaN
# 1               -1189.0               -33773.0                   NaN
# 2               -2267.0               -65296.0                   NaN
# 3               -2527.0               -87876.0                   NaN
# 4               -1318.0               -13676.0                   NaN
# ...                 ...                    ...                   ...
# 145               146.0               -19446.0                -257.0
# 146               -59.0                -5742.0                  30.0
# 147              -275.0                -8986.0                -105.0
# 148              -374.0               -13945.0                -108.0
# 149               146.0               -19446.0                -257.0
#
#      disc_oper_misc_cash_flow_adj incr_decr_cash beg_cash end_cash  \
# None
# 0                             NaN         5624.0  20289.0  25913.0
# 1                             NaN        24770.0  20289.0  45059.0
# 2                             NaN        11682.0  20289.0  31971.0
# 3                             NaN         5624.0  20289.0  25913.0
# 4                             NaN        18858.0  25913.0  44771.0
# ...                           ...            ...      ...      ...
# 145                           NaN         -135.0   3177.0   3042.0
# 146                           NaN          948.0   3177.0   4125.0
# 147                           NaN          253.0   3177.0   3430.0
# 148                           NaN         2492.0   3177.0   5669.0
# 149                           NaN         -135.0   3177.0   3042.0
#
#      tot_deprec_amort_qd stock_based_compsn_qd cash_flow_oper_activity_qd  \
# None
# 0                    NaN                   NaN                        NaN
# 1                 2739.0                1348.0                    15130.0
# 2                 2665.0                1351.0                    14488.0
# 3                 2754.0                1345.0                    19523.0
# 4                 3395.0                1559.0                    26690.0
# ...                  ...                   ...                        ...
# 145                  NaN                   NaN                        NaN
# 146               4470.0                   NaN                     8519.0
# 147               4589.0                   NaN                     7780.0
# 148               4658.0                   NaN                    11108.0
# 149               5028.0                   NaN                     8607.0
#
#      net_change_prop_plant_equip_qd comm_stock_div_paid_qd  \
# None
# 0                               NaN                    NaN
# 1                           -4195.0                -3190.0
# 2                           -3267.0                -3653.0
# 3                           -3041.0                -3530.0
# 4                           -3355.0                -3568.0
# ...                             ...                    ...
# 145                             NaN                    NaN
# 146                         -3349.0                -3334.0
# 147                         -4927.0                -3594.0
# 148                         -5204.0                -3560.0
# 149                         -6094.0                -3553.0
#
#      pref_stock_div_paid_qd tot_comm_pref_stock_div_qd data_type_ind qtr_nbr  \
# None
# 0                      None                        NaN             F       4
# 1                      None                    -3190.0             F       2
# 2                      None                    -3653.0             F       3
# 3                      None                    -3530.0             F       4
# 4                      None                    -3568.0             F       1
# ...                     ...                        ...           ...     ...
# 145                    None                        NaN             F       4
# 146                    None                    -3334.0             F       1
# 147                    None                    -3594.0             F       2
# 148                    None                    -3560.0             F       3
# 149                    None                    -3553.0             F       4
#
#      basic_net_eps  diluted_net_eps  avg_d_shares  avg_b_shares
# None
# 0            12.01            11.91      5000.109      4955.377
# 1             2.75             2.73      5068.493      5024.877
# 2             2.36             2.34      4926.609      4882.167
# 3             2.94             2.91      4847.547      4801.589
# 4             4.22             4.18      4773.252      4735.820
# ...            ...              ...           ...           ...
# 145           4.88             4.88      4270.000      4270.000
# 146           1.09             1.09      4270.000      4270.000
# 147           0.92             0.92      4271.000      4271.000
# 148           1.46             1.46      4271.000      4271.000
# 149           1.41             1.41      4270.000      4270.000
#
# [150 rows x 635 columns]

# %% [markdown]
# ### Zacks Fundamentals Collection B

# %%
# Zacks Fundamentals Condensed
    #Z_F_C_B

Z_F_C_B = quandl.get_table("ZACKS/FC", paginate=True)
Z_F_C_B
# Out:
#      m_ticker ticker        comp_name              comp_name_2 exchange  \
# None
# 0        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 1        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 2        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 3        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 4        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# ...       ...    ...              ...                      ...      ...
# 145         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 146         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 147         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 148         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 149         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
#
#      currency_code per_end_date per_type per_code  per_fisc_year  \
# None
# 0              USD   2018-09-30        A     None           2018
# 1              USD   2018-03-31        Q     None           2018
# 2              USD   2018-06-30        Q     None           2018
# 3              USD   2018-09-30        Q     None           2018
# 4              USD   2018-12-31        Q     None           2019
# ...            ...          ...      ...      ...            ...
# 145            USD   2018-12-31        A     None           2018
# 146            USD   2018-03-31        Q     None           2018
# 147            USD   2018-06-30        Q     None           2018
# 148            USD   2018-09-30        Q     None           2018
# 149            USD   2018-12-31        Q     None           2018
#
#       per_fisc_qtr  per_cal_year  per_cal_qtr data_type_ind filing_type  \
# None
# 0                4          2018            3             F        10-K
# 1                2          2018            1             F        10-Q
# 2                3          2018            2             F        10-Q
# 3                4          2018            3             F        10-Q
# 4                1          2018            4             F        10-Q
# ...            ...           ...          ...           ...         ...
# 145              4          2018            4             F        10-K
# 146              1          2018            1             F        10-Q
# 147              2          2018            2             F        10-Q
# 148              3          2018            3             F        10-Q
# 149              4          2018            4             F        10-Q
#
#       qtr_nbr  zacks_sector_code  zacks_x_ind_code  zacks_metrics_ind_code  \
# None
# 0        2018                 10               199                       9
# 1      201802                 10               199                       9
# 2      201803                 10               199                       9
# 3      201804                 10               199                       9
# 4      201901                 10               199                       9
# ...       ...                ...               ...                     ...
# 145      2018                 12               132                      21
# 146    201801                 12               132                      21
# 147    201802                 12               132                      21
# 148    201803                 12               132                      21
# 149    201804                 12               132                      21
#
#       fye_month    comp_cik per_len sic_code filing_date last_changed_date  \
# None
# 0             9  0000320193      12     3571  2018-11-05        2018-11-05
# 1             9  0000320193       3     3571  2018-05-02        2018-05-02
# 2             9  0000320193       3     3571  2018-08-01        2018-08-01
# 3             9  0000320193       3     3571  2018-11-05        2018-11-05
# 4             9  0000320193       3     3571  2019-01-30        2019-01-30
# ...         ...         ...     ...      ...         ...               ...
# 145          12  0000034088      12     2911  2019-02-27        2019-02-27
# 146          12  0000034088       3     2911  2018-05-03        2018-05-03
# 147          12  0000034088       3     2911  2018-08-02        2018-08-02
# 148          12  0000034088       3     2911  2018-11-07        2018-11-07
# 149          12  0000034088       3     2911  2019-02-27        2019-02-27
#
#       ... net_comm_equity_issued_repurch net_pref_equity_issued_repurch  \
# None  ...
# 0     ...                       -72069.0                            NaN
# 1     ...                       -32524.0                            NaN
# 2     ...                       -53306.0                            NaN
# 3     ...                       -72069.0                            NaN
# 4     ...                        -8796.0                            NaN
# ...   ...                            ...                            ...
# 145   ...                         -626.0                            NaN
# 146   ...                         -427.0                            NaN
# 147   ...                         -429.0                            NaN
# 148   ...                         -430.0                            NaN
# 149   ...                         -626.0                            NaN
#
#      net_tot_equity_issued_repurch tot_comm_pref_stock_div_paid  \
# None
# 0                         -72069.0                     -13712.0
# 1                         -32524.0                      -6529.0
# 2                         -53306.0                     -10182.0
# 3                         -72069.0                     -13712.0
# 4                          -8796.0                      -3568.0
# ...                            ...                          ...
# 145                         -626.0                     -14041.0
# 146                         -427.0                      -3334.0
# 147                         -429.0                      -6928.0
# 148                         -430.0                     -10488.0
# 149                         -626.0                     -14041.0
#
#      fin_activity_other cash_flow_fin_activity fgn_exchange_rate_adj  \
# None
# 0               -2527.0               -87876.0                   NaN
# 1               -1189.0               -33773.0                   NaN
# 2               -2267.0               -65296.0                   NaN
# 3               -2527.0               -87876.0                   NaN
# 4               -1318.0               -13676.0                   NaN
# ...                 ...                    ...                   ...
# 145               146.0               -19446.0                -257.0
# 146               -59.0                -5742.0                  30.0
# 147              -275.0                -8986.0                -105.0
# 148              -374.0               -13945.0                -108.0
# 149               146.0               -19446.0                -257.0
#
#      disc_oper_misc_cash_flow_adj incr_decr_cash beg_cash end_cash  \
# None
# 0                             NaN         5624.0  20289.0  25913.0
# 1                             NaN        24770.0  20289.0  45059.0
# 2                             NaN        11682.0  20289.0  31971.0
# 3                             NaN         5624.0  20289.0  25913.0
# 4                             NaN        18858.0  25913.0  44771.0
# ...                           ...            ...      ...      ...
# 145                           NaN         -135.0   3177.0   3042.0
# 146                           NaN          948.0   3177.0   4125.0
# 147                           NaN          253.0   3177.0   3430.0
# 148                           NaN         2492.0   3177.0   5669.0
# 149                           NaN         -135.0   3177.0   3042.0
#
#      stock_based_compsn comm_stock_div_paid pref_stock_div_paid  \
# None
# 0                5340.0            -13712.0                None
# 1                2644.0             -6529.0                None
# 2                3995.0            -10182.0                None
# 3                5340.0            -13712.0                None
# 4                1559.0             -3568.0                None
# ...                 ...                 ...                 ...
# 145                 NaN            -14041.0                None
# 146                 NaN             -3334.0                None
# 147                 NaN             -6928.0                None
# 148                 NaN            -10488.0                None
# 149                 NaN            -14041.0                None
#
#       tot_deprec_amort_qd  stock_based_compsn_qd  cash_flow_oper_activity_qd  \
# None
# 0                     NaN                    NaN                         NaN
# 1                  2739.0                 1348.0                     15130.0
# 2                  2665.0                 1351.0                     14488.0
# 3                  2754.0                 1345.0                     19523.0
# 4                  3395.0                 1559.0                     26690.0
# ...                   ...                    ...                         ...
# 145                   NaN                    NaN                         NaN
# 146                4470.0                    NaN                      8519.0
# 147                4589.0                    NaN                      7780.0
# 148                4658.0                    NaN                     11108.0
# 149                5028.0                    NaN                      8607.0
#
#      net_change_prop_plant_equip_qd  comm_stock_div_paid_qd  \
# None
# 0                               NaN                     NaN
# 1                           -4195.0                 -3190.0
# 2                           -3267.0                 -3653.0
# 3                           -3041.0                 -3530.0
# 4                           -3355.0                 -3568.0
# ...                             ...                     ...
# 145                             NaN                     NaN
# 146                         -3349.0                 -3334.0
# 147                         -4927.0                 -3594.0
# 148                         -5204.0                 -3560.0
# 149                         -6094.0                 -3553.0
#
#      pref_stock_div_paid_qd tot_comm_pref_stock_div_qd wavg_shares_out  \
# None
# 0                      None                        NaN        4955.377
# 1                      None                    -3190.0        5024.877
# 2                      None                    -3653.0        4882.167
# 3                      None                    -3530.0        4955.377
# 4                      None                    -3568.0        4735.820
# ...                     ...                        ...             ...
# 145                    None                        NaN        4270.000
# 146                    None                    -3334.0        4270.000
# 147                    None                    -3594.0        4271.000
# 148                    None                    -3560.0        4271.000
# 149                    None                    -3553.0        4270.000
#
#      wavg_shares_out_diluted  eps_basic_net eps_diluted_net
# None
# 0                   5000.109          12.01           11.91
# 1                   5068.493           2.75            2.73
# 2                   4926.609           2.36            2.34
# 3                   5000.109           2.98            2.95
# 4                   4773.252           4.22            4.18
# ...                      ...            ...             ...
# 145                 4270.000           4.88            4.88
# 146                 4270.000           1.09            1.09
# 147                 4271.000           0.92            0.92
# 148                 4271.000           1.46            1.46
# 149                 4270.000           1.41            1.41
#
# [150 rows x 249 columns]

# %%
# Zacks Fundamental Ratios
    # Z_F_R_B
    
Z_F_R_B = quandl.get_table("ZACKS/FR", paginate=True)
Z_F_R_B
# Out:
#      m_ticker ticker        comp_name              comp_name_2 exchange  \
# None
# 0        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 1        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 2        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 3        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 4        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# ...       ...    ...              ...                      ...      ...
# 145         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 146         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 147         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 148         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 149         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
#
#      currency_code per_end_date per_type per_code  per_fisc_year  \
# None
# 0              USD   2018-09-30        A     None           2018
# 1              USD   2018-03-31        Q     None           2018
# 2              USD   2018-06-30        Q     None           2018
# 3              USD   2018-09-30        Q     None           2018
# 4              USD   2018-12-31        Q     None           2019
# ...            ...          ...      ...      ...            ...
# 145            USD   2018-12-31        A     None           2018
# 146            USD   2018-03-31        Q     None           2018
# 147            USD   2018-06-30        Q     None           2018
# 148            USD   2018-09-30        Q     None           2018
# 149            USD   2018-12-31        Q     None           2018
#
#       per_fisc_qtr  per_cal_year  per_cal_qtr  form_7_type  curr_ratio  \
# None
# 0                4          2018            3            7      1.1329
# 1                2          2018            1            7      1.4560
# 2                3          2018            2            7      1.3073
# 3                4          2018            3            7      1.1329
# 4                1          2018            4            7      1.3006
# ...            ...           ...          ...          ...         ...
# 145              4          2018            4            7      0.8396
# 146              1          2018            1            7      0.8012
# 147              2          2018            2            7      0.8096
# 148              3          2018            3            7      0.8267
# 149              4          2018            4            7      0.8396
#
#       non_perform_asset_tot_loan  loan_loss_reserve  lterm_debt_cap  \
# None
# 0                            NaN                NaN          0.4666
# 1                            NaN                NaN          0.4441
# 2                            NaN                NaN          0.4580
# 3                            NaN                NaN          0.4666
# 4                            NaN                NaN          0.4410
# ...                          ...                ...             ...
# 145                          NaN                NaN          0.0938
# 146                          NaN                NaN          0.0963
# 147                          NaN                NaN          0.0967
# 148                          NaN                NaN          0.0948
# 149                          NaN                NaN          0.0938
#
#       tot_debt_tot_equity  gross_margin  oper_profit_margin  ebit_margin  \
# None
# 0                  1.0685       38.3437             26.6940      26.6940
# 1                  0.9603       38.3107             25.9974      25.9974
# 2                  0.9970       38.3385             23.6778      23.6778
# 3                  1.0685       38.2894             25.6248      25.6248
# 4                  0.9732       37.9919             27.6907      27.6907
# ...                   ...           ...                 ...          ...
# 145                0.1904       22.2923             10.6657      10.9296
# 146                0.2084       22.4084             10.6141      10.9132
# 147                0.2130       20.2460              8.8597       9.0597
# 148                0.2034       22.7518             11.8530      12.1141
# 149                0.1904       23.7847             11.2956      11.5947
#
#       ebitda_margin  pretax_profit_margin  profit_margin  free_cash_flow  \
# None
# 0           30.7992               27.4489        22.4142         64121.0
# 1               NaN               26.4455        22.6082         36418.0
# 2               NaN               24.9395        21.6258         47639.0
# 3               NaN               26.1065        22.4563         64121.0
# 4               NaN               28.3549        23.6805         23335.0
# ...             ...                   ...            ...             ...
# 145         17.3887               10.6657         7.1810         16440.0
# 146             NaN               10.6141         6.8171          5170.0
# 147             NaN                8.8597         5.3741          8023.0
# 148             NaN               11.8530         8.1457         13927.0
# 149             NaN               11.2956         8.3455         16440.0
#
#       loss_ratio  exp_ratio  comb_ratio  asset_turn  invty_turn  rcv_turn  \
# None
# 0            NaN        NaN         NaN      0.7262     41.3943    5.4209
# 1            NaN        NaN         NaN      0.1664      4.9223    2.7284
# 2            NaN        NaN         NaN      0.1525      5.5330    2.0201
# 3            NaN        NaN         NaN      0.1720      9.8119    1.2838
# 4            NaN        NaN         NaN      0.2256     10.4810    2.2798
# ...          ...        ...         ...         ...         ...       ...
# 145          NaN        NaN         NaN      0.8383     11.8956       NaN
# 146          NaN        NaN         NaN      0.1955      2.9325       NaN
# 147          NaN        NaN         NaN      0.2107      3.1716       NaN
# 148          NaN        NaN         NaN      0.2160      3.1542       NaN
# 149          NaN        NaN         NaN      0.2077      2.8903       NaN
#
#       day_sale_rcv  ret_equity  ret_tang_equity  ret_asset  ret_invst  \
# None
# 0          67.3325     55.5601          55.5601    16.2775    29.6348
# 1          32.9869     10.8939          10.8939     3.7611     6.0559
# 2          44.5514     10.0210          10.0210     3.2987     5.4315
# 3          70.1041     13.1828          13.1828     3.8622     7.0315
# 4          39.4768     16.9350          16.9350     5.3422     9.4674
# ...            ...         ...              ...        ...        ...
# 145            NaN     10.7899          10.7899     6.1875     9.7783
# 146            NaN      2.4539           2.4539     1.3712     2.2175
# 147            NaN      2.0596           2.0596     1.1428     1.8604
# 148            NaN      3.2749           3.2749     1.8177     2.9643
# 149            NaN      3.1260           3.1260     1.7926     2.8329
#
#       free_cash_flow_per_share  book_val_per_share  oper_cash_flow_per_share
# None
# 0                      12.8239             22.5336                   15.4865
# 1                       7.1852             25.6668                    8.5672
# 2                       9.6697             23.7355                   11.7547
# 3                      12.8239             22.5336                   15.4865
# 4                       4.8887             24.9254                    5.5916
# ...                        ...                 ...                       ...
# 145                     3.8501             46.8558                    8.4342
# 146                     1.2108             46.0347                    1.9951
# 147                     1.8785             45.7093                    3.8162
# 148                     3.2608             46.4882                    6.4170
# 149                     3.8501             46.8558                    8.4342
#
# [150 rows x 40 columns]

# %%
# Zacks Master Table
    # Z_M_T_B
    
Z_M_T_B = quandl.get_table("ZACKS/MT", paginate=True)
Z_M_T_B
# Out:
#      m_ticker ticker        comp_name  \
# None
# 0        AAPL   AAPL        APPLE INC
# 1         AXP    AXP  AMER EXPRESS CO
# 2          BA     BA        BOEING CO
# 3         CTR    CAT  CATERPILLAR INC
# 4        CSCO   CSCO    CISCO SYSTEMS
# 5          SD    CVX     CHEVRON CORP
# 6         DOW     DD  DUPONT DE NEMRS
# 7         DIS    DIS      DISNEY WALT
# 8          GE     GE    GENL ELECTRIC
# 9         GS&     GS    GOLDMAN SACHS
# 10       HOMD     HD       HOME DEPOT
# 11        IBM    IBM    INTL BUS MACH
# 12        ITL   INTC       INTEL CORP
# 13        JNJ    JNJ  JOHNSON & JOHNS
# 14        CHL    JPM   JPMORGAN CHASE
# 15         KO     KO     COCA COLA CO
# 16        MCD    MCD   MCDONALDS CORP
# 17        MMM    MMM            3M CO
# 18        MRK    MRK   MERCK & CO INC
# 19       MSFT   MSFT   MICROSOFT CORP
# 20       NIKE    NKE       NIKE INC-B
# 21        PFE    PFE       PFIZER INC
# 22         PG     PG  PROCTER & GAMBL
# 23        SPM    TRV    TRAVELERS COS
# 24       UNIH    UNH  UNITEDHEALTH GP
# 25         UA    UTX   UTD TECHS CORP
# 26       VISA      V       VISA INC-A
# 27        BEL     VZ     VERIZON COMM
# 28        WMS    WMT      WALMART INC
# 29          J    XOM  EXXON MOBIL CRP
#
#                                       comp_name_2 exchange currency_code  \
# None
# 0                                      Apple Inc.     NSDQ           USD
# 1                        American Express Company     NYSE           USD
# 2                              The Boeing Company     NYSE           USD
# 3                                Caterpillar Inc.     NYSE           USD
# 4                             Cisco Systems, Inc.     NSDQ           USD
# 5                             Chevron Corporation     NYSE           USD
# 6                         DuPont de Nemours, Inc.     NYSE           USD
# 7                         The Walt Disney Company     NYSE           USD
# 8                        General Electric Company     NYSE           USD
# 9                   The Goldman Sachs Group, Inc.     NYSE           USD
# 10                           The Home Depot, Inc.     NYSE           USD
# 11    International Business Machines Corporation     NYSE           USD
# 12                              Intel Corporation     NSDQ           USD
# 13                              Johnson & Johnson     NYSE           USD
# 14                           JPMorgan Chase & Co.     NYSE           USD
# 15                        Coca-Cola Company (The)     NYSE           USD
# 16                         McDonald's Corporation     NYSE           USD
# 17                                     3M Company     NYSE           USD
# 18                              Merck & Co., Inc.     NYSE           USD
# 19                          Microsoft Corporation     NSDQ           USD
# 20                                     NIKE, Inc.     NYSE           USD
# 21                                    Pfizer Inc.     NYSE           USD
# 22                 Procter & Gamble Company (The)     NYSE           USD
# 23                  The Travelers Companies, Inc.     NYSE           USD
# 24                UnitedHealth Group Incorporated     NYSE           USD
# 25                United Technologies Corporation     NYSE           USD
# 26                                      Visa Inc.     NYSE           USD
# 27                    Verizon Communications Inc.     NYSE           USD
# 28                                   Walmart Inc.     NYSE           USD
# 29                        Exxon Mobil Corporation     NYSE           USD
#
#      ticker_type active_ticker_flag                             comp_url  \
# None
# 0              S                  Y                 http://www.apple.com
# 1              S                  Y       http://www.americanexpress.com
# 2              S                  Y                http://www.boeing.com
# 3              S                  Y           http://www.caterpillar.com
# 4              S                  Y                 http://www.cisco.com
# 5              S                  Y               http://www.chevron.com
# 6              S                  Y                http://www.dupont.com
# 7              S                  Y  http://www.thewaltdisneycompany.com
# 8              S                  Y                    http://www.ge.com
# 9              S                  Y          http://www.goldmansachs.com
# 10             S                  Y             http://www.homedepot.com
# 11             S                  Y                   http://www.ibm.com
# 12             S                  Y                 http://www.intel.com
# 13             S                  Y                   http://www.jnj.com
# 14             S                  Y         http://www.jpmorganchase.com
# 15             S                  Y      http://www.coca-colacompany.com
# 16             S                  Y              corporate.mcdonalds.com
# 17             S                  Y                    http://www.3m.com
# 18             S                  Y                 http://www.merck.com
# 19             S                  Y             http://www.microsoft.com
# 20             S                  Y                  http://www.nike.com
# 21             S                  Y                http://www.pfizer.com
# 22             S                  Y                    https://us.pg.com
# 23             S                  Y             http://www.travelers.com
# 24             S                  Y     http://www.unitedhealthgroup.com
# 25             S                  Y                   http://www.utc.com
# 26             S                  Y                  http://usa.visa.com
# 27             S                  Y               http://www.verizon.com
# 28             S                  Y         http://www.stock.walmart.com
# 29             S                  Y      http://corporate.exxonmobil.com
#
#       sic_4_code                                         sic_4_desc  \
# None
# 0           3571                               Electronic computers
# 1           6199                  Nondepository credit institutions
# 2           3721                                           Aircraft
# 3           3531                             Construction machinery
# 4           3576                        Computer & office equipment
# 5           2911                                 Petroleum refining
# 6           2821                        Plastics materials & resins
# 7           4841              Cable & other pay television services
# 8           3600  Electronic, electrical equipment & components,...
# 9           6211                         Security brokers & dealers
# 10          5211                  Lumber & other building materials
# 11          3570                        Computer & office equipment
# 12          3674                   Semiconductors & related devices
# 13          2834                        Pharmaceutical preparations
# 14          6021                          National commercial banks
# 15          2080                                          Beverages
# 16          5812                                      Eating places
# 17          3841                     Surgical & medical instruments
# 18          2834                        Pharmaceutical preparations
# 19          7372                               Prepackaged software
# 20          3021                         Rubber & plastics footwear
# 21          2834                        Pharmaceutical preparations
# 22          2840  Soap, detergents, & cleaning preparations; per...
# 23          6331                 Fire, marine, & casualty insurance
# 24          6324                   Hospital & medical service plans
# 25          3724                    Aircraft engines & engine parts
# 26          7389        Business services, not elsewhere classified
# 27          4813              Telephone communication, except radio
# 28          5331                                     Variety stores
# 29          2911                                 Petroleum refining
#
#       zacks_x_ind_code                zacks_x_ind_desc  zacks_x_sector_code  \
# None
# 0                  199                       COMP-MINI                   10
# 1                   69                   FIN-MISC SVCS                   13
# 2                    2                  AEROSP/DEFENSE                   11
# 3                   95                  MACH-CONST/MNG                    7
# 4                  198                   COMP-NETWORKS                   10
# 5                  132                  OIL-INTL INTGD                   12
# 6                   34                  CHEM-DIVERSIFD                    6
# 7                  208                   MEDIA CONGLOM                    2
# 8                   48                 DIVERSIFIED OPS                    9
# 9                   62                 FIN-INVEST BKRS                   13
# 10                  25                 BLDG PRD-RT/WHL                    3
# 11                 203                 COMP-INTEGT SYS                   10
# 12                 241                    SEMI-GENERAL                   10
# 13                 225                Large Cap Pharma                    4
# 14                 204                 BANKS-MJR REGNL                   13
# 15                  20                  BEVERAGES-SOFT                    1
# 16                 160                 RETAIL-RESTRNTS                    3
# 17                  48                 DIVERSIFIED OPS                    9
# 18                 225                Large Cap Pharma                    4
# 19                  44                   COMP-SOFTWARE                   10
# 20                 173                 SHOES&REL APPRL                    2
# 21                 225                Large Cap Pharma                    4
# 22                 174                 SOAP&CLNG PREPS                    1
# 23                  89                 INS-PROP&CASLTY                   13
# 24                 108                         MED-HMO                    4
# 25                  48                 DIVERSIFIED OPS                    9
# 26                 282  Financial Transaction Services                   16
# 27                 238               Wireless National                   10
# 28                 167                 RETAIL-SUPERMKT                    3
# 29                 132                  OIL-INTL INTGD                   12
#
#              zacks_x_sector_desc  zacks_m_ind_code       zacks_m_ind_desc  \
# None
# 0        Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 1                        Finance                48                FINANCE
# 2                      Aerospace                38      AEROSPACE/DEFENSE
# 3            Industrial Products                26              MACHINERY
# 4        Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 5                    Oils/Energy                44         OIL-INTEGRATED
# 6                Basic Materials                19              CHEMICALS
# 7         Consumer Discretionary                10                  MEDIA
# 8     Multi-Sector Conglomerates                30          CONGLOMERATES
# 9                        Finance                50       INVEST BKRS/MGMT
# 10              Retail/Wholesale                14      NONFOOD RETAIL/WH
# 11       Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 12       Computer and Technology                33          ELECTRON-SEMI
# 13                       Medical                15                  DRUGS
# 14                       Finance                46            BANKS-MAJOR
# 15              Consumer Staples                 2              BEVERAGES
# 16              Retail/Wholesale                13      FOOD/DRUG-RTL/WHL
# 17    Multi-Sector Conglomerates                30          CONGLOMERATES
# 18                       Medical                15                  DRUGS
# 19       Computer and Technology                32     COMPUTER SOFT/SERV
# 20        Consumer Discretionary                 1                APPAREL
# 21                       Medical                15                  DRUGS
# 22              Consumer Staples                 5        SOAPS/COSMETICS
# 23                       Finance                49              INSURANCE
# 24                       Medical                16           MEDICAL CARE
# 25    Multi-Sector Conglomerates                30          CONGLOMERATES
# 26             Business Services                59      BUSINESS SERVICES
# 27       Computer and Technology                37          TELECOMM SVCS
# 28              Retail/Wholesale                13      FOOD/DRUG-RTL/WHL
# 29                   Oils/Energy                44         OIL-INTEGRATED
#
#       per_end_month_nbr mr_split_date  mr_split_factor    comp_cik  \
# None
# 0                     9    2014-06-09             7.00  0000320193
# 1                    12    2000-05-11             3.00  0000004962
# 2                    12    1997-06-09             2.00  0000012927
# 3                    12    2005-07-14             2.00  0000018230
# 4                     7    2000-03-23             2.00  0000858877
# 5                    12    2004-09-13             2.00  0000093410
# 6                    12    2019-06-03             0.33  0001666700
# 7                     9    1998-07-10             3.00  0001744489
# 8                    12    2000-05-08             3.00  0000040545
# 9                    12           NaT              NaN  0000886982
# 10                    1    1999-12-31             1.50  0000354950
# 11                   12    1999-05-27             2.00  0000051143
# 12                   12    2000-07-31             2.00  0000050863
# 13                   12    2001-06-13             2.00  0000200406
# 14                   12    2000-06-12             1.50  0000019617
# 15                   12    2012-08-13             2.00  0000021344
# 16                   12    1999-03-08             2.00  0000063908
# 17                   12    2003-09-30             2.00  0000066740
# 18                   12    1999-02-17             2.00  0000310158
# 19                    6    2003-02-18             2.00  0000789019
# 20                    5    2015-12-24             2.00  0000320187
# 21                   12    1999-07-01             3.00  0000078003
# 22                    6    2004-06-21             2.00  0000080424
# 23                   12    1998-05-12             2.00  0000086312
# 24                   12    2005-05-31             2.00  0000731766
# 25                   12    2005-06-13             2.00  0000101829
# 26                    9    2015-03-19             4.00  0001403161
# 27                   12    1998-06-30             2.00  0000732712
# 28                    1    1999-04-20             2.00  0000104169
# 29                   12    2001-07-19             2.00  0000034088
#
#      country_code   country_name  comp_type optionable_flag sp500_member_flag  \
# None
# 0              US  UNITED STATES          1               Y                 Y
# 1              US  UNITED STATES          2               Y                 Y
# 2              US  UNITED STATES          1               Y                 Y
# 3              US  UNITED STATES          1               Y                 Y
# 4              US  UNITED STATES          1               Y                 Y
# 5              US  UNITED STATES          1               Y                 Y
# 6              US  UNITED STATES          1               Y                 Y
# 7              US  UNITED STATES          1               Y                 Y
# 8              US  UNITED STATES          1               Y                 Y
# 9              US  UNITED STATES         10               Y                 Y
# 10             US  UNITED STATES          1               Y                 Y
# 11             US  UNITED STATES          1               Y                 Y
# 12             US  UNITED STATES          1               Y                 Y
# 13             US  UNITED STATES          1               Y                 Y
# 14             US  UNITED STATES          2               Y                 Y
# 15             US  UNITED STATES          1               Y                 Y
# 16             US  UNITED STATES          1               Y                 Y
# 17             US  UNITED STATES          1               Y                 Y
# 18             US  UNITED STATES          1               Y                 Y
# 19             US  UNITED STATES          1               Y                 Y
# 20             US  UNITED STATES          1               Y                 Y
# 21             US  UNITED STATES          1               Y                 Y
# 22             US  UNITED STATES          1               Y                 Y
# 23             US  UNITED STATES          7               Y                 Y
# 24             US  UNITED STATES          1               Y                 Y
# 25             US  UNITED STATES          1               Y                 Y
# 26             US  UNITED STATES          1               Y                 Y
# 27             US  UNITED STATES          6               Y                 Y
# 28             US  UNITED STATES          1               Y                 Y
# 29             US  UNITED STATES          1               Y                 Y
#
#      asset_type
# None
# 0           COM
# 1           COM
# 2           COM
# 3           COM
# 4           COM
# 5           COM
# 6           COM
# 7           COM
# 8           COM
# 9           COM
# 10          COM
# 11          COM
# 12          COM
# 13          COM
# 14          COM
# 15          COM
# 16          COM
# 17          COM
# 18          COM
# 19          COM
# 20          COM
# 21          COM
# 22          COM
# 23          COM
# 24          COM
# 25          COM
# 26          COM
# 27          COM
# 28          COM
# 29          COM

# %% [markdown]
# ### Zacks Fundamentals Collection A

# %%
# Zacks Fundamentals Condensed
    # Z_F_C_A
    
Z_F_C_A = quandl.get_table("ZACKS/FC", paginate=True)
Z_F_C_A
# Out:
#      m_ticker ticker        comp_name              comp_name_2 exchange  \
# None
# 0        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 1        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 2        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 3        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 4        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# ...       ...    ...              ...                      ...      ...
# 145         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 146         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 147         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 148         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 149         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
#
#      currency_code per_end_date per_type per_code  per_fisc_year  \
# None
# 0              USD   2018-09-30        A     None           2018
# 1              USD   2018-03-31        Q     None           2018
# 2              USD   2018-06-30        Q     None           2018
# 3              USD   2018-09-30        Q     None           2018
# 4              USD   2018-12-31        Q     None           2019
# ...            ...          ...      ...      ...            ...
# 145            USD   2018-12-31        A     None           2018
# 146            USD   2018-03-31        Q     None           2018
# 147            USD   2018-06-30        Q     None           2018
# 148            USD   2018-09-30        Q     None           2018
# 149            USD   2018-12-31        Q     None           2018
#
#       per_fisc_qtr  per_cal_year  per_cal_qtr data_type_ind filing_type  \
# None
# 0                4          2018            3             F        10-K
# 1                2          2018            1             F        10-Q
# 2                3          2018            2             F        10-Q
# 3                4          2018            3             F        10-Q
# 4                1          2018            4             F        10-Q
# ...            ...           ...          ...           ...         ...
# 145              4          2018            4             F        10-K
# 146              1          2018            1             F        10-Q
# 147              2          2018            2             F        10-Q
# 148              3          2018            3             F        10-Q
# 149              4          2018            4             F        10-Q
#
#       qtr_nbr  zacks_sector_code  zacks_x_ind_code  zacks_metrics_ind_code  \
# None
# 0        2018                 10               199                       9
# 1      201802                 10               199                       9
# 2      201803                 10               199                       9
# 3      201804                 10               199                       9
# 4      201901                 10               199                       9
# ...       ...                ...               ...                     ...
# 145      2018                 12               132                      21
# 146    201801                 12               132                      21
# 147    201802                 12               132                      21
# 148    201803                 12               132                      21
# 149    201804                 12               132                      21
#
#       fye_month    comp_cik per_len sic_code filing_date last_changed_date  \
# None
# 0             9  0000320193      12     3571  2018-11-05        2018-11-05
# 1             9  0000320193       3     3571  2018-05-02        2018-05-02
# 2             9  0000320193       3     3571  2018-08-01        2018-08-01
# 3             9  0000320193       3     3571  2018-11-05        2018-11-05
# 4             9  0000320193       3     3571  2019-01-30        2019-01-30
# ...         ...         ...     ...      ...         ...               ...
# 145          12  0000034088      12     2911  2019-02-27        2019-02-27
# 146          12  0000034088       3     2911  2018-05-03        2018-05-03
# 147          12  0000034088       3     2911  2018-08-02        2018-08-02
# 148          12  0000034088       3     2911  2018-11-07        2018-11-07
# 149          12  0000034088       3     2911  2019-02-27        2019-02-27
#
#       ... net_comm_equity_issued_repurch net_pref_equity_issued_repurch  \
# None  ...
# 0     ...                       -72069.0                            NaN
# 1     ...                       -32524.0                            NaN
# 2     ...                       -53306.0                            NaN
# 3     ...                       -72069.0                            NaN
# 4     ...                        -8796.0                            NaN
# ...   ...                            ...                            ...
# 145   ...                         -626.0                            NaN
# 146   ...                         -427.0                            NaN
# 147   ...                         -429.0                            NaN
# 148   ...                         -430.0                            NaN
# 149   ...                         -626.0                            NaN
#
#      net_tot_equity_issued_repurch tot_comm_pref_stock_div_paid  \
# None
# 0                         -72069.0                     -13712.0
# 1                         -32524.0                      -6529.0
# 2                         -53306.0                     -10182.0
# 3                         -72069.0                     -13712.0
# 4                          -8796.0                      -3568.0
# ...                            ...                          ...
# 145                         -626.0                     -14041.0
# 146                         -427.0                      -3334.0
# 147                         -429.0                      -6928.0
# 148                         -430.0                     -10488.0
# 149                         -626.0                     -14041.0
#
#      fin_activity_other cash_flow_fin_activity fgn_exchange_rate_adj  \
# None
# 0               -2527.0               -87876.0                   NaN
# 1               -1189.0               -33773.0                   NaN
# 2               -2267.0               -65296.0                   NaN
# 3               -2527.0               -87876.0                   NaN
# 4               -1318.0               -13676.0                   NaN
# ...                 ...                    ...                   ...
# 145               146.0               -19446.0                -257.0
# 146               -59.0                -5742.0                  30.0
# 147              -275.0                -8986.0                -105.0
# 148              -374.0               -13945.0                -108.0
# 149               146.0               -19446.0                -257.0
#
#      disc_oper_misc_cash_flow_adj incr_decr_cash beg_cash end_cash  \
# None
# 0                             NaN         5624.0  20289.0  25913.0
# 1                             NaN        24770.0  20289.0  45059.0
# 2                             NaN        11682.0  20289.0  31971.0
# 3                             NaN         5624.0  20289.0  25913.0
# 4                             NaN        18858.0  25913.0  44771.0
# ...                           ...            ...      ...      ...
# 145                           NaN         -135.0   3177.0   3042.0
# 146                           NaN          948.0   3177.0   4125.0
# 147                           NaN          253.0   3177.0   3430.0
# 148                           NaN         2492.0   3177.0   5669.0
# 149                           NaN         -135.0   3177.0   3042.0
#
#      stock_based_compsn comm_stock_div_paid pref_stock_div_paid  \
# None
# 0                5340.0            -13712.0                None
# 1                2644.0             -6529.0                None
# 2                3995.0            -10182.0                None
# 3                5340.0            -13712.0                None
# 4                1559.0             -3568.0                None
# ...                 ...                 ...                 ...
# 145                 NaN            -14041.0                None
# 146                 NaN             -3334.0                None
# 147                 NaN             -6928.0                None
# 148                 NaN            -10488.0                None
# 149                 NaN            -14041.0                None
#
#       tot_deprec_amort_qd  stock_based_compsn_qd  cash_flow_oper_activity_qd  \
# None
# 0                     NaN                    NaN                         NaN
# 1                  2739.0                 1348.0                     15130.0
# 2                  2665.0                 1351.0                     14488.0
# 3                  2754.0                 1345.0                     19523.0
# 4                  3395.0                 1559.0                     26690.0
# ...                   ...                    ...                         ...
# 145                   NaN                    NaN                         NaN
# 146                4470.0                    NaN                      8519.0
# 147                4589.0                    NaN                      7780.0
# 148                4658.0                    NaN                     11108.0
# 149                5028.0                    NaN                      8607.0
#
#      net_change_prop_plant_equip_qd  comm_stock_div_paid_qd  \
# None
# 0                               NaN                     NaN
# 1                           -4195.0                 -3190.0
# 2                           -3267.0                 -3653.0
# 3                           -3041.0                 -3530.0
# 4                           -3355.0                 -3568.0
# ...                             ...                     ...
# 145                             NaN                     NaN
# 146                         -3349.0                 -3334.0
# 147                         -4927.0                 -3594.0
# 148                         -5204.0                 -3560.0
# 149                         -6094.0                 -3553.0
#
#      pref_stock_div_paid_qd tot_comm_pref_stock_div_qd wavg_shares_out  \
# None
# 0                      None                        NaN        4955.377
# 1                      None                    -3190.0        5024.877
# 2                      None                    -3653.0        4882.167
# 3                      None                    -3530.0        4955.377
# 4                      None                    -3568.0        4735.820
# ...                     ...                        ...             ...
# 145                    None                        NaN        4270.000
# 146                    None                    -3334.0        4270.000
# 147                    None                    -3594.0        4271.000
# 148                    None                    -3560.0        4271.000
# 149                    None                    -3553.0        4270.000
#
#      wavg_shares_out_diluted  eps_basic_net eps_diluted_net
# None
# 0                   5000.109          12.01           11.91
# 1                   5068.493           2.75            2.73
# 2                   4926.609           2.36            2.34
# 3                   5000.109           2.98            2.95
# 4                   4773.252           4.22            4.18
# ...                      ...            ...             ...
# 145                 4270.000           4.88            4.88
# 146                 4270.000           1.09            1.09
# 147                 4271.000           0.92            0.92
# 148                 4271.000           1.46            1.46
# 149                 4270.000           1.41            1.41
#
# [150 rows x 249 columns]

# %%
# Zacks Fundamental Ratios
    # Z_F_R_A
    
Z_F_R_A = quandl.get_table("ZACKS/FR", paginate=True)
Z_F_R_A
# Out:
#      m_ticker ticker        comp_name              comp_name_2 exchange  \
# None
# 0        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 1        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 2        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 3        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 4        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# ...       ...    ...              ...                      ...      ...
# 145         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 146         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 147         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 148         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 149         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
#
#      currency_code per_end_date per_type per_code  per_fisc_year  \
# None
# 0              USD   2018-09-30        A     None           2018
# 1              USD   2018-03-31        Q     None           2018
# 2              USD   2018-06-30        Q     None           2018
# 3              USD   2018-09-30        Q     None           2018
# 4              USD   2018-12-31        Q     None           2019
# ...            ...          ...      ...      ...            ...
# 145            USD   2018-12-31        A     None           2018
# 146            USD   2018-03-31        Q     None           2018
# 147            USD   2018-06-30        Q     None           2018
# 148            USD   2018-09-30        Q     None           2018
# 149            USD   2018-12-31        Q     None           2018
#
#       per_fisc_qtr  per_cal_year  per_cal_qtr  form_7_type  curr_ratio  \
# None
# 0                4          2018            3            7      1.1329
# 1                2          2018            1            7      1.4560
# 2                3          2018            2            7      1.3073
# 3                4          2018            3            7      1.1329
# 4                1          2018            4            7      1.3006
# ...            ...           ...          ...          ...         ...
# 145              4          2018            4            7      0.8396
# 146              1          2018            1            7      0.8012
# 147              2          2018            2            7      0.8096
# 148              3          2018            3            7      0.8267
# 149              4          2018            4            7      0.8396
#
#       non_perform_asset_tot_loan  loan_loss_reserve  lterm_debt_cap  \
# None
# 0                            NaN                NaN          0.4666
# 1                            NaN                NaN          0.4441
# 2                            NaN                NaN          0.4580
# 3                            NaN                NaN          0.4666
# 4                            NaN                NaN          0.4410
# ...                          ...                ...             ...
# 145                          NaN                NaN          0.0938
# 146                          NaN                NaN          0.0963
# 147                          NaN                NaN          0.0967
# 148                          NaN                NaN          0.0948
# 149                          NaN                NaN          0.0938
#
#       tot_debt_tot_equity  gross_margin  oper_profit_margin  ebit_margin  \
# None
# 0                  1.0685       38.3437             26.6940      26.6940
# 1                  0.9603       38.3107             25.9974      25.9974
# 2                  0.9970       38.3385             23.6778      23.6778
# 3                  1.0685       38.2894             25.6248      25.6248
# 4                  0.9732       37.9919             27.6907      27.6907
# ...                   ...           ...                 ...          ...
# 145                0.1904       22.2923             10.6657      10.9296
# 146                0.2084       22.4084             10.6141      10.9132
# 147                0.2130       20.2460              8.8597       9.0597
# 148                0.2034       22.7518             11.8530      12.1141
# 149                0.1904       23.7847             11.2956      11.5947
#
#       ebitda_margin  pretax_profit_margin  profit_margin  free_cash_flow  \
# None
# 0           30.7992               27.4489        22.4142         64121.0
# 1               NaN               26.4455        22.6082         36418.0
# 2               NaN               24.9395        21.6258         47639.0
# 3               NaN               26.1065        22.4563         64121.0
# 4               NaN               28.3549        23.6805         23335.0
# ...             ...                   ...            ...             ...
# 145         17.3887               10.6657         7.1810         16440.0
# 146             NaN               10.6141         6.8171          5170.0
# 147             NaN                8.8597         5.3741          8023.0
# 148             NaN               11.8530         8.1457         13927.0
# 149             NaN               11.2956         8.3455         16440.0
#
#       loss_ratio  exp_ratio  comb_ratio  asset_turn  invty_turn  rcv_turn  \
# None
# 0            NaN        NaN         NaN      0.7262     41.3943    5.4209
# 1            NaN        NaN         NaN      0.1664      4.9223    2.7284
# 2            NaN        NaN         NaN      0.1525      5.5330    2.0201
# 3            NaN        NaN         NaN      0.1720      9.8119    1.2838
# 4            NaN        NaN         NaN      0.2256     10.4810    2.2798
# ...          ...        ...         ...         ...         ...       ...
# 145          NaN        NaN         NaN      0.8383     11.8956       NaN
# 146          NaN        NaN         NaN      0.1955      2.9325       NaN
# 147          NaN        NaN         NaN      0.2107      3.1716       NaN
# 148          NaN        NaN         NaN      0.2160      3.1542       NaN
# 149          NaN        NaN         NaN      0.2077      2.8903       NaN
#
#       day_sale_rcv  ret_equity  ret_tang_equity  ret_asset  ret_invst  \
# None
# 0          67.3325     55.5601          55.5601    16.2775    29.6348
# 1          32.9869     10.8939          10.8939     3.7611     6.0559
# 2          44.5514     10.0210          10.0210     3.2987     5.4315
# 3          70.1041     13.1828          13.1828     3.8622     7.0315
# 4          39.4768     16.9350          16.9350     5.3422     9.4674
# ...            ...         ...              ...        ...        ...
# 145            NaN     10.7899          10.7899     6.1875     9.7783
# 146            NaN      2.4539           2.4539     1.3712     2.2175
# 147            NaN      2.0596           2.0596     1.1428     1.8604
# 148            NaN      3.2749           3.2749     1.8177     2.9643
# 149            NaN      3.1260           3.1260     1.7926     2.8329
#
#       free_cash_flow_per_share  book_val_per_share  oper_cash_flow_per_share
# None
# 0                      12.8239             22.5336                   15.4865
# 1                       7.1852             25.6668                    8.5672
# 2                       9.6697             23.7355                   11.7547
# 3                      12.8239             22.5336                   15.4865
# 4                       4.8887             24.9254                    5.5916
# ...                        ...                 ...                       ...
# 145                     3.8501             46.8558                    8.4342
# 146                     1.2108             46.0347                    1.9951
# 147                     1.8785             45.7093                    3.8162
# 148                     3.2608             46.4882                    6.4170
# 149                     3.8501             46.8558                    8.4342
#
# [150 rows x 40 columns]

# %%
# Zacks Master Table
    # Z_M_T_A
    
Z_M_T_A = quandl.get_table("ZACKS/MT", paginate=True)
Z_M_T_A
# Out:
#      m_ticker ticker        comp_name  \
# None
# 0        AAPL   AAPL        APPLE INC
# 1         AXP    AXP  AMER EXPRESS CO
# 2          BA     BA        BOEING CO
# 3         CTR    CAT  CATERPILLAR INC
# 4        CSCO   CSCO    CISCO SYSTEMS
# 5          SD    CVX     CHEVRON CORP
# 6         DOW     DD  DUPONT DE NEMRS
# 7         DIS    DIS      DISNEY WALT
# 8          GE     GE    GENL ELECTRIC
# 9         GS&     GS    GOLDMAN SACHS
# 10       HOMD     HD       HOME DEPOT
# 11        IBM    IBM    INTL BUS MACH
# 12        ITL   INTC       INTEL CORP
# 13        JNJ    JNJ  JOHNSON & JOHNS
# 14        CHL    JPM   JPMORGAN CHASE
# 15         KO     KO     COCA COLA CO
# 16        MCD    MCD   MCDONALDS CORP
# 17        MMM    MMM            3M CO
# 18        MRK    MRK   MERCK & CO INC
# 19       MSFT   MSFT   MICROSOFT CORP
# 20       NIKE    NKE       NIKE INC-B
# 21        PFE    PFE       PFIZER INC
# 22         PG     PG  PROCTER & GAMBL
# 23        SPM    TRV    TRAVELERS COS
# 24       UNIH    UNH  UNITEDHEALTH GP
# 25         UA    UTX   UTD TECHS CORP
# 26       VISA      V       VISA INC-A
# 27        BEL     VZ     VERIZON COMM
# 28        WMS    WMT      WALMART INC
# 29          J    XOM  EXXON MOBIL CRP
#
#                                       comp_name_2 exchange currency_code  \
# None
# 0                                      Apple Inc.     NSDQ           USD
# 1                        American Express Company     NYSE           USD
# 2                              The Boeing Company     NYSE           USD
# 3                                Caterpillar Inc.     NYSE           USD
# 4                             Cisco Systems, Inc.     NSDQ           USD
# 5                             Chevron Corporation     NYSE           USD
# 6                         DuPont de Nemours, Inc.     NYSE           USD
# 7                         The Walt Disney Company     NYSE           USD
# 8                        General Electric Company     NYSE           USD
# 9                   The Goldman Sachs Group, Inc.     NYSE           USD
# 10                           The Home Depot, Inc.     NYSE           USD
# 11    International Business Machines Corporation     NYSE           USD
# 12                              Intel Corporation     NSDQ           USD
# 13                              Johnson & Johnson     NYSE           USD
# 14                           JPMorgan Chase & Co.     NYSE           USD
# 15                        Coca-Cola Company (The)     NYSE           USD
# 16                         McDonald's Corporation     NYSE           USD
# 17                                     3M Company     NYSE           USD
# 18                              Merck & Co., Inc.     NYSE           USD
# 19                          Microsoft Corporation     NSDQ           USD
# 20                                     NIKE, Inc.     NYSE           USD
# 21                                    Pfizer Inc.     NYSE           USD
# 22                 Procter & Gamble Company (The)     NYSE           USD
# 23                  The Travelers Companies, Inc.     NYSE           USD
# 24                UnitedHealth Group Incorporated     NYSE           USD
# 25                United Technologies Corporation     NYSE           USD
# 26                                      Visa Inc.     NYSE           USD
# 27                    Verizon Communications Inc.     NYSE           USD
# 28                                   Walmart Inc.     NYSE           USD
# 29                        Exxon Mobil Corporation     NYSE           USD
#
#      ticker_type active_ticker_flag                             comp_url  \
# None
# 0              S                  Y                 http://www.apple.com
# 1              S                  Y       http://www.americanexpress.com
# 2              S                  Y                http://www.boeing.com
# 3              S                  Y           http://www.caterpillar.com
# 4              S                  Y                 http://www.cisco.com
# 5              S                  Y               http://www.chevron.com
# 6              S                  Y                http://www.dupont.com
# 7              S                  Y  http://www.thewaltdisneycompany.com
# 8              S                  Y                    http://www.ge.com
# 9              S                  Y          http://www.goldmansachs.com
# 10             S                  Y             http://www.homedepot.com
# 11             S                  Y                   http://www.ibm.com
# 12             S                  Y                 http://www.intel.com
# 13             S                  Y                   http://www.jnj.com
# 14             S                  Y         http://www.jpmorganchase.com
# 15             S                  Y      http://www.coca-colacompany.com
# 16             S                  Y              corporate.mcdonalds.com
# 17             S                  Y                    http://www.3m.com
# 18             S                  Y                 http://www.merck.com
# 19             S                  Y             http://www.microsoft.com
# 20             S                  Y                  http://www.nike.com
# 21             S                  Y                http://www.pfizer.com
# 22             S                  Y                    https://us.pg.com
# 23             S                  Y             http://www.travelers.com
# 24             S                  Y     http://www.unitedhealthgroup.com
# 25             S                  Y                   http://www.utc.com
# 26             S                  Y                  http://usa.visa.com
# 27             S                  Y               http://www.verizon.com
# 28             S                  Y         http://www.stock.walmart.com
# 29             S                  Y      http://corporate.exxonmobil.com
#
#       sic_4_code                                         sic_4_desc  \
# None
# 0           3571                               Electronic computers
# 1           6199                  Nondepository credit institutions
# 2           3721                                           Aircraft
# 3           3531                             Construction machinery
# 4           3576                        Computer & office equipment
# 5           2911                                 Petroleum refining
# 6           2821                        Plastics materials & resins
# 7           4841              Cable & other pay television services
# 8           3600  Electronic, electrical equipment & components,...
# 9           6211                         Security brokers & dealers
# 10          5211                  Lumber & other building materials
# 11          3570                        Computer & office equipment
# 12          3674                   Semiconductors & related devices
# 13          2834                        Pharmaceutical preparations
# 14          6021                          National commercial banks
# 15          2080                                          Beverages
# 16          5812                                      Eating places
# 17          3841                     Surgical & medical instruments
# 18          2834                        Pharmaceutical preparations
# 19          7372                               Prepackaged software
# 20          3021                         Rubber & plastics footwear
# 21          2834                        Pharmaceutical preparations
# 22          2840  Soap, detergents, & cleaning preparations; per...
# 23          6331                 Fire, marine, & casualty insurance
# 24          6324                   Hospital & medical service plans
# 25          3724                    Aircraft engines & engine parts
# 26          7389        Business services, not elsewhere classified
# 27          4813              Telephone communication, except radio
# 28          5331                                     Variety stores
# 29          2911                                 Petroleum refining
#
#       zacks_x_ind_code                zacks_x_ind_desc  zacks_x_sector_code  \
# None
# 0                  199                       COMP-MINI                   10
# 1                   69                   FIN-MISC SVCS                   13
# 2                    2                  AEROSP/DEFENSE                   11
# 3                   95                  MACH-CONST/MNG                    7
# 4                  198                   COMP-NETWORKS                   10
# 5                  132                  OIL-INTL INTGD                   12
# 6                   34                  CHEM-DIVERSIFD                    6
# 7                  208                   MEDIA CONGLOM                    2
# 8                   48                 DIVERSIFIED OPS                    9
# 9                   62                 FIN-INVEST BKRS                   13
# 10                  25                 BLDG PRD-RT/WHL                    3
# 11                 203                 COMP-INTEGT SYS                   10
# 12                 241                    SEMI-GENERAL                   10
# 13                 225                Large Cap Pharma                    4
# 14                 204                 BANKS-MJR REGNL                   13
# 15                  20                  BEVERAGES-SOFT                    1
# 16                 160                 RETAIL-RESTRNTS                    3
# 17                  48                 DIVERSIFIED OPS                    9
# 18                 225                Large Cap Pharma                    4
# 19                  44                   COMP-SOFTWARE                   10
# 20                 173                 SHOES&REL APPRL                    2
# 21                 225                Large Cap Pharma                    4
# 22                 174                 SOAP&CLNG PREPS                    1
# 23                  89                 INS-PROP&CASLTY                   13
# 24                 108                         MED-HMO                    4
# 25                  48                 DIVERSIFIED OPS                    9
# 26                 282  Financial Transaction Services                   16
# 27                 238               Wireless National                   10
# 28                 167                 RETAIL-SUPERMKT                    3
# 29                 132                  OIL-INTL INTGD                   12
#
#              zacks_x_sector_desc  zacks_m_ind_code       zacks_m_ind_desc  \
# None
# 0        Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 1                        Finance                48                FINANCE
# 2                      Aerospace                38      AEROSPACE/DEFENSE
# 3            Industrial Products                26              MACHINERY
# 4        Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 5                    Oils/Energy                44         OIL-INTEGRATED
# 6                Basic Materials                19              CHEMICALS
# 7         Consumer Discretionary                10                  MEDIA
# 8     Multi-Sector Conglomerates                30          CONGLOMERATES
# 9                        Finance                50       INVEST BKRS/MGMT
# 10              Retail/Wholesale                14      NONFOOD RETAIL/WH
# 11       Computer and Technology                31  COMPUTER/OFFICE EQUIP
# 12       Computer and Technology                33          ELECTRON-SEMI
# 13                       Medical                15                  DRUGS
# 14                       Finance                46            BANKS-MAJOR
# 15              Consumer Staples                 2              BEVERAGES
# 16              Retail/Wholesale                13      FOOD/DRUG-RTL/WHL
# 17    Multi-Sector Conglomerates                30          CONGLOMERATES
# 18                       Medical                15                  DRUGS
# 19       Computer and Technology                32     COMPUTER SOFT/SERV
# 20        Consumer Discretionary                 1                APPAREL
# 21                       Medical                15                  DRUGS
# 22              Consumer Staples                 5        SOAPS/COSMETICS
# 23                       Finance                49              INSURANCE
# 24                       Medical                16           MEDICAL CARE
# 25    Multi-Sector Conglomerates                30          CONGLOMERATES
# 26             Business Services                59      BUSINESS SERVICES
# 27       Computer and Technology                37          TELECOMM SVCS
# 28              Retail/Wholesale                13      FOOD/DRUG-RTL/WHL
# 29                   Oils/Energy                44         OIL-INTEGRATED
#
#       per_end_month_nbr mr_split_date  mr_split_factor    comp_cik  \
# None
# 0                     9    2014-06-09             7.00  0000320193
# 1                    12    2000-05-11             3.00  0000004962
# 2                    12    1997-06-09             2.00  0000012927
# 3                    12    2005-07-14             2.00  0000018230
# 4                     7    2000-03-23             2.00  0000858877
# 5                    12    2004-09-13             2.00  0000093410
# 6                    12    2019-06-03             0.33  0001666700
# 7                     9    1998-07-10             3.00  0001744489
# 8                    12    2000-05-08             3.00  0000040545
# 9                    12           NaT              NaN  0000886982
# 10                    1    1999-12-31             1.50  0000354950
# 11                   12    1999-05-27             2.00  0000051143
# 12                   12    2000-07-31             2.00  0000050863
# 13                   12    2001-06-13             2.00  0000200406
# 14                   12    2000-06-12             1.50  0000019617
# 15                   12    2012-08-13             2.00  0000021344
# 16                   12    1999-03-08             2.00  0000063908
# 17                   12    2003-09-30             2.00  0000066740
# 18                   12    1999-02-17             2.00  0000310158
# 19                    6    2003-02-18             2.00  0000789019
# 20                    5    2015-12-24             2.00  0000320187
# 21                   12    1999-07-01             3.00  0000078003
# 22                    6    2004-06-21             2.00  0000080424
# 23                   12    1998-05-12             2.00  0000086312
# 24                   12    2005-05-31             2.00  0000731766
# 25                   12    2005-06-13             2.00  0000101829
# 26                    9    2015-03-19             4.00  0001403161
# 27                   12    1998-06-30             2.00  0000732712
# 28                    1    1999-04-20             2.00  0000104169
# 29                   12    2001-07-19             2.00  0000034088
#
#      country_code   country_name  comp_type optionable_flag sp500_member_flag  \
# None
# 0              US  UNITED STATES          1               Y                 Y
# 1              US  UNITED STATES          2               Y                 Y
# 2              US  UNITED STATES          1               Y                 Y
# 3              US  UNITED STATES          1               Y                 Y
# 4              US  UNITED STATES          1               Y                 Y
# 5              US  UNITED STATES          1               Y                 Y
# 6              US  UNITED STATES          1               Y                 Y
# 7              US  UNITED STATES          1               Y                 Y
# 8              US  UNITED STATES          1               Y                 Y
# 9              US  UNITED STATES         10               Y                 Y
# 10             US  UNITED STATES          1               Y                 Y
# 11             US  UNITED STATES          1               Y                 Y
# 12             US  UNITED STATES          1               Y                 Y
# 13             US  UNITED STATES          1               Y                 Y
# 14             US  UNITED STATES          2               Y                 Y
# 15             US  UNITED STATES          1               Y                 Y
# 16             US  UNITED STATES          1               Y                 Y
# 17             US  UNITED STATES          1               Y                 Y
# 18             US  UNITED STATES          1               Y                 Y
# 19             US  UNITED STATES          1               Y                 Y
# 20             US  UNITED STATES          1               Y                 Y
# 21             US  UNITED STATES          1               Y                 Y
# 22             US  UNITED STATES          1               Y                 Y
# 23             US  UNITED STATES          7               Y                 Y
# 24             US  UNITED STATES          1               Y                 Y
# 25             US  UNITED STATES          1               Y                 Y
# 26             US  UNITED STATES          1               Y                 Y
# 27             US  UNITED STATES          6               Y                 Y
# 28             US  UNITED STATES          1               Y                 Y
# 29             US  UNITED STATES          1               Y                 Y
#
#      asset_type
# None
# 0           COM
# 1           COM
# 2           COM
# 3           COM
# 4           COM
# 5           COM
# 6           COM
# 7           COM
# 8           COM
# 9           COM
# 10          COM
# 11          COM
# 12          COM
# 13          COM
# 14          COM
# 15          COM
# 16          COM
# 17          COM
# 18          COM
# 19          COM
# 20          COM
# 21          COM
# 22          COM
# 23          COM
# 24          COM
# 25          COM
# 26          COM
# 27          COM
# 28          COM
# 29          COM

# %% [markdown]
# ### Sharadar Core US Equities Bundle

# %%
# Core US Fundamentals
    # Core_US_Fundamentals
    
Core_US_Fundamentals = quandl.get_table("SHARADAR/SF1", paginate=True)
Core_US_Fundamentals
# Out:
#      ticker dimension calendardate    datekey reportperiod lastupdated  \
# None
# 0       XOM       MRY   2018-12-31 2018-12-31   2018-12-31  2020-02-26
# 1       XOM       MRY   2017-12-31 2017-12-31   2017-12-31  2020-02-26
# 2       XOM       MRY   2016-12-31 2016-12-31   2016-12-31  2020-02-26
# 3       XOM       MRY   2015-12-31 2015-12-31   2015-12-31  2020-02-26
# 4       XOM       MRY   2014-12-31 2014-12-31   2014-12-31  2020-02-26
# ...     ...       ...          ...        ...          ...         ...
# 243    AAPL       MRY   2015-12-31 2015-09-26   2015-09-26  2020-01-29
# 244    AAPL       MRY   2014-12-31 2014-09-27   2014-09-27  2020-01-29
# 245    AAPL       MRY   2013-12-31 2013-09-28   2013-09-28  2020-01-29
# 246    AAPL       MRY   2012-12-31 2012-09-29   2012-09-29  2020-01-29
# 247    AAPL       MRY   2011-12-31 2011-09-24   2011-09-24  2020-01-29
#
#            accoci        assets     assetsavg       assetsc      assetsnc  \
# None
# 0    -19564000000  346196000000  349610000000  4.797300e+10  2.982230e+11
# 1    -16262000000  348691000000  346334750000  4.713400e+10  3.015570e+11
# 2    -22239000000  330314000000  338740500000  4.141600e+10  2.888980e+11
# 3    -23511000000  336758000000  342160250000  4.262300e+10  2.941350e+11
# 4    -18957000000  349493000000  353469000000  5.291000e+10  2.965830e+11
# ...           ...           ...           ...           ...           ...
# 243    -345000000  290345000000  271646000000  8.937800e+10  2.009670e+11
# 244    1082000000  231839000000  221383000000  6.853100e+10  1.633080e+11
# 245    -471000000  207000000000  199421750000  7.328600e+10  1.337140e+11
# 246     499000000  176064000000  157143750000  5.765300e+10  1.184110e+11
# 247     443000000  116371000000  101193750000  4.498800e+10  7.138300e+10
#
#       assetturnover    bvps        capex      cashneq   cashnequsd  \
# None
# 0             0.830  45.301 -19574000000   3042000000   3042000000
# 1             0.706  44.296 -15402000000   3177000000   3177000000
# 2             0.614  40.351 -16163000000   3657000000   3657000000
# 3             0.728  41.031 -26490000000   3705000000   3705000000
# 4             1.165  41.185 -32952000000   4658000000   4658000000
# ...             ...     ...          ...          ...          ...
# 243           0.860  20.745 -11488000000  21120000000  21120000000
# 244           0.826  18.330  -9813000000  13844000000  13844000000
# 245           0.857  19.074  -9076000000  14259000000  14259000000
# 246           0.996  18.065  -9402000000  10746000000  10746000000
# 247           1.070  11.842  -7452000000   9815000000   9815000000
#
#                cor    consolinc  currentratio     de         debt  \
# None
# 0     188835000000  21421000000         0.840  0.770  37796000000
# 1     158321000000  19848000000         0.816  0.822  42336000000
# 2     133191000000   8375000000         0.869  0.935  42762000000
# 3     160312000000  16551000000         0.790  0.936  38687000000
# 4     287600000000  33615000000         0.819  0.966  29121000000
# ...            ...          ...           ...    ...          ...
# 243   140089000000  53394000000         1.109  1.433  64328000000
# 244   112258000000  39510000000         1.080  1.078  35295000000
# 245   106606000000  37037000000         1.679  0.675  16960000000
# 246    87846000000  41733000000         1.496  0.489            0
# 247    64431000000  25922000000         1.608  0.519            0
#
#              debtc        debtnc      debtusd  deferredrev  ...    price  \
# None                                                        ...
# 0     1.725800e+10  2.053800e+10  37796000000            0  ...   68.190
# 1     1.793000e+10  2.440600e+10  42336000000            0  ...   83.640
# 2     1.383000e+10  2.893200e+10  42762000000            0  ...   90.260
# 3     1.876200e+10  1.992500e+10  38687000000            0  ...   77.950
# 4     1.746800e+10  1.165300e+10  29121000000            0  ...   92.450
# ...            ...           ...          ...          ...  ...      ...
# 243   1.099900e+10  5.332900e+10  64328000000  12564000000  ...  114.710
# 244   6.308000e+09  2.898700e+10  35295000000  11522000000  ...  100.750
# 245   0.000000e+00  1.696000e+10  16960000000  10060000000  ...   68.964
# 246   0.000000e+00  0.000000e+00            0   8601000000  ...   95.301
# 247   0.000000e+00  0.000000e+00            0   5777000000  ...   57.757
#
#          ps    ps1  receivables       retearn       revenue    revenueusd  \
# None
# 0     0.995  0.995  24701000000  421653000000  290212000000  290212000000
# 1     1.450  1.450  25597000000  414540000000  244363000000  244363000000
# 2     1.798  1.798  21394000000  407831000000  208114000000  208114000000
# 3     1.302  1.302  19875000000  412444000000  249248000000  249248000000
# 4     0.950  0.950  28009000000  408384000000  411939000000  411939000000
# ...     ...    ...          ...           ...           ...           ...
# 243   2.799  2.824  30343000000   92284000000  233715000000  233715000000
# 244   3.300  3.354  27219000000   87152000000  182795000000  182795000000
# 245   2.566  2.614  20641000000  104256000000  170910000000  170910000000
# 246   3.996  3.985  18692000000  101289000000  156508000000  156508000000
# 247   3.463  3.452  11717000000   62841000000  108249000000  108249000000
#
#              rnd    roa    roe   roic    ros      sbcomp         sgna  \
# None
# 0     1466000000  0.060  0.110  0.096  0.107           0  11480000000
# 1     1790000000  0.057  0.109  0.058  0.078           0  10649000000
# 2     1467000000  0.023  0.046  0.024  0.038           0  10443000000
# 3     1523000000  0.047  0.094  0.069  0.088           0  11501000000
# 4     1669000000  0.092  0.183  0.167  0.123           0  12598000000
# ...          ...    ...    ...    ...    ...         ...          ...
# 243   8067000000  0.197  0.429  0.322  0.310  3586000000  14329000000
# 244   6041000000  0.178  0.328  0.309  0.293  2863000000  11993000000
# 245   4475000000  0.186  0.291  0.339  0.293  2253000000  10830000000
# 246   3381000000  0.266  0.395  0.517  0.356  1740000000  10040000000
# 247   2429000000  0.256  0.396  0.560  0.316  1168000000   7599000000
#
#       sharefactor   sharesbas    shareswa   shareswadil     sps     tangibles  \
# None
# 0             1.0  4233807170  4233807170           NaN  68.546  346196000000
# 1             1.0  4237106077  4237106077           NaN  57.672  348691000000
# 2             1.0  4146693326  4146693326           NaN  50.188  330314000000
# 3             1.0  4162938512  4162938512           NaN  59.873  336758000000
# 4             1.0  4234528643  4234528643           NaN  97.281  349493000000
# ...           ...         ...         ...           ...     ...           ...
# 243           1.0  5702722000  5753421000  5.793069e+09  40.622  281336000000
# 244           1.0  5987867000  6085572000  6.122663e+09  30.037  223081000000
# 245           1.0  6359479000  6477320000  6.521634e+09  26.386  201244000000
# 246           1.0  6561842000  6543726000  6.617483e+09  23.917  170705000000
# 247           1.0  6489636202  6469806000  6.556515e+09  16.731  111939000000
#
#        taxassets       taxexp  taxliabilities   tbvps  workingcapital
# None
# 0              0   9532000000     29856000000  81.769   -9.165000e+09
# 1              0  -1174000000     29938000000  82.295   -1.063700e+10
# 2              0   -406000000     36656000000  79.657   -6.222000e+09
# 3              0   5415000000     39620000000  80.894   -1.135300e+10
# 4              0  18015000000     44168000000  82.534   -1.172300e+10
# ...          ...          ...             ...     ...             ...
# 243            0  19121000000               0  48.899    8.768000e+09
# 244   4318000000  13973000000               0  36.657    5.083000e+09
# 245   3453000000  13118000000               0  31.069    2.962800e+10
# 246   2583000000  14030000000               0  26.087    1.911100e+10
# 247   2014000000   8283000000               0  17.302    1.701800e+10
#
# [248 rows x 111 columns]

# %%
# Tickers and Metadata
    # TIX_META
    
TIX_META = quandl.get_table("SHARADAR/TICKERS", paginate=True,api_key='dbyBuiq4bczbbuz9bA4t')
TIX_META
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-c29e77bc8aeb> in <module>
#       2     # TIX_META
#       3
# ----> 4 TIX_META = quandl.get_table("SHARADAR/TICKERS", paginate=True,api_key='dbyBuiq4bczbbuz9bA4t')
#       5 TIX_META
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\quandl\get_table.py in get_table(datatable_code, **options)
#      17     while True:
#      18         next_options = copy.deepcopy(options)
# ---> 19         next_data = Datatable(datatable_code).data(params=next_options)
#      20
#      21         if data is None:
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\quandl\model\datatable.py in data(self, **options)
#      26         if not options:
#      27             options = {'params': {}}
# ---> 28         return Data.page(self, **options)
#      29
#      30     def download_file(self, file_or_folder_path, **options):
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\quandl\operations\list.py in page(cls, datatable, **options)
#      28         updated_options = Util.convert_options(request_type=request_type, **options)
#      29
# ---> 30         r = Connection.request(request_type, path, **updated_options)
#      31
#      32         response_data = r.json()
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\quandl\connection.py in request(cls, http_verb, url, **options)
#      36         abs_url = '%s/%s' % (ApiConfig.api_base, url)
#      37
# ---> 38         return cls.execute_request(http_verb, abs_url, **options)
#      39
#      40     @classmethod
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\quandl\connection.py in execute_request(cls, http_verb, url, **options)
#      43
#      44         try:
# ---> 45             response = session.request(method=http_verb,
#      46                                        url=url,
#      47                                        verify=ApiConfig.verify_ssl,
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     663
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#     667                 method,
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     992         # Force connect early to allow us to validate the connection.
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#     996         if not conn.is_verified:
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\urllib3\connection.py in connect(self)
#     298     def connect(self):
#     299         # Add certificate verification
# --> 300         conn = self._new_conn()
#     301         hostname = self.host
#     302
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     154
#     155         try:
# --> 156             conn = connection.create_connection(
#     157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~\AppData\Local\Continuum\anaconda3\envs\notebook\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72             if source_address:
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#      76
#
# KeyboardInterrupt:

# %% [markdown]
# ## IEX
# * https://addisonlynch.github.io/iexfinance/stable/index.html
# * pd.iex.daily.IEXDailyReader(symbols=None, start=None,end=None, retry_count=3,pause=0.1, session=None, chunksize=25, api_key=None)
#
# ### GENERAL:
#
# #### Passing as an Argument I.

# %%
from iexfinance.refdata import get_symbols

get_symbols(output_format='pandas', token='pk_b740ad24ded147cca822e98ded174c3d')

a = Stock('TICKER', token='pk_b740ad24ded147cca822e98ded174c3d')

# %% [markdown]
# #### Passing as an Argument II.

# %%
from iexfinance.stocks import Stock

a = Stock('AAPL', token='pk_b740ad24ded147cca822e98ded174c3d')
a.get_quote()
# Out:
# {'symbol': 'AAPL',
#  'companyName': 'Apple, Inc.',
#  'primaryExchange': 'NASDAQ',
#  'calculationPrice': 'close',
#  'open': 281.96,
#  'openTime': 1583505000332,
#  'close': 289.03,
#  'closeTime': 1583528400820,
#  'high': 290.82,
#  'low': 281.23,
#  'latestPrice': 289.03,
#  'latestSource': 'Close',
#  'latestTime': 'March 6, 2020',
#  'latestUpdate': 1583528400820,
#  'latestVolume': 56420877,
#  'iexRealtimePrice': 288.98,
#  'iexRealtimeSize': 100,
#  'iexLastUpdated': 1583528399970,
#  'delayedPrice': 288.99,
#  'delayedPriceTime': 1583531228174,
#  'oddLotDelayedPrice': 289.03,
#  'oddLotDelayedPriceTime': 1583528400807,
#  'extendedPrice': 286,
#  'extendedChange': -3.03,
#  'extendedChangePercent': -0.01048,
#  'extendedPriceTime': 1583542799980,
#  'previousClose': 292.92,
#  'previousVolume': 46893219,
#  'change': -3.89,
#  'changePercent': -0.01328,
#  'volume': 56420877,
#  'iexMarketPercent': 0.007492687502890109,
#  'iexVolume': 422744,
#  'avgTotalVolume': 43388597,
#  'iexBidPrice': 0,
#  'iexBidSize': 0,
#  'iexAskPrice': 0,
#  'iexAskSize': 0,
#  'marketCap': 1264644984400,
#  'peRatio': 22.66,
#  'week52High': 327.85,
#  'week52Low': 169.5,
#  'ytdChange': -0.038017999999999996,
#  'lastTradeTime': 1583528402134,
#  'isUSMarketOpen': False}

# %% [markdown]
# ####  FORMATTING FOR PULLS:

# %%
start = datetime(2016, 9, 1)
end = datetime(2018, 9, 1)

IEX_API_KEY='pk_b740ad24ded147cca822e98ded174c3d'


f = web.DataReader('F', 'iex', start, end, api_key=IEX_API_KEY)

# %% [markdown]
# #### Fetch all stock symbols
# * Returns a Pandas Dataframe of all stock symbols, names, and more.
# * iexfinance.refdata.get_symbols(**kwargs)

# %%
from iexfinance.refdata import get_symbols
get_symbols(token='pk_b740ad24ded147cca822e98ded174c3d')[:2]
# Out:
# [{'symbol': 'A',
#   'exchange': 'NYS',
#   'name': 'Agilent Technologies Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_46574843354B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C2V3D6',
#   'cik': '1090872'},
#  {'symbol': 'AA',
#   'exchange': 'NYS',
#   'name': 'Alcoa Corp.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4238333734532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00B3T3HD3',
#   'cik': '1675149'}]

# %%
from iexfinance.refdata import get_symbols

get_symbols(output_format='pandas', token='pk_b740ad24ded147cca822e98ded174c3d')
# Out:
#      symbol exchange                                 name        date type  \
# 0         A      NYS            Agilent Technologies Inc.  2020-03-06   cs
# 1        AA      NYS                          Alcoa Corp.  2020-03-06   cs
# 2      AAAU      PSE         Perth Mint Physical Gold ETF  2020-03-06   et
# 3      AACG      NAS  ATA Creativity Global Sponsored ADR  2020-03-06   ad
# 4      AADR      PSE  AdvisorShares Dorsey Wright ADR ETF  2020-03-06   et
# ...     ...      ...                                  ...         ...  ...
# 8857    ZUO      NYS                   Zuora Inc. Class A  2020-03-06   cs
# 8858    ZVO      NAS                           Zovio Inc.  2020-03-06   cs
# 8859   ZYME      NYS                       Zymeworks Inc.  2020-03-06   cs
# 8860   ZYNE      NAS          Zynerba Pharmaceuticals Inc  2020-03-06   cs
# 8861   ZYXI      NAS                           Zynex Inc.  2020-03-06   cs
#
#                      iexId region currency  isEnabled          figi      cik
# 0     IEX_46574843354B2D52     US      USD       True  BBG000C2V3D6  1090872
# 1     IEX_4238333734532D52     US      USD       True  BBG00B3T3HD3  1675149
# 2     IEX_474B433136332D52     US      USD       True  BBG00LPXX872     None
# 3     IEX_44595A4C53392D52     US      USD       True  BBG000V2S3P6     None
# 4     IEX_5253355435362D52     US      USD       True  BBG000BDYRW6     None
# ...                    ...    ...      ...        ...           ...      ...
# 8857  IEX_4D474631525A2D52     US      USD       True  BBG000BT3HG5  1423774
# 8858  IEX_514A435352362D52     US      USD       True  BBG000C3CQP1  1305323
# 8859  IEX_5253315838322D52     US      USD       True  BBG00GD15LJ5  1403752
# 8860  IEX_4E3154424A382D52     US      USD       True  BBG007BBS8B7  1621443
# 8861  IEX_4E464C4C4A462D52     US      USD       True  BBG000BJBXZ2     None
#
# [8862 rows x 11 columns]

# %%
from iexfinance.stocks import Stock

aapl = Stock("AAPL", output_format='pandas', token='pk_b740ad24ded147cca822e98ded174c3d')
aapl.get_quote().head()
# Out:
#                       AAPL
# avgTotalVolume    43388597
# calculationPrice     close
# change               -3.89
# changePercent     -0.01328
# close               289.03

# %% [markdown]
# ####  Available Data Points For a Symbol
# * To obtain all available data points for a symbol, simply pass the symbol to get_data_points with no key:

# %%
from iexfinance.data_apis import get_data_points

data_pts=(get_data_points("AAPL", token='pk_b740ad24ded147cca822e98ded174c3d'))
data_pts
# Out:
# [{'key': 'NEXTDIVIDENDDATE',
#   'weight': 1,
#   'description': '',
#   'lastUpdated': '2020-02-07T16:24:55+00:00'},
#  {'key': 'ACCOUNTSPAYABLE',
#   'weight': 3000,
#   'description': 'Balance Sheet: accountsPayable',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'CAPITALSURPLUS',
#   'weight': 3000,
#   'description': 'Balance Sheet: capitalSurplus',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'COMMONSTOCK',
#   'weight': 3000,
#   'description': 'Balance Sheet: commonStock',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'CURRENTASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: currentAssets',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'CURRENTCASH',
#   'weight': 3000,
#   'description': 'Balance Sheet: currentCash',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'CURRENTLONGTERMDEBT',
#   'weight': 3000,
#   'description': 'Balance Sheet: currentLongTermDebt',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'GOODWILL',
#   'weight': 3000,
#   'description': 'Balance Sheet: goodwill',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'INTANGIBLEASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: intangibleAssets',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'INVENTORY',
#   'weight': 3000,
#   'description': 'Balance Sheet: inventory',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'LONGTERMDEBT',
#   'weight': 3000,
#   'description': 'Balance Sheet: longTermDebt',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'LONGTERMINVESTMENTS',
#   'weight': 3000,
#   'description': 'Balance Sheet: longTermInvestments',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'NETTANGIBLEASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: netTangibleAssets',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'OTHERASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: otherAssets',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'OTHERCURRENTASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: otherCurrentAssets',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'OTHERCURRENTLIABILITIES',
#   'weight': 3000,
#   'description': 'Balance Sheet: otherCurrentLiabilities',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'OTHERLIABILITIES',
#   'weight': 3000,
#   'description': 'Balance Sheet: otherLiabilities',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'PROPERTYPLANTEQUIPMENT',
#   'weight': 3000,
#   'description': 'Balance Sheet: propertyPlantEquipment',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'RECEIVABLES',
#   'weight': 3000,
#   'description': 'Balance Sheet: receivables',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'RETAINEDEARNINGS',
#   'weight': 3000,
#   'description': 'Balance Sheet: retainedEarnings',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'SHAREHOLDEREQUITY',
#   'weight': 3000,
#   'description': 'Balance Sheet: shareholderEquity',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'SHORTTERMINVESTMENTS',
#   'weight': 3000,
#   'description': 'Balance Sheet: shortTermInvestments',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'TOTALASSETS',
#   'weight': 3000,
#   'description': 'Balance Sheet: totalAssets',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'TOTALCURRENTLIABILITIES',
#   'weight': 3000,
#   'description': 'Balance Sheet: totalCurrentLiabilities',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'TOTALLIABILITIES',
#   'weight': 3000,
#   'description': 'Balance Sheet: totalLiabilities',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'TREASURYSTOCK',
#   'weight': 3000,
#   'description': 'Balance Sheet: treasuryStock',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'CAPITALEXPENDITURES',
#   'weight': 1000,
#   'description': 'Cash Flow: capitalExpenditures',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'CASHCHANGE',
#   'weight': 1000,
#   'description': 'Cash Flow: cashChange',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'CASHFLOW',
#   'weight': 1000,
#   'description': 'Cash Flow: cashFlow',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'CASHFLOWFINANCING',
#   'weight': 1000,
#   'description': 'Cash Flow: cashFlowFinancing',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'CHANGESININVENTORIES',
#   'weight': 1000,
#   'description': 'Cash Flow: changesInInventories',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'CHANGESINRECEIVABLES',
#   'weight': 1000,
#   'description': 'Cash Flow: changesInReceivables',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'DEPRECIATION',
#   'weight': 1000,
#   'description': 'Cash Flow: depreciation',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'DIVIDENDSPAID',
#   'weight': 1000,
#   'description': 'Cash Flow: dividendsPaid',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'EXCHANGERATEEFFECT',
#   'weight': 1000,
#   'description': 'Cash Flow: exchangeRateEffect',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'INVESTINGACTIVITYOTHER',
#   'weight': 1000,
#   'description': 'Cash Flow: investingActivityOther',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'INVESTMENTS',
#   'weight': 1000,
#   'description': 'Cash Flow: investments',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'NETBORROWINGS',
#   'weight': 1000,
#   'description': 'Cash Flow: netBorrowings',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'OTHERFINANCINGCASHFLOWS',
#   'weight': 1000,
#   'description': 'Cash Flow: otherFinancingCashFlows',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'TOTALINVESTINGCASHFLOWS',
#   'weight': 1000,
#   'description': 'Cash Flow: totalInvestingCashFlows',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'EBITDA',
#   'weight': 500,
#   'description': 'EBITDA',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'COSTOFREVENUE',
#   'weight': 1000,
#   'description': 'Income Statement: costOfRevenue',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'CURRENCY',
#   'weight': 1000,
#   'description': 'Income Statement: currency',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'EBIT',
#   'weight': 1000,
#   'description': 'Income Statement: ebit',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'FISCALDATE',
#   'weight': 1000,
#   'description': 'Income Statement: fiscalDate',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'INCOMETAX',
#   'weight': 1000,
#   'description': 'Income Statement: incomeTax',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'INTERESTINCOME',
#   'weight': 1000,
#   'description': 'Income Statement: interestIncome',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'MINORITYINTEREST',
#   'weight': 1000,
#   'description': 'Income Statement: minorityInterest',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'NETINCOME',
#   'weight': 1000,
#   'description': 'Income Statement: netIncome',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'NETINCOMEBASIC',
#   'weight': 1000,
#   'description': 'Income Statement: netIncomeBasic',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'OPERATINGEXPENSE',
#   'weight': 1000,
#   'description': 'Income Statement: operatingExpense',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'OPERATINGINCOME',
#   'weight': 1000,
#   'description': 'Income Statement: operatingIncome',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'OTHERINCOMEEXPENSENET',
#   'weight': 1000,
#   'description': 'Income Statement: otherIncomeExpenseNet',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'PRETAXINCOME',
#   'weight': 1000,
#   'description': 'Income Statement: pretaxIncome',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'REPORTDATE',
#   'weight': 1000,
#   'description': 'Income Statement: reportDate',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'RESEARCHANDDEVELOPMENT',
#   'weight': 1000,
#   'description': 'Income Statement: researchAndDevelopment',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'SELLINGGENERALANDADMIN',
#   'weight': 1000,
#   'description': 'Income Statement: sellingGeneralAndAdmin',
#   'lastUpdated': '2020-03-06T08:06:54+00:00'},
#  {'key': 'LAST-DIVIDEND-AMOUNT',
#   'weight': 10,
#   'description': 'Last dividend amount',
#   'lastUpdated': '2020-03-06T20:27:33+00:00'},
#  {'key': 'LAST-DIVIDEND-EX-DATE',
#   'weight': 10,
#   'description': 'Last dividend ex date',
#   'lastUpdated': '2020-03-06T20:27:33+00:00'},
#  {'key': 'LAST-DIVIDEND-PAYMENT-DATE',
#   'weight': 10,
#   'description': 'Last dividend payment date',
#   'lastUpdated': '2020-03-06T20:27:33+00:00'},
#  {'key': 'COMPANY-LAST-UPDATED',
#   'weight': 0,
#   'description': 'Last update epoch for company endpoint',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'LATEST-FINANCIAL-ANNUAL-REPORT-DATE',
#   'weight': 0,
#   'description': 'Latest annual financials report date available',
#   'lastUpdated': '2020-03-06T08:04:01+00:00'},
#  {'key': 'LATEST-FINANCIAL-REPORT-DATE',
#   'weight': 0,
#   'description': 'Latest financials report date available',
#   'lastUpdated': '2020-03-06T08:11:47+00:00'},
#  {'key': 'LATEST-FINANCIAL-QUARTERLY-REPORT-DATE',
#   'weight': 0,
#   'description': 'Latest quarterly financials report date available',
#   'lastUpdated': '2020-03-06T08:11:47+00:00'},
#  {'key': 'PRICE-TARGET',
#   'weight': 500,
#   'description': 'Price target average',
#   'lastUpdated': '2020-03-06T21:00:28+00:00'},
#  {'key': 'QUOTE-CHANGE',
#   'weight': 1,
#   'description': 'Quote: change',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-CHANGEPERCENT',
#   'weight': 1,
#   'description': 'Quote: changePercent',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-CLOSE',
#   'weight': 1,
#   'description': 'Quote: close',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-CLOSETIME',
#   'weight': 1,
#   'description': 'Quote: closeTime',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-EXTENDEDCHANGE',
#   'weight': 1,
#   'description': 'Quote: extendedChange',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-EXTENDEDCHANGEPERCENT',
#   'weight': 1,
#   'description': 'Quote: extendedChangePercent',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-EXTENDEDPRICE',
#   'weight': 1,
#   'description': 'Quote: extendedPrice',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-HIGH',
#   'weight': 1,
#   'description': 'Quote: high',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-IEXVOLUME',
#   'weight': 1,
#   'description': 'Quote: iexVolume',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-LATESTPRICE',
#   'weight': 1,
#   'description': 'Quote: latestPrice',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-LATESTUPDATE',
#   'weight': 1,
#   'description': 'Quote: latestUpdate',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-LATESTVOLUME',
#   'weight': 1,
#   'description': 'Quote: latestVolume',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-LOW',
#   'weight': 1,
#   'description': 'Quote: low',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-MARKETCAP',
#   'weight': 1,
#   'description': 'Quote: marketCap',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-OPEN',
#   'weight': 1,
#   'description': 'Quote: open',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'QUOTE-OPENTIME',
#   'weight': 1,
#   'description': 'Quote: openTime',
#   'lastUpdated': '2020-03-07T01:15:00+00:00'},
#  {'key': 'LATEST-NEWS',
#   'weight': 0,
#   'description': 'Timestamp of the latest available news item',
#   'lastUpdated': '2020-03-07T02:15:02+00:00'},
#  {'key': 'ADDRESS',
#   'weight': 1,
#   'description': 'address',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'AVG10VOLUME',
#   'weight': 1,
#   'description': 'avg10Volume',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'AVG30VOLUME',
#   'weight': 1,
#   'description': 'avg30Volume',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'BETA',
#   'weight': 1,
#   'description': 'beta',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'CEO',
#   'weight': 1,
#   'description': 'ceo',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'CITY',
#   'weight': 1,
#   'description': 'city',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'COMPANYNAME',
#   'weight': 1,
#   'description': 'companyName',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'COUNTRY',
#   'weight': 1,
#   'description': 'country',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'CURRENTDEBT',
#   'weight': 500,
#   'description': 'currentDebt',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'DAY200MOVINGAVG',
#   'weight': 1,
#   'description': 'day200MovingAvg',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'DAY50MOVINGAVG',
#   'weight': 1,
#   'description': 'day50MovingAvg',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'DEBTTOEQUITY',
#   'weight': 500,
#   'description': 'debtToEquity',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'DIVIDENDYIELD',
#   'weight': 1,
#   'description': 'dividendYield',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'EMPLOYEES',
#   'weight': 1,
#   'description': 'employees',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'ENTERPRISEVALUE',
#   'weight': 500,
#   'description': 'enterpriseValue',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'ENTERPRISEVALUETOREVENUE',
#   'weight': 500,
#   'description': 'enterpriseValueToRevenue',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'EXCHANGE',
#   'weight': 1,
#   'description': 'exchange',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'FLOAT',
#   'weight': 1,
#   'description': 'float',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'FORWARDPERATIO',
#   'weight': 500,
#   'description': 'forwardPERatio',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'GROSSPROFIT',
#   'weight': 500,
#   'description': 'grossProfit',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'INDUSTRY',
#   'weight': 1,
#   'description': 'industry',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'ISSUETYPE',
#   'weight': 1,
#   'description': 'issuetype',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'LONGDESCRIPTION',
#   'weight': 1,
#   'description': 'longDescription',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'PEHIGH',
#   'weight': 500,
#   'description': 'peHigh',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'PELOW',
#   'weight': 500,
#   'description': 'peLow',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'PEGRATIO',
#   'weight': 500,
#   'description': 'pegRatio',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'PHONE',
#   'weight': 1,
#   'description': 'phone',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'PRICETOBOOK',
#   'weight': 500,
#   'description': 'priceToBook',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'PRICETOSALES',
#   'weight': 500,
#   'description': 'priceToSales',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'PROFITMARGIN',
#   'weight': 500,
#   'description': 'profitMargin',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'REVENUE',
#   'weight': 500,
#   'description': 'revenue',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'REVENUEPEREMPLOYEE',
#   'weight': 500,
#   'description': 'revenuePerEmployee',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'REVENUEPERSHARE',
#   'weight': 500,
#   'description': 'revenuePerShare',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'SECTOR',
#   'weight': 1,
#   'description': 'sector',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'SECURITYNAME',
#   'weight': 1,
#   'description': 'securityName',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'SHARESOUTSTANDING',
#   'weight': 1,
#   'description': 'sharesOutstanding',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'STATE',
#   'weight': 1,
#   'description': 'state',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'TOTALCASH',
#   'weight': 500,
#   'description': 'totalCash',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'TOTALREVENUE',
#   'weight': 500,
#   'description': 'totalRevenue',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'TTMDIVIDENDRATE',
#   'weight': 1,
#   'description': 'ttmDividendRate',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'TTMEPS',
#   'weight': 1,
#   'description': 'ttmEPS',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'WEBSITE',
#   'weight': 1,
#   'description': 'website',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'WEEK52CHANGE',
#   'weight': 1,
#   'description': 'week52change',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'WEEK52HIGH',
#   'weight': 1,
#   'description': 'week52high',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'WEEK52HIGHDATE',
#   'weight': 500,
#   'description': 'week52highDate',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'WEEK52LOW',
#   'weight': 1,
#   'description': 'week52low',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'},
#  {'key': 'WEEK52LOWDATE',
#   'weight': 500,
#   'description': 'week52lowDate',
#   'lastUpdated': '2020-03-06T21:09:38+00:00'},
#  {'key': 'ZIP',
#   'weight': 1,
#   'description': 'zip',
#   'lastUpdated': '2020-03-06T20:37:45+00:00'}]

# %% [markdown]
# ####  Individual Data Points For a Symbol
# * To obtain an individual data point for a single symbol, pass the symbol and the data point ID to get_data_points:

# %%
import locale
from iexfinance.data_apis import get_data_points

data_pts1=get_data_points('AAPL', 'NETINCOME', token = 'pk_3e46a4b55bd04bd68bb778802602595b')

print('$'+f'{data_pts1:,}')
# Out:
# $17,891,000,000

# %% [markdown]
# ####  All Available Time Series
# * To obtain a list of all available time series, simply call get_time_series with no parameters:

# %%
from iexfinance.data_apis import get_time_series

get_time_series(token = 'pk_3e46a4b55bd04bd68bb778802602595b')
# Out:
# [{'id': 'PREMIUM_WALLSTREETHORIZON_OPTION_EXPIRATION_DATE',
#   'description': 'Company Events (Option Expiration Date)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'optionSymbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'usStockExchange': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'expirationDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'expirationFrequency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'strikeStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'optionType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_OPTION_EXPIRATION_DATE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:16',
#   'lastUpdated': '2019-10-14 18:04:16'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_WITCHING_HOURS',
#   'description': 'Calendar Events (Witching hours)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDay': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'financialCenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_WITCHING_HOURS',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:19',
#   'lastUpdated': '2019-10-14 18:04:19'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_FILING_DUE_DATE',
#   'description': 'Company Events (Filing Due Date)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'filingDueDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'quarter': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fiscalYear': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_FILING_DUE_DATE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:17',
#   'lastUpdated': '2019-10-14 18:04:17'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_BUYBACK',
#   'description': 'Dividend Events (Buyback)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'recordType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'buybackStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'buybackMethod': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'approvalDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'numberOfShares': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'sharesDifferent': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'percentOfShares': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'shareValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'shareValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'valueDifferent': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'priceFrom': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'priceTo': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'tenderResult': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'tenderExpiration': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'newsReferences': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'externalNotes': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_BUYBACK',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:00',
#   'lastUpdated': '2019-10-14 18:04:00'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_PRODUCT_EVENTS',
#   'description': 'Product Events (Product Events)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'releaseDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'releaseTitle': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'region': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'distributor': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'accuracy': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_PRODUCT_EVENTS',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:15',
#   'lastUpdated': '2019-10-14 18:04:15'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_GENERAL_CONFERENCE',
#   'description': 'Conference Events (General Conference)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'presenters': {'presenter': {'eventId': {'anyOf': [{'type': 'string'},
#         {'type': 'null'}]},
#       'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'time': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'announceDate': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'presenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterTitle': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}}}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_GENERAL_CONFERENCE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:03',
#   'lastUpdated': '2019-10-14 18:04:03'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_STOCK_SPECIFIC_FDA_ADVISORY_COMMITTEE_MEETING',
#   'description': 'Government Events (Stock Specific FDA Advisory Committee meeting)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_STOCK_SPECIFIC_FDA_ADVISORY_COMMITTEE_MEETING',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:00',
#   'lastUpdated': '2019-10-14 18:04:00'},
#  {'id': 'ADVANCED_RIGHTS_TO_PURCHASE',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'symbol': {'type': 'string'}},
#    'required': ['symbol'],
#    'additionalProperties': True},
#   'weightKey': 'ADVANCED_RIGHTS_TO_PURCHASE',
#   'weight': 0,
#   'created': '2019-11-25 14:26:55',
#   'lastUpdated': '2019-11-25 14:26:55'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_HOLIDAYS',
#   'description': 'Calendar Events (holidays)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDay': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'earlyCloseTime': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'countryCode': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'financialCenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_HOLIDAYS',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:18',
#   'lastUpdated': '2019-10-14 18:04:18'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_FISCAL_QUARTER_END_DATE',
#   'description': 'Company Events (Fiscal quarter End Date)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'quarterEndDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'quarter': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fiscalYear': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_FISCAL_QUARTER_END_DATE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:16',
#   'lastUpdated': '2019-10-14 18:04:16'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_LEGAL_ACTIONS',
#   'description': 'Legal/Activist (Legal actions)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'contactAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'caseDescription': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'contactEmail': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'caseUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'contactName': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'lawfirm': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'category': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'contactPhone': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'lawfirmHomepage': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'classPeriodBegin': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'motionDeadline': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'classPeriodEnd': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'prUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'stage': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_LEGAL_ACTIONS',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:14',
#   'lastUpdated': '2019-10-14 18:04:14'},
#  {'id': 'ADVANCED_DISTRIBUTION',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'countryCode': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'electionDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fromFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'hasWithdrawalRights': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'maxPrice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'minPrice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'parValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'paymentDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'ratio': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'recordDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'refid': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'securityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'source': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'subkey': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'toFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'withdrawalFromDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'withdrawalToDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': ['symbol'],
#    'additionalProperties': False},
#   'weightKey': 'ADVANCED_DISTRIBUTION',
#   'weight': 75000,
#   'created': '2019-11-25 14:19:27',
#   'lastUpdated': '2019-11-25 14:19:27'},
#  {'id': 'ADVANCED_RETURN_OF_CAPITAL',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'cashBack': {'anyOf': [{'type': 'number'},
#       {'type': 'null'}]},
#     'countryCode': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'currency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'electionDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'hasWithdrawalRights': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'parValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'paymentDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'recordDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'refid': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'securityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'source': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'subkey': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'withdrawalFromDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'withdrawalToDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': ['symbol'],
#    'additionalProperties': False},
#   'weightKey': 'ADVANCED_RETURN_OF_CAPITAL',
#   'weight': 75000,
#   'created': '2019-11-25 13:55:30',
#   'lastUpdated': '2019-11-25 13:55:30'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_RD_DAY',
#   'description': 'Analyst/Investor Events (RD Day)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_RD_DAY',
#   'weight': 1125000,
#   'created': '2019-10-14 19:10:37',
#   'lastUpdated': '2019-10-14 19:10:37'},
#  {'id': 'PREMIUM_BRAIN_RANKING_2_DAYS',
#   'description': 'The stock ranking according to Brain Machine Learning Model. Each stock is ranked by a score (or "alpha") related to the predicted future returns for the time horizon of 2 days.',
#   'schema': {'type': 'object',
#    'properties': {'calculationDate': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'compositeFigi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'mlAlpha': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'daysForecast': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['calculationDate',
#     'compositeFigi',
#     'symbol',
#     'mlAlpha',
#     'daysForecast']},
#   'weightKey': 'PREMIUM_BRAIN_RANKING_2_DAYS',
#   'weight': 211538,
#   'created': '2020-02-06 21:38:49',
#   'lastUpdated': '2020-02-06 21:38:49'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_MERGER_ACQUISITIONS',
#   'description': 'Merger acquisition (Merger Acquisitions)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'actionType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'actionStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'acquirerCompanyId': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'acquirerSymbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'acquirerName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'targetCompanyId': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'targetSymbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'targetIsin': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'targetName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'approvalDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'closeDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'percentInterest': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'pricePerShareCurrency': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'purchasePriceCash': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'purchasePriceCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purchasePricePerShare': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'purchasePriceSharesNumber': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'etFlag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'etDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'srFlag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'srDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'secReferences': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'newsReferences': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'actionNotes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_MERGER_ACQUISITIONS',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:15',
#   'lastUpdated': '2019-10-14 18:04:15'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_FORUM',
#   'description': 'Conference Events (Forum)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'presenters': {'presenter': {'eventId': {'anyOf': [{'type': 'string'},
#         {'type': 'null'}]},
#       'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'time': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'announceDate': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'presenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterTitle': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}}}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_FORUM',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:06',
#   'lastUpdated': '2019-10-14 18:04:06'},
#  {'id': 'NEWS',
#   'description': 'News Headlines',
#   'schema': {'type': 'object',
#    'properties': {'datetime': {'type': 'number'},
#     'headline': {'type': 'string'},
#     'source': {'type': ['string', 'null']},
#     'url': {'type': 'string'},
#     'summary': {'type': 'string'},
#     'related': {'type': 'string'}},
#    'required': ['datetime', 'headline', 'url'],
#    'additionalProperties': True},
#   'weightKey': 'NEWS',
#   'weight': 5000,
#   'created': '2019-11-07 20:28:36',
#   'lastUpdated': '2019-11-07 20:28:36'},
#  {'id': 'PREMIUM_BRAIN_RANKING_21_DAYS',
#   'description': 'The stock ranking according to Brain Machine Learning Model. Each stock is ranked by a score (or "alpha") related to the predicted future returns for the time horizon of 21 days.',
#   'schema': {'type': 'object',
#    'properties': {'calculationDate': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'compositeFigi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'mlAlpha': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'daysForecast': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['calculationDate',
#     'compositeFigi',
#     'symbol',
#     'mlAlpha',
#     'daysForecast']},
#   'weightKey': 'PREMIUM_BRAIN_RANKING_21_DAYS',
#   'weight': 211538,
#   'created': '2020-02-26 16:43:56',
#   'lastUpdated': '2020-02-26 16:43:56'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_INITIAL_PUBLIC_OFFERING',
#   'description': 'Public Offerings (Initial public offering)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'ipoStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'modified': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'iposcoopId': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'iposcoopCompanyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'industry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fileddate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'offeringdate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'offerprice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'firstdayclose': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'currentprice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'return': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'shares': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'pricerangelow': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'pricerangehigh': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'volume': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'managers': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'quietperiod': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'lockupperiod': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'rating': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_INITIAL_PUBLIC_OFFERING',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:13',
#   'lastUpdated': '2019-10-14 18:04:13'},
#  {'id': 'ECONOMIC',
#   'description': 'General economic data',
#   'schema': {'type': 'object',
#    'properties': {'value': {'type': 'number'}},
#    'required': ['value'],
#    'additionalProperties': False},
#   'weightKey': 'TIME_SERIES_ECONOMIC',
#   'weight': 1000,
#   'created': '2019-10-11 16:54:37',
#   'lastUpdated': '2019-10-11 16:54:37'},
#  {'id': 'PREMIUM_EXTRACT_ALPHA_CAM',
#   'description': 'The ExtractAlpha Cross-Asset Model 1 (CAM1) is an innovative quantitative stock selection model designed to capture the information contained in options market prices and volumes.',
#   'schema': {'type': 'object',
#    'properties': {'spreadComponent': {'type': 'number'},
#     'skewComponent': {'type': 'number'},
#     'volumeComponent': {'type': 'number'},
#     'cam1': {'type': 'number'},
#     'cam1Slow': {'type': 'number'}},
#    'required': ['spreadComponent',
#     'skewComponent',
#     'volumeComponent',
#     'cam1',
#     'cam1Slow'],
#    'additionalProperties': False},
#   'weightKey': 'PREMIUM_EXTRACT_ALPHA_CAM',
#   'weight': 76190,
#   'created': '2019-11-15 15:39:53',
#   'lastUpdated': '2019-11-15 15:39:53'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_CAPITAL_MARKETS_DAY',
#   'description': 'Analyst/Investor Events (Capital Markets day)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_CAPITAL_MARKETS_DAY',
#   'weight': 1125000,
#   'created': '2019-10-14 19:34:19',
#   'lastUpdated': '2019-10-14 19:34:19'},
#  {'id': 'PREMIUM_FRAUD_FACTORS_NON_TIMELY_FILINGS',
#   'description': 'The data set records the date in which a firm files a Non-Timely notification with the SEC.',
#   'schema': {'type': 'object',
#    'properties': {'cik': {'type': 'string'},
#     'companyName': {'type': 'string'},
#     'filingDate': {'type': 'string'},
#     'filingType': {'type': 'string'}},
#    'required': ['cik', 'filingDate', 'filingType'],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_FRAUD_FACTORS_NON_TIMELY_FILINGS',
#   'weight': 1,
#   'created': '2019-11-05 20:03:16',
#   'lastUpdated': '2019-11-05 20:03:16'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_PROJECTED_EARNINGS_ANNOUNCEMENT_DATE',
#   'description': 'Earnings Events (Projected Earnings Announcement Date)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'earningsDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'timeOfDay': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'quarter': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fiscalYear': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'earningsDateStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_PROJECTED_EARNINGS_ANNOUNCEMENT_DATE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:01',
#   'lastUpdated': '2019-10-14 18:04:01'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_WORKSHOP',
#   'description': 'Conference Events (Workshop)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'presenters': {'presenter': {'eventId': {'anyOf': [{'type': 'string'},
#         {'type': 'null'}]},
#       'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'time': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterTitle': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}}}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_WORKSHOP',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:13',
#   'lastUpdated': '2019-10-14 18:04:13'},
#  {'id': 'REPORTED_FINANCIALS',
#   'description': 'As reported financials directly from company filings. Data has not been cleaned and further manipulated. For curated financials use Cash Flow, Balance Sheet, and Income Statement endpoints.',
#   'schema': {'type': 'object',
#    'properties': {'formFiscalYear': {'type': 'number'},
#     'formFiscalQuarter': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'version': {'type': 'string'},
#     'periodStart': {'type': 'number'},
#     'periodEnd': {'type': 'number'},
#     'dateFiled': {'type': 'number'},
#     'reportLink': {'type': 'string'}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'REPORTED_FINANCIALS',
#   'weight': 5000,
#   'created': '2019-06-04 21:33:04',
#   'lastUpdated': '2019-06-04 21:33:04'},
#  {'id': 'ADVANCED_DIVIDENDS',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'adrFee': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'amount': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'countryCode': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'coupon': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'currency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'declaredCurrencyCD': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'declaredDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'declaredGrossAmount': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fiscalYearEndDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'frequency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fromFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'fxDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'grossAmount': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'installmentPayDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'isApproximate': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'isCapitalGains': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'isDAP': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'isNetInvestmentIncome': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'marker': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'netAmount': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'optionalElectionDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'parValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'paymentDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'periodEndDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'recordDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'refid': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'registrationDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'secondExDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'secondPaymentDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'securityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'source': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'subkey': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'taxRate': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'toDate': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'toFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['symbol'],
#    'additionalProperties': False},
#   'weightKey': 'ADVANCED_DIVIDENDS',
#   'weight': 75000,
#   'created': '2019-11-07 13:47:37',
#   'lastUpdated': '2019-11-07 13:47:37'},
#  {'id': 'ADVANCED_SECURITY_RECLASSIFICATION',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'countryCode': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'fromFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'parValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'ratio': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'refid': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'resultSecurityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'securityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'source': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'subkey': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'toFactor': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['symbol'],
#    'additionalProperties': False},
#   'weightKey': 'ADVANCED_SECURITY_RECLASSIFICATION',
#   'weight': 75000,
#   'created': '2019-11-25 14:51:48',
#   'lastUpdated': '2019-11-25 14:51:48'},
#  {'id': 'FX',
#   'description': '52 pairs, SP tenor, historical forex data',
#   'schema': {'type': 'object',
#    'properties': {'timestamp': {'type': 'number'},
#     'rate': {'type': 'number'},
#     'symbol': {'type': 'string'}},
#    'required': ['timestamp', 'rate'],
#    'additionalProperties': True},
#   'weightKey': 'FX',
#   'weight': 100000,
#   'created': '2019-11-01 15:12:28',
#   'lastUpdated': '2019-11-01 15:12:28'},
#  {'id': 'ADVANCED_RIGHT_TO_PURCHASE',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'countryCode': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'currency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'isOverSubscription': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'issuePrice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
# ...
#         {'type': 'null'}]},
#       'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'time': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterTitle': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}}}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_TRADE_SHOW',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:07',
#   'lastUpdated': '2019-10-14 18:04:07'},
#  {'id': 'PREMIUM_BRAIN_RANKING_3_DAYS',
#   'description': 'The stock ranking according to Brain Machine Learning Model. Each stock is ranked by a score (or "alpha") related to the predicted future returns for the time horizon of 3 days.',
#   'schema': {'type': 'object',
#    'properties': {'calculationDate': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'compositeFigi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'mlAlpha': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'daysForecast': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['calculationDate',
#     'compositeFigi',
#     'symbol',
#     'mlAlpha',
#     'daysForecast']},
#   'weightKey': 'PREMIUM_BRAIN_RANKING_3_DAYS',
#   'weight': 211538,
#   'created': '2020-02-06 21:42:15',
#   'lastUpdated': '2020-02-06 21:42:15'},
#  {'id': 'PREMIUM_BRAIN_SENTIMENT_30_DAYS',
#   'description': 'Brain Company proprietary sentiment scores for each company, calculated by taking into account news articles in the past 30 days.',
#   'schema': {'type': 'object',
#    'properties': {'calculationDate': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'compositeFigi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'volume': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'volumeSentiment': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'sentimentScore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'numberOfDaysIncluded': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['calculationDate',
#     'companyName',
#     'compositeFigi',
#     'symbol',
#     'volume',
#     'volumeSentiment',
#     'sentimentScore',
#     'numberOfDaysIncluded'],
#    'additionalProperties': False},
#   'weightKey': 'PREMIUM_BRAIN_SENTIMENT_30_DAYS',
#   'weight': 60000,
#   'created': '2020-02-06 21:31:35',
#   'lastUpdated': '2020-02-06 21:31:35'},
#  {'id': 'PREMIUM_KAVOUT_KSCORE',
#   'description': 'Kavout K Score',
#   'schema': {'type': 'object',
#    'properties': {'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'tradeDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'kscore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'qualityScore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'growthScore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'valueScore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'momentumScore': {'anyOf': [{'type': 'number'}, {'type': 'null'}]}},
#    'required': ['symbol', 'tradeDate'],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_KAVOUT_KSCORE',
#   'weight': 126263,
#   'created': '2020-02-26 15:59:47',
#   'lastUpdated': '2020-02-26 15:59:47'},
#  {'id': 'ENERGY',
#   'description': 'Commodities data - energy',
#   'schema': {'type': 'object',
#    'properties': {'value': {'type': 'number'}},
#    'required': ['value'],
#    'additionalProperties': False},
#   'weightKey': 'TIME_SERIES_ENERGY',
#   'weight': 1000,
#   'created': '2019-10-14 14:01:27',
#   'lastUpdated': '2019-10-14 14:01:27'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_SEMINAR',
#   'description': 'Conference Events (Seminar)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'presenters': {'presenter': {'eventId': {'anyOf': [{'type': 'string'},
#         {'type': 'null'}]},
#       'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'time': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'announceDate': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'presenterName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'presenterTitle': {'anyOf': [{'type': 'string'},
#         {'type': 'number'},
#         {'type': 'null'}]},
#       'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#       'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}}}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_SEMINAR',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:06',
#   'lastUpdated': '2019-10-14 18:04:06'},
#  {'id': 'PREMIUM_EXTRACT_ALPHA_TM',
#   'description': 'The ExtractAlpha Tactical Model 1 (TM1) is a quantitative stock selection model designed to capture the technical dynamics of single US equities over one to ten trading day horizons.',
#   'schema': {'type': 'object',
#    'properties': {'reversalComponent': {'type': 'number'},
#     'factorMomentumComponent': {'type': 'number'},
#     'liquidityShockComponent': {'type': 'number'},
#     'seasonalityComponent': {'type': 'number'},
#     'tm1': {'type': 'number'},
#     'listingExchange': {'type': 'string'},
#     'countryCode': {'type': 'string'}},
#    'required': ['reversalComponent',
#     'factorMomentumComponent',
#     'liquidityShockComponent',
#     'seasonalityComponent',
#     'tm1'],
#    'additionalProperties': False},
#   'weightKey': 'PREMIUM_EXTRACT_ALPHA_TM',
#   'weight': 42850,
#   'created': '2019-11-15 15:39:53',
#   'lastUpdated': '2019-11-15 15:39:53'},
#  {'id': 'ADVANCED_SPINOFF',
#   'description': 'Advanced dividends',
#   'schema': {'type': 'object',
#    'properties': {'countryCode': {'anyOf': [{'type': 'string'},
#       {'type': 'null'}]},
#     'created': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'currency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'date': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'description': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'effectiveDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'electionDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'exDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'figi': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'flag': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'hasWithdrawalRights': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'id': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'key': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'lastUpdated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'maxPrice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'minPrice': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'notes': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'parValue': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'parValueCurrency': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'paymentDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'recordDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'refid': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'securityType': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'source': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'subkey': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'number'}, {'type': 'null'}]},
#     'withdrawalFromDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'withdrawalToDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': ['symbol'],
#    'additionalProperties': False},
#   'weightKey': 'ADVANCED_SPINOFF',
#   'weight': 75000,
#   'created': '2019-11-25 14:05:52',
#   'lastUpdated': '2019-11-25 14:05:52'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_BUSINESS_UPDATE',
#   'description': 'Analyst/Investor Events (Business Update)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_BUSINESS_UPDATE',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:02',
#   'lastUpdated': '2019-10-14 18:04:02'},
#  {'id': 'FX-DAILY',
#   'description': '52 pairs, SP tenor, historical forex data',
#   'schema': {'type': 'object',
#    'properties': {'timestamp': {'type': 'number'},
#     'rate': {'type': 'number'},
#     'symbol': {'type': 'string'}},
#    'required': ['timestamp', 'rate'],
#    'additionalProperties': True},
#   'weightKey': 'FX_DAILY',
#   'weight': 50000,
#   'created': '2019-10-08 17:23:18',
#   'lastUpdated': '2019-10-08 17:23:18'},
#  {'id': 'MORTGAGE',
#   'description': 'Mortgage Rates',
#   'schema': {'type': 'object',
#    'properties': {'value': {'type': 'number'}},
#    'required': ['value'],
#    'additionalProperties': False},
#   'weightKey': 'TIME_SERIES_MORTGAGE',
#   'weight': 1000,
#   'created': '2019-10-11 16:54:40',
#   'lastUpdated': '2019-10-11 16:54:40'},
#  {'id': 'PREMIUM_WALLSTREETHORIZON_COMPANY_TRAVEL',
#   'description': 'Analyst/Investor Events (Company Travel)',
#   'schema': {'type': 'object',
#    'properties': {'eventId': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'symbol': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'companyName': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'announceDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'organizer': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventDesc': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'eventStatus': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'sectorNames': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'startDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'endDate': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'localTimeStart': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'timeZone': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venue': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueAddress': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'venueCity': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueState': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountry': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'venueCountryIso': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'purl': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'inviteUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'scheduleUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'additionalInfoUrl': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'externalNote': {'anyOf': [{'type': 'string'},
#       {'type': 'number'},
#       {'type': 'null'}]},
#     'referenceLink': {'anyOf': [{'type': 'string'}, {'type': 'null'}]},
#     'updated': {'anyOf': [{'type': 'string'}, {'type': 'null'}]}},
#    'required': [],
#    'additionalProperties': True},
#   'weightKey': 'PREMIUM_WALLSTREETHORIZON_COMPANY_TRAVEL',
#   'weight': 1125000,
#   'created': '2019-10-14 18:04:03',
#   'lastUpdated': '2019-10-14 18:04:03'}]

# %% [markdown]
# ####  Individual Time Series
# * Whereas calling get_time_series with no parameters returns a full inventory of time series endpoints
# * calling get_time_series with an individual series ID and (optional) keys and subkeys as parameters.
#
# * For example, to obtain the REPORTED_FINANCIALS time series entry for Apple Inc. (AAPL):

# %%
get_time_series('REPORTED_FINANCIALS', 'AAPL', token = 'pk_3e46a4b55bd04bd68bb778802602595b')

    # OR WITH A SUB KEY
# get_time_series("REPORTED_FINANCIALS", "AAPL", "10-Q")
# Out:
# [{'AccountsPayableCurrent': 46236000000,
#   'formFiscalYear': 2019,
#   'version': 'us-gaap',
#   'periodStart': 1538352000000,
#   'periodEnd': 1569801600000,
#   'dateFiled': 1572480000000,
#   'formFiscalQuarter': None,
#   'reportLink': 'https://www.sec.gov/Archives/edgar/data/0000320193/000032019319000119/',
#   'AccountsReceivableNetCurrent': 22926000000,
#   'AccruedIncomeTaxesNoncurrent': 29545000000,
#   'AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment': 58579000000,
#   'AccumulatedOtherComprehensiveIncomeLossNetOfTax': -584000000,
#   'AdjustmentsToAdditionalPaidInCapitalTaxEffectFromShareBasedCompensationIncludingTransferPricing': 620000000,
#   'AllocatedShareBasedCompensationExpense': 6068000000,
#   'AmountUtilizedUnderShareRepurchaseProgram': 96100000000,
#   'AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount': 15500000,
#   'Assets': 338516000000,
#   'AssetsCurrent': 162819000000,
#   'AssetsNoncurrent': 175697000000,
#   'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedGainBeforeTax': 1202000000,
#   'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedLossBeforeTax': 281000000,
#   'AvailableForSaleDebtSecuritiesAmortizedCostBasis': 204977000000,
#   'AvailableForSaleSecuritiesDebtSecurities': 205898000000,
#   'CashAndCashEquivalentsAtCarryingValue': 48844000000,
#   'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents': 50224000000,
#   'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect': 24311000000,
#   'CommercialPaper': 5980000000,
#   'CommitmentsAndContingencies': 0,
#   'CommonStockDividendsPerShareDeclared': 3,
#   'CommonStockParOrStatedValuePerShare': 0,
#   'CommonStockSharesAuthorized': 12600000000,
#   'CommonStockSharesIssued': 4443236000,
#   'CommonStockSharesOutstanding': 4443236000,
#   'CommonStocksIncludingAdditionalPaidInCapital': 45174000000,
#   'ComprehensiveIncomeNetOfTax': 58037000000,
#   'ContractWithCustomerLiability': 8100000000,
#   'ContractWithCustomerLiabilityCurrent': 5522000000,
#   'ContractWithCustomerLiabilityRevenueRecognized': 5900000000,
#   'CostOfGoodsAndServicesSold': 161782000000,
#   'CurrentFederalTaxExpenseBenefit': 6384000000,
#   'CurrentForeignTaxExpenseBenefit': 3962000000,
#   'CurrentStateAndLocalTaxExpenseBenefit': 475000000,
#   'DebtInstrumentCarryingAmount': 101679000000,
#   'DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet': 224000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLonger': 28167000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLongerAccumulatedLoss': 143000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12Months': 28151000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12MonthsAccumulatedLoss': 138000000,
#   'DebtSecuritiesAvailableForSaleUnrealizedLossPosition': 56318000000,
#   'DebtSecuritiesAvailableForSaleUnrealizedLossPositionAccumulatedLoss': 281000000,
#   'DecreaseInUnrecognizedTaxBenefitsIsReasonablyPossible': 2000000000,
#   'DeferredFederalIncomeTaxExpenseBenefit': -2939000000,
#   'DeferredForeignIncomeTaxExpenseBenefit': 2666000000,
#   'DeferredIncomeTaxExpenseBenefit': -340000000,
#   'DeferredIncomeTaxLiabilities': 11595000000,
#   'DeferredStateAndLocalIncomeTaxExpenseBenefit': -67000000,
#   'DeferredTaxAssetsDeferredIncome': 1372000000,
#   'DeferredTaxAssetsGoodwillAndIntangibleAssets': 11433000000,
#   'DeferredTaxAssetsLiabilitiesNet': 8045000000,
#   'DeferredTaxAssetsNet': 19640000000,
#   'DeferredTaxAssetsOther': 697000000,
#   'DeferredTaxAssetsPropertyPlantAndEquipment': 137000000,
#   'DeferredTaxAssetsTaxDeferredExpenseCompensationAndBenefitsShareBasedCompensationCost': 749000000,
#   'DeferredTaxAssetsTaxDeferredExpenseReservesAndAccruals': 5389000000,
#   'DeferredTaxAssetsUnrealizedLossesOnAvailableforSaleSecuritiesGross': 0,
#   'DeferredTaxLiabilitiesMinimumTaxonForeignEarnings': 10809000000,
#   'DeferredTaxLiabilitiesOther': 456000000,
#   'DeferredTaxLiabilitiesUndistributedForeignEarnings': 330000000,
#   'DefinedContributionPlanMaximumAnnualContributionsPerEmployeeAmount': 19000,
#   'Depreciation': 11300000000,
#   'DepreciationDepletionAndAmortization': 12547000000,
#   'DerivativeAssetsReductionforMasterNettingArrangements': 2700000000,
#   'DerivativeFairValueOfDerivativeNet': -407000000,
#   'DerivativeLiabilitiesReductionforMasterNettingArrangements': 2700000000,
#   'EarningsPerShareBasic': 11.97,
#   'EarningsPerShareDiluted': 11.89,
#   'EffectiveIncomeTaxRateContinuingOperations': 0.159,
#   'EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate': 0.21,
#   'EffectiveIncomeTaxRateReconciliationShareBasedCompensationExcessTaxBenefitAmount': -639000000,
#   'EffectiveIncomeTaxRateReconciliationTaxCutsAndJobsActOf2017Amount': 0,
#   'EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized': 10500000000,
#   'EmployeeServiceShareBasedCompensationTaxBenefitFromCompensationExpense': 1967000000,
#   'EntityCommonStockSharesOutstanding': 4443265000,
#   'EntityPublicFloat': 874698000000,
#   'EquitySecuritiesWithoutReadilyDeterminableFairValueAmount': 2900000000,
#   'FederalIncomeTaxExpenseBenefitContinuingOperations': 3445000000,
#   'ForeignIncomeTaxExpenseBenefitContinuingOperations': 6628000000,
#   'GainLossFromComponentsExcludedFromAssessmentOfFairValueHedgeEffectivenessNet': 777000000,
#   'GrossProfit': 98392000000,
#   'HedgeAccountingAdjustmentsRelatedToLongTermDebt': 612000000,
#   'IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest': 65737000000,
#   'IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign': 44300000000,
#   'IncomeTaxesPaidNet': 15263000000,
#   'IncomeTaxExpenseBenefit': 10481000000,
#   'IncomeTaxReconciliationForeignIncomeTaxRateDifferential': -2625000000,
#   'IncomeTaxReconciliationIncomeTaxExpenseBenefitAtFederalStatutoryIncomeTaxRate': 13805000000,
#   'IncomeTaxReconciliationOtherAdjustments': 65000000,
#   'IncomeTaxReconciliationStateAndLocalIncomeTaxes': 423000000,
#   'IncomeTaxReconciliationTaxCreditsResearch': 548000000,
#   'IncreaseDecreaseInAccountsPayable': -1923000000,
#   'IncreaseDecreaseInAccountsReceivable': -245000000,
#   'IncreaseDecreaseInContractWithCustomerLiability': -625000000,
#   'IncreaseDecreaseInInventories': 289000000,
#   'IncreaseDecreaseInOtherOperatingAssets': -873000000,
#   'IncreaseDecreaseInOtherOperatingLiabilities': -4700000000,
#   'IncreaseDecreaseInOtherReceivables': -2931000000,
#   'InterestCostsIncurred': 3200000000,
#   'InterestExpense': 3576000000,
#   'InterestPaidNet': 3423000000,
#   'InventoryNet': 4106000000,
#   'InvestmentIncomeInterestAndDividend': 4961000000,
#   'Liabilities': 248028000000,
#   'LiabilitiesAndStockholdersEquity': 338516000000,
#   'LiabilitiesCurrent': 105718000000,
#   'LiabilitiesNoncurrent': 142310000000,
#   'LongTermDebtCurrent': 10260000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive': 53802000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths': 10270000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive': 10039000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour': 9290000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree': 9528000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo': 8750000000,
#   'LongTermDebtNoncurrent': 91807000000,
#   'MarketableSecuritiesCurrent': 51713000000,
#   'MarketableSecuritiesNoncurrent': 105341000000,
#   'NetCashProvidedByUsedInFinancingActivities': -90976000000,
#   'NetCashProvidedByUsedInInvestingActivities': 45896000000,
#   'NetCashProvidedByUsedInOperatingActivities': 69391000000,
#   'NetIncomeLoss': 55256000000,
#   'NonCashActivitiesInvolvingPropertyPlantandEquipmentNetIncreaseDecreasetoAccountsPayableandOtherCurrentLiabilities': -2900000000,
#   'NoncurrentAssets': 37378000000,
#   'NonoperatingIncomeExpense': 1807000000,
#   'NontradeReceivablesCurrent': 22878000000,
#   'OperatingExpenses': 34462000000,
#   'OperatingIncomeLoss': 63930000000,
#   'OperatingLeasesFutureMinimumPaymentsDue': 10838000000,
#   'OperatingLeasesFutureMinimumPaymentsDueCurrent': 1306000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInFiveYears': 834000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInFourYears': 912000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInThreeYears': 1137000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInTwoYears': 1276000000,
#   'OperatingLeasesFutureMinimumPaymentsDueThereafter': 5373000000,
#   'OperatingLeasesRentExpenseNet': 1300000000,
#   'OtherAccruedLiabilitiesNoncurrent': 20958000000,
#   'OtherAssetsCurrent': 12352000000,
#   'OtherAssetsNoncurrent': 32978000000,
#   'OtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax': 3827000000,
#   'OtherComprehensiveIncomeLossDerivativesQualifyingAsHedgesNetOfTax': -638000000,
#   'OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax': -408000000,
#   'OtherComprehensiveIncomeLossNetOfTaxPortionAttributableToParent': 2781000000,
#   'OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIForSaleOfSecuritiesNetOfTax': -25000000,
#   'OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIOnDerivativesNetOfTax': -23000000,
#   'OtherComprehensiveIncomeUnrealizedGainLossOnDerivativesArisingDuringPeriodNetOfTax': -661000000,
#   'OtherComprehensiveIncomeUnrealizedHoldingGainLossOnSecuritiesArisingDuringPeriodNetOfTax': 3802000000,
#   'OtherLiabilitiesCurrent': 37720000000,
#   'OtherLiabilitiesNoncurrent': 50503000000,
#   'OtherNoncashIncomeExpense': 652000000,
#   'OtherNonoperatingIncomeExpense': 422000000,
#   'PaymentsForProceedsFromOtherInvestingActivities': 1078000000,
#   'PaymentsForRepurchaseOfCommonStock': 66897000000,
#   'PaymentsOfDividends': 14119000000,
#   'PaymentsRelatedToTaxWithholdingForShareBasedCompensation': 2817000000,
#   'PaymentsToAcquireAvailableForSaleSecuritiesDebt': 39630000000,
#   'PaymentsToAcquireBusinessesNetOfCashAcquired': 624000000,
#   'PaymentsToAcquireOtherInvestments': 1001000000,
#   'PaymentsToAcquirePropertyPlantAndEquipment': 10495000000,
#   'PerformanceObligationsinArrangements': 3,
#   'ProceedsFromIssuanceOfCommonStock': 781000000,
#   'ProceedsFromIssuanceOfLongTermDebt': 6963000000,
#   'ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities': 40102000000,
#   'ProceedsFromPaymentsForOtherFinancingActivities': -105000000,
#   'ProceedsFromRepaymentsOfCommercialPaper': -5977000000,
#   'ProceedsFromRepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths': -2729000000,
#   'ProceedsFromRepaymentsOfShortTermDebtMaturingInThreeMonthsOrLess': -3248000000,
#   'ProceedsFromSaleAndMaturityOfOtherInvestments': 1634000000,
#   'ProceedsFromSaleOfAvailableForSaleSecuritiesDebt': 56988000000,
#   'ProceedsFromShortTermDebtMaturingInMoreThanThreeMonths': 13874000000,
#   'PropertyPlantAndEquipmentGross': 95957000000,
#   'PropertyPlantAndEquipmentNet': 37378000000,
#   'RepaymentsOfLongTermDebt': 8805000000,
#   'RepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths': 16603000000,
#   'ResearchAndDevelopmentExpense': 16217000000,
#   'RestrictedCashAndCashEquivalentsAtCarryingValue': 23000000,
#   'RestrictedCashAndCashEquivalentsNoncurrent': 1357000000,
#   'RestrictedInvestments': 18900000000,
#   'RetainedEarningsAccumulatedDeficit': 45898000000,
#   'RevenueFromContractWithCustomerExcludingAssessedTax': 260174000000,
#   'SellingGeneralAndAdministrativeExpense': 18245000000,
#   'ShareBasedCompensation': 6068000000,
#   'ShortTermDebtWeightedAverageInterestRate': 0.0224,
#   'StandardProductWarrantyAccrual': 3570000000,
#   'StandardProductWarrantyAccrualPayments': 3857000000,
#   'StandardProductWarrantyAccrualWarrantiesIssued': 3735000000,
#   'StateAndLocalIncomeTaxExpenseBenefitContinuingOperations': 408000000,
#   'StockholdersEquity': 90488000000,
#   'StockRepurchasedAndRetiredDuringPeriodShares': 345200000,
#   'StockRepurchasedAndRetiredDuringPeriodValue': 67100000000,
#   'StockRepurchaseProgramAuthorizedAmount1': 175000000000,
#   'UnrecognizedTaxBenefits': 15619000000,
#   'UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions': 686000000,
#   'UnrecognizedTaxBenefitsDecreasesResultingFromSettlementsWithTaxingAuthorities': 852000000,
#   'UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued': 1300000000,
#   'UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestExpense': 73000000,
#   'UnrecognizedTaxBenefitsIncreasesResultingFromCurrentPeriodTaxPositions': 1697000000,
#   'UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions': 5845000000,
#   'UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations': 79000000,
#   'UnrecognizedTaxBenefitsThatWouldImpactEffectiveTaxRate': 8600000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFifthAnniversary': 218000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary': 2476000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFourthAnniversary': 1162000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnSecondAnniversary': 2386000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary': 1859000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount': 8211000000,
#   'UnrecordedUnconditionalPurchaseObligationDueAfterFiveYears': 110000000,
#   'WeightedAverageNumberDilutedSharesOutstandingAdjustment': 31079000,
#   'WeightedAverageNumberOfDilutedSharesOutstanding': 4648913000,
#   'WeightedAverageNumberOfSharesOutstandingBasic': 4617834000,
#   'id': 'REPORTED_FINANCIALS',
#   'source': 'SEC',
#   'key': 'AAPL',
#   'subkey': '10-K',
#   'date': 1572480000000,
#   'updated': 1581627630000}]

# %%
get_time_series("REPORTED_FINANCIALS", "AAPL", "10-K", last=1, token = 'pk_3e46a4b55bd04bd68bb778802602595b')
# Out:
# [{'AccountsPayableCurrent': 46236000000,
#   'formFiscalYear': 2019,
#   'version': 'us-gaap',
#   'periodStart': 1538352000000,
#   'periodEnd': 1569801600000,
#   'dateFiled': 1572480000000,
#   'formFiscalQuarter': None,
#   'reportLink': 'https://www.sec.gov/Archives/edgar/data/0000320193/000032019319000119/',
#   'AccountsReceivableNetCurrent': 22926000000,
#   'AccruedIncomeTaxesNoncurrent': 29545000000,
#   'AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment': 58579000000,
#   'AccumulatedOtherComprehensiveIncomeLossNetOfTax': -584000000,
#   'AdjustmentsToAdditionalPaidInCapitalTaxEffectFromShareBasedCompensationIncludingTransferPricing': 620000000,
#   'AllocatedShareBasedCompensationExpense': 6068000000,
#   'AmountUtilizedUnderShareRepurchaseProgram': 96100000000,
#   'AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount': 15500000,
#   'Assets': 338516000000,
#   'AssetsCurrent': 162819000000,
#   'AssetsNoncurrent': 175697000000,
#   'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedGainBeforeTax': 1202000000,
#   'AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedLossBeforeTax': 281000000,
#   'AvailableForSaleDebtSecuritiesAmortizedCostBasis': 204977000000,
#   'AvailableForSaleSecuritiesDebtSecurities': 205898000000,
#   'CashAndCashEquivalentsAtCarryingValue': 48844000000,
#   'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents': 50224000000,
#   'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect': 24311000000,
#   'CommercialPaper': 5980000000,
#   'CommitmentsAndContingencies': 0,
#   'CommonStockDividendsPerShareDeclared': 3,
#   'CommonStockParOrStatedValuePerShare': 0,
#   'CommonStockSharesAuthorized': 12600000000,
#   'CommonStockSharesIssued': 4443236000,
#   'CommonStockSharesOutstanding': 4443236000,
#   'CommonStocksIncludingAdditionalPaidInCapital': 45174000000,
#   'ComprehensiveIncomeNetOfTax': 58037000000,
#   'ContractWithCustomerLiability': 8100000000,
#   'ContractWithCustomerLiabilityCurrent': 5522000000,
#   'ContractWithCustomerLiabilityRevenueRecognized': 5900000000,
#   'CostOfGoodsAndServicesSold': 161782000000,
#   'CurrentFederalTaxExpenseBenefit': 6384000000,
#   'CurrentForeignTaxExpenseBenefit': 3962000000,
#   'CurrentStateAndLocalTaxExpenseBenefit': 475000000,
#   'DebtInstrumentCarryingAmount': 101679000000,
#   'DebtInstrumentUnamortizedDiscountPremiumAndDebtIssuanceCostsNet': 224000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLonger': 28167000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPosition12MonthsOrLongerAccumulatedLoss': 143000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12Months': 28151000000,
#   'DebtSecuritiesAvailableForSaleContinuousUnrealizedLossPositionLessThan12MonthsAccumulatedLoss': 138000000,
#   'DebtSecuritiesAvailableForSaleUnrealizedLossPosition': 56318000000,
#   'DebtSecuritiesAvailableForSaleUnrealizedLossPositionAccumulatedLoss': 281000000,
#   'DecreaseInUnrecognizedTaxBenefitsIsReasonablyPossible': 2000000000,
#   'DeferredFederalIncomeTaxExpenseBenefit': -2939000000,
#   'DeferredForeignIncomeTaxExpenseBenefit': 2666000000,
#   'DeferredIncomeTaxExpenseBenefit': -340000000,
#   'DeferredIncomeTaxLiabilities': 11595000000,
#   'DeferredStateAndLocalIncomeTaxExpenseBenefit': -67000000,
#   'DeferredTaxAssetsDeferredIncome': 1372000000,
#   'DeferredTaxAssetsGoodwillAndIntangibleAssets': 11433000000,
#   'DeferredTaxAssetsLiabilitiesNet': 8045000000,
#   'DeferredTaxAssetsNet': 19640000000,
#   'DeferredTaxAssetsOther': 697000000,
#   'DeferredTaxAssetsPropertyPlantAndEquipment': 137000000,
#   'DeferredTaxAssetsTaxDeferredExpenseCompensationAndBenefitsShareBasedCompensationCost': 749000000,
#   'DeferredTaxAssetsTaxDeferredExpenseReservesAndAccruals': 5389000000,
#   'DeferredTaxAssetsUnrealizedLossesOnAvailableforSaleSecuritiesGross': 0,
#   'DeferredTaxLiabilitiesMinimumTaxonForeignEarnings': 10809000000,
#   'DeferredTaxLiabilitiesOther': 456000000,
#   'DeferredTaxLiabilitiesUndistributedForeignEarnings': 330000000,
#   'DefinedContributionPlanMaximumAnnualContributionsPerEmployeeAmount': 19000,
#   'Depreciation': 11300000000,
#   'DepreciationDepletionAndAmortization': 12547000000,
#   'DerivativeAssetsReductionforMasterNettingArrangements': 2700000000,
#   'DerivativeFairValueOfDerivativeNet': -407000000,
#   'DerivativeLiabilitiesReductionforMasterNettingArrangements': 2700000000,
#   'EarningsPerShareBasic': 11.97,
#   'EarningsPerShareDiluted': 11.89,
#   'EffectiveIncomeTaxRateContinuingOperations': 0.159,
#   'EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate': 0.21,
#   'EffectiveIncomeTaxRateReconciliationShareBasedCompensationExcessTaxBenefitAmount': -639000000,
#   'EffectiveIncomeTaxRateReconciliationTaxCutsAndJobsActOf2017Amount': 0,
#   'EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized': 10500000000,
#   'EmployeeServiceShareBasedCompensationTaxBenefitFromCompensationExpense': 1967000000,
#   'EntityCommonStockSharesOutstanding': 4443265000,
#   'EntityPublicFloat': 874698000000,
#   'EquitySecuritiesWithoutReadilyDeterminableFairValueAmount': 2900000000,
#   'FederalIncomeTaxExpenseBenefitContinuingOperations': 3445000000,
#   'ForeignIncomeTaxExpenseBenefitContinuingOperations': 6628000000,
#   'GainLossFromComponentsExcludedFromAssessmentOfFairValueHedgeEffectivenessNet': 777000000,
#   'GrossProfit': 98392000000,
#   'HedgeAccountingAdjustmentsRelatedToLongTermDebt': 612000000,
#   'IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest': 65737000000,
#   'IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign': 44300000000,
#   'IncomeTaxesPaidNet': 15263000000,
#   'IncomeTaxExpenseBenefit': 10481000000,
#   'IncomeTaxReconciliationForeignIncomeTaxRateDifferential': -2625000000,
#   'IncomeTaxReconciliationIncomeTaxExpenseBenefitAtFederalStatutoryIncomeTaxRate': 13805000000,
#   'IncomeTaxReconciliationOtherAdjustments': 65000000,
#   'IncomeTaxReconciliationStateAndLocalIncomeTaxes': 423000000,
#   'IncomeTaxReconciliationTaxCreditsResearch': 548000000,
#   'IncreaseDecreaseInAccountsPayable': -1923000000,
#   'IncreaseDecreaseInAccountsReceivable': -245000000,
#   'IncreaseDecreaseInContractWithCustomerLiability': -625000000,
#   'IncreaseDecreaseInInventories': 289000000,
#   'IncreaseDecreaseInOtherOperatingAssets': -873000000,
#   'IncreaseDecreaseInOtherOperatingLiabilities': -4700000000,
#   'IncreaseDecreaseInOtherReceivables': -2931000000,
#   'InterestCostsIncurred': 3200000000,
#   'InterestExpense': 3576000000,
#   'InterestPaidNet': 3423000000,
#   'InventoryNet': 4106000000,
#   'InvestmentIncomeInterestAndDividend': 4961000000,
#   'Liabilities': 248028000000,
#   'LiabilitiesAndStockholdersEquity': 338516000000,
#   'LiabilitiesCurrent': 105718000000,
#   'LiabilitiesNoncurrent': 142310000000,
#   'LongTermDebtCurrent': 10260000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalAfterYearFive': 53802000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInNextTwelveMonths': 10270000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFive': 10039000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearFour': 9290000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearThree': 9528000000,
#   'LongTermDebtMaturitiesRepaymentsOfPrincipalInYearTwo': 8750000000,
#   'LongTermDebtNoncurrent': 91807000000,
#   'MarketableSecuritiesCurrent': 51713000000,
#   'MarketableSecuritiesNoncurrent': 105341000000,
#   'NetCashProvidedByUsedInFinancingActivities': -90976000000,
#   'NetCashProvidedByUsedInInvestingActivities': 45896000000,
#   'NetCashProvidedByUsedInOperatingActivities': 69391000000,
#   'NetIncomeLoss': 55256000000,
#   'NonCashActivitiesInvolvingPropertyPlantandEquipmentNetIncreaseDecreasetoAccountsPayableandOtherCurrentLiabilities': -2900000000,
#   'NoncurrentAssets': 37378000000,
#   'NonoperatingIncomeExpense': 1807000000,
#   'NontradeReceivablesCurrent': 22878000000,
#   'OperatingExpenses': 34462000000,
#   'OperatingIncomeLoss': 63930000000,
#   'OperatingLeasesFutureMinimumPaymentsDue': 10838000000,
#   'OperatingLeasesFutureMinimumPaymentsDueCurrent': 1306000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInFiveYears': 834000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInFourYears': 912000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInThreeYears': 1137000000,
#   'OperatingLeasesFutureMinimumPaymentsDueInTwoYears': 1276000000,
#   'OperatingLeasesFutureMinimumPaymentsDueThereafter': 5373000000,
#   'OperatingLeasesRentExpenseNet': 1300000000,
#   'OtherAccruedLiabilitiesNoncurrent': 20958000000,
#   'OtherAssetsCurrent': 12352000000,
#   'OtherAssetsNoncurrent': 32978000000,
#   'OtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax': 3827000000,
#   'OtherComprehensiveIncomeLossDerivativesQualifyingAsHedgesNetOfTax': -638000000,
#   'OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax': -408000000,
#   'OtherComprehensiveIncomeLossNetOfTaxPortionAttributableToParent': 2781000000,
#   'OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIForSaleOfSecuritiesNetOfTax': -25000000,
#   'OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIOnDerivativesNetOfTax': -23000000,
#   'OtherComprehensiveIncomeUnrealizedGainLossOnDerivativesArisingDuringPeriodNetOfTax': -661000000,
#   'OtherComprehensiveIncomeUnrealizedHoldingGainLossOnSecuritiesArisingDuringPeriodNetOfTax': 3802000000,
#   'OtherLiabilitiesCurrent': 37720000000,
#   'OtherLiabilitiesNoncurrent': 50503000000,
#   'OtherNoncashIncomeExpense': 652000000,
#   'OtherNonoperatingIncomeExpense': 422000000,
#   'PaymentsForProceedsFromOtherInvestingActivities': 1078000000,
#   'PaymentsForRepurchaseOfCommonStock': 66897000000,
#   'PaymentsOfDividends': 14119000000,
#   'PaymentsRelatedToTaxWithholdingForShareBasedCompensation': 2817000000,
#   'PaymentsToAcquireAvailableForSaleSecuritiesDebt': 39630000000,
#   'PaymentsToAcquireBusinessesNetOfCashAcquired': 624000000,
#   'PaymentsToAcquireOtherInvestments': 1001000000,
#   'PaymentsToAcquirePropertyPlantAndEquipment': 10495000000,
#   'PerformanceObligationsinArrangements': 3,
#   'ProceedsFromIssuanceOfCommonStock': 781000000,
#   'ProceedsFromIssuanceOfLongTermDebt': 6963000000,
#   'ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities': 40102000000,
#   'ProceedsFromPaymentsForOtherFinancingActivities': -105000000,
#   'ProceedsFromRepaymentsOfCommercialPaper': -5977000000,
#   'ProceedsFromRepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths': -2729000000,
#   'ProceedsFromRepaymentsOfShortTermDebtMaturingInThreeMonthsOrLess': -3248000000,
#   'ProceedsFromSaleAndMaturityOfOtherInvestments': 1634000000,
#   'ProceedsFromSaleOfAvailableForSaleSecuritiesDebt': 56988000000,
#   'ProceedsFromShortTermDebtMaturingInMoreThanThreeMonths': 13874000000,
#   'PropertyPlantAndEquipmentGross': 95957000000,
#   'PropertyPlantAndEquipmentNet': 37378000000,
#   'RepaymentsOfLongTermDebt': 8805000000,
#   'RepaymentsOfShortTermDebtMaturingInMoreThanThreeMonths': 16603000000,
#   'ResearchAndDevelopmentExpense': 16217000000,
#   'RestrictedCashAndCashEquivalentsAtCarryingValue': 23000000,
#   'RestrictedCashAndCashEquivalentsNoncurrent': 1357000000,
#   'RestrictedInvestments': 18900000000,
#   'RetainedEarningsAccumulatedDeficit': 45898000000,
#   'RevenueFromContractWithCustomerExcludingAssessedTax': 260174000000,
#   'SellingGeneralAndAdministrativeExpense': 18245000000,
#   'ShareBasedCompensation': 6068000000,
#   'ShortTermDebtWeightedAverageInterestRate': 0.0224,
#   'StandardProductWarrantyAccrual': 3570000000,
#   'StandardProductWarrantyAccrualPayments': 3857000000,
#   'StandardProductWarrantyAccrualWarrantiesIssued': 3735000000,
#   'StateAndLocalIncomeTaxExpenseBenefitContinuingOperations': 408000000,
#   'StockholdersEquity': 90488000000,
#   'StockRepurchasedAndRetiredDuringPeriodShares': 345200000,
#   'StockRepurchasedAndRetiredDuringPeriodValue': 67100000000,
#   'StockRepurchaseProgramAuthorizedAmount1': 175000000000,
#   'UnrecognizedTaxBenefits': 15619000000,
#   'UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions': 686000000,
#   'UnrecognizedTaxBenefitsDecreasesResultingFromSettlementsWithTaxingAuthorities': 852000000,
#   'UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued': 1300000000,
#   'UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestExpense': 73000000,
#   'UnrecognizedTaxBenefitsIncreasesResultingFromCurrentPeriodTaxPositions': 1697000000,
#   'UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions': 5845000000,
#   'UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations': 79000000,
#   'UnrecognizedTaxBenefitsThatWouldImpactEffectiveTaxRate': 8600000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFifthAnniversary': 218000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFirstAnniversary': 2476000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnFourthAnniversary': 1162000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnSecondAnniversary': 2386000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceOnThirdAnniversary': 1859000000,
#   'UnrecordedUnconditionalPurchaseObligationBalanceSheetAmount': 8211000000,
#   'UnrecordedUnconditionalPurchaseObligationDueAfterFiveYears': 110000000,
#   'WeightedAverageNumberDilutedSharesOutstandingAdjustment': 31079000,
#   'WeightedAverageNumberOfDilutedSharesOutstanding': 4648913000,
#   'WeightedAverageNumberOfSharesOutstandingBasic': 4617834000,
#   'id': 'REPORTED_FINANCIALS',
#   'source': 'SEC',
#   'key': 'AAPL',
#   'subkey': '10-K',
#   'date': 1572480000000,
#   'updated': 1581627630000}]

# %% [markdown]
# ### Historical Data
# * It's possible to obtain historical data using get_historical_data and get_historical_intraday.

# %% [markdown]
# #### Daily
# * To obtain daily historical price data for one or more symbols, use the get_historical_data function.
# * This will return a daily time-series of the ticker requested over the desired date range
#     * (start and end passed as datetime.datetime objects):

# %%
from datetime import datetime
from iexfinance.stocks import get_historical_data

start = datetime(2017, 1, 1)
end = datetime(2018, 1, 1)

df = get_historical_data("TSLA", start, end, token='pk_b740ad24ded147cca822e98ded174c3d')
df
# Out:
# {'2017-01-03': {'open': 214.86,
#   'high': 220.33,
#   'low': 210.96,
#   'close': 216.99,
#   'volume': 5923254},
#  '2017-01-04': {'open': 214.75,
#   'high': 228.0,
#   'low': 214.31,
#   'close': 226.99,
#   'volume': 11213471},
#  '2017-01-05': {'open': 226.42,
#   'high': 227.48,
#   'low': 221.95,
#   'close': 226.75,
#   'volume': 5911695},
#  '2017-01-06': {'open': 226.93,
#   'high': 230.31,
#   'low': 225.45,
#   'close': 229.01,
#   'volume': 5527893},
#  '2017-01-09': {'open': 228.97,
#   'high': 231.92,
#   'low': 228.0,
#   'close': 231.28,
#   'volume': 3979484},
#  '2017-01-10': {'open': 232.0,
#   'high': 232.0,
#   'low': 226.89,
#   'close': 229.87,
#   'volume': 3659955},
#  '2017-01-11': {'open': 229.07,
#   'high': 229.98,
#   'low': 226.68,
#   'close': 229.73,
#   'volume': 3650825},
#  '2017-01-12': {'open': 229.06,
#   'high': 230.7,
#   'low': 225.58,
#   'close': 229.59,
#   'volume': 3790229},
#  '2017-01-13': {'open': 230.0,
#   'high': 237.85,
#   'low': 229.59,
#   'close': 237.75,
#   'volume': 6092960},
#  '2017-01-17': {'open': 236.7,
#   'high': 239.96,
#   'low': 234.37,
#   'close': 235.58,
#   'volume': 4617522},
#  '2017-01-18': {'open': 236.65,
#   'high': 239.71,
#   'low': 235.58,
#   'close': 238.36,
#   'volume': 3768967},
#  '2017-01-19': {'open': 247.25,
#   'high': 248.68,
#   'low': 240.75,
#   'close': 243.76,
#   'volume': 7732303},
#  '2017-01-20': {'open': 245.46,
#   'high': 246.0,
#   'low': 243.01,
#   'close': 244.73,
#   'volume': 4204275},
#  '2017-01-23': {'open': 245.85,
#   'high': 250.89,
#   'low': 245.5,
#   'close': 248.92,
#   'volume': 6262938},
#  '2017-01-24': {'open': 250.0,
#   'high': 254.8,
#   'low': 249.65,
#   'close': 254.61,
#   'volume': 4965451},
#  '2017-01-25': {'open': 257.31,
#   'high': 258.46,
#   'low': 251.8,
#   'close': 254.47,
#   'volume': 5146361},
#  '2017-01-26': {'open': 254.29,
#   'high': 255.74,
#   'low': 250.75,
#   'close': 252.51,
#   'volume': 3152123},
#  '2017-01-27': {'open': 251.38,
#   'high': 253.0,
#   'low': 248.52,
#   'close': 252.95,
#   'volume': 3166336},
#  '2017-01-30': {'open': 252.53,
#   'high': 255.29,
#   'low': 247.1,
#   'close': 250.63,
#   'volume': 3801074},
#  '2017-01-31': {'open': 249.24,
#   'high': 255.89,
#   'low': 247.7,
#   'close': 251.93,
#   'volume': 4116104},
#  '2017-02-01': {'open': 253.05,
#   'high': 253.2,
#   'low': 249.05,
#   'close': 249.24,
#   'volume': 3958829},
#  '2017-02-02': {'open': 248.34,
#   'high': 252.42,
#   'low': 247.71,
#   'close': 251.55,
#   'volume': 2499775},
#  '2017-02-03': {'open': 251.91,
#   'high': 252.18,
#   'low': 249.68,
#   'close': 251.33,
#   'volume': 2186723},
#  '2017-02-06': {'open': 251.0,
#   'high': 257.82,
#   'low': 250.63,
#   'close': 257.77,
#   'volume': 3562517},
#  '2017-02-07': {'open': 258.19,
#   'high': 260.0,
#   'low': 256.42,
#   'close': 257.48,
#   'volume': 4244775},
#  '2017-02-08': {'open': 257.35,
#   'high': 263.36,
#   'low': 256.2,
#   'close': 262.08,
#   'volume': 3933014},
#  '2017-02-09': {'open': 266.25,
#   'high': 271.18,
#   'low': 266.15,
#   'close': 269.2,
#   'volume': 7820222},
#  '2017-02-10': {'open': 269.79,
#   'high': 270.95,
#   'low': 266.11,
#   'close': 269.23,
#   'volume': 3619739},
#  '2017-02-13': {'open': 270.74,
#   'high': 280.79,
#   'low': 270.51,
#   'close': 280.6,
#   'volume': 7029605},
#  '2017-02-14': {'open': 279.03,
#   'high': 287.39,
#   'low': 278.61,
#   'close': 280.98,
#   'volume': 7345224},
#  '2017-02-15': {'open': 280.0,
#   'high': 282.24,
#   'low': 276.44,
#   'close': 279.76,
#   'volume': 4947856},
#  '2017-02-16': {'open': 277.6,
#   'high': 280.0,
#   'low': 268.5,
#   'close': 268.95,
#   'volume': 7077322},
#  '2017-02-17': {'open': 265.8,
#   'high': 272.89,
#   'low': 264.15,
#   'close': 272.23,
#   'volume': 6257149},
#  '2017-02-21': {'open': 275.45,
#   'high': 281.4,
#   'low': 274.01,
#   'close': 277.39,
#   'volume': 5676747},
#  '2017-02-22': {'open': 280.31,
#   'high': 283.45,
#   'low': 272.6,
#   'close': 273.51,
#   'volume': 8754975},
#  '2017-02-23': {'open': 264.0,
#   'high': 264.66,
#   'low': 255.56,
#   'close': 255.99,
#   'volume': 14915249},
#  '2017-02-24': {'open': 252.66,
#   'high': 258.25,
#   'low': 250.2,
#   'close': 257.0,
#   'volume': 8171626},
#  '2017-02-27': {'open': 248.17,
#   'high': 248.36,
#   'low': 242.01,
#   'close': 246.23,
#   'volume': 11460810},
#  '2017-02-28': {'open': 244.19,
#   'high': 251.0,
#   'low': 243.9,
#   'close': 249.99,
#   'volume': 6078145},
#  '2017-03-01': {'open': 254.18,
#   'high': 254.85,
#   'low': 249.11,
#   'close': 250.02,
#   'volume': 4809488},
#  '2017-03-02': {'open': 249.71,
#   'high': 253.28,
#   'low': 248.27,
#   'close': 250.48,
#   'volume': 3351833},
#  '2017-03-03': {'open': 250.74,
#   'high': 251.9,
#   'low': 249.0,
#   'close': 251.57,
#   'volume': 2929234},
#  '2017-03-06': {'open': 247.91,
#   'high': 251.7,
#   'low': 247.51,
#   'close': 251.21,
#   'volume': 3355500},
#  '2017-03-07': {'open': 251.92,
#   'high': 253.89,
#   'low': 248.32,
#   'close': 248.59,
#   'volume': 3459470},
#  '2017-03-08': {'open': 247.0,
#   'high': 250.07,
#   'low': 245.32,
#   'close': 246.87,
#   'volume': 3728649},
#  '2017-03-09': {'open': 247.63,
#   'high': 248.66,
#   'low': 243.0,
#   'close': 244.9,
#   'volume': 3879293},
#  '2017-03-10': {'open': 246.21,
#   'high': 246.5,
#   'low': 243.0,
#   'close': 243.69,
#   'volume': 3066272},
#  '2017-03-13': {'open': 244.82,
#   'high': 246.85,
#   'low': 242.78,
#   'close': 246.17,
#   'volume': 3022625},
#  '2017-03-14': {'open': 246.11,
#   'high': 258.12,
#   'low': 246.02,
#   'close': 258.0,
#   'volume': 7598446},
#  '2017-03-15': {'open': 257.0,
#   'high': 261.0,
#   'low': 254.27,
#   'close': 255.73,
#   'volume': 5330806},
#  '2017-03-16': {'open': 262.4,
#   'high': 265.75,
#   'low': 259.06,
#   'close': 262.05,
#   'volume': 7132153},
#  '2017-03-17': {'open': 264.0,
#   'high': 265.33,
#   'low': 261.2,
#   'close': 261.5,
#   'volume': 6497496},
#  '2017-03-20': {'open': 260.6,
#   'high': 264.55,
#   'low': 258.82,
#   'close': 261.92,
#   'volume': 3614294},
#  '2017-03-21': {'open': 262.83,
#   'high': 264.8,
#   'low': 250.24,
#   'close': 250.68,
#   'volume': 6908554},
#  '2017-03-22': {'open': 251.56,
#   'high': 255.07,
#   'low': 250.51,
#   'close': 255.01,
#   'volume': 4059297},
#  '2017-03-23': {'open': 255.39,
#   'high': 257.67,
#   'low': 253.3,
#   'close': 254.78,
#   'volume': 3320245},
#  '2017-03-24': {'open': 255.7,
#   'high': 263.89,
#   'low': 255.01,
#   'close': 263.16,
#   'volume': 5647253},
#  '2017-03-27': {'open': 260.6,
#   'high': 270.57,
#   'low': 259.75,
#   'close': 270.22,
#   'volume': 6230795},
#  '2017-03-28': {'open': 277.02,
#   'high': 280.68,
#   'low': 275.0,
#   'close': 277.45,
#   'volume': 7987604},
#  '2017-03-29': {'open': 278.34,
#   'high': 279.6,
#   'low': 275.54,
#   'close': 277.38,
#   'volume': 3676157},
#  '2017-03-30': {'open': 278.04,
#   'high': 282.0,
#   'low': 277.21,
#   'close': 277.92,
#   'volume': 4148426},
#  '2017-03-31': {'open': 278.73,
#   'high': 279.68,
#   'low': 276.32,
#   'close': 278.3,
#   'volume': 3294640},
#  '2017-04-03': {'open': 286.9,
#   'high': 299.0,
#   'low': 284.58,
#   'close': 298.52,
#   'volume': 13888618},
#  '2017-04-04': {'open': 296.89,
#   'high': 304.81,
#   'low': 294.53,
#   'close': 303.7,
#   'volume': 10134556},
#  '2017-04-05': {'open': 302.04,
#   'high': 304.88,
#   'low': 294.2,
#   'close': 295.0,
#   'volume': 7880938},
#  '2017-04-06': {'open': 296.88,
#   'high': 301.94,
#   'low': 294.1,
#   'close': 298.7,
#   'volume': 5520588},
#  '2017-04-07': {'open': 297.5,
#   'high': 302.69,
#   'low': 297.15,
#   'close': 302.54,
#   'volume': 4579613},
#  '2017-04-10': {'open': 309.15,
#   'high': 313.73,
#   'low': 308.71,
#   'close': 312.39,
#   'volume': 7664458},
#  '2017-04-11': {'open': 313.38,
#   'high': 313.47,
#   'low': 305.5,
#   'close': 308.71,
#   'volume': 5724577},
#  '2017-04-12': {'open': 306.34,
#   'high': 308.45,
#   'low': 296.32,
#   'close': 296.84,
#   'volume': 6050682},
#  '2017-04-13': {'open': 296.7,
#   'high': 307.39,
#   'low': 295.3,
#   'close': 304.0,
#   'volume': 9284634},
#  '2017-04-17': {'open': 302.7,
#   'high': 304.0,
#   'low': 298.68,
#   'close': 301.44,
#   'volume': 4138736},
#  '2017-04-18': {'open': 299.7,
#   'high': 300.84,
#   'low': 297.9,
#   'close': 300.25,
#   'volume': 3035698},
#  '2017-04-19': {'open': 302.46,
#   'high': 306.62,
#   'low': 302.11,
#   'close': 305.52,
#   'volume': 3898024},
#  '2017-04-20': {'open': 306.51,
#   'high': 309.15,
#   'low': 300.23,
#   'close': 302.51,
#   'volume': 6149352},
#  '2017-04-21': {'open': 302.0,
#   'high': 306.4,
#   'low': 300.42,
#   'close': 305.6,
#   'volume': 4509756},
#  '2017-04-24': {'open': 309.22,
#   'high': 310.55,
#   'low': 306.02,
#   'close': 308.03,
#   'volume': 5083505},
#  '2017-04-25': {'open': 308.0,
#   'high': 313.98,
#   'low': 305.86,
#   'close': 313.79,
#   'volume': 6737708},
#  '2017-04-26': {'open': 312.37,
#   'high': 314.5,
#   'low': 309.0,
#   'close': 310.17,
#   'volume': 4695044},
#  '2017-04-27': {'open': 311.69,
#   'high': 313.09,
#   'low': 307.5,
#   'close': 308.63,
#   'volume': 3468569},
#  '2017-04-28': {'open': 309.83,
#   'high': 314.8,
#   'low': 308.0,
#   'close': 314.07,
#   'volume': 4505478},
#  '2017-05-01': {'open': 314.88,
#   'high': 327.25,
#   'low': 314.81,
#   'close': 322.83,
#   'volume': 8829565},
#  '2017-05-02': {'open': 324.0,
#   'high': 327.66,
#   'low': 316.56,
#   'close': 318.89,
#   'volume': 5382777},
#  '2017-05-03': {'open': 317.67,
#   'high': 321.53,
#   'low': 310.45,
#   'close': 311.02,
#   'volume': 7133365},
#  '2017-05-04': {'open': 307.44,
#   'high': 307.77,
#   'low': 290.76,
#   'close': 295.46,
#   'volume': 14152008},
#  '2017-05-05': {'open': 298.0,
#   'high': 308.55,
#   'low': 296.8,
#   'close': 308.35,
#   'volume': 8177347},
#  '2017-05-08': {'open': 310.9,
#   'high': 313.79,
#   'low': 305.82,
#   'close': 307.19,
#   'volume': 7006471},
#  '2017-05-09': {'open': 309.38,
#   'high': 321.99,
#   'low': 309.1,
#   'close': 321.26,
#   'volume': 9676537},
#  '2017-05-10': {'open': 321.56,
#   'high': 325.5,
#   'low': 318.12,
#   'close': 325.22,
#   'volume': 5741607},
#  '2017-05-11': {'open': 323.4,
#   'high': 326.0,
#   'low': 319.6,
#   'close': 323.1,
#   'volume': 4753819},
#  '2017-05-12': {'open': 325.48,
#   'high': 327.0,
#   'low': 321.53,
#   'close': 324.81,
#   'volume': 4121612},
#  '2017-05-15': {'open': 318.38,
#   'high': 320.2,
#   'low': 312.53,
#   'close': 315.88,
#   'volume': 7622004},
#  '2017-05-16': {'open': 317.59,
#   'high': 320.06,
#   'low': 315.14,
#   'close': 317.01,
#   'volume': 4152484},
#  '2017-05-17': {'open': 314.39,
#   'high': 314.63,
#   'low': 305.5,
#   'close': 306.11,
#   'volume': 6711940},
#  '2017-05-18': {'open': 307.0,
#   'high': 313.94,
#   'low': 305.31,
#   'close': 313.06,
#   'volume': 5653801},
#  '2017-05-19': {'open': 315.5,
#   'high': 316.5,
#   'low': 310.2,
#   'close': 310.83,
#   'volume': 4687572},
#  '2017-05-22': {'open': 312.8,
#   'high': 314.37,
#   'low': 306.8,
#   'close': 310.35,
#   'volume': 4329178},
#  '2017-05-23': {'open': 310.46,
#   'high': 310.73,
#   'low': 303.48,
#   'close': 303.86,
#   'volume': 4318354},
#  '2017-05-24': {'open': 306.51,
#   'high': 311.0,
#   'low': 305.4,
#   'close': 310.22,
#   'volume': 5041692},
#  '2017-05-25': {'open': 311.02,
#   'high': 316.97,
#   'low': 307.81,
#   'close': 316.83,
#   'volume': 5013963},
#  '2017-05-26': {'open': 317.28,
#   'high': 325.49,
#   'low': 316.31,
#   'close': 325.14,
#   'volume': 7802199},
#  '2017-05-30': {'open': 326.0,
#   'high': 336.28,
#   'low': 325.76,
#   'close': 335.1,
#   'volume': 7782916},
#  '2017-05-31': {'open': 337.69,
#   'high': 342.89,
#   'low': 335.16,
#   'close': 341.01,
#   'volume': 9963444},
#  '2017-06-01': {'open': 344.0,
#   'high': 344.88,
#   'low': 337.29,
#   'close': 340.37,
#   'volume': 7607996},
#  '2017-06-02': {'open': 339.77,
#   'high': 342.88,
#   'low': 335.93,
#   'close': 339.85,
#   'volume': 5590239},
#  '2017-06-05': {'open': 338.5,
#   'high': 348.44,
#   'low': 334.21,
#   'close': 347.32,
#   'volume': 6784368},
#  '2017-06-06': {'open': 344.7,
#   'high': 359.49,
#   'low': 339.97,
#   'close': 352.85,
#   'volume': 11086798},
#  '2017-06-07': {'open': 356.34,
#   'high': 360.5,
#   'low': 355.14,
#   'close': 359.65,
#   'volume': 9397959},
#  '2017-06-08': {'open': 363.75,
#   'high': 371.9,
#   'low': 360.22,
#   'close': 370.0,
#   'volume': 9061496},
#  '2017-06-09': {'open': 374.42,
#   'high': 376.87,
#   'low': 354.8,
#   'close': 357.32,
#   'volume': 17261435},
#  '2017-06-12': {'open': 357.99,
#   'high': 364.5,
#   'low': 350.62,
#   'close': 359.01,
#   'volume': 10517660},
#  '2017-06-13': {'open': 367.62,
#   'high': 376.0,
#   'low': 366.61,
#   'close': 375.95,
#   'volume': 11807920},
#  '2017-06-14': {'open': 381.09,
#   'high': 384.25,
#   'low': 376.31,
#   'close': 380.66,
#   'volume': 12818429},
#  '2017-06-15': {'open': 372.5,
#   'high': 375.46,
#   'low': 366.49,
#   'close': 375.34,
#   'volume': 10426469},
#  '2017-06-16': {'open': 377.98,
#   'high': 378.01,
#   'low': 370.1,
#   'close': 371.4,
#   'volume': 6730973},
#  '2017-06-19': {'open': 375.0,
#   'high': 376.7,
#   'low': 367.8,
#   'close': 369.8,
#   'volume': 6549332},
#  '2017-06-20': {'open': 376.67,
#   'high': 378.88,
#   'low': 369.73,
#   'close': 372.24,
#   'volume': 7438701},
#  '2017-06-21': {'open': 374.35,
#   'high': 376.99,
#   'low': 368.02,
#   'close': 376.4,
#   'volume': 4923210},
#  '2017-06-22': {'open': 377.99,
#   'high': 385.0,
#   'low': 373.57,
#   'close': 382.61,
#   'volume': 7529778},
#  '2017-06-23': {'open': 382.45,
#   'high': 386.99,
#   'low': 379.35,
#   'close': 383.45,
#   'volume': 6445758},
#  '2017-06-26': {'open': 386.69,
#   'high': 386.95,
#   'low': 373.1,
#   'close': 377.49,
#   'volume': 6604099},
#  '2017-06-27': {'open': 376.4,
#   'high': 376.4,
#   'low': 362.02,
#   'close': 362.37,
#   'volume': 6996399},
#  '2017-06-28': {'open': 366.68,
#   'high': 371.74,
#   'low': 362.52,
#   'close': 371.24,
#   'volume': 6302463},
#  '2017-06-29': {'open': 370.61,
#   'high': 371.0,
#   'low': 354.1,
#   'close': 360.75,
#   'volume': 8221038},
#  '2017-06-30': {'open': 363.71,
#   'high': 366.77,
#   'low': 359.62,
#   'close': 361.61,
#   'volume': 5848521},
#  '2017-07-03': {'open': 370.24,
#   'high': 371.35,
#   'low': 351.5,
#   'close': 352.62,
#   'volume': 6305401},
#  '2017-07-05': {'open': 347.2,
#   'high': 347.24,
#   'low': 326.33,
#   'close': 327.09,
#   'volume': 17046701},
#  '2017-07-06': {'open': 317.26,
#   'high': 320.79,
#   'low': 306.3,
#   'close': 308.83,
#   'volume': 19324495},
#  '2017-07-07': {'open': 313.5,
#   'high': 317.0,
#   'low': 307.38,
#   'close': 313.22,
#   'volume': 14176915},
#  '2017-07-10': {'open': 312.9,
#   'high': 317.94,
#   'low': 303.13,
#   'close': 316.05,
#   'volume': 13820889},
#  '2017-07-11': {'open': 316.0,
#   'high': 327.28,
#   'low': 314.3,
#   'close': 327.22,
#   'volume': 11559402},
#  '2017-07-12': {'open': 330.4,
#   'high': 333.1,
#   'low': 324.5,
#   'close': 329.52,
#   'volume': 10346127},
#  '2017-07-13': {'open': 330.11,
#   'high': 331.6,
#   'low': 319.97,
#   'close': 323.41,
#   'volume': 8594466},
#  '2017-07-14': {'open': 323.19,
#   'high': 328.42,
#   'low': 321.22,
#   'close': 327.78,
#   'volume': 5625211},
#  '2017-07-17': {'open': 325.54,
#   'high': 327.1,
#   'low': 313.45,
#   'close': 319.57,
#   'volume': 9876912},
#  '2017-07-18': {'open': 317.5,
#   'high': 329.13,
#   'low': 315.66,
#   'close': 328.24,
#   'volume': 6373720},
#  '2017-07-19': {'open': 328.23,
#   'high': 331.65,
#   'low': 323.22,
#   'close': 325.26,
#   'volume': 6357014},
#  '2017-07-20': {'open': 326.9,
#   'high': 330.22,
#   'low': 324.2,
#   'close': 329.92,
#   'volume': 5166188},
#  '2017-07-21': {'open': 329.46,
#   'high': 331.26,
#   'low': 325.8,
#   'close': 328.4,
#   'volume': 4901606},
#  '2017-07-24': {'open': 330.24,
#   'high': 343.4,
#   'low': 330.01,
#   'close': 342.52,
#   'volume': 8637082},
#  '2017-07-25': {'open': 345.0,
#   'high': 345.6,
#   'low': 334.15,
#   'close': 339.6,
#   'volume': 6989197},
#  '2017-07-26': {'open': 340.36,
#   'high': 345.5,
#   'low': 338.12,
#   'close': 343.85,
#   'volume': 4820790},
#  '2017-07-27': {'open': 346.0,
#   'high': 347.5,
#   'low': 326.29,
#   'close': 334.46,
#   'volume': 8302405},
#  '2017-07-28': {'open': 336.89,
#   'high': 339.6,
#   'low': 332.51,
#   'close': 335.07,
#   'volume': 4880414},
#  '2017-07-31': {'open': 335.5,
#   'high': 341.49,
#   'low': 321.04,
#   'close': 323.47,
#   'volume': 8535136},
#  '2017-08-01': {'open': 323.0,
#   'high': 324.45,
#   'low': 316.13,
#   'close': 319.57,
#   'volume': 8303102},
#  '2017-08-02': {'open': 318.94,
#   'high': 327.12,
#   'low': 311.22,
#   'close': 325.89,
#   'volume': 13091462},
#  '2017-08-03': {'open': 345.33,
#   'high': 350.0,
#   'low': 343.15,
#   'close': 347.09,
#   'volume': 13535033},
#  '2017-08-04': {'open': 347.0,
#   'high': 357.27,
#   'low': 343.3,
#   'close': 356.91,
#   'volume': 9268909},
#  '2017-08-07': {'open': 357.35,
#   'high': 359.48,
#   'low': 352.75,
#   'close': 355.17,
#   'volume': 6324480},
#  '2017-08-08': {'open': 357.53,
#   'high': 368.58,
#   'low': 357.4,
#   'close': 365.22,
#   'volume': 7449837},
#  '2017-08-09': {'open': 361.0,
#   'high': 370.0,
#   'low': 358.95,
#   'close': 363.53,
#   'volume': 6892096},
#  '2017-08-10': {'open': 361.6,
#   'high': 366.65,
#   'low': 354.66,
#   'close': 355.4,
#   'volume': 7092858},
#  '2017-08-11': {'open': 356.97,
#   'high': 361.26,
#   'low': 353.62,
#   'close': 357.87,
#   'volume': 4365783},
#  '2017-08-14': {'open': 364.63,
#   'high': 367.66,
#   'low': 362.6,
#   'close': 363.8,
#   'volume': 4519186},
#  '2017-08-15': {'open': 365.2,
#   'high': 365.49,
#   'low': 359.37,
#   'close': 362.33,
#   'volume': 3085088},
#  '2017-08-16': {'open': 363.0,
#   'high': 366.5,
#   'low': 362.52,
#   'close': 362.91,
#   'volume': 3413773},
#  '2017-08-17': {'open': 361.21,
#   'high': 363.3,
#   'low': 351.59,
#   'close': 351.92,
#   'volume': 5027660},
#  '2017-08-18': {'open': 352.91,
#   'high': 354.0,
#   'low': 345.8,
#   'close': 347.46,
#   'volume': 5408183},
#  '2017-08-21': {'open': 345.82,
#   'high': 345.82,
#   'low': 331.85,
#   'close': 337.86,
#   'volume': 6495424},
#  '2017-08-22': {'open': 341.13,
#   'high': 342.24,
#   'low': 337.37,
#   'close': 341.35,
#   'volume': 4321966},
#  '2017-08-23': {'open': 338.99,
#   'high': 353.49,
#   'low': 338.3,
#   'close': 352.77,
#   'volume': 4954504},
#  '2017-08-24': {'open': 352.52,
#   'high': 356.66,
#   'low': 349.74,
#   'close': 352.93,
#   'volume': 4584687},
#  '2017-08-25': {'open': 354.24,
#   'high': 355.69,
#   'low': 347.3,
#   'close': 348.05,
#   'volume': 3483956},
#  '2017-08-28': {'open': 347.28,
#   'high': 347.35,
#   'low': 339.72,
#   'close': 345.66,
#   'volume': 3763956},
#  '2017-08-29': {'open': 339.48,
#   'high': 349.05,
#   'low': 338.75,
#   'close': 347.36,
#   'volume': 4073675},
#  '2017-08-30': {'open': 349.67,
#   'high': 353.47,
#   'low': 347.0,
#   'close': 353.18,
#   'volume': 3412943},
#  '2017-08-31': {'open': 353.55,
#   'high': 358.44,
#   'low': 352.82,
#   'close': 355.9,
#   'volume': 4072795},
#  '2017-09-01': {'open': 356.12,
#   'high': 357.59,
#   'low': 353.69,
#   'close': 355.4,
#   'volume': 3049546},
#  '2017-09-05': {'open': 353.8,
#   'high': 355.49,
#   'low': 345.89,
#   'close': 349.59,
#   'volume': 3848382},
#  '2017-09-06': {'open': 349.5,
#   'high': 350.98,
#   'low': 341.56,
#   'close': 344.53,
#   'volume': 4091351},
#  '2017-09-07': {'open': 345.98,
#   'high': 352.48,
#   'low': 343.45,
#   'close': 350.61,
#   'volume': 4239213},
#  '2017-09-08': {'open': 348.99,
#   'high': 349.78,
#   'low': 342.3,
#   'close': 343.4,
#   'volume': 3263508},
#  '2017-09-11': {'open': 351.35,
#   'high': 363.71,
#   'low': 350.0,
#   'close': 363.69,
#   'volume': 7667055},
#  '2017-09-12': {'open': 364.49,
#   'high': 368.76,
#   'low': 360.4,
#   'close': 362.75,
#   'volume': 5972907},
#  '2017-09-13': {'open': 363.82,
#   'high': 368.07,
#   'low': 359.59,
#   'close': 366.23,
#   'volume': 4185231},
#  '2017-09-14': {'open': 364.33,
#   'high': 377.96,
#   'low': 362.63,
#   'close': 377.64,
#   'volume': 7202524},
#  '2017-09-15': {'open': 374.51,
#   'high': 380.0,
#   'low': 372.7,
#   'close': 379.81,
#   'volume': 5420496},
#  '2017-09-18': {'open': 380.25,
#   'high': 389.61,
#   'low': 377.68,
#   'close': 385.0,
#   'volume': 7187980},
#  '2017-09-19': {'open': 380.0,
#   'high': 382.39,
#   'low': 373.57,
#   'close': 375.1,
#   'volume': 6451886},
#  '2017-09-20': {'open': 373.0,
#   'high': 378.25,
#   'low': 371.07,
#   'close': 373.91,
#   'volume': 4919052},
#  '2017-09-21': {'open': 374.9,
#   'high': 376.83,
#   'low': 364.51,
#   'close': 366.48,
#   'volume': 4618190},
#  '2017-09-22': {'open': 366.49,
#   'high': 369.9,
#   'low': 350.88,
#   'close': 351.09,
#   'volume': 8159418},
#  '2017-09-25': {'open': 353.15,
#   'high': 357.47,
#   'low': 342.88,
#   'close': 344.99,
#   'volume': 7605946},
#  '2017-09-26': {'open': 350.93,
#   'high': 351.24,
#   'low': 340.9,
#   'close': 345.25,
#   'volume': 7156274},
#  '2017-09-27': {'open': 349.9,
#   'high': 351.49,
#   'low': 340.5,
#   'close': 340.97,
#   'volume': 6060330},
#  '2017-09-28': {'open': 339.88,
#   'high': 342.75,
#   'low': 335.4,
#   'close': 339.6,
#   'volume': 5319617},
#  '2017-09-29': {'open': 341.86,
#   'high': 344.68,
#   'low': 338.6,
#   'close': 341.1,
#   'volume': 5107082},
#  '2017-10-02': {'open': 342.52,
#   'high': 343.7,
#   'low': 335.51,
#   'close': 341.53,
#   'volume': 5286774},
#  '2017-10-03': {'open': 335.9,
#   'high': 348.55,
#   'low': 331.28,
#   'close': 348.14,
#   'volume': 10153596},
#  '2017-10-04': {'open': 351.25,
#   'high': 358.62,
#   'low': 349.6,
#   'close': 355.01,
#   'volume': 8163543},
#  '2017-10-05': {'open': 356.0,
#   'high': 357.44,
#   'low': 351.35,
#   'close': 355.33,
#   'volume': 4171675},
#  '2017-10-06': {'open': 353.1,
#   'high': 360.1,
#   'low': 352.25,
#   'close': 356.88,
#   'volume': 4297474},
#  '2017-10-09': {'open': 349.65,
#   'high': 351.75,
#   'low': 342.67,
#   'close': 342.94,
#   'volume': 7493654},
#  '2017-10-10': {'open': 346.8,
#   'high': 355.63,
#   'low': 345.53,
#   'close': 355.59,
#   'volume': 6978495},
#  '2017-10-11': {'open': 353.89,
#   'high': 357.6,
#   'low': 351.15,
#   'close': 354.6,
#   'volume': 4500831},
#  '2017-10-12': {'open': 352.95,
#   'high': 359.78,
#   'low': 352.64,
#   'close': 355.68,
#   'volume': 4087048},
#  '2017-10-13': {'open': 356.98,
#   'high': 358.49,
#   'low': 353.68,
#   'close': 355.57,
#   'volume': 3540533},
#  '2017-10-16': {'open': 353.76,
#   'high': 354.48,
#   'low': 347.16,
#   'close': 350.6,
#   'volume': 5375486},
#  '2017-10-17': {'open': 350.91,
#   'high': 356.22,
#   'low': 350.07,
#   'close': 355.75,
#   'volume': 3293345},
#  '2017-10-18': {'open': 355.97,
#   'high': 363.0,
#   'low': 354.13,
#   'close': 359.65,
#   'volume': 4939074},
#  '2017-10-19': {'open': 355.56,
#   'high': 357.15,
#   'low': 348.2,
#   'close': 351.81,
#   'volume': 5061843},
#  '2017-10-20': {'open': 352.69,
#   'high': 354.55,
#   'low': 344.34,
#   'close': 345.1,
#   'volume': 4930395},
#  '2017-10-23': {'open': 349.88,
#   'high': 349.95,
#   'low': 336.25,
#   'close': 337.02,
#   'volume': 5747346},
#  '2017-10-24': {'open': 338.8,
#   'high': 342.8,
#   'low': 336.16,
#   'close': 337.34,
#   'volume': 4491672},
#  '2017-10-25': {'open': 336.7,
#   'high': 337.5,
#   'low': 323.56,
#   'close': 325.84,
#   'volume': 8594073},
#  '2017-10-26': {'open': 327.78,
#   'high': 330.23,
#   'low': 323.2,
#   'close': 326.17,
#   'volume': 5023500},
#  '2017-10-27': {'open': 319.75,
#   'high': 324.59,
#   'low': 316.66,
#   'close': 320.87,
#   'volume': 6979704},
#  '2017-10-30': {'open': 319.18,
#   'high': 323.78,
#   'low': 317.25,
#   'close': 320.08,
#   'volume': 4254378},
#  '2017-10-31': {'open': 320.23,
#   'high': 331.95,
#   'low': 320.18,
#   'close': 331.53,
#   'volume': 5672347},
#  '2017-11-01': {'open': 332.25,
#   'high': 332.61,
#   'low': 320.26,
#   'close': 321.08,
#   'volume': 8457336},
#  '2017-11-02': {'open': 300.13,
#   'high': 308.69,
#   'low': 292.63,
#   'close': 299.26,
#   'volume': 19791416},
#  '2017-11-03': {'open': 299.5,
#   'high': 306.25,
#   'low': 295.13,
#   'close': 306.09,
#   'volume': 8893974},
#  '2017-11-06': {'open': 307.0,
#   'high': 307.5,
#   'low': 299.01,
#   'close': 302.78,
#   'volume': 6486009},
#  '2017-11-07': {'open': 301.02,
#   'high': 306.5,
#   'low': 300.03,
#   'close': 306.05,
#   'volume': 5294274},
#  '2017-11-08': {'open': 305.5,
#   'high': 306.89,
#   'low': 301.3,
#   'close': 304.39,
#   'volume': 4725271},
#  '2017-11-09': {'open': 302.5,
#   'high': 304.46,
#   'low': 296.3,
#   'close': 302.99,
#   'volume': 5447147},
#  '2017-11-10': {'open': 302.5,
#   'high': 308.36,
#   'low': 301.85,
#   'close': 302.99,
#   'volume': 4625429},
#  '2017-11-13': {'open': 300.13,
#   'high': 316.8,
#   'low': 299.11,
#   'close': 315.4,
#   'volume': 7584944},
#  '2017-11-14': {'open': 315.0,
#   'high': 316.35,
#   'low': 306.9,
#   'close': 308.7,
#   'volume': 5676076},
#  '2017-11-15': {'open': 306.01,
#   'high': 312.49,
#   'low': 301.5,
#   'close': 311.3,
#   'volume': 5978665},
#  '2017-11-16': {'open': 313.99,
#   'high': 318.14,
#   'low': 311.3,
#   'close': 312.5,
#   'volume': 5822073},
#  '2017-11-17': {'open': 325.67,
#   'high': 326.67,
#   'low': 313.15,
#   'close': 315.05,
#   'volume': 13735139},
#  '2017-11-20': {'open': 313.79,
#   'high': 315.5,
#   'low': 304.75,
#   'close': 308.74,
#   'volume': 8247650},
#  '2017-11-21': {'open': 310.86,
#   'high': 318.23,
#   'low': 308.71,
#   'close': 317.81,
#   'volume': 7261273},
#  '2017-11-22': {'open': 316.77,
#   'high': 317.42,
#   'low': 311.84,
#   'close': 312.6,
#   'volume': 4917636},
#  '2017-11-24': {'open': 313.79,
#   'high': 316.41,
#   'low': 311.0,
#   'close': 315.55,
#   'volume': 3244065},
#  '2017-11-27': {'open': 313.25,
#   'high': 317.34,
#   'low': 309.51,
#   'close': 316.81,
#   'volume': 4555894},
#  '2017-11-28': {'open': 316.36,
#   'high': 320.0,
#   'low': 313.92,
#   'close': 317.55,
#   'volume': 4949491},
#  '2017-11-29': {'open': 317.3,
#   'high': 318.0,
#   'low': 301.23,
#   'close': 307.54,
#   'volume': 8767398},
#  '2017-11-30': {'open': 308.56,
#   'high': 310.7,
#   'low': 304.54,
#   'close': 308.85,
#   'volume': 4351587},
#  '2017-12-01': {'open': 305.44,
#   'high': 310.32,
#   'low': 305.05,
#   'close': 306.53,
#   'volume': 4292868},
#  '2017-12-04': {'open': 306.5,
#   'high': 308.27,
#   'low': 300.61,
#   'close': 305.2,
#   'volume': 5835140},
#  '2017-12-05': {'open': 302.0,
#   'high': 308.0,
#   'low': 301.0,
#   'close': 303.7,
#   'volume': 4646520},
#  '2017-12-06': {'open': 300.1,
#   'high': 313.39,
#   'low': 300.0,
#   'close': 313.26,
#   'volume': 7195341},
#  '2017-12-07': {'open': 312.0,
#   'high': 318.63,
#   'low': 311.05,
#   'close': 311.24,
#   'volume': 4780597},
#  '2017-12-08': {'open': 314.6,
#   'high': 316.98,
#   'low': 311.26,
#   'close': 315.13,
#   'volume': 3468458},
#  '2017-12-11': {'open': 314.63,
#   'high': 329.01,
#   'low': 313.75,
#   'close': 328.91,
#   'volume': 7937981},
#  '2017-12-12': {'open': 330.45,
#   'high': 341.44,
#   'low': 330.03,
#   'close': 341.03,
#   'volume': 8733199},
#  '2017-12-13': {'open': 340.93,
#   'high': 344.22,
#   'low': 336.5,
#   'close': 339.03,
#   'volume': 6221461},
#  '2017-12-14': {'open': 341.01,
#   'high': 347.44,
#   'low': 336.9,
#   'close': 337.89,
#   'volume': 5799916},
#  '2017-12-15': {'open': 342.04,
#   'high': 343.9,
#   'low': 335.76,
#   'close': 343.45,
#   'volume': 6933199},
#  '2017-12-18': {'open': 344.9,
#   'high': 346.73,
#   'low': 337.58,
#   'close': 338.87,
#   'volume': 5476166},
#  '2017-12-19': {'open': 340.26,
#   'high': 341.49,
#   'low': 330.3,
#   'close': 331.1,
#   'volume': 6824971},
#  '2017-12-20': {'open': 332.69,
#   'high': 333.1,
#   'low': 325.04,
#   'close': 328.98,
#   'volume': 5953800},
#  '2017-12-21': {'open': 329.59,
#   'high': 333.74,
#   'low': 327.21,
#   'close': 331.66,
#   'volume': 4385222},
#  '2017-12-22': {'open': 329.51,
#   'high': 330.92,
#   'low': 324.82,
#   'close': 325.2,
#   'volume': 4215807},
#  '2017-12-26': {'open': 323.83,
#   'high': 323.94,
#   'low': 316.58,
#   'close': 317.29,
#   'volume': 4378413},
#  '2017-12-27': {'open': 316.0,
#   'high': 317.68,
#   'low': 310.75,
#   'close': 311.64,
#   'volume': 4712111},
#  '2017-12-28': {'open': 311.75,
#   'high': 315.82,
#   'low': 309.54,
#   'close': 315.36,
#   'volume': 4316347},
#  '2017-12-29': {'open': 316.18,
#   'high': 316.41,
#   'low': 310.0,
#   'close': 311.35,
#   'volume': 3777155}}

# %%
    # To obtain daily closing prices only (reduces message count), set close_only=True:
df = get_historical_data("TSLA", "20190617", close_only=True, token='pk_b740ad24ded147cca822e98ded174c3d')
df
# Out:
# {'2019-06-17': {'close': 225.03, 'volume': 12316803}}

# %%
    # For Pandas DataFrame output formatting, pass output_format:
df = get_historical_data("TSLA", start, end, output_format='pandas', token='pk_b740ad24ded147cca822e98ded174c3d')

# %%
    # It's really simple to plot this data, using matplotlib:
import matplotlib.pyplot as plt

df.plot()
plt.show()

# %% [markdown]
# #### Minutely (Intraday)
# * To obtain historical intraday data, use get_historical_intraday as follows.
# * Pass an optional date to specify a date within three months prior to the current day (default is current date):

# %%
from datetime import datetime
from iexfinance.stocks import get_historical_intraday

date = datetime(2018, 11, 27)

get_historical_intraday("AAPL", date, token='pk_b740ad24ded147cca822e98ded174c3d')
# Out:
# []

# %%
    # or for a Pandas Dataframe indexed by each minute:

get_historical_intraday("AAPL", output_format='pandas', token='pk_b740ad24ded147cca822e98ded174c3d')
# Out:
#                            date     label     high      low  average  volume  \
# 2020-03-06 09:30:00  2020-03-06  09:30 AM  283.370  281.360  282.502   14100
# 2020-03-06 09:31:00  2020-03-06  09:31 AM  283.230  282.230  282.842    7814
# 2020-03-06 09:32:00  2020-03-06  09:32 AM  284.725  282.900  283.682   24941
# 2020-03-06 09:33:00  2020-03-06  09:33 AM  284.900  284.335  284.536    4760
# 2020-03-06 09:34:00  2020-03-06  09:34 AM  284.470  282.880  284.305   27212
# ...                         ...       ...      ...      ...      ...     ...
# 2020-03-06 15:55:00  2020-03-06   3:55 PM  289.490  288.910  289.124    2021
# 2020-03-06 15:56:00  2020-03-06   3:56 PM  289.660  288.880  289.366    3340
# 2020-03-06 15:57:00  2020-03-06   3:57 PM  290.740  289.605  290.320    5669
# 2020-03-06 15:58:00  2020-03-06   3:58 PM  290.120  289.385  289.736    5610
# 2020-03-06 15:59:00  2020-03-06   3:59 PM  289.360  288.370  288.738   12777
#
#                         notional  numberOfTrades  marketHigh  marketLow  \
# 2020-03-06 09:30:00  3983284.400              95     283.645     281.23
# 2020-03-06 09:31:00  2210125.685              59     283.280     282.13
# 2020-03-06 09:32:00  7075300.330              66     284.764     282.78
# 2020-03-06 09:33:00  1354392.970              35     284.960     284.15
# 2020-03-06 09:34:00  7736514.450              24     284.500     282.80
# ...                          ...             ...         ...        ...
# 2020-03-06 15:55:00   584320.120              27     289.640     288.79
# 2020-03-06 15:56:00   966482.400              35     289.670     288.84
# 2020-03-06 15:57:00  1645825.070              67     290.820     289.56
# 2020-03-06 15:58:00  1625417.045              63     290.120     289.31
# 2020-03-06 15:59:00  3689208.605             154     289.520     288.33
#
#                      marketAverage  marketVolume  marketNotional  \
# 2020-03-06 09:30:00        282.120       1256434    3.544654e+08
# 2020-03-06 09:31:00        282.735        288926    8.168942e+07
# 2020-03-06 09:32:00        283.899        361483    1.026245e+08
# 2020-03-06 09:33:00        284.540        290693    8.271392e+07
# 2020-03-06 09:34:00        283.699        329061    9.335433e+07
# ...                            ...           ...             ...
# 2020-03-06 15:55:00        289.208        217476    6.289579e+07
# 2020-03-06 15:56:00        289.439        230990    6.685759e+07
# 2020-03-06 15:57:00        290.173        441171    1.280162e+08
# 2020-03-06 15:58:00        289.740        349260    1.011947e+08
# 2020-03-06 15:59:00        288.850        651867    1.882917e+08
#
#                      marketNumberOfTrades     open    close  marketOpen  \
# 2020-03-06 09:30:00                  2587  281.890  282.830     282.000
# 2020-03-06 09:31:00                  1773  283.005  283.055     282.840
# 2020-03-06 09:32:00                  1927  282.965  284.485     283.010
# 2020-03-06 09:33:00                  1555  284.700  284.470     284.600
# 2020-03-06 09:34:00                  1732  284.385  283.540     284.440
# ...                                   ...      ...      ...         ...
# 2020-03-06 15:55:00                  1318  289.010  288.940     288.976
# 2020-03-06 15:56:00                  1310  288.880  289.480     288.850
# 2020-03-06 15:57:00                  2271  289.640  289.830     289.610
# 2020-03-06 15:58:00                  1977  289.610  289.490     289.780
# 2020-03-06 15:59:00                  3386  289.300  288.980     289.490
#
#                      marketClose  changeOverTime  marketChangeOverTime
# 2020-03-06 09:30:00      282.900        0.000000              0.000000
# 2020-03-06 09:31:00      283.055        0.001204              0.002180
# 2020-03-06 09:32:00      284.620        0.004177              0.006306
# 2020-03-06 09:33:00      284.349        0.007200              0.008578
# 2020-03-06 09:34:00      283.480        0.006382              0.005597
# ...                          ...             ...                   ...
# 2020-03-06 15:55:00      288.822        0.023441              0.025124
# 2020-03-06 15:56:00      289.632        0.024297              0.025943
# 2020-03-06 15:57:00      289.845        0.027674              0.028545
# 2020-03-06 15:58:00      289.460        0.025607              0.027010
# 2020-03-06 15:59:00      289.060        0.022074              0.023855
#
# [390 rows x 20 columns]

# %% [markdown]
# #### Real-time Quotes
# * To obtain real-time quotes for one or more symbols, use the get_price method of the Stock object:

# %%
from iexfinance.stocks import Stock
tsla = Stock('TSLA', token='pk_b740ad24ded147cca822e98ded174c3d')
tsla.get_price()
# Out:
# 703.48

# %% [markdown]
# ### Fundamentals

# %% [markdown]
# #### Balance Sheet

# %%
from iexfinance.stocks import Stock

aapl = Stock("AAPL", token='pk_b740ad24ded147cca822e98ded174c3d')
aapl.get_balance_sheet()
# Out:
# {'symbol': 'AAPL',
#  'balancesheet': [{'reportDate': '2019-12-31',
#    'fiscalDate': '2019-12-28',
#    'currency': 'USD',
#    'currentCash': 22986000000,
#    'shortTermInvestments': 84244000000,
#    'receivables': 20970000000,
#    'inventory': 4097000000,
#    'otherCurrentAssets': 11958000000,
#    'currentAssets': 163231000000,
#    'longTermInvestments': 101725000000,
#    'propertyPlantEquipment': 44293000000,
#    'goodwill': None,
#    'intangibleAssets': None,
#    'otherAssets': 31369000000,
#    'totalAssets': 340618000000,
#    'accountsPayable': 45111000000,
#    'currentLongTermDebt': 10238000000,
#    'otherCurrentLiabilities': 40577000000,
#    'totalCurrentLiabilities': 102161000000,
#    'longTermDebt': 100278000000,
#    'otherLiabilities': 2550000000,
#    'minorityInterest': 0,
#    'totalLiabilities': 251087000000,
#    'commonStock': 4384959000,
#    'retainedEarnings': 43977000000,
#    'treasuryStock': None,
#    'capitalSurplus': None,
#    'shareholderEquity': 89531000000,
#    'netTangibleAssets': 89531000000}]}

# %% [markdown]
# #### Income Statement

# %%
aapl.get_income_statement()
# Out:
# [{'reportDate': '2019-12-31',
#   'fiscalDate': '2019-12-28',
#   'currency': 'USD',
#   'totalRevenue': 91722000000,
#   'costOfRevenue': 56773000000,
#   'grossProfit': 34949000000,
#   'researchAndDevelopment': 4451000000,
#   'sellingGeneralAndAdmin': 5197000000,
#   'operatingExpense': 66421000000,
#   'operatingIncome': 25301000000,
#   'otherIncomeExpenseNet': 617000000,
#   'ebit': 25301000000,
#   'interestIncome': 785000000,
#   'pretaxIncome': 25918000000,
#   'incomeTax': 3682000000,
#   'minorityInterest': 0,
#   'netIncome': 22236000000,
#   'netIncomeBasic': 22236000000}]

# %% [markdown]
# #### Cash Flow

# %%
aapl.get_cash_flow()
# Out:
# {'symbol': 'AAPL',
#  'cashflow': [{'reportDate': '2019-12-31',
#    'fiscalDate': '2019-12-28',
#    'currency': 'USD',
#    'netIncome': 22236000000,
#    'depreciation': 2816000000,
#    'changesInReceivables': 1956000000,
#    'changesInInventories': -28000000,
#    'cashChange': -8559000000,
#    'cashFlow': 30516000000,
#    'capitalExpenditures': -2107000000,
#    'investments': -10473000000,
#    'investingActivityOther': -130000000,
#    'totalInvestingCashFlows': -13668000000,
#    'dividendsPaid': -3539000000,
#    'netBorrowings': 231000000,
#    'otherFinancingCashFlows': -1395000000,
#    'cashFlowFinancing': -25407000000,
#    'exchangeRateEffect': None}]}

# %% [markdown]
# #### Modeling/Valuation Tools
# * Analyst Estimates

# %%
from iexfinance.stocks import Stock

aapl = Stock("AAPL",token = 'pk_3e46a4b55bd04bd68bb778802602595b')

aapl.get_estimates()
# Out:
# {'symbol': 'AAPL',
#  'estimates': [{'consensusEPS': 2.7,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 36,
#    'reportDate': '2020-05-05',
#    'fiscalPeriod': 'Q1 2020',
#    'fiscalEndDate': '2020-03-31',
#    'currency': 'USD'}]}

# %% [markdown]
# #### Price Target

# %%
aapl.get_price_target()
# Out:
# {'symbol': 'AAPL',
#  'updatedDate': '2020-03-04',
#  'priceTargetAverage': 331.09,
#  'priceTargetHigh': 400,
#  'priceTargetLow': 190,
#  'numberOfAnalysts': 39,
#  'currency': 'USD'}

# %% [markdown]
# #### Social Sentiment
# * iexfinance.altdata.get_social_sentiment(symbol, period_type=None, date=None, **kwargs)

# %%
from iexfinance.altdata import get_social_sentiment
get_social_sentiment("AAPL", token='pk_b740ad24ded147cca822e98ded174c3d')
# Out:
# {}

# %% [markdown]
# ####  CEO Compensation
# * iexfinance.altdata.get_ceo_compensation(symbol, **kwargs)

# %%
from iexfinance.altdata import get_ceo_compensation
get_ceo_compensation("AAPL", token='pk_b740ad24ded147cca822e98ded174c3d')
# Out:
# {'symbol': 'AAPL',
#  'name': 'Timothy Cook',
#  'companyName': 'Apple Inc.',
#  'location': 'Cupertino, CA',
#  'salary': 3000000,
#  'bonus': 0,
#  'stockAwards': 0,
#  'optionAwards': 0,
#  'nonEquityIncentives': 12000000,
#  'pensionAndDeferred': 0,
#  'otherComp': 682219,
#  'total': 15682219,
#  'year': '2018'}

# %% [markdown]
# ####  Fund and Institutional Ownership

# %%
from iexfinance.stocks import Stock
aapl = Stock("AAPL", token = 'pk_3e46a4b55bd04bd68bb778802602595b')

# Fund ownership
aapl.get_fund_ownership()

# Institutional ownership
aapl.get_institutional_ownership()
# Out:
# [{'reportDate': 1577750400000,
#   'adjHolding': 321838023,
#   'reportedHolding': 321838023,
#   'adjMv': 94507735454,
#   'entityProperName': 'Vanguard Group, Inc. (Subfiler)'},
#  {'reportDate': 1577750400000,
#   'adjHolding': 245155566,
#   'reportedHolding': 245155566,
#   'adjMv': 71989931956,
#   'entityProperName': 'Berkshire Hathaway, Inc.'},
#  {'reportDate': 1577750400000,
#   'adjHolding': 182854781,
#   'reportedHolding': 182854781,
#   'adjMv': 53695306441,
#   'entityProperName': 'State Street Corp.'},
#  {'reportDate': 1577750400000,
#   'adjHolding': 105216722,
#   'reportedHolding': 105216722,
#   'adjMv': 30896890415,
#   'entityProperName': 'BlackRock Institutional Trust Co. NA'},
#  {'reportDate': 1577750400000,
#   'adjHolding': 88533508,
#   'reportedHolding': 88533508,
#   'adjMv': 25997864624,
#   'entityProperName': 'Fidelity Management & Research Co. LLC'},
#  {'reportDate': 1577750400000,
#   'adjHolding': 84638689,
#   'reportedHolding': 84638689,
#   'adjMv': 24854151025,
#   'entityProperName': 'BlackRock Fund Advisors'},
#  {'reportDate': 1577750400000,
#   'adjHolding': 62482090,
#   'reportedHolding': 62482090,
#   'adjMv': 18347865729,
#   'entityProperName': 'Geode Capital Management LLC'},
#  {'reportDate': 1577750400000,
#   'adjHolding': 55032139,
#   'reportedHolding': 55032139,
#   'adjMv': 16160187617,
#   'entityProperName': 'Northern Trust Corp.'},
#  {'reportDate': 1577750400000,
#   'adjHolding': 51779477,
#   'reportedHolding': 51779477,
#   'adjMv': 15205043421,
#   'entityProperName': 'T. Rowe Price Associates, Inc. (Investment Management)'},
#  {'reportDate': 1577750400000,
#   'adjHolding': 46856273,
#   'reportedHolding': 46856273,
#   'adjMv': 13759344566,
#   'entityProperName': 'Norges Bank (13F)'}]

# %% [markdown]
# #### List of Symbols IEX supports for API calls

# %%
from iexfinance.refdata import get_symbols


get_symbols(token = 'pk_3e46a4b55bd04bd68bb778802602595b')
# Out:
# [{'symbol': 'A',
#   'exchange': 'NYS',
#   'name': 'Agilent Technologies Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_46574843354B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C2V3D6',
#   'cik': '1090872'},
#  {'symbol': 'AA',
#   'exchange': 'NYS',
#   'name': 'Alcoa Corp.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4238333734532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00B3T3HD3',
#   'cik': '1675149'},
#  {'symbol': 'AAAU',
#   'exchange': 'PSE',
#   'name': 'Perth Mint Physical Gold ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_474B433136332D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00LPXX872',
#   'cik': None},
#  {'symbol': 'AACG',
#   'exchange': 'NAS',
#   'name': 'ATA Creativity Global Sponsored ADR',
#   'date': '2020-03-06',
#   'type': 'ad',
#   'iexId': 'IEX_44595A4C53392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000V2S3P6',
#   'cik': None},
#  {'symbol': 'AADR',
#   'exchange': 'PSE',
#   'name': 'AdvisorShares Dorsey Wright ADR ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5253355435362D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BDYRW6',
#   'cik': None},
#  {'symbol': 'AAL',
#   'exchange': 'NAS',
#   'name': 'American Airlines Group Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4353464A535A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG005P7Q881',
#   'cik': '6201'},
#  {'symbol': 'AAMC',
#   'exchange': 'ASE',
#   'name': 'Altisource Asset Management Corp.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5442323844432D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG003PNL136',
#   'cik': '1555074'},
#  {'symbol': 'AAME',
#   'exchange': 'NAS',
#   'name': 'Atlantic American Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5737584C53442D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000B9XB24',
#   'cik': '8177'},
#  {'symbol': 'AAN',
#   'exchange': 'NYS',
#   'name': "Aaron's Inc.",
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_534D305A30592D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000D9V7T4',
#   'cik': '706688'},
#  {'symbol': 'AAOI',
#   'exchange': 'NAS',
#   'name': 'Applied Optoelectronics Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C394B5933512D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000D6VW15',
#   'cik': '1158114'},
#  {'symbol': 'AAON',
#   'exchange': 'NAS',
#   'name': 'AAON Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4E57434244582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C2LZP3',
#   'cik': '824142'},
#  {'symbol': 'AAP',
#   'exchange': 'NYS',
#   'name': 'Advance Auto Parts Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4850353858392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000F7RCJ1',
#   'cik': '1158449'},
#  {'symbol': 'AAPL',
#   'exchange': 'NAS',
#   'name': 'Apple Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4D48333344362D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000B9XRY4',
#   'cik': '320193'},
#  {'symbol': 'AAT',
#   'exchange': 'NYS',
#   'name': 'American Assets Trust Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4742423330312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00161BCR0',
#   'cik': '1500217'},
#  {'symbol': 'AAU',
#   'exchange': 'ASE',
#   'name': 'Almaden Minerals Ltd.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5639393533472D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000DGFSY4',
#   'cik': '1015647'},
#  {'symbol': 'AAWW',
#   'exchange': 'NAS',
#   'name': 'Atlas Air Worldwide Holdings Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4754595032502D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000Q57YP0',
#   'cik': '1135185'},
#  {'symbol': 'AAXJ',
#   'exchange': 'NAS',
#   'name': 'iShares MSCI All Country Asia ex Japan ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_4332325853592D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000G6GXC5',
#   'cik': None},
#  {'symbol': 'AAXN',
#   'exchange': 'NAS',
#   'name': 'Axon Enterprise Inc',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_52584D56394D2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BHJWG1',
#   'cik': '1069183'},
#  {'symbol': 'AB',
#   'exchange': 'NYS',
#   'name': 'AllianceBernstein Holding L.P.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4E465333304C2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000B9WM03',
#   'cik': '825313'},
#  {'symbol': 'ABB',
#   'exchange': 'NYS',
#   'name': 'ABB Ltd. Sponsored ADR',
#   'date': '2020-03-06',
#   'type': 'ad',
#   'iexId': 'IEX_47395A4B54312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000DK5Q25',
#   'cik': '1091587'},
#  {'symbol': 'ABBV',
#   'exchange': 'NYS',
#   'name': 'AbbVie Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4334484252542D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG0025Y4RY4',
#   'cik': '1551152'},
#  {'symbol': 'ABC',
#   'exchange': 'NYS',
#   'name': 'AmerisourceBergen Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_424B324652572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000MDCQC2',
#   'cik': '1140859'},
#  {'symbol': 'ABCB',
#   'exchange': 'NAS',
#   'name': 'Ameris Bancorp',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_52584C584A522D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000CDY3H5',
#   'cik': '351569'},
#  {'symbol': 'ABEO',
#   'exchange': 'NAS',
#   'name': 'Abeona Therapeutics Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4E31383330472D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000DT5D52',
#   'cik': '318306'},
#  {'symbol': 'ABEQ',
#   'exchange': 'PSE',
#   'name': 'Absolute Core Strategy ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_57474C4750582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00RHHGQY2',
#   'cik': None},
#  {'symbol': 'ABEV',
#   'exchange': 'NYS',
#   'name': 'Ambev SA Sponsored ADR',
#   'date': '2020-03-06',
#   'type': 'ad',
#   'iexId': 'IEX_56314334584C2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BN5VZ4',
#   'cik': '1565025'},
#  {'symbol': 'ABG',
#   'exchange': 'NYS',
#   'name': 'Asbury Automotive Group Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5452384E30442D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BKDWB5',
#   'cik': '1144980'},
#  {'symbol': 'ABIO',
#   'exchange': 'NAS',
#   'name': 'ARCA biopharma Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5338544E53332D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BWNN28',
#   'cik': '907654'},
#  {'symbol': 'ABM',
#   'exchange': 'NYS',
#   'name': 'ABM Industries Incorporated',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_514C4C3154342D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000B9YYH7',
#   'cik': '771497'},
#  {'symbol': 'ABMD',
#   'exchange': 'NAS',
#   'name': 'ABIOMED Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_484E313935472D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C101X4',
#   'cik': '815094'},
#  {'symbol': 'ABR',
#   'exchange': 'NYS',
#   'name': 'Arbor Realty Trust Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5638354657572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000KMVDV1',
#   'cik': '1253986'},
#  {'symbol': 'ABR-A',
#   'exchange': 'NYS',
#   'name': 'Arbor Realty Trust Inc 8.25 % Cum Red Pfd Registered Series A',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_5636474453342D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'ABR-B',
#   'exchange': 'NYS',
#   'name': 'Arbor Realty Trust Inc 7.75 % Cum Red Pfd Registered Series B',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_53564A4243352D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'ABR-C',
#   'exchange': 'NYS',
#   'name': 'Arbor Realty Trust Inc 8.5 % Cum Red Pfd Registered Series C',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_4636303634572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'ABT',
#   'exchange': 'NYS',
#   'name': 'Abbott Laboratories',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_53484E444C542D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000B9ZXB4',
#   'cik': '1800'},
#  {'symbol': 'ABTX',
#   'exchange': 'NAS',
#   'name': 'Allegiance Bancshares Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_43324C5043372D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BNYLL9',
#   'cik': '1642081'},
#  {'symbol': 'ABUS',
#   'exchange': 'NAS',
#   'name': 'Arbutus Biopharma Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5342324E33502D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000RR8V85',
#   'cik': '1447028'},
#  {'symbol': 'AC',
#   'exchange': 'NYS',
#   'name': 'Associated Capital Group Inc. Class A',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4850503351532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG008NZ8QC0',
#   'cik': '1642122'},
#  {'symbol': 'ACA',
#   'exchange': 'NYS',
#   'name': 'Arcosa Inc',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_424256334B5A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00JGMWFM9',
#   'cik': '1739445'},
#  {'symbol': 'ACAD',
#   'exchange': 'NAS',
#   'name': 'ACADIA Pharmaceuticals Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_535A465A36352D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BHG9K0',
#   'cik': '1070494'},
#  {'symbol': 'ACAM',
#   'exchange': 'NAS',
#   'name': 'Acamar Partners Acquisition Corp. Class A',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5438435A304E2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00N36CWD4',
#   'cik': '1759008'},
#  {'symbol': 'ACAMU',
#   'exchange': 'NAS',
#   'name': 'Acamar Partners Acquisition Corp. Units Cons of 1 Sh -A- + 1/3 Wt 30.12.25',
#   'date': '2020-03-06',
#   'type': 'ut',
#   'iexId': 'IEX_47314C5054542D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00N0THPG4',
#   'cik': '1759008'},
#  {'symbol': 'ACAMW',
#   'exchange': 'NAS',
#   'name': 'Acamar Partners Acquisition Corp Warrant -30.12.25 on Acamr Ptrs Acqn',
#   'date': '2020-03-06',
#   'type': 'wt',
#   'iexId': 'IEX_5248574753332D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00NWKHBT5',
#   'cik': None},
#  {'symbol': 'ACB',
#   'exchange': 'NYS',
#   'name': 'Aurora Cannabis Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4750444A48562D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG006SCSYG7',
#   'cik': '1683541'},
#  {'symbol': 'ACBI',
#   'exchange': 'NAS',
#   'name': 'Atlantic Capital Bancshares Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5458464E56362D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG009XQG7V9',
#   'cik': '1461755'},
#  {'symbol': 'ACC',
#   'exchange': 'NYS',
#   'name': 'American Campus Communities Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_52505658594D2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000M9KP89',
#   'cik': '1283630'},
#  {'symbol': 'ACCO',
#   'exchange': 'NYS',
#   'name': 'ACCO Brands Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5250574354312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000J06K07',
#   'cik': '712034'},
#  {'symbol': 'ACEL',
#   'exchange': 'NYS',
#   'name': 'Accel Entertainment Inc. Class A',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4E35565A35362D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00GX221W3',
#   'cik': '708717'},
#  {'symbol': 'ACEL+',
#   'exchange': 'NYS',
#   'name': 'Accel Entertainment Inc. Warrant 2019-20.11.24 on Accel Entmt',
#   'date': '2020-03-06',
#   'type': 'wt',
#   'iexId': 'IEX_5339313351542D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00GX7LX60',
#   'cik': None},
#  {'symbol': 'ACER',
#   'exchange': 'NAS',
#   'name': 'Acer Therapeutics Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5752545447382D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BG5S59',
#   'cik': '1069308'},
#  {'symbol': 'ACES',
#   'exchange': 'BATS',
#   'name': 'ALPS Clean Energy ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_534D4A4331312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00L99FCT0',
#   'cik': None},
#  {'symbol': 'ACGL',
#   'exchange': 'NAS',
#   'name': 'Arch Capital Group Ltd.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C4A4B3850512D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000HXNN20',
#   'cik': '947484'},
#  {'symbol': 'ACGLO',
#   'exchange': 'NAS',
#   'name': 'Arch Capital Group Ltd. Deposit Shs Repr 1/1000th 5.45 % Non-Cum Pfd Shs Series F',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_4D58533556562D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'ACGLP',
#   'exchange': 'NAS',
#   'name': 'Arch Capital Group Ltd Deposit Repr 1/1000th Non-Cum Pfd Series E',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_5030575A35462D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'ACH',
#   'exchange': 'NYS',
#   'name': 'Aluminum Corporation of China Limited Sponsored ADR Class H',
#   'date': '2020-03-06',
#   'type': 'ad',
#   'iexId': 'IEX_5846375A30472D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000CMRVH1',
#   'cik': '1161611'},
#  {'symbol': 'ACHC',
#   'exchange': 'NAS',
#   'name': 'Acadia Healthcare Company Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_56383944464C2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000FPNN38',
#   'cik': '1520697'},
#  {'symbol': 'ACHV',
#   'exchange': 'NAS',
#   'name': 'Achieve Life Sciences Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4D4E52424C4E2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000FB8S62',
#   'cik': '949858'},
#  {'symbol': 'ACIA',
#   'exchange': 'NAS',
#   'name': 'Acacia Communications Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5148314C50312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00359HX70',
#   'cik': '1651235'},
#  {'symbol': 'ACIO',
#   'exchange': 'BATS',
#   'name': 'Aptus Collared Income Opportunity ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_4A4C3847324A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00PNSDFF3',
#   'cik': None},
#  {'symbol': 'ACIU',
#   'exchange': 'NAS',
#   'name': 'AC Immune SA',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5334383954322D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00D0RHJ38',
#   'cik': '1651625'},
#  {'symbol': 'ACIW',
#   'exchange': 'NAS',
#   'name': 'ACI Worldwide Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_57504B4842382D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000PMBV39',
#   'cik': '935036'},
#  {'symbol': 'ACLS',
#   'exchange': 'NAS',
#   'name': 'Axcelis Technologies Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4735474344472D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000DW34S2',
#   'cik': '1113232'},
#  {'symbol': 'ACM',
#   'exchange': 'NYS',
#   'name': 'AECOM',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_565A5A3350322D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000F61RJ8',
#   'cik': '868857'},
#  {'symbol': 'ACMR',
#   'exchange': 'NAS',
#   'name': 'ACM Research Inc. Class A',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_434748584C532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00HPSG933',
#   'cik': '1680062'},
#  {'symbol': 'ACN',
#   'exchange': 'NYS',
#   'name': 'Accenture Plc Class A',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4257445A32502D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000D9D830',
#   'cik': '1467373'},
#  {'symbol': 'ACNB',
#   'exchange': 'NAS',
#   'name': 'ACNB Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_574E464342392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BJ2LY9',
#   'cik': '715579'},
#  {'symbol': 'ACOR',
#   'exchange': 'NAS',
#   'name': 'Acorda Therapeutics Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_56424B4D43482D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000FD10V8',
#   'cik': '1008848'},
#  {'symbol': 'ACP',
#   'exchange': 'NYS',
#   'name': 'Aberdeen Income Credit Strategies Fund of Benef Interest',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_5659314B36392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG001K93163',
#   'cik': None},
#  {'symbol': 'ACRE',
#   'exchange': 'NYS',
#   'name': 'Ares Commercial Real Estate Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_44465A5A44312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG0022MMQB0',
#   'cik': '1529377'},
#  {'symbol': 'ACRS',
#   'exchange': 'NAS',
#   'name': 'Aclaris Therapeutics Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4248464A38512D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG003LF0QR9',
#   'cik': '1557746'},
#  {'symbol': 'ACRX',
#   'exchange': 'NAS',
#   'name': 'AcelRx Pharmaceuticals Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C535A5044352D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG0018YYFX7',
#   'cik': '1427925'},
#  {'symbol': 'ACSG',
#   'exchange': 'PSE',
#   'name': 'Xtrackers MSCI ACWI ex USA ESG Leaders Equity ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5831373248352D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00MQCZF86',
#   'cik': None},
#  {'symbol': 'ACSI',
#   'exchange': 'BATS',
#   'name': 'American Customer Satisfaction ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_53484E5254502D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00F40VFY6',
#   'cik': None},
#  {'symbol': 'ACST',
#   'exchange': 'NAS',
#   'name': 'Acasti Pharma Inc. Class A',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_485730484E482D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG001NMDXS6',
#   'cik': '1444192'},
#  {'symbol': 'ACT',
#   'exchange': 'NAS',
#   'name': 'AdvisorShares Vice ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5151383634582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00JGGJ4N1',
#   'cik': '884629'},
#  {'symbol': 'ACTG',
#   'exchange': 'NAS',
#   'name': 'Acacia Research Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_474E434248302D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000KF9J02',
#   'cik': '934549'},
#  {'symbol': 'ACTT',
#   'exchange': 'NAS',
#   'name': 'Act II Global Acquisition Corp. Class A',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_474C574A4E4B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00NZJ4H98',
#   'cik': '1753706'},
#  {'symbol': 'ACTTU',
#   'exchange': 'NAS',
#   'name': 'Act II Global Acquisition Corp. Units Cons of 1 Shs + 1/2 Wt',
#   'date': '2020-03-06',
#   'type': 'ut',
#   'iexId': 'IEX_4A4A313351422D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00NTNQM37',
#   'cik': '1753706'},
#  {'symbol': 'ACTTW',
#   'exchange': 'NAS',
#   'name': 'Act II Global Acquisition Corp Warrant - on Act II Glb Acqn',
#   'date': '2020-03-06',
#   'type': 'wt',
#   'iexId': 'IEX_4C51315037352D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00P4MZ5G4',
#   'cik': '1753706'},
#  {'symbol': 'ACU',
#   'exchange': 'ASE',
#   'name': 'Acme United Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_52344D30524D2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BB3LM8',
#   'cik': '2098'},
#  {'symbol': 'ACV',
#   'exchange': 'NYS',
#   'name': 'AllianzGI Diversified Income & Convertible Fund',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_524C573750342D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG008HMBD22',
#   'cik': '1368457'},
#  {'symbol': 'ACWF',
#   'exchange': 'PSE',
#   'name': 'iShares Edge MSCI Multifactor Global ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_533530394A4A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG008LNZHV8',
#   'cik': None},
#  {'symbol': 'ACWI',
#   'exchange': 'NAS',
#   'name': 'iShares MSCI ACWI ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5330574D4E422D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000TH6VB3',
#   'cik': None},
#  {'symbol': 'ACWV',
#   'exchange': 'BATS',
#   'name': 'iShares Edge MSCI Min Vol Global ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_53424D5052542D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG0025X38X0',
#   'cik': None},
#  {'symbol': 'ACWX',
#   'exchange': 'NAS',
#   'name': 'iShares MSCI ACWI ex U.S. ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_505939524D4D2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000TH7DF8',
#   'cik': None},
#  {'symbol': 'ACY',
#   'exchange': 'ASE',
#   'name': 'AeroCentury Corp.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_424E4C5339482D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000B9WP24',
#   'cik': '1036848'},
#  {'symbol': 'ADAP',
#   'exchange': 'NAS',
#   'name': 'Adaptimmune Therapeutics PLC Sponsored ADR',
#   'date': '2020-03-06',
#   'type': 'ad',
#   'iexId': 'IEX_5232595752342D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG008G65WC2',
#   'cik': '1621227'},
#  {'symbol': 'ADBE',
#   'exchange': 'NAS',
#   'name': 'Adobe Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_444A4332544E2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BB5006',
#   'cik': '796343'},
#  {'symbol': 'ADC',
#   'exchange': 'NYS',
#   'name': 'Agree Realty Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4B433656424C2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BC9DK0',
#   'cik': '917251'},
#  {'symbol': 'ADES',
#   'exchange': 'NAS',
#   'name': 'Advanced Emissions Solutions Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4336484B38312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000JFNL85',
#   'cik': '1515156'},
#  {'symbol': 'ADI',
#   'exchange': 'NAS',
#   'name': 'Analog Devices Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_463137534A312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BB6G37',
#   'cik': '6281'},
#  {'symbol': 'ADIL',
#   'exchange': 'NAS',
#   'name': 'Adial Pharmaceuticals Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5652304B32422D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00HNGDTR4',
#   'cik': '1513525'},
#  {'symbol': 'ADILW',
#   'exchange': 'NAS',
#   'name': 'Adial Pharmaceuticals Inc Warrant 2018-31.07.23 on Adial Phrmctcals',
#   'date': '2020-03-06',
#   'type': 'wt',
#   'iexId': 'IEX_4B50595734532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00LLBDVV8',
#   'cik': None},
#  {'symbol': 'ADM',
#   'exchange': 'NYS',
#   'name': 'Archer-Daniels-Midland Company',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4D51313139582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BB6WG8',
#   'cik': '7084'},
#  {'symbol': 'ADMA',
#   'exchange': 'NAS',
#   'name': 'ADMA Biologics Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4333573739572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG002NCK5M5',
#   'cik': '1368514'},
#  {'symbol': 'ADME',
#   'exchange': 'BATS',
#   'name': 'Aptus Drawdown Managed Equity ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_44533234434D2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00D20HG22',
#   'cik': None},
#  {'symbol': 'ADMP',
#   'exchange': 'NAS',
#   'name': 'Adamis Pharmaceuticals Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_514C4D3833382D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BYB544',
#   'cik': '887247'},
#  {'symbol': 'ADMS',
#   'exchange': 'NAS',
#   'name': 'Adamas Pharmaceuticals Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_544A4B304D332D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00203JGZ4',
#   'cik': '1328143'},
#  {'symbol': 'ADNT',
#   'exchange': 'NYS',
#   'name': 'Adient plc',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5757374442572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG009PN0C87',
#   'cik': '1670541'},
#  {'symbol': 'ADP',
#   'exchange': 'NAS',
#   'name': 'Automatic Data Processing Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5459323032512D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000JG0547',
#   'cik': '8670'},
#  {'symbol': 'ADPT',
#   'exchange': 'NAS',
#   'name': 'Adaptive Biotechnologies Corp.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_574C5A5259332D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG001J2PFF5',
#   'cik': '1478320'},
#  {'symbol': 'ADRE',
#   'exchange': 'NAS',
#   'name': 'Invesco BLDRS Emerging Markets 50 ADR Index Fund',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5732375038392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000FQ6838',
#   'cik': '1169717'},
#  {'symbol': 'ADRO',
#   'exchange': 'NAS',
#   'name': 'Aduro BioTech Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_524C564735442D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000DW9ZK5',
#   'cik': '1435049'},
#  {'symbol': 'ADS',
#   'exchange': 'NYS',
#   'name': 'Alliance Data Systems Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4E444E3544542D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BFNR17',
#   'cik': '1101215'},
#  {'symbol': 'ADSK',
#   'exchange': 'NAS',
#   'name': 'Autodesk Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4A584D4C59382D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BM7HL0',
#   'cik': '769397'},
#  {'symbol': 'ADSW',
#   'exchange': 'NYS',
#   'name': 'Advanced Disposal Services Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5133524651392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG003FJ1CY0',
#   'cik': '1585790'},
#  {'symbol': 'ADT',
#   'exchange': 'NYS',
#   'name': 'ADT Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C364E514B4B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BP9WJ1',
#   'cik': '1703056'},
#  {'symbol': 'ADTN',
#   'exchange': 'NAS',
#   'name': 'ADTRAN Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5034425A52422D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C4K3D4',
#   'cik': '926282'},
#  {'symbol': 'ADUS',
#   'exchange': 'NAS',
#   'name': 'Addus HomeCare Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_51304E324B482D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000NJGX84',
#   'cik': '1468328'},
#  {'symbol': 'ADVM',
#   'exchange': 'NAS',
#   'name': 'Adverum Biotechnologies Inc',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4B31365450382D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG006D9MR17',
#   'cik': '1501756'},
#  {'symbol': 'ADX',
#   'exchange': 'NYS',
#   'name': 'Adams Diversified Equity Fund Inc Shs',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_5439524E59362D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BB8MR6',
#   'cik': '2230'},
#  {'symbol': 'ADXN',
#   'exchange': 'NAS',
#   'name': 'Addex Therapeutics Ltd Sponsored ADR',
#   'date': '2020-03-06',
#   'type': 'ad',
#   'iexId': 'IEX_4357324D4C372D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00R48ST95',
#   'cik': None},
#  {'symbol': 'ADXS',
#   'exchange': 'NAS',
#   'name': 'Advaxis Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_42475A5A56442D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000KVF074',
#   'cik': '1100397'},
#  {'symbol': 'AE',
#   'exchange': 'ASE',
#   'name': 'Adams Resources & Energy Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4630334B395A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BB92C5',
#   'cik': '2178'},
#  {'symbol': 'AEB',
#   'exchange': 'NYS',
#   'name': 'Aegon N.V. Floating Rate Perpetual Capital Security 2005 Without fixed maturity',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_4D3948334A582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': '769218'},
#  {'symbol': 'AEE',
#   'exchange': 'NYS',
#   'name': 'Ameren Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_47525344534B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000B9X8C0',
#   'cik': '1002910'},
#  {'symbol': 'AEF',
#   'exchange': 'ASE',
#   'name': 'Aberdeen Emerging Markets Equity Income Fund Inc.',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_445235384C562D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BGWCV5',
#   'cik': '769218'},
#  {'symbol': 'AEFC',
#   'exchange': 'NYS',
#   'name': 'AEGON Funding Company LLC 5.1 % Notes 2019-15.12.49 Gtd Global',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_5337545A484B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'AEG',
#   'exchange': 'NYS',
#   'name': 'AEGON N.V. ADR',
#   'date': '2020-03-06',
#   'type': 'ad',
#   'iexId': 'IEX_4B5733564D382D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000CKQSN6',
#   'cik': '769218'},
#  {'symbol': 'AEGN',
#   'exchange': 'NAS',
#   'name': 'Aegion Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_464A35544D4C2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000KPWTD8',
#   'cik': '353020'},
#  {'symbol': 'AEHR',
#   'exchange': 'NAS',
#   'name': 'Aehr Test Systems',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_54305054384D2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BWM083',
#   'cik': '1040470'},
#  {'symbol': 'AEIS',
#   'exchange': 'NAS',
#   'name': 'Advanced Energy Industries Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4252564C4C332D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000FKMP26',
#   'cik': '927003'},
#  {'symbol': 'AEL',
#   'exchange': 'NYS',
#   'name': 'American Equity Investment Life Holding Company',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5653355A58572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BB6H99',
#   'cik': '1039828'},
#  {'symbol': 'AEL-A',
#   'exchange': 'NYS',
#   'name': 'American Equity Investment Life Holding Co Depositary Shs Repr 1/1000th Non-Cum Red Perp Pfd Registered Shs Ser A',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_4D35315153372D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'AEM',
#   'exchange': 'NYS',
#   'name': 'Agnico Eagle Mines Limited',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4B4448424E4E2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000DLVDK3',
#   'cik': '2809'},
#  {'symbol': 'AEMD',
#   'exchange': 'NAS',
#   'name': 'Aethlon Medical Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5451384D57392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000L78XT8',
#   'cik': '882291'},
#  {'symbol': 'AEO',
#   'exchange': 'NYS',
#   'name': 'American Eagle Outfitters Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_44314C4A34372D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BGXZB5',
#   'cik': '919012'},
#  {'symbol': 'AEP',
#   'exchange': 'NYS',
#   'name': 'American Electric Power Company Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4435303247392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BB9KF2',
#   'cik': '4904'},
#  {'symbol': 'AEP-B',
#   'exchange': 'NYS',
#   'name': 'American Electric Power Company Inc. Equity Units Cons of USD 50 Nom Nts 15.03.24 + 1 PC 15.03.22',
#   'date': '2020-03-06',
#   'type': 'ut',
#   'iexId': 'IEX_5248514838462D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'AER',
#   'exchange': 'NYS',
#   'name': 'AerCap Holdings NV',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4E38355244582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000Q9FZL4',
#   'cik': '1378789'},
#  {'symbol': 'AERI',
#   'exchange': 'NAS',
#   'name': 'Aerie Pharmaceuticals Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_48314B32314E2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG001KJ7WJ5',
#   'cik': '1337553'},
#  {'symbol': 'AES',
#   'exchange': 'NYS',
#   'name': 'AES Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C59363533482D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C23KJ3',
#   'cik': '874761'},
#  {'symbol': 'AESE',
#   'exchange': 'NAS',
#   'name': 'Allied Esports Entertainment Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_47464D47534E2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00J2442Y1',
#   'cik': '1708341'},
#  {'symbol': 'AESR',
#   'exchange': 'BATS',
#   'name': 'Anfield U.S. Equity Sector Rotation ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_4A59544443312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00R4084K6',
#   'cik': None},
#  {'symbol': 'AEY',
#   'exchange': 'NAS',
#   'name': 'ADDvantage Technologies Group Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_56584C4C47322D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000CFWHD5',
#   'cik': '874292'},
#  {'symbol': 'AEYE',
#   'exchange': 'NAS',
#   'name': 'AudioEye Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5635425050502D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG002ZQLQB6',
#   'cik': None},
#  {'symbol': 'AEZS',
#   'exchange': 'NAS',
#   'name': 'Aeterna Zentaris Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5657464C54392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000LZRK22',
#   'cik': '1113423'},
#  {'symbol': 'AFB',
#   'exchange': 'NYS',
#   'name': 'AllianceBernstein National Municipal Income FundInc National Municipal Income Fund',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_5654395134472D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000DTM676',
#   'cik': None},
#  {'symbol': 'AFC',
#   'exchange': 'NYS',
#   'name': 'Ares Capital Corporation 6.875 % Notes 2007-15.4.47 Global',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_4B383256424B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': '3906'},
#  {'symbol': 'AFG',
#   'exchange': 'NYS',
#   'name': 'American Financial Group Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5143534430462D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000DPKKK0',
#   'cik': '1042046'},
#  {'symbol': 'AFGB',
#   'exchange': 'NYS',
#   'name': 'American Financial Group Inc. 5.875 % Debentures 2019-30.03.59 Global',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_524D385148572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'AFGC',
#   'exchange': 'NYS',
#   'name': 'American Financial Group Inc. 5.125 % Debentures 2019-15.12.59 Global',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_524C484658542D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'AFGH',
#   'exchange': 'NYS',
#   'name': 'American Financial Group Inc (New) 6 % Debentures 2015-15.11.55',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_43314D4D30302D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'AFH',
#   'exchange': 'NAS',
#   'name': 'Atlas Financial Holdings Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_51485844354C2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG003948N06',
#   'cik': '1539894'},
#  {'symbol': 'AFI',
#   'exchange': 'NYS',
#   'name': 'Armstrong Flooring Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_575043314A512D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG0085ZZXW3',
#   'cik': '1655075'},
#  {'symbol': 'AFIF',
#   'exchange': 'BATS',
#   'name': 'Anfield Universal Fixed Income ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_474A43574B502D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00LZQ9356',
#   'cik': None},
#  {'symbol': 'AFIN',
#   'exchange': 'NAS',
#   'name': 'American Finance Trust Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_47344231505A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG004Z1PW11',
#   'cik': '1568162'},
#  {'symbol': 'AFINP',
#   'exchange': 'NAS',
#   'name': 'American Finance Trust Inc. 7.5 % Cum Conv Perp Red Pfd Registered Shs Series A',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_425A4A4851542D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'AFK',
#   'exchange': 'PSE',
#   'name': 'VanEck Vectors Africa Index ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_4359364758532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000H0B9J8',
#   'cik': None},
#  {'symbol': 'AFL',
#   'exchange': 'NYS',
#   'name': 'Aflac Incorporated',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_584C593633562D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BBBNC6',
#   'cik': '4977'},
#  {'symbol': 'AFLG',
#   'exchange': 'PSE',
#   'name': 'First Trust Active Factor Large Cap ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_48374D3252362D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00QZ0DQB9',
#   'cik': None},
#  {'symbol': 'AFMC',
#   'exchange': 'PSE',
#   'name': 'First Trust Active Factor Mid Cap ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5850394E48312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00QZ0GVP0',
#   'cik': None},
#  {'symbol': 'AFMD',
#   'exchange': 'NAS',
#   'name': 'Affimed N.V.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_515A313859342D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG006R5SSH5',
#   'cik': '1608390'},
#  {'symbol': 'AFSM',
#   'exchange': 'PSE',
#   'name': 'First Trust Active Factor Small Cap ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5244543552442D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00QZ0H932',
#   'cik': None},
#  {'symbol': 'AFT',
#   'exchange': 'NYS',
#   'name': 'Apollo Senior Floating Rate Fund Inc',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_4D524335584E2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00174L007',
#   'cik': None},
#  {'symbol': 'AFTY',
#   'exchange': 'PSE',
#   'name': 'Pacer CSOP FTSE China A50 ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_58514C5242312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG0087HJHZ1',
#   'cik': None},
#  {'symbol': 'AFYA',
#   'exchange': 'NAS',
#   'name': 'Afya Limited Class A',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4230565A325A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00PK9C4C7',
#   'cik': '1771007'},
#  {'symbol': 'AG',
#   'exchange': 'NYS',
#   'name': 'First Majestic Silver Corp.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C35373633372D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000CH7WB8',
#   'cik': '1308648'},
#  {'symbol': 'AGBA',
#   'exchange': 'NAS',
#   'name': 'AGBA Acquisition Ltd.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_485854384B432D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00P4XQ9W4',
#   'cik': '1769624'},
#  {'symbol': 'AGBAR',
#   'exchange': 'NAS',
#   'name': 'AGBA Acquisition Ltd Rights For Shares',
#   'date': '2020-03-06',
#   'type': 'rt',
#   'iexId': 'IEX_4A485A464D572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00PPX10R3',
#   'cik': '1769624'},
#  {'symbol': 'AGBAU',
#   'exchange': 'NAS',
#   'name': 'AGBA Acquisition Ltd. Units Cons of 1 Shs + 1/2 Wt + 1/10 Rg',
#   'date': '2020-03-06',
#   'type': 'ut',
#   'iexId': 'IEX_4D4E514442392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00NW19H59',
#   'cik': '1769624'},
#  {'symbol': 'AGBAW',
#   'exchange': 'NAS',
#   'name': 'AGBA Acquisition Ltd Warrant - on AGBA',
#   'date': '2020-03-06',
#   'type': 'wt',
#   'iexId': 'IEX_4444543932382D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00PPX1PX1',
#   'cik': None},
#  {'symbol': 'AGCO',
#   'exchange': 'NYS',
#   'name': 'AGCO Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_53484D48575A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000DCCZW2',
#   'cik': '880266'},
#  {'symbol': 'AGD',
#   'exchange': 'NYS',
#   'name': 'Aberdeen Global Dynamic Dividend Fund of Benef Interest',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_5334443852352D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000PMSMG7',
#   'cik': None},
#  {'symbol': 'AGE',
#   'exchange': 'ASE',
#   'name': 'AgeX Therapeutics Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_545A52434D4A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00HCXQ7B0',
#   'cik': '1708599'},
#  {'symbol': 'AGEN',
#   'exchange': 'NAS',
#   'name': 'Agenus Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_464D4644465A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C8SWQ9',
#   'cik': '1098972'},
#  {'symbol': 'AGFS',
#   'exchange': 'NAS',
#   'name': 'AgroFresh Solutions Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5332343242532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00699CVL2',
#   'cik': '1592016'},
#  {'symbol': 'AGFSW',
#   'exchange': 'NAS',
#   'name': 'AgroFresh Solutions Inc Warrants 2014-19.2.19 on Shs',
#   'date': '2020-03-06',
#   'type': 'wt',
#   'iexId': 'IEX_534E393746392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00699CWN8',
#   'cik': None},
#  {'symbol': 'AGG',
#   'exchange': 'PSE',
#   'name': 'iShares Core U.S. Aggregate Bond ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_42444E4B51462D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000Q123R0',
#   'cik': None},
#  {'symbol': 'AGGP',
#   'exchange': 'PSE',
#   'name': 'IQ Enhanced Core Plus Bond U.S. ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_575350384A512D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00CVW3NH6',
#   'cik': None},
#  {'symbol': 'AGGY',
#   'exchange': 'PSE',
#   'name': 'WisdomTree Yield Enhanced U.S. Aggregate Bond Fund',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_524437425A582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG009KCY2B7',
#   'cik': None},
#  {'symbol': 'AGI',
#   'exchange': 'NYS',
#   'name': 'Alamos Gold Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5339595251312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG009HT6BL4',
#   'cik': '1178819'},
#  {'symbol': 'AGIO',
#   'exchange': 'NAS',
#   'name': 'Agios Pharmaceuticals Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C37425744582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000QY4ZD0',
#   'cik': '1439222'},
#  {'symbol': 'AGLE',
#   'exchange': 'NAS',
#   'name': 'Aeglea BioTherapeutics Inc',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_52515332334A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG0067L94B2',
#   'cik': '1636282'},
#  {'symbol': 'AGM',
#   'exchange': 'NYS',
#   'name': 'Federal Agricultural Mortgage Corporation Class C',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5843303251572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000G8ZKY4',
#   'cik': '845877'},
#  {'symbol': 'AGM.A',
#   'exchange': 'NYS',
#   'name': 'Federal Agricultural Mortgage Corporation Class A',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5148424658512D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000G8Y1Z6',
#   'cik': '845877'},
#  {'symbol': 'AGM-A',
#   'exchange': 'NYS',
#   'name': 'Federal Agricultural Mortgage Corporation 5.875 % Non Cum Pfd Registered Series A',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_424D513350502D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'AGM-C',
#   'exchange': 'NYS',
#   'name': 'Federal Agricultural Mortgage Corp Pfd Shs Series C',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_505A395237362D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'AGM-D',
#   'exchange': 'NYS',
#   'name': 'Federal Agricultural Mortgage Corporation Pfd Registered Shs Series D',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_433051565A572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'AGMH',
#   'exchange': 'NAS',
#   'name': 'AGM Group Holdings Inc. Class A',
#   'date': '2020-03-06',
#   'type': 'cs',
# ...
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000CKVYZ4',
#   'cik': None},
#  {'symbol': 'BLUE',
#   'exchange': 'NAS',
#   'name': 'bluebird bio Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5035345943532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000QGWY50',
#   'cik': '1293971'},
#  {'symbol': 'BLV',
#   'exchange': 'PSE',
#   'name': 'Vanguard Long-Term Bond ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5254355739372D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000R45489',
#   'cik': None},
#  {'symbol': 'BLW',
#   'exchange': 'NYS',
#   'name': 'Blackrock Limited Duration Income Trust',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_47333634474B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000PLYMY2',
#   'cik': '831001'},
#  {'symbol': 'BLX',
#   'exchange': 'NYS',
#   'name': 'Banco Latinoamericano de Comercio Exterior S.A. Class E',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_445756484C342D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000CWSZN2',
#   'cik': '890541'},
#  {'symbol': 'BMA',
#   'exchange': 'NYS',
#   'name': 'Banco Macro SA Sponsored ADR Class B',
#   'date': '2020-03-06',
#   'type': 'ad',
#   'iexId': 'IEX_4E30364A58582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000Q44W43',
#   'cik': '1347426'},
#  {'symbol': 'BMAR',
#   'exchange': 'BATS',
#   'name': 'Innovator S&P 500 Buffer ETF - March',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_4D5648464E352D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00S1NCRJ3',
#   'cik': None},
#  {'symbol': 'BMCH',
#   'exchange': 'NAS',
#   'name': 'BMC Stock Holdings Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_54355A4643362D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG004PQN2M2',
#   'cik': '1574815'},
#  {'symbol': 'BME',
#   'exchange': 'NYS',
#   'name': 'Blackrock Health Sciences Trust',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_4D44574C51582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000QSYZF8',
#   'cik': None},
#  {'symbol': 'BMEZ',
#   'exchange': 'NYS',
#   'name': 'Blackrock Health Sciences Trust II',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_464A3136354D2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00R28MS68',
#   'cik': None},
#  {'symbol': 'BMI',
#   'exchange': 'NYS',
#   'name': 'Badger Meter Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_57385951304A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BDGHD9',
#   'cik': '9092'},
#  {'symbol': 'BML-G',
#   'exchange': 'NYS',
#   'name': 'Bank of America Corp Deposit shs Repr 1/1200th Fltg Rate Non-Cum Pfd Shs Series 1',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_4430484C4B4A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'BML-H',
#   'exchange': 'NYS',
#   'name': 'Bank of America Corp Deposit Shs Repr 1/1200th Fltg Rate Non Cum Pfd Shs Series 2',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_564D4A4847442D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'BML-J',
#   'exchange': 'NYS',
#   'name': 'Bank of America Corp Deposit Shs Repr 1/1200th Fltg Rate Non Cum Pfd Shs Series 4',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_52334A485A392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'BML-L',
#   'exchange': 'NYS',
#   'name': 'Bank of America Corp Deposit Shs Repr 1/1200th Pfd Shs Series 5',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_5059363554382D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'BMLP',
#   'exchange': 'NAS',
#   'name': 'Dorsey Wright MLP Index ETN',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_4746464D4A312D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00FJVS8H1',
#   'cik': None},
#  {'symbol': 'BMO',
#   'exchange': 'NYS',
#   'name': 'Bank of Montreal',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5756335659592D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000DLY9B9',
#   'cik': '927971'},
#  {'symbol': 'BMRA',
#   'exchange': 'NAS',
#   'name': 'Biomerica Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C4E333847592D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BDH8F6',
#   'cik': '73290'},
#  {'symbol': 'BMRC',
#   'exchange': 'NAS',
#   'name': 'Bank of Marin Bancorp',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_583435435A362D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C3N539',
#   'cik': '1403475'},
#  {'symbol': 'BMRN',
#   'exchange': 'NAS',
#   'name': 'BioMarin Pharmaceutical Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5147355630392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000CZWZ05',
#   'cik': '1048477'},
#  {'symbol': 'BMTC',
#   'exchange': 'NAS',
#   'name': 'Bryn Mawr Bank Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4E464D4D48442D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BDJ2F7',
#   'cik': '802681'},
#  {'symbol': 'BMY',
#   'exchange': 'NYS',
#   'name': 'Bristol-Myers Squibb Company',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C38534B4C542D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000DQLV23',
#   'cik': '14272'},
#  {'symbol': 'BMY^',
#   'exchange': 'NYS',
#   'name': 'Bristol-Myers Squibb Company Contingent Value Rights 2019-31.12.2020',
#   'date': '2020-03-06',
#   'type': 'rt',
#   'iexId': 'IEX_484A4E484B432D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00QXKC8R1',
#   'cik': None},
#  {'symbol': 'BND',
#   'exchange': 'NAS',
#   'name': 'Vanguard Total Bond Market ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5652305050542D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BZZS63',
#   'cik': None},
#  {'symbol': 'BNDC',
#   'exchange': 'PSE',
#   'name': 'FlexShares Core Select Bond Fund',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5230374752592D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00F9ZDXS2',
#   'cik': None},
#  {'symbol': 'BNDW',
#   'exchange': 'NAS',
#   'name': 'Vanguard Total World Bond ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_52593235374E2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00LWSF7T3',
#   'cik': None},
#  {'symbol': 'BNDX',
#   'exchange': 'NAS',
#   'name': 'Vanguard Total International Bond ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_434D4E3556522D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG004N1LFT5',
#   'cik': None},
#  {'symbol': 'BNED',
#   'exchange': 'NYS',
#   'name': 'Barnes & Noble Education Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_465A474E51502D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG009CNQCW6',
#   'cik': None},
#  {'symbol': 'BNFT',
#   'exchange': 'NAS',
#   'name': 'Benefitfocus Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C473253565A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG0053Z92V9',
#   'cik': '1576169'},
#  {'symbol': 'BNGO',
#   'exchange': 'NAS',
#   'name': 'BioNano Genomics Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4A473651384A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG001KWWRS9',
#   'cik': '1411690'},
#  {'symbol': 'BNGOW',
#   'exchange': 'NAS',
#   'name': 'Bionano Genomics Inc Warrant 2018-20.08.23 on Bionano Genom',
#   'date': '2020-03-06',
#   'type': 'wt',
#   'iexId': 'IEX_53564B5348582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00M16VDP6',
#   'cik': None},
#  {'symbol': 'BNKD',
#   'exchange': 'PSE',
#   'name': 'MicroSectors U.S. Big Banks Index -3X Inverse Leveraged ETNs',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5656305A33572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00NS9ZBC3',
#   'cik': None},
#  {'symbol': 'BNKO',
#   'exchange': 'PSE',
#   'name': 'MicroSectors U.S. Big Banks Index 2X Leveraged ETNs',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_4C4D504E5A4E2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00NS9YKX1',
#   'cik': None},
#  {'symbol': 'BNKU',
#   'exchange': 'PSE',
#   'name': 'MicroSectors U.S. Big Banks Index 3X Leveraged ETNs',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_4E44363537362D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00NS9YGW1',
#   'cik': None},
#  {'symbol': 'BNKZ',
#   'exchange': 'PSE',
#   'name': 'MicroSectors U.S. Big Banks Index -2X Inverse Leveraged ETNs',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5637565431432D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00NS9YTM4',
#   'cik': None},
#  {'symbol': 'BNO',
#   'exchange': 'PSE',
#   'name': 'United States Brent Oil Fund LP',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_545A395639392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000QZBM11',
#   'cik': None},
#  {'symbol': 'BNOV',
#   'exchange': 'BATS',
#   'name': 'Innovator S&P 500 Buffer ETF - November',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5450335250572D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00QPZ0H72',
#   'cik': None},
#  {'symbol': 'BNS',
#   'exchange': 'NYS',
#   'name': 'Bank of Nova Scotia',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5846334A4B392D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C2RV03',
#   'cik': '9631'},
#  {'symbol': 'BNSO',
#   'exchange': 'NAS',
#   'name': 'Bonso Electronics International Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4B464E5742592D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000F640B2',
#   'cik': '846546'},
#  {'symbol': 'BNTC',
#   'exchange': 'NAS',
#   'name': 'Benitec Biopharma Limited Sponsored ADR',
#   'date': '2020-03-06',
#   'type': 'ad',
#   'iexId': 'IEX_4832534E48512D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG006KZDLB3',
#   'cik': None},
#  {'symbol': 'BNTCW',
#   'exchange': 'NAS',
#   'name': 'Benitec Biopharma Ltd Warrants 2015-14.8.20 on ADS',
#   'date': '2020-03-06',
#   'type': 'wt',
#   'iexId': 'IEX_5037355933482D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG009STG4P3',
#   'cik': None},
#  {'symbol': 'BNTX',
#   'exchange': 'NAS',
#   'name': 'BioNTech SE Sponsored ADR',
#   'date': '2020-03-06',
#   'type': 'ad',
#   'iexId': 'IEX_4D465930544C2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00Q70B3V1',
#   'cik': None},
#  {'symbol': 'BNY',
#   'exchange': 'NYS',
#   'name': 'Blackrock New York Municipal Income Trust',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_58384C3932502D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BZF6G2',
#   'cik': '1176197'},
#  {'symbol': 'BOCH',
#   'exchange': 'NAS',
#   'name': 'Bank of Commerce Holdings',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_583957444C422D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C61V11',
#   'cik': '702513'},
#  {'symbol': 'BOCT',
#   'exchange': 'BATS',
#   'name': 'Innovator S&P 500 Buffer ETF - October',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_51594B4A51362D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00M4NZ5C3',
#   'cik': None},
#  {'symbol': 'BOE',
#   'exchange': 'NYS',
#   'name': 'BlackRock Enhanced Global Dividend Trust of Benef Interest',
#   'date': '2020-03-06',
#   'type': 'cef',
#   'iexId': 'IEX_42444B5A54302D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000CLJL39',
#   'cik': None},
#  {'symbol': 'BOH',
#   'exchange': 'NYS',
#   'name': 'Bank of Hawaii Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_464E4B4C4C302D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000C8D8G9',
#   'cik': '46195'},
#  {'symbol': 'BOIL',
#   'exchange': 'PSE',
#   'name': 'ProShares Ultra Bloomberg Natural Gas',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_4442343358502D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG0024TGRQ2',
#   'cik': None},
#  {'symbol': 'BOKF',
#   'exchange': 'NAS',
#   'name': 'BOK Financial Corporation',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5338595858332D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000CFZ003',
#   'cik': '875357'},
#  {'symbol': 'BOKFL',
#   'exchange': 'NAS',
#   'name': 'BOK Financial Corp 5.375 % Notes 2016-30.06.56',
#   'date': '2020-03-06',
#   'type': 'ps',
#   'iexId': 'IEX_54324B5A56562D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': None,
#   'cik': None},
#  {'symbol': 'BOMN',
#   'exchange': 'NAS',
#   'name': 'Boston Omaha Corp. Class A',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_533051334D4E2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG0021J73K6',
#   'cik': None},
#  {'symbol': 'BOND',
#   'exchange': 'PSE',
#   'name': 'PIMCO Active Bond ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_5632424247582D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG002N12B91',
#   'cik': None},
#  {'symbol': 'BOOM',
#   'exchange': 'NAS',
#   'name': 'DMC Global Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C39523939512D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BDLPF3',
#   'cik': '34067'},
#  {'symbol': 'BOOT',
#   'exchange': 'NYS',
#   'name': 'Boot Barn Holdings Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_4C4E444A4E342D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG0077SYZV6',
#   'cik': '1610250'},
#  {'symbol': 'BORR',
#   'exchange': 'NYS',
#   'name': 'Borr Drilling Limited',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_5231484B46522D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00KVSR8X6',
#   'cik': '1715497'},
#  {'symbol': 'BOSC',
#   'exchange': 'NAS',
#   'name': 'BOS Better Online Solutions Ltd',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_534853535A592D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000KVX9C9',
#   'cik': '1005516'},
#  {'symbol': 'BOSS',
#   'exchange': 'BATS',
#   'name': 'Global X Founder-Run Companies ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_434C324231382D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00FZHY342',
#   'cik': None},
#  {'symbol': 'BOTJ',
#   'exchange': 'NAS',
#   'name': 'Bank of the James Financial Group Inc.',
#   'date': '2020-03-06',
#   'type': 'cs',
#   'iexId': 'IEX_423034484C372D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG000BXNHY4',
#   'cik': '1275101'},
#  {'symbol': 'BOTZ',
#   'exchange': 'NAS',
#   'name': 'Global X Robotics & Artificial Intelligence ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_54424C3433512D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00DSB42G0',
#   'cik': None},
#  {'symbol': 'BOUT',
#   'exchange': 'PSE',
#   'name': 'Innovator IBD Breakout Opportunities ETF',
#   'date': '2020-03-06',
#   'type': 'et',
#   'iexId': 'IEX_434E564638322D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True,
#   'figi': 'BBG00LYC7Z68',
#   'cik': None},
#  ...]

# %% [markdown]
# ### MORE DATA PULL OPTIONS

# %%
# Returns DataFrame of historical stock prices from symbols,
    # over date range, start to end. To avoid being
    # penalized by IEX servers, pauses between downloading 
    # ‘chunks’ of symbols can be specified.

pdr.iex.daily.IEXDailyReader(symbols=None, start=None,end=None,
                            retry_count=3,pause=0.1, 
                            session=None, chunksize=25, api_key='pk_3e46a4b55bd04bd68bb778802602595b')

# %%
start = datetime(2016, 9, 1)
end = datetime(2018, 9, 1)

IEX_API_KEY='pk_b740ad24ded147cca822e98ded174c3d'


f = web.DataReader('F', 'iex', start, end, api_key=IEX_API_KEY)

f=pd.DataFrame(f.loc['2018-08-31'])
f
# Out:
#          2018-08-31
# open           9.64
# high           9.68
# low            9.40
# close          9.48
# volume  76424884.00

# %%
f = web.DataReader('goog', 'iex-tops')
f[:10]
# Out:
#                                 0
# symbol                       GOOG
# sector         mediaentertainment
# securityType          commonstock
# bidPrice                        0
# bidSize                         0
# askPrice                        0
# askSize                         0
# lastUpdated         1583529039972
# lastSalePrice             1297.19
# lastSaleSize                  100

# %% [markdown]
# ## TINGO

# %%
pdr.tiingo.TiingoDailyReader('TSLA',start=None, end=None,
                            retry_count=3, pause=0.1,
                            timeout=30, session=None,
                            freq=None,api_key='84d060da157bf79a157c6a9601dc46a28b62bc5c')

# %%
TIINGO_API_KEY='84d060da157bf79a157c6a9601dc46a28b62bc5c'

df = pdr.get_data_tiingo('GOOG', api_key=TIINGO_API_KEY)
df.head()
# Out:
#                                    close    high      low    open   volume  \
# symbol date
# GOOG   2015-03-09 00:00:00+00:00  568.85  570.27  563.535  566.86  1059336
#        2015-03-10 00:00:00+00:00  555.01  564.85  554.730  564.25  1787357
#        2015-03-11 00:00:00+00:00  551.18  558.14  550.680  555.14  1815763
#        2015-03-12 00:00:00+00:00  555.51  556.37  550.460  553.51  1385772
#        2015-03-13 00:00:00+00:00  547.32  558.40  544.220  553.50  1698872
#
#                                   adjClose  adjHigh   adjLow  adjOpen  \
# symbol date
# GOOG   2015-03-09 00:00:00+00:00    568.85   570.27  563.535   566.86
#        2015-03-10 00:00:00+00:00    555.01   564.85  554.730   564.25
#        2015-03-11 00:00:00+00:00    551.18   558.14  550.680   555.14
#        2015-03-12 00:00:00+00:00    555.51   556.37  550.460   553.51
#        2015-03-13 00:00:00+00:00    547.32   558.40  544.220   553.50
#
#                                   adjVolume  divCash  splitFactor
# symbol date
# GOOG   2015-03-09 00:00:00+00:00    1059336      0.0          1.0
#        2015-03-10 00:00:00+00:00    1787357      0.0          1.0
#        2015-03-11 00:00:00+00:00    1815763      0.0          1.0
#        2015-03-12 00:00:00+00:00    1385772      0.0          1.0
#        2015-03-13 00:00:00+00:00    1698872      0.0          1.0

# %% [markdown]
# ## Alpha Vantage
# * Through the Alpha Vantage Time Series endpoints, it is possible to obtain historical equities data for individual symbols. For daily, weekly, and monthly frequencies, 20+ years of historical data is available. The past 3-5 days of
# * intraday data is also available.
# * Alpha vantage is used to get the minute level stock market data. You need to signup on alpha vantage to get the free API key.

# %%
# Import TimeSeries class
from alpha_vantage.timeseries import TimeSeries
ALPHA_VANTAGE_API_KEY = '0R9QKMGY0T17LR42'

# Initialize the TimeSeries class with key and output format
ts = TimeSeries(key=ALPHA_VANTAGE_API_KEY, output_format='pandas')

# Get pandas dataframe with the intraday data and information of the data
data, data_info=ts.get_daily('ACBI', outputsize ='compact')

# Print the information of the data
data_info
# Out:
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#  '2. Symbol': 'ACBI',
#  '3. Last Refreshed': '2020-03-06',
#  '4. Output Size': 'Compact',
#  '5. Time Zone': 'US/Eastern'}

# %%
# Print the intraday data
data.head()
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2020-03-06    16.78    17.15   16.40     16.88   129080.0
# 2020-03-05    18.50    18.50   17.44     17.67    70614.0
# 2020-03-04    18.36    18.52   17.95     18.48    63817.0
# 2020-03-03    18.67    18.67   18.01     18.25    77213.0
# 2020-03-02    18.06    18.81   17.89     18.75    82827.0

# %%
data['4. close'].plot(figsize=(10, 7))

# Define the label for the title of the figure
plt.title("Close Price", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Time', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
# Returns DataFrame of the Alpha Vantage Stock Time Series endpoints

pdr.av.time_series.AVTimeSeriesReader(symbols=None,
                                     function='TIME_SERIES_DAILY',
                                     start=None, end=None,
                                     retry_count=3,
                                     pause=0.1, session=None,
                                     chunksize=25,api_key='1K573OJSLIUGLAGE')

# %%
# Returns DataFrame of the Alpha Vantage Sector Performances SECTOR data
pdr.av.sector.AVSectorPerformanceReader(symbols=None,start=None,
                                       end=None,retry_count=3,
                                       pause=0.1, 
                                       session=None,api_key='1K573OJSLIUGLAGE')

# %% [markdown]
# ### The following endpoints are available:
# * av-intraday - Intraday Time Series
# * av-daily - Daily Time Series
# * av-daily-adjusted - Daily Time Series (Adjusted)
# * av-weekly - Weekly Time Series
# * av-weekly-adjusted - Weekly Time Series (Adjusted)
# * av-monthly - Monthly Time Series
# * av-monthly-adjusted - Monthly Time Series (Adjusted)

# %%
# Historical Time Series Data

ALPHA_VANTAGE_API_KEY='1K573OJSLIUGLAGE'

tickers=['ACBI']

av_start=datetime(2017,1,1)
av_end=datetime(2020,1,1)

f = web.DataReader(tickers, "av-daily", start=av_start,end=av_end,
                   api_key=ALPHA_VANTAGE_API_KEY)

f
# Out:
#              open   high    low  close  volume
# 2017-01-03  19.10  19.20  18.75  18.90   95649
# 2017-01-04  19.05  19.15  19.00  19.15   50922
# 2017-01-05  19.10  19.40  19.00  19.30  113982
# 2017-01-06  19.40  19.65  19.35  19.65   54635
# 2017-01-09  19.55  19.75  19.55  19.70   60131
# ...           ...    ...    ...    ...     ...
# 2019-12-24  18.59  18.77  18.52  18.72   23513
# 2019-12-26  18.67  18.72  18.57  18.62   22988
# 2019-12-27  18.60  18.61  18.33  18.36   53920
# 2019-12-30  18.29  18.71  18.27  18.35   60706
# 2019-12-31  18.25  18.48  18.25  18.35   81207
#
# [754 rows x 5 columns]

# %%
f = web.DataReader(["USD/JPY", "BTC/CNY"], "av-forex",
                   api_key=ALPHA_VANTAGE_API_KEY)
f
# Out:
#                                  USD/JPY              BTC/CNY
# From_Currency Code                   USD                  BTC
# From_Currency Name  United States Dollar              Bitcoin
# To_Currency Code                     JPY                  CNY
# To_Currency Name            Japanese Yen         Chinese Yuan
# Exchange Rate               105.35000000       63083.66149600
# Last Refreshed       2020-03-07 03:42:02  2020-03-07 03:42:06
# Time Zone                            UTC                  UTC
# Bid Price                   105.34000000       63079.08558400
# Ask Price                   105.36000000       63086.01878400

# %% [markdown]
# ## YAHOO FINANCE (yfinance)
# One of the first sources from which you can get daily price-volume stock market data is Yahoo finance. You can use pandas_datareader or yfinance module to get the data.
#
# ####   Advantages
# Adjusted close price stock market data is available Most recent stock market data is available Doesn't require API key to fetch the stock market data
#
# #### Disadvantages
# It is not a stable source to fetch the stock market data If the stock market data fetching fails from yahoo finance using the pandas_datareader then you can use yfinance package to fetch the data.
#
# ##### yfinance is another module which can be used to fetch the minute level stock market data. It returns the stock market data for the last 7 days.
#
# The yfinance module has the download method which can be used to download the stock market data. It takes the following parameters:
#
# ticker: The name of the tickers you want the data for. If you want data for multiple tickers then separate them by space
#
# period: The number of days/month of data required. The valid frequencies are 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max
#
# interval: The frequency of data. The valid intervals are 1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo
#
# The below code fetches the stock market data for MSFT for the past 5 days of 1-minute frequency.

# %% [markdown]
# ##### Featured Methods
# get_financial_stmts(frequency, statement_type, reformat=True)
# frequency can be either ‘annual’ or ‘quarterly’.
# statement_type can be ‘income’, ‘balance’, ‘cash’ or a list of several.
# reformat optional value defaulted to true. Enter False for unprocessed raw data from Yahoo Finance.
# get_stock_price_data(reformat=True)
# reformat optional value defaulted to true. Enter False for unprocessed raw data from Yahoo Finance.
# get_stock_earnings_data(reformat=True)
# reformat optional value defaulted to true. Enter False for unprocessed raw data from Yahoo Finance.
# get_summary_data(reformat=True)
# Returns financial summary data for cryptocurrencies, stocks, currencies, ETFs, mutual funds, U.S. Treasuries, commodity futures, and indexes.
# reformat optional value defaulted to true. Enter False for unprocessed raw data from Yahoo Finance.
# get_stock_quote_type_data()
# get_historical_price_data(start_date, end_date, time_interval)
# This method will pull historical pricing data for stocks, currencies, ETFs, mutual funds, U.S. Treasuries, cryptocurrencies, commodities, and indexes.
# start_date should be entered in the ‘YYYY-MM-DD’ format and is the first day that data will be pulled for.
# end_date should be entered in the ‘YYYY-MM-DD’ format and is the last day that data will be pulled for.
# time_interval can be either ‘daily’, ‘weekly’, or ‘monthly’. This variable determines the time period interval for your pull.
# Data response includes relevant pricing event data such as dividends and stock splits.
# get_num_shares_outstanding(price_type=’current’)
# price_type can also be set to ‘average’ to calculate the shares outstanding with the daily average price.

# %% [markdown]
# ##### Additional Module Methods
# get_interest_expense()
# get_operating_income()
# get_total_operating_expense()
# get_total_revenue()
# get_cost_of_revenue()
# get_income_before_tax()
# get_income_tax_expense()
# get_gross_profit()
# get_net_income_from_continuing_ops()
# get_research_and_development()
# get_current_price()
# get_current_change()
# get_current_percent_change()
# get_current_volume()
# get_prev_close_price()
# get_open_price()
# get_ten_day_avg_daily_volume()
# get_three_month_avg_daily_volume()
# get_stock_exchange()
# get_market_cap()
# get_daily_low()
# get_daily_high()
# get_currency()
# get_yearly_high()
# get_yearly_low()
# get_dividend_yield()
# get_annual_avg_div_yield()
# get_five_yr_avg_div_yield()
# get_dividend_rate()
# get_annual_avg_div_rate()
# get_50day_moving_avg()
# get_200day_moving_avg()
# get_beta()
# get_payout_ratio()
# get_pe_ratio()
# get_price_to_sales()
# get_exdividend_date()
# get_book_value()
# get_ebit()
# get_net_income()
# get_earnings_per_share()
# get_key_statistics_data()

# %%
ydata = yf.download(tickers="MSFT",
 period="5d",
 interval="1m")
ydata.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2020-03-02 09:30:00-05:00  165.149994  166.020004  164.699997  165.630005
# 2020-03-02 09:31:00-05:00  165.659393  166.100006  164.999100  165.940002
# 2020-03-02 09:32:00-05:00  165.979996  166.460007  165.320007  165.373505
# 2020-03-02 09:33:00-05:00  165.205002  165.205002  165.205002  165.205002
# 2020-03-02 09:34:00-05:00  165.089996  165.130005  165.089996  165.130005
#
#                             Adj Close   Volume
# Datetime
# 2020-03-02 09:30:00-05:00  165.630005  3149061
# 2020-03-02 09:31:00-05:00  165.940002   593869
# 2020-03-02 09:32:00-05:00  165.373505   408026
# 2020-03-02 09:33:00-05:00  165.205002   373780
# 2020-03-02 09:34:00-05:00  165.130005   510292

# %% [markdown]
# ###  Stocks Fundamental Data
# We have used yfinance to get the fundamental data.
#
# The first step is to set the ticker and then call the appropriate properties to get the right stock market data.

# %%
# Set the ticker as MSFT
# !pip install yfinance

# Import yfinance
import yfinance as yf

# Set the ticker as MSFT
y_finance = yf.Ticker("MSFT")


#yticker='MSFT'
#y_finance=yf.Ticker(yticker)
# Out:
# Requirement already satisfied: yfinance in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (0.1.54)
# Requirement already satisfied: requests>=2.20 in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (from yfinance) (2.22.0)
# Requirement already satisfied: pandas>=0.24 in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (from yfinance) (1.0.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (from yfinance) (1.18.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (from requests>=2.20->yfinance) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (from requests>=2.20->yfinance) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (from requests>=2.20->yfinance) (2.8)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (from pandas>=0.24->yfinance) (2019.3)
# Requirement already satisfied: six>=1.5 in c:\users\gordo\appdata\local\continuum\anaconda3\envs\notebook\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.14.0)

# %% [markdown]
# ### Key Ratios
# You can fetch the latest price to book ratio and price to earnings ratio as shown below.

# %%
# get price to book
pb = y_finance.info['priceToBook']
pe = y_finance.info['regularMarketPrice']/y_finance.info['trailingEps']

print('Price to Book Ratio is: %.2f' % pb)
print('Price to Earnings Ratio is: %.2f' % pe)
print('')

#or
ptb=y_finance.info['priceToBook']
print(ptb)
# Out:
# Price to Book Ratio is: 11.17
# Price to Earnings Ratio is: 28.32
#
# 11.168177

# %%
# show revenues

revenue = y_finance.info['enterpriseToRevenue']

revenue

#plt.bar(revenue.index, revenue.values)
#plt.ylabel("Total Revenues")
#plt.show()
# Out:
# 8.803

# %%
# Earnings Before Interest and Taxes

EBIT = y_finance.info['enterpriseToEbitda']

EBIT

#plt.bar(EBIT,'years')
#plt.ylabel("EBIT")
#plt.show()
# Out:
# 19.29

# %%
# show income statement
y_finance.financials

# show balance heet
y_finance.balance_sheet

# show cashflow
y_finance.cashflow

# show other info
y_finance.info
# Out:
# {'zip': '98052',
#  'sector': 'Technology',
#  'fullTimeEmployees': 144000,
#  'longBusinessSummary': "Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company's Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, and Skype for Business, as well as related Client Access Licenses (CAL); and Skype, Outlook.com, and OneDrive. It also provides LinkedIn that includes Talent and marketing solutions, and subscriptions; and Dynamics 365, a set of cloud-based and on-premises business solutions for small and medium businesses, large organizations, and divisions of enterprises. The company's Intelligent Cloud segment licenses SQL and Windows Servers, Visual Studio, System Center, and related CALs; GitHub that provides a collaboration platform and code hosting service for developers; and Azure, a cloud platform. It also provides support services and Microsoft consulting services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification to developers and IT professionals on various Microsoft products. The company's More Personal Computing segment offers Windows OEM licensing and other non-volume licensing of the Windows operating system; Windows Commercial comprising volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; Windows Internet of Things; and MSN advertising. It also provides Microsoft Surface, PC accessories, and other intelligent devices; Gaming, including Xbox hardware, and Xbox software and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. The company sells its products through distributors and resellers; and directly through digital marketplaces, online stores, and retail stores. It has strategic partnerships with Humana Inc. and Nokia. The company was founded in 1975 and is headquartered in Redmond, Washington.",
#  'city': 'Redmond',
#  'phone': '425-882-8080',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.microsoft.com',
#  'maxAge': 1,
#  'address1': 'One Microsoft Way',
#  'fax': '425-706-7329',
#  'industry': 'Software—Infrastructure',
#  'previousClose': 166.27,
#  'regularMarketOpen': 162.61,
#  'twoHundredDayAverage': 152.51007,
#  'trailingAnnualDividendYield': 0.011667769000000001,
#  'payoutRatio': 0.32930002,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 163.11,
#  'navPrice': None,
#  'averageDailyVolume10Day': 69348800,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 166.27,
#  'fiftyDayAverage': 173.70029,
#  'trailingAnnualDividendRate': 1.94,
#  'open': 162.61,
#  'averageVolume10days': 69348800,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 2.04,
#  'exDividendDate': 1582070400,
#  'beta': 1.091844,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 156,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 28.14318,
#  'regularMarketVolume': 72821057,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1228909576192,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 33603162,
#  'priceToSalesTrailing12Months': 9.153957,
#  'dayLow': 156,
#  'ask': 160.4,
#  'ytdReturn': None,
#  'askSize': 1800,
#  'volume': 72821057,
#  'fiftyTwoWeekHigh': 190.7,
#  'forwardPE': 25.60539,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 2,
#  'fiftyTwoWeekLow': 108.8,
#  'bid': 160.2,
#  'tradeable': True,
#  'dividendYield': 0.0123000005,
#  'bidSize': 1100,
#  'dayHigh': 163.11,
#  'exchange': 'NMS',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'messageBoardId': 'finmb_21835',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 8.803,
#  'beta3Year': None,
#  'profitMargins': 0.33016,
#  'enterpriseToEbitda': 19.29,
#  '52WeekChange': 0.5062053,
#  'morningStarRiskRating': None,
#  'forwardEps': 6.31,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 7606049792,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 14.467,
#  'sharesShort': 56193866,
#  'sharesPercentSharesOut': 0.0074,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1561852800,
#  'heldPercentInstitutions': 0.74424005,
#  'netIncomeToCommon': 44323000320,
#  'trailingEps': 5.741,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.10004258,
#  'priceToBook': 11.168177,
#  'heldPercentInsiders': 0.01421,
#  'nextFiscalYearEnd': 1625011200,
#  'mostRecentQuarter': 1577750400,
#  'shortRatio': 1.74,
#  'sharesShortPreviousMonthDate': 1579046400,
#  'floatShares': 7494922663,
#  'enterpriseValue': 1181824974848,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1045526400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.383,
#  'dateShortInterest': 1581638400,
#  'pegRatio': 1.97,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0074,
#  'sharesShortPriorMonth': 63639312,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 162.61,
#  'logo_url': 'https://logo.clearbit.com/microsoft.com'}

# %% [markdown]
# ### more data pulls

# %%
# Plot the adjusted close price
data['4. close'].plot(figsize=(10, 7))

# Define the label for the title of the figure
plt.title("Adjusted Close Price of %s" % ticker, fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

# Show the plot
plt.show()

# %%
start = datetime(2016, 12, 31)
end = datetime.now()

stock_data = pdr.DataReader(["SBUX", "SHOP", "BIDU", "WDAY", "WIX",],
                             'yahoo', start, end)

stock_data=pd.DataFrame(stock_data['Adj Close'])
stock_data
# Out:
# Symbols          SBUX        SHOP        BIDU        WDAY         WIX
# Date
# 2017-01-03  51.889256   42.820000  168.300003   68.379997   44.950001
# 2017-01-04  52.489239   44.139999  171.960007   71.360001   46.200001
# 2017-01-05  52.929848   47.680000  177.470001   72.279999   47.000000
# 2017-01-06  53.557957   46.900002  176.380005   73.849998   47.450001
# 2017-01-09  54.561058   47.180000  177.160004   74.760002   47.900002
# ...               ...         ...         ...         ...         ...
# 2020-03-02  82.379997  488.399994  120.769997  172.889999  138.720001
# 2020-03-03  78.599998  476.940002  117.970001  166.559998  135.130005
# 2020-03-04  79.669998  512.229980  121.410004  170.889999  140.710007
# 2020-03-05  76.190002  498.220001  118.239998  165.309998  137.179993
# 2020-03-06  75.339996  472.070007  113.739998  158.679993  136.250000
#
# [799 rows x 5 columns]

# %%
stock_data_closing_prices = stock_data
stock_data_closing_prices.plot()
plt.xlabel("Date")
plt.ylabel("Adjusted Closing Price")
plt.title("Tech Stocks Adjusted Price Over Time")
plt.show()

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ## Plot Portfolio

# %%
start = datetime(2016, 12, 31)
end = datetime.now()

stock_data = pdr.DataReader(["SBUX", "SHOP", "BIDU", "WDAY", "WIX",],
                             'yahoo', start, end)

stock_data=pd.DataFrame(stock_data['Adj Close'])
stock_data
# Out:
# Symbols          SBUX        SHOP        BIDU        WDAY         WIX
# Date
# 2017-01-03  51.889256   42.820000  168.300003   68.379997   44.950001
# 2017-01-04  52.489239   44.139999  171.960007   71.360001   46.200001
# 2017-01-05  52.929848   47.680000  177.470001   72.279999   47.000000
# 2017-01-06  53.557957   46.900002  176.380005   73.849998   47.450001
# 2017-01-09  54.561058   47.180000  177.160004   74.760002   47.900002
# ...               ...         ...         ...         ...         ...
# 2020-03-02  82.379997  488.399994  120.769997  172.889999  138.720001
# 2020-03-03  78.599998  476.940002  117.970001  166.559998  135.130005
# 2020-03-04  79.669998  512.229980  121.410004  170.889999  140.710007
# 2020-03-05  76.190002  498.220001  118.239998  165.309998  137.179993
# 2020-03-06  75.339996  472.070007  113.739998  158.679993  136.250000
#
# [799 rows x 5 columns]

# %%
stock_data_closing_prices = stock_data
stock_data_closing_prices.plot()
plt.xlabel("Date")
plt.ylabel("Adjusted Closing Price")
plt.title("Tech Stocks Adjusted Price Over Time")
plt.show()

# %%
stock_data_daily_returns = stock_data.pct_change()
stock_data_daily_returns.plot()
plt.xlabel("Date")
plt.ylabel("ROR")
plt.title("Daily Simple Rate of Return Over time")
plt.figure(figsize=(16,9))
plt.show()

# %%
fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)



ax1.plot(stock_data['SBUX'].pct_change())
ax1.set_title("SBUX")
ax2.plot(stock_data['SHOP'].pct_change())
ax2.set_title("SHOP")
ax3.plot(stock_data['BIDU'].pct_change())
ax3.set_title("BIDU")
ax4.plot(stock_data['WDAY'].pct_change())
ax4.set_title("WDAY")
ax5.plot(stock_data['WIX'].pct_change())
ax5.set_title("WIX")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## GRAPH DAILY MEAN

# %%
# calculate daily mean
daily_mean = stock_data_daily_returns.mean()
daily_mean1=pd.DataFrame(daily_mean)

# daily mean index for the x axis
daily_mean.keys()

# grab each daily mean value for the y axis
height = []
for key in daily_mean.keys():
    height.append(daily_mean[key])

# arrange keys on x axis based on length
x_pos = np.arange(len(daily_mean.keys()))


# plot bars
plt.bar(x_pos, height)
 
# create names on the x-axis
plt.xticks(x_pos, daily_mean.keys())

# label chart
plt.xlabel("Tech_Stocks")
plt.ylabel("daily mean")
plt.title("daily mean rate of return")

# show graphic
plt.show()

daily_mean1
# Out:
#                 0
# Symbols
# SBUX     0.000554
# SHOP     0.003456
# BIDU    -0.000265
# WDAY     0.001293
# WIX      0.001757

# %% [markdown]
# ## VARIANCE

# %%
# calculate variance
daily_var = stock_data_daily_returns.var()
daily_var1=pd.DataFrame(daily_var)

# variance index for the x axis
daily_var.keys()

# grab each variance value for the y axis
height = []
for key in daily_var.keys():
    height.append(daily_var[key])
    
# arrange keys on x axis based on length
x_pos = np.arange(len(daily_var.keys()))



# plot bars
plt.bar(x_pos, height)
 
# create names on the x-axis
plt.xticks(x_pos, daily_var.keys())

# label chart
plt.xlabel("Tech_Stocks")
plt.ylabel("variance")
plt.title("daily variance")

# show graphic
plt.show()

daily_var1
# Out:
#                 0
# Symbols
# SBUX     0.000172
# SHOP     0.000886
# BIDU     0.000449
# WDAY     0.000474
# WIX      0.000730

# %% [markdown]
# ## STANDARD DEVIATION (STD)

# %%
# calculate standard deviation
daily_std = stock_data_daily_returns.std()
daily_std1=pd.DataFrame(daily_std)

# standard deviation index for the x axis
daily_var.keys()

# grab each standard deviation value for the y axis
height = []
for key in daily_std.keys():
    height.append(daily_std[key])
    
# arrange keys on x axis based on length
x_pos = np.arange(len(daily_std.keys()))


# plot bars
plt.bar(x_pos, height)
 
# create names on the x-axis
plt.xticks(x_pos, daily_std.keys())

# label chart
plt.xlabel("Tech_Stocks")
plt.ylabel("std")
plt.title("daily std")

# show graphic
plt.show()

daily_std1
# Out:
#                 0
# Symbols
# SBUX     0.013116
# SHOP     0.029774
# BIDU     0.021185
# WDAY     0.021774
# WIX      0.027022

# %% [markdown]
# # RATIO ANALYSIS
#
# 1. Daily Mean
# 2. Concept
# 3. concept

# %% [markdown]
# ## DAILY MEAN RoR

# %%
# calculate daily mean
daily_mean = stock_data_daily_returns.mean()
daily_mean1=pd.DataFrame(daily_mean)

daily_mean1
# Out:
#                 0
# Symbols
# SBUX     0.000554
# SHOP     0.003456
# BIDU    -0.000265
# WDAY     0.001293
# WIX      0.001757

# %% [markdown]
# ## variance

# %%
# calculate variance
daily_var = stock_data_daily_returns.var()
daily_var1=pd.DataFrame(daily_var)
daily_var1
# Out:
#                 0
# Symbols
# SBUX     0.000172
# SHOP     0.000886
# BIDU     0.000449
# WDAY     0.000474
# WIX      0.000730

# %% [markdown]
# ## Standard Deviation

# %%
# calculate standard deviation
daily_std = stock_data_daily_returns.std()
daily_std1=pd.DataFrame(daily_std)
daily_std1
# Out:
#                 0
# Symbols
# SBUX     0.013116
# SHOP     0.029774
# BIDU     0.021185
# WDAY     0.021774
# WIX      0.027022

# %% [markdown]
# ## PORTFOLIO CORRELATION

# %%
stock_data_daily_returns.corr()
# Out:
# Symbols      SBUX      SHOP      BIDU      WDAY       WIX
# Symbols
# SBUX     1.000000  0.249708  0.150864  0.271676  0.270624
# SHOP     0.249708  1.000000  0.342702  0.540264  0.504994
# BIDU     0.150864  0.342702  1.000000  0.333676  0.292584
# WDAY     0.271676  0.540264  0.333676  1.000000  0.507631
# WIX      0.270624  0.504994  0.292584  0.507631  1.000000

# %% [markdown]
# # STRATEGIES

# %% [markdown]
# ## PAIRS TRADING STRATEGY

# %%
# Initializing variables

data = []
headers = ['Date','commodity1','commodity2','zscore','signal','status',\
              'buy price','sell price','mtm','pnl','Cointegration test']
data.append(headers)
threshold = 1.75    # Tolerance for the stdev above and below the mean
start=80
end=90
prev_status = ""
mtm = ""
prev_sell_price = ""
sell_price = ""
prev_buy_price = ""
buy_price = ""
SL = -10000      # Stop loss
TP = 20000       # Take profit
N=5000           # Lot size for data1
M=5000           # Lot size for data2

# %%
from quantrautil import get_quantinsti_api_key

# To get your API key, sign up for a free Quandl account.
# Then, you can find your API key on Quandl account settings page.

QUANDL_API_KEY = 'dbyBuiq4bczbbuz9bA4t'

data1 = quandl.get("CHRIS/MCX_AL1", start_date="2014-04-01", \
                   end_date="2016-07-01", api_key= QUANDL_API_KEY)

data2 = quandl.get("CHRIS/MCX_PB1", start_date="2014-04-01", \
                   end_date="2016-07-01", api_key= QUANDL_API_KEY)

# %%
data1
# Out:
#               Open    High     Low   Close  Volume  Open Interest
# Date
# 2014-04-01  106.00  106.70  105.65  106.25  5022.0         2282.0
# 2014-04-02  106.00  108.45  105.90  106.35  8147.0         3343.0
# 2014-04-03  108.15  110.10  108.00  108.40  7821.0         3384.0
# 2014-04-04  109.60  110.35  108.05  109.60  6639.0         3144.0
# 2014-04-07  108.00  109.90  107.80  108.00  6874.0         3208.0
# ...            ...     ...     ...     ...     ...            ...
# 2016-06-27  109.20  109.60  107.80  107.90  6787.0         2487.0
# 2016-06-28  108.20  110.10  108.20  109.75  5581.0         2468.0
# 2016-06-29  109.70  109.85  108.90  109.75  4151.0         2019.0
# 2016-06-30  109.60  110.80  109.55  110.55  3082.0         1175.0
# 2016-07-01  105.05  107.30  105.00  106.90   171.0           61.0
#
# [558 rows x 6 columns]

# %%
data2
# Out:
#               Open    High     Low   Close   Volume  Open Interest
# Date
# 2014-04-01  124.25  124.25  122.35  124.40   8458.0         2528.0
# 2014-04-02  122.50  123.70  122.10  122.45   9275.0         2559.0
# 2014-04-03  123.00  124.30  122.45  123.00  10047.0         2424.0
# 2014-04-04  124.30  124.75  123.00  124.20   9162.0         2734.0
# 2014-04-07  123.30  124.25  123.00  123.35   8829.0         2752.0
# ...            ...     ...     ...     ...      ...            ...
# 2016-06-27  115.80  116.30  114.95  115.15  10184.0         2986.0
# 2016-06-28  115.60  117.85  115.60  117.25  13089.0         2448.0
# 2016-06-29  117.00  119.30  117.00  119.05  11925.0         1873.0
# 2016-06-30  120.00  120.75  119.05  120.30   7195.0          750.0
# 2016-07-01  114.50  116.85  113.70  116.75    221.0           80.0
#
# [558 rows x 6 columns]

# %%
QUANDL_API_KEY = 'dbyBuiq4bczbbuz9bA4t'

# Set the start and end date
start_date = '1990-01-01'
end_date = '2018-03-01'

# Set the ticker name
ticker = 'AMZN'

# Feth the data
data1 = quandl.get("CHRIS/MCX_AL1", start_date="2014-04-01", \
                   end_date="2016-07-01", api_key= QUANDL_API_KEY)
data2 = quandl.get("CHRIS/MCX_PB1", start_date="2014-04-01", \
                   end_date="2016-07-01", api_key= QUANDL_API_KEY)


# Print the first 5 rows of the dataframe
data
# Out:
# [['Date',
#   'commodity1',
#   'commodity2',
#   'zscore',
#   'signal',
#   'status',
#   'buy price',
#   'sell price',
#   'mtm',
#   'pnl',
#   'Cointegration test']]

# %% [markdown]
# ### Columns

# %%
# Drop nan columns
data1 = data1.dropna()
data2 = data2.dropna()

# To make the data uniform date wise
data1['key']=data1.index
data2['key']=data2.index

# Merge dataframes to find common dates
result = pd.merge(data1, data2, on='key', left_index=True, right_index=False)

data1 = result[['Open_x','High_x','Low_x','Close_x','Volume_x']] 
data2 = result[['Open_y','High_y','Low_y','Close_y','Volume_y']]

data1.columns = ['Open','High','Low','Close','Volume'] # Rename the columns

data2.columns = ['Open','High','Low','Close','Volume'] # Rename the columns

# %%
data1
# Out:
#               Open    High     Low   Close  Volume
# Date
# 2014-04-01  106.00  106.70  105.65  106.25  5022.0
# 2014-04-02  106.00  108.45  105.90  106.35  8147.0
# 2014-04-03  108.15  110.10  108.00  108.40  7821.0
# 2014-04-04  109.60  110.35  108.05  109.60  6639.0
# 2014-04-07  108.00  109.90  107.80  108.00  6874.0
# ...            ...     ...     ...     ...     ...
# 2016-06-27  109.20  109.60  107.80  107.90  6787.0
# 2016-06-28  108.20  110.10  108.20  109.75  5581.0
# 2016-06-29  109.70  109.85  108.90  109.75  4151.0
# 2016-06-30  109.60  110.80  109.55  110.55  3082.0
# 2016-07-01  105.05  107.30  105.00  106.90   171.0
#
# [558 rows x 5 columns]

# %%
data2
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2014-04-01  124.25  124.25  122.35  124.40   8458.0
# 2014-04-02  122.50  123.70  122.10  122.45   9275.0
# 2014-04-03  123.00  124.30  122.45  123.00  10047.0
# 2014-04-04  124.30  124.75  123.00  124.20   9162.0
# 2014-04-07  123.30  124.25  123.00  123.35   8829.0
# ...            ...     ...     ...     ...      ...
# 2016-06-27  115.80  116.30  114.95  115.15  10184.0
# 2016-06-28  115.60  117.85  115.60  117.25  13089.0
# 2016-06-29  117.00  119.30  117.00  119.05  11925.0
# 2016-06-30  120.00  120.75  119.05  120.30   7195.0
# 2016-07-01  114.50  116.85  113.70  116.75    221.0
#
# [558 rows x 5 columns]

# %% [markdown]
# ### Functions

# %%
# Define cointegration test function

# Use OLS method to find the spread of the two series
# Check for stationarity of the spread using adfuller test
import statsmodels.api as sm
from alpha_vantage.timeseries import TimeSeries as ts
        
def cointegration_test(x, y):
    result = sm.OLS(x['Close'], y['Close']).fit()   
    return ts.adfuller(result.resid)

# %%
# Define z-score calculation function
def zscore_cal(data1,data2,start,end):
    s1 = pd.Series(data1['Close'][start:end])
    s2 = pd.Series(data2['Close'][start:end])

    mvavg_old = np.mean(np.log(s1/s2))  # Compute mean of the spread till now

    std_old = np.std(np.log(s1/s2))    #  Compute stdev of the spread till now
    
    current_spread = np.log(data1['Close'][end]/data2['Close'][end])   # Compute spread
    
    # This is the same as current_spread = np.log(data1['Close'][end]) - np.log(data2['Close'][end])
    
    zscore = (current_spread - mvavg_old)/std_old if std_old > 0 else 0  # Compute z-score

    return zscore

# %%
# Generating trading signals
def signal_cal(zscore,threshold,adftest):
    if zscore > threshold and adftest == 'Yes': 
        signal = 'SELL' # Z-score is greater than threshold, the spread shall fall towards mean

    elif zscore < -threshold and adftest == 'Yes':
        signal = 'BUY' # Z-score is smaller than threshold, the spread shall rise towards mean
    else:
        signal = ''
    return signal

# %%
# Defining status
def status_cal(prev_status,mtm,SL,TP,signal,adftest):
    if prev_status in ["","SL","TP","CB"]:
        status = signal
    else:
        if adftest == "No":
            status = "CB"   # Break in the cointegration status of the pair
        else:
            if mtm == "":
                status = ""
            else:
                if mtm<SL:
                    status="SL"   # Stop loss status
                else:
                    if mtm>TP:
                        status="TP"  # Take profit status
                    else:
                        status = prev_status

    return status

# %%
# Calculating buy price
def buy_price_cal(prev_status,prev_buy_price,buy_price,signal,status,data1, data2,end):
    if status == prev_status:
        buy_price = prev_buy_price
    else:
        if status in ["SL","TP","CB",""]:
            buy_price = ""
        else:
            if signal == "BUY":    # Signal is to buy the spread
                buy_price = data1['Close'][end]  # Hence, buy price = close of first security
            else:
                if signal == "SELL":  # Signal is to sell the spread
                    buy_price = data2['Close'][end]  # Hence, buy price = close of second security
                else:
                    buy_price = ""   # no signal hence no buy price

    return buy_price

# %%
# Calculating sell price
def sell_price_cal(prev_status,prev_sell_price,sell_price,signal,status, data1,data2,end):
    if status == prev_status:
        sell_price = prev_sell_price
    else:
        if status in ["SL","TP","CB",""]:
            sell_price = ""
        else:
            if signal == "BUY":  # Signal is to buy the spread
                sell_price = data2['Close'][end] # Hence sell price = close of second security
            else:
                if signal == "SELL": # signal is to sell the spread
                    sell_price = data1['Close'][end] # Hence sell price = close of first security
                else:
                    sell_price = "" # No signal hence no sell price either

    return sell_price

# %%
# Calculating mtm
def mtm_cal(data1,data2,prev_status,prev_sell_price,prev_buy_price,M,N,end):
    if prev_status == "BUY":
        mtm = (prev_sell_price-data2['Close'][end])*M + (data1['Close'][end]-\
               prev_buy_price)*N  # Calculate mtm of the trades using their lot sizes
    else:
        if prev_status == "SELL":
            mtm =(prev_sell_price-data1['Close'][end])*N +(data2['Close'][end]\
                   -prev_buy_price)*M    # Calculate mtm of the trades using their lot sizes
        else:
            mtm = ""

    return mtm

# %%
# Defining the strategy function to execute the pairs trading program
def strategy(data1,data2,threshold,start,end,prev_status,mtm,prev_sell_price,\
             sell_price,prev_buy_price,buy_price,SL,TP,M,N):
    pnl = 0
    i = 0
    for row in data1[90:].iterrows():

         # Running the ADF test for each day, starting from day 91
        d1 = data1[i:90+i]
        d2 = data2[i:90+i]
        c_t = cointegration_test(d1, d2)
        if c_t[0] <= c_t[4]['10%'] and c_t[1] <= 0.1:
            adftest = "Yes"
        else:
            adftest = "No"
   
        # Calculating z-score
        zscore = zscore_cal(data1,data2,start,end)

        # Generating trading signals
        signal = signal_cal(zscore,threshold,adftest)

        # Calculating mtm
        mtm = mtm_cal(data1,data2,prev_status,prev_sell_price,\
                      prev_buy_price,M,N,end)

        # Assigning status
        status = status_cal(prev_status,mtm,SL,TP,signal,adftest)

        # Assigning buy_price
        buy_price = buy_price_cal(prev_status,prev_buy_price,buy_price,\
                                  signal,status,data1,data2,end)


        # Assigning sell_price
        sell_price = sell_price_cal(prev_status,prev_sell_price,sell_price,\
                                    signal,status,data1,data2,end)

        # Calculating pnl
        pnl = (pnl + mtm) if status in ["TP","SL","CB"] else pnl

        # Assigning prev values
        prev_sell_price = sell_price
        prev_status = status
        prev_buy_price = buy_price

        # Appending calculations to the data array
        data.append([str(data1.index[end])[:10],data1['Close'][end],\
                         data2['Close'][end],zscore,signal,status,buy_price,\
                         sell_price,mtm,pnl,adftest])

        # Incrementing variables to consider the next set of data
        end = end+1
        start = start+1
        i = i+1
        
    pyexcel.save_as(array = data, dest_file_name = \
                        'pair_strategy_without_zipline-90.csv')  # Save to CSV for debugging

# %%
fig,ax = plt.subplots(1,1,figsize = (10,5))

# Plot data1.Close
ax.plot(data1.index, data1.Close, label ='Aluminium') 

# Plot data2.Close
ax.plot(data2.index, data2.Close, label ='Lead') 

plt.legend() # Let matplotlib choose best location for legend
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Close Prices', fontsize = 20)
plt.title('Aluminium and Lead Close Prices', fontsize = 20)

plt.grid() # Display the major grid
plt.tight_layout()
plt.show() # Finally display the plot

# %%
fig,ax = plt.subplots(1,1,figsize = (10,5))

# Plot the spread
ax.plot(data2.index, np.log(data1.Close.values/data2.Close.values), label = 'Spread') 

plt.legend()
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Spread', fontsize = 20)
plt.title('Spread of Aluminium and Lead Close Prices', fontsize = 20)
plt.grid() 
plt.tight_layout()
plt.show()

# %%
    # Run the strategy

strategy(data1, data2, threshold, start, end, prev_status, mtm, prev_sell_price,\
             sell_price, prev_buy_price, buy_price, SL, TP, M, N) 

result = pd.DataFrame(data, columns=headers)[1:] # Ignore the first row
result.set_index('Date',inplace=True)  # Set Date column as index for better plotting
result.index = pd.to_datetime(result.index) # Convert index to a datetime index

result.pnl.plot(figsize=(10,5), label ='PnL') 
plt.legend() 
plt.ylabel('PnL')
plt.title('PnL')
plt.grid() 
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-324-2adfea86a3f5> in <module>
#       1 # Run the strategy
#       2
# ----> 3 strategy(data1, data2, threshold, start, end, prev_status, mtm, prev_sell_price,\
#       4          sell_price, prev_buy_price, buy_price, SL, TP, M, N)
#       5
#
# <ipython-input-321-2add91ee7eda> in strategy(data1, data2, threshold, start, end, prev_status, mtm, prev_sell_price, sell_price, prev_buy_price, buy_price, SL, TP, M, N)
#       9         d1 = data1[i:90+i]
#      10         d2 = data2[i:90+i]
# ---> 11         c_t = cointegration_test(d1, d2)
#      12         if c_t[0] <= c_t[4]['10%'] and c_t[1] <= 0.1:
#      13             adftest = "Yes"
#
# <ipython-input-314-87c99f13cb4a> in cointegration_test(x, y)
#       8 def cointegration_test(x, y):
#       9     result = sm.OLS(x['Close'], y['Close']).fit()
# ---> 10     return ts.adfuller(result.resid)
#
# AttributeError: type object 'TimeSeries' has no attribute 'adfuller'

# %% [markdown]
# ## INCOME STMT ANALYSIS (with waterfall chart)

# %%
def selectquote(quote): 
    r= requests.get(f"https://financialmodelingprep.com/api/v3/financials/income-statement/{quote}?period=quarter") 
    r = r.json() 
    stock = r['financials']
    stock = pd.DataFrame.from_dict(stock) 
    stock = stock.T   
    stock.columns = stock.iloc[0]
    stock.reset_index(inplace=True) 
    return stock 

selectquote('AAPL')
# Out:
# date                       index      2019-12-28      2019-09-28  \
# 0                           date      2019-12-28      2019-09-28
# 1                        Revenue   91819000000.0   64040000000.0
# 2                 Revenue Growth             0.0             0.0
# 3                Cost of Revenue   56602000000.0   39727000000.0
# 4                   Gross Profit   35217000000.0   24313000000.0
# ..                           ...             ...             ...
# 27                        EBITDA   28385000000.0   18804000000.0
# 28                          EBIT   25569000000.0   15625000000.0
# 29           Consolidated Income   22236000000.0   13686000000.0
# 30    Earnings Before Tax Margin  0.282272732223  0.251826983136
# 31             Net Profit Margin  0.242172099457  0.213710181137
#
# date      2019-06-29      2019-03-30      2018-12-29      2018-09-29  \
# 0         2019-06-29      2019-03-30      2018-12-29      2018-09-29
# 1      53809000000.0   58015000000.0   84310000000.0   62900000000.0
# 2                0.0             0.0             0.0             0.0
# 3      33582000000.0   36194000000.0   52279000000.0   38816000000.0
# 4      20227000000.0   21821000000.0   32031000000.0   24084000000.0
# ..               ...             ...             ...             ...
# 27     14477000000.0   16455000000.0   26741000000.0   18872000000.0
# 28     11544000000.0   13415000000.0   23346000000.0   16118000000.0
# 29     10044000000.0   11561000000.0   19965000000.0   14125000000.0
# 30     0.22135702206  0.237748858054  0.283548807971   0.26106518283
# 31    0.186660224126  0.199276049298  0.236804649508  0.224562798092
#
# date      2018-06-30      2018-03-31      2017-12-30      2017-09-30  \
# 0         2018-06-30      2018-03-31      2017-12-30      2017-09-30
# 1      53265000000.0   61137000000.0   88293000000.0   52579000000.0
# 2                0.0             0.0             0.0             0.0
# 3      32844000000.0   37715000000.0   54381000000.0   32648000000.0
# 4      20421000000.0   23422000000.0   33912000000.0   19931000000.0
# ..               ...             ...             ...             ...
# 27     15277000000.0   18633000000.0   29019000000.0   15604000000.0
# 28     12612000000.0   15894000000.0   26274000000.0   13120000000.0
# 29     11519000000.0   13822000000.0   20065000000.0   10714000000.0
# 30     0.24939453675  0.264455239871  0.306139784581  0.264687422735
# 31    0.216258330987   0.22608240509  0.227254708754  0.203769565796
#
# date      2017-07-01      2017-04-01      2016-12-31      2016-09-24  \
# 0         2017-07-01      2017-04-01      2016-12-31      2016-09-24
# 1      45408000000.0   52896000000.0   78351000000.0   46852000000.0
# 2                0.0             0.0             0.0             0.0
# 3      27920000000.0   32305000000.0   48175000000.0   29039000000.0
# 4      17488000000.0   20591000000.0   30176000000.0   17813000000.0
# ..               ...             ...             ...             ...
# 27     13122000000.0   16429000000.0   26346000000.0   14309000000.0
# 28     10768000000.0   14097000000.0   23359000000.0   11761000000.0
# 29      8717000000.0   11029000000.0   17891000000.0    9014000000.0
# 30    0.249031007752  0.277601330913  0.308611249378  0.260138307863
# 31    0.191970577872  0.208503478524  0.228344245766  0.192393067532
#
# date      2016-06-25      2016-03-26      2015-12-26      2015-09-26  \
# 0         2016-06-25      2016-03-26      2015-12-26      2015-09-26
# 1      42358000000.0   50557000000.0   75872000000.0   51501000000.0
# 2                0.0             0.0             0.0             0.0
# 3      26252000000.0   30636000000.0   45449000000.0   30953000000.0
# 4      16106000000.0   19921000000.0   30423000000.0   20548000000.0
# ..               ...             ...             ...             ...
# 27     12631000000.0   16464000000.0   27125000000.0   17742000000.0
# 28     10105000000.0   13987000000.0   24171000000.0   14623000000.0
# 29      7796000000.0   10516000000.0   18361000000.0   11124000000.0
# 30    0.247155200907  0.279723876021  0.323874420076  0.292460340576
# 31    0.184050238444   0.20800284827  0.241999683678  0.215995805907
#
# date      2015-06-27      2015-03-28      2014-12-27      2014-09-27  \
# 0         2015-06-27      2015-03-28      2014-12-27      2014-09-27
# 1      49605000000.0   58010000000.0   74599000000.0   42123000000.0
# 2                0.0             0.0             0.0             0.0
# 3      29924000000.0   34354000000.0   44858000000.0   26114000000.0
# 4      19681000000.0   23656000000.0   29741000000.0   16009000000.0
# ..               ...             ...             ...             ...
# 27     17167000000.0   20757000000.0   26821000000.0   13134000000.0
# 28     14083000000.0   18278000000.0   24246000000.0   11165000000.0
# 29     10677000000.0   13569000000.0   18024000000.0    8467000000.0
# 30     0.29176494305  0.320013790726  0.327296612555  0.272345274553
# 31    0.215240399153  0.233907946906  0.241611817853   0.20100657598
#
# date      2014-06-28      2014-03-29      2013-12-28      2013-09-28  \
# 0         2014-06-28      2014-03-29      2013-12-28      2013-09-28
# 1      37432000000.0   45646000000.0   57594000000.0   37472000000.0
# 2                0.0             0.0             0.0             0.0
# 3      22697000000.0   27699000000.0   35748000000.0   23601000000.0
# 4      14735000000.0   17947000000.0   21846000000.0   13871000000.0
# ..               ...             ...             ...             ...
# 27     12228000000.0   15480000000.0   19607000000.0   11813000000.0
# 28     10282000000.0   13593000000.0   17463000000.0   10030000000.0
# 29      7748000000.0   10223000000.0   13072000000.0    7512000000.0
# 30    0.280081213935  0.302720939403  0.307479945828  0.270682109308
# 31    0.206988672793  0.223962669237  0.226968086954  0.200469684031
#
# date      2013-06-29      2013-03-30      2012-12-29      2012-09-29  \
# 0         2013-06-29      2013-03-30      2012-12-29      2012-09-29
# 1      35323000000.0   43603000000.0   54512000000.0   35966000000.0
# 2                0.0             0.0             0.0             0.0
# 3      22299000000.0   27254000000.0   33452000000.0   21565000000.0
# 4      13024000000.0   16349000000.0   21060000000.0   14401000000.0
# ..               ...             ...             ...             ...
# 27     10895000000.0   14250000000.0   18798000000.0   11925000000.0
# 28      9201000000.0   12558000000.0   17210000000.0   10944000000.0
# 29      6900000000.0    9547000000.0   13078000000.0    8223000000.0
# 30    0.267106417915  0.295965873908   0.32418550044  0.302869376633
# 31    0.195340146647  0.218952824347  0.239910478427  0.228632597453
#
# date      2012-06-30      2012-03-31      2011-12-31      2011-09-24  \
# 0         2012-06-30      2012-03-31      2011-12-31      2011-09-24
# 1      35023000000.0   39186000000.0   46333000000.0   28270000000.0
# 2                0.0             0.0             0.0             0.0
# 3      20029000000.0   20622000000.0   25630000000.0   16890000000.0
# 4      14994000000.0   18564000000.0   20703000000.0   11380000000.0
# ..               ...             ...             ...             ...
# 27     12408000000.0   16124000000.0   18061000000.0    9253000000.0
# 28     11573000000.0   15384000000.0   17340000000.0    8710000000.0
# 29      8824000000.0   11622000000.0   13064000000.0    6623000000.0
# 30    0.338663164206  0.396366049099  0.377204152548  0.310965688008
# 31    0.251948719413  0.296585515235  0.281958863013  0.234276618323
#
# date      2011-06-25      2011-03-26      2010-12-25      2010-09-25  \
# 0         2011-06-25      2011-03-26      2010-12-25      2010-09-25
# 1      28571000000.0   24667000000.0   26741000000.0   20343000000.0
# 2                0.0             0.0             0.0             0.0
# 3      16649000000.0   14449000000.0   16443000000.0   12831000000.0
# 4      11922000000.0   10218000000.0   10298000000.0    7512000000.0
# ..               ...             ...             ...             ...
# 27      9860000000.0    8308000000.0    8183000000.0    5776000000.0
# 28      9379000000.0    7874000000.0    7827000000.0    5447000000.0
# 29      7308000000.0    5987000000.0    6004000000.0    4308000000.0
# 30     0.33429001435  0.320265942352  0.297782431472  0.268446148552
# 31    0.255783836758  0.242712936312  0.224524138963  0.211768175785
#
# date      2010-06-26      2010-03-27         2009-12-26         2009-09-26  \
# 0         2010-06-26      2010-03-27         2009-12-26         2009-09-26
# 1      15700000000.0   29182000000.0      15683000000.0      12207000000.0
# 2                0.0             0.0  0.284754648971901  0.254057941236902
# 3       9564000000.0   17146000000.0       9272000000.0       7102000000.0
# 4       6136000000.0   12036000000.0       6411000000.0       5105000000.0
# ..               ...             ...                ...                ...
# 27      4507000000.0    9129000000.0       4967000000.0       3932000000.0
# 28      4234000000.0    8704000000.0       4758000000.0       3729000000.0
# 29      3253000000.0    6452000000.0       3378000000.0       2532000000.0
# 30    0.273375796178  0.301110273456             0.3034             0.3055
# 31    0.207197452229  0.221095195669             0.2154             0.2074
#
# date    2009-06-27
# 0       2009-06-27
# 1     9734000000.0
# 2           0.3041
# 3     5751000000.0
# 4     3983000000.0
# ..             ...
# 27    2874000000.0
# 28    2692000000.0
# 29    1828000000.0
# 30          0.2766
# 31          0.1878
#
# [32 rows x 44 columns]

# %%
def selectquote1(quote):
    r= requests.get(f"https://financialmodelingprep.com/api/v3/financials/income-statement/{quote}?period=quarter")
    r = r.json()
    stock = r['financials']
    stock = pd.DataFrame.from_dict(stock)
    stock = stock.T
    stock.columns = stock.iloc[0]
    stock.reset_index(inplace=True)
    stock = stock.iloc[:,0:2]
    stock.rename(columns={ stock.columns[1]: quote }, inplace = True)
    cols = stock.columns.drop('index')
    stock = stock.iloc[1:,]
    return stock

selectquote1('AAPL')
# Out:
# date                       index            AAPL
# 1                        Revenue   91819000000.0
# 2                 Revenue Growth             0.0
# 3                Cost of Revenue   56602000000.0
# 4                   Gross Profit   35217000000.0
# 5                   R&D Expenses    4451000000.0
# ..                           ...             ...
# 27                        EBITDA   28385000000.0
# 28                          EBIT   25569000000.0
# 29           Consolidated Income   22236000000.0
# 30    Earnings Before Tax Margin  0.282272732223
# 31             Net Profit Margin  0.242172099457
#
# [31 rows x 2 columns]

# %%
r=requests.get("https://financialmodelingprep.com/api/v3/financials/income-statement/AAPL?period=quarter")
r=r.json()
d=r['financials']
count=0
for item in d:
    if count ==0:
        d=r['financials']
        d=d[0]
        incomeinitial=pd.DataFrame(list(d.items()),columns=['item','value'])
    count=count+1
    if count>5:
        continue
    d=r['financials']
    d=d[count]
    
    incomeinitial2=pd.DataFrame(list(d.items()),columns=['item','value'])
    incomeinitial=incomeinitial.merge(incomeinitial2,on="item",how='left')
    
incomeinitial=pd.DataFrame(list(d.items()),columns=['item','value'])
incomeinitial.columns=incomeinitial.iloc[0]
incomeinitial=incomeinitial[1:]
incomeinitial
cols=incomeinitial.columns
cols=cols[1:]

# %%
print('Here Is The Financial Report For: AAPL')
incomeinitial
# Out:
# Here Is The Financial Report For: AAPL
# 0                         date      2018-09-29
# 1                      Revenue   62900000000.0
# 2               Revenue Growth             0.0
# 3              Cost of Revenue   38816000000.0
# 4                 Gross Profit   24084000000.0
# 5                 R&D Expenses    3750000000.0
# ..                         ...             ...
# 27                      EBITDA   18872000000.0
# 28                        EBIT   16118000000.0
# 29         Consolidated Income   14125000000.0
# 30  Earnings Before Tax Margin   0.26106518283
# 31           Net Profit Margin  0.224562798092
#
# [31 rows x 2 columns]

# %% [markdown]
# ## Portfolio Allocation and Sharp Ratio

# %%
# . . . . . . . . . . DEFINE 5 SECURITIES TO LOOKUP . . . . . . . . . .
s1=input('Enter Ticker 1: ')
s2=input('Enter Ticker 2: ')
s3=input('Enter Ticker 3: ')
s4=input('Enter Ticker 4: ')

# . . . . . . . . . . ASSIGN ASSETS TO LONG STRING 'STOCKS' . . . . . . . . . .
stocks=(s1+'_'+s2+'_'+s3+'_'+s4)
# Out:
# Enter Ticker 1: TSLA
# Enter Ticker 2: AMZN
# Enter Ticker 3: AAPL
# Enter Ticker 4: AMD

# %%
start = datetime(2015, 1, 1)
end = datetime.now()

quandl.ApiConfig.api_key = 'zdZRZgzAuK8P2AnsZhU3'
data_df_1 = quandl.get('WIKI/' + s1+'.11', start_date=start, end_date=end, api_key = 'dbyBuiq4bczbbuz9bA4t')
data_df_2 = quandl.get('WIKI/' + s2+'.11', start_date=start, end_date=end, api_key = 'dbyBuiq4bczbbuz9bA4t')
data_df_3 = quandl.get('WIKI/' + s3+'.11', start_date=start, end_date=end, api_key = 'dbyBuiq4bczbbuz9bA4t')
data_df_4 = quandl.get('WIKI/' + s4+'.11', start_date=start, end_date=end, api_key = 'dbyBuiq4bczbbuz9bA4t')


data_price_1 = data_df_1['Adj. Close'].values
data_np_1 = data_df_1.values

data_price_2 = data_df_2['Adj. Close'].values
data_np_2 = data_df_2.values

data_price_3 = data_df_3['Adj. Close'].values
data_np_3 = data_df_3.values

data_price_4 = data_df_4['Adj. Close'].values
data_np_4 = data_df_4.values


data_df_1.to_csv(r'C:\Users\gordo\Programming\Data_Bank\PACKT\gdp_resource\_'+s1+'.csv')
data_df_2.to_csv(r'C:\Users\gordo\Programming\Data_Bank\PACKT\gdp_resource\_'+s2+'.csv')
data_df_3.to_csv(r'C:\Users\gordo\Programming\Data_Bank\PACKT\gdp_resource\_'+s3+'.csv')
data_df_4.to_csv(r'C:\Users\gordo\Programming\Data_Bank\PACKT\gdp_resource\_'+s4+'.csv')

# %%
for df_stock in (data_df_1,data_df_2,data_df_3,data_df_4):
    df_stock['Normalize Return'] = df_stock['Adj. Close']/df_stock.iloc[0]['Adj. Close']
#print(s1)
#data_df_1

for df_stock in (data_df_1,data_df_2,data_df_3,data_df_4):
    df_stock['Normalize Return'] = df_stock['Adj. Close']/df_stock.iloc[1]['Adj. Close']

#print(s2)
#data_df_2

for df_stock in (data_df_1,data_df_2,data_df_3,data_df_4):
    df_stock['Normalize Return'] = df_stock['Adj. Close']/df_stock.iloc[2]['Adj. Close']

#print(s3)
#data_df_3

for df_stock in (data_df_1,data_df_2,data_df_3,data_df_4):
    df_stock['Normalize Return'] = df_stock['Adj. Close']/df_stock.iloc[3]['Adj. Close']

#print(s4)
#data_df_4

# %%
# INPUT ALLOCATIONS PER ASSET

s1_allocate=input('Enter Allocation In Decimal Format - (0.3) : ')
s1_a=float(s1_allocate)

s2_allocate=input('Enter Allocation In Decimal Format - (0.3) : ')
s2_a=float(s2_allocate)

s3_allocate=input('Enter Allocation In Decimal Format - (0.3) : ')
s3_a=float(s3_allocate)

s4_allocate=input('Enter Allocation In Decimal Format - (0.3) : ')
s4_a=float(s4_allocate)
# Out:
# Enter Allocation In Decimal Format - (0.3) : .3
# Enter Allocation In Decimal Format - (0.3) : .22
# Enter Allocation In Decimal Format - (0.3) : .33
# Enter Allocation In Decimal Format - (0.3) : .15

# %%
for df_stock,allocation in zip([data_df_1,data_df_2,data_df_3,data_df_4],[s1_a,s2_a,s3_a,s4_a]):
    df_stock['Allocation'] = df_stock['Normalize Return']*allocation

# %%
#print(s1)
#data_df_1

# %%
for df_stock in [data_df_1,data_df_2,data_df_3,data_df_4]:
    df_stock['Position Values'] = df_stock['Allocation']*10000

# %%
print(s1)
data_df_1
# Out:
# TSLA
#             Adj. Close  Normalize Return  Allocation  Position Values
# Date
# 2015-01-02     219.310          1.039630    0.311889      3118.890732
# 2015-01-05     210.090          0.995923    0.298777      2987.769614
# 2015-01-06     211.280          1.001564    0.300469      3004.693055
# 2015-01-07     210.950          1.000000    0.300000      3000.000000
# 2015-01-08     210.615          0.998412    0.299524      2995.235838
# ...                ...               ...         ...              ...
# 2018-03-21     316.530          1.500498    0.450149      4501.493245
# 2018-03-22     309.100          1.465276    0.439583      4395.828395
# 2018-03-23     301.540          1.429438    0.428831      4288.314767
# 2018-03-26     304.180          1.441953    0.432586      4325.859208
# 2018-03-27     279.180          1.323442    0.397032      3970.324721
#
# [813 rows x 4 columns]

# %%
portfolio_val = pd.concat([data_df_1['Position Values'],data_df_2['Position Values'],data_df_3['Position Values'],data_df_4['Position Values']],axis=1)

# %%
portfolio_val.columns = [s1,s2,s3,s4]
portfolio_val
# Out:
#                    TSLA          AMZN         AAPL          AMD
# Date
# 2015-01-02  3118.890732   2274.458816  3348.389791  1563.953488
# 2015-01-05  2987.769614   2227.793043  3254.060325  1546.511628
# 2015-01-06  3004.693055   2176.925139  3254.366589  1529.069767
# 2015-01-07  3000.000000   2200.000000  3300.000000  1500.000000
# 2015-01-08  2995.235838   2215.039206  3426.793503  1517.441860
# ...                 ...           ...          ...          ...
# 2018-03-21  4501.493245  11661.725085  5521.441073  6546.511628
# 2018-03-22  4395.828395  11383.352322  5443.263374  6343.023256
# 2018-03-23  4288.314767  11025.507674  5317.373099  6180.232558
# 2018-03-26  4325.859208  11470.048924  5569.798413  6069.767442
# 2018-03-27  3970.324721  11036.492192  5426.983069  5813.953488
#
# [813 rows x 4 columns]

# %%
portfolio_val['Total Pos'] = portfolio_val.sum(axis=1)
portfolio_val
# Out:
#                    TSLA          AMZN         AAPL          AMD     Total Pos
# Date
# 2015-01-02  3118.890732   2274.458816  3348.389791  1563.953488  10305.692828
# 2015-01-05  2987.769614   2227.793043  3254.060325  1546.511628  10016.134610
# 2015-01-06  3004.693055   2176.925139  3254.366589  1529.069767   9965.054551
# 2015-01-07  3000.000000   2200.000000  3300.000000  1500.000000  10000.000000
# 2015-01-08  2995.235838   2215.039206  3426.793503  1517.441860  10154.510408
# ...                 ...           ...          ...          ...           ...
# 2018-03-21  4501.493245  11661.725085  5521.441073  6546.511628  28231.171031
# 2018-03-22  4395.828395  11383.352322  5443.263374  6343.023256  27565.467347
# 2018-03-23  4288.314767  11025.507674  5317.373099  6180.232558  26811.428097
# 2018-03-26  4325.859208  11470.048924  5569.798413  6069.767442  27435.473988
# 2018-03-27  3970.324721  11036.492192  5426.983069  5813.953488  26247.753471
#
# [813 rows x 5 columns]

# %%
portfolio_val['Total Pos'].plot(figsize=(10,8))
plt.title('Total Portfolio Value')
# Out:
# Text(0.5, 1.0, 'Total Portfolio Value')

# %%
portfolio_val.drop('Total Pos',axis=1).plot(kind='line')

# %% [markdown]
# ## Quantitative Value Strategy

# %% [markdown]
# ### Define The Method To Extract Fundamental Data

# %%
def get_fundamental_data(df):
    for symbol in df.index:

        url = ("http://finviz.com/quote.ashx?t=" + symbol.lower())
        soup = bs(requests.get(url).content)  # , features='html5lib')
        for m in df.columns:
            try:
                df.loc[symbol, m] = fundamental_metric(soup, m)
            except Exception as e:
                print(symbol, 'not found')
                print(e)
                break
    return df

# %%
def fundamental_metric(soup, metric):
    return soup.find(text=metric).find_next(class_='snapshot-td2').text

# %% [markdown]
# ### Define A List Of Stocks And The Fundamental Metrics

# %%
stock_list = ['AMZN', 'GOOG', 'AXL', 'FB', 'TSLA', 'WMT', 'DIS','KO', 'PEP', '', 'FICO', 'AMD', 'IBM', 'AAPL', 'LPL']

metric = ['P/B',
'P/E',
'Forward P/E',
'PEG',
'Debt/Eq',
'EPS (ttm)',
'Dividend %',
'ROE',
'ROI',
'EPS Q/Q',
'Insider Own'
]

# %%
df = pd.DataFrame(index=stock_list,columns=metric)
df = get_fundamental_data(df)

print('')
print("All stocks with fundamental data")

df
# Out:
#  not found
# 'NoneType' object has no attribute 'find_next'
#
# All stocks with fundamental data
#         P/B     P/E Forward P/E   PEG Debt/Eq EPS (ttm) Dividend %      ROE  \
# AMZN  15.19   82.59       47.32  2.75    0.83     23.02          -   21.10%
# GOOG   4.44   26.41       20.71  1.67       -     49.16          -        -
# AXL    0.59       -        3.28     -    3.73     -4.31          -  -35.40%
# FB     5.11   29.75       16.60  2.25    0.00      6.09          -   20.00%
# TSLA  19.13       -       50.61     -    2.03     -5.01          -  -15.00%
# WMT    4.65   22.59       21.57  3.80    0.76      5.19      1.84%   18.20%
# DIS    2.32   19.43       18.79  4.10    0.54      5.93      1.53%   11.60%
# KO    12.47   26.72       22.59  3.13    2.25      2.07      2.97%   48.80%
# PEP   12.94   26.43       21.65  4.18    2.17      5.19      2.78%   51.30%
#         NaN     NaN         NaN   NaN     NaN       NaN        NaN      NaN
# FICO  43.12   52.31       36.54  2.74    3.84      6.84          -   79.10%
# AMD   19.59  168.13       30.73  4.71    0.17      0.29          -   15.70%
# IBM    5.44   11.90        9.01  1.64    3.02     10.73      5.07%   51.70%
# AAPL  14.25   22.83       18.43  1.88    1.22     12.66      1.07%   60.20%
# LPL    0.40       -       21.32     -    1.03     -1.02          -   -6.50%
#
#          ROI  EPS Q/Q Insider Own
# AMZN  10.70%   12.70%      11.20%
# GOOG       -   19.30%       5.66%
# AXL   -5.40%  -28.00%       1.44%
# FB    17.50%   -7.10%       0.99%
# TSLA  -0.90%  -28.00%       0.10%
# WMT   10.50%  103.20%       0.30%
# DIS    8.40%  -36.10%       0.10%
# KO    12.20%  134.00%       0.74%
# PEP   17.80%  -69.70%       0.10%
#          NaN      NaN         NaN
# FICO  20.60%   38.00%       1.00%
# AMD   12.40%  187.40%       0.60%
# IBM   11.40%   -5.00%       0.10%
# AAPL  26.90%   19.30%       0.10%
# LPL   -0.30%        -      51.10%

# %% [markdown]
# ### Businesses which are quoted at low valuations
# * P/E < 20
# * P/B < 3

# %%
try:
    df = df[(df['P/E'].astype(float) < 20) & (df['P/B'].astype(float) < 3)]
except:
    pass

# %% [markdown]
# ### Businesses which have demonstrated earning power
# * EPS Q/Q > 10%

# %%
try:
    df['EPS Q/Q'] = df['EPS Q/Q'].map(lambda x: x[:-1])
    df = df[df['EPS Q/Q'].astype(float) > 10]
except:
    pass

# %% [markdown]
# ### Businesses earning good returns on equity while employing little or no debt
# * Debt/Eq < 1
# * ROE > 10%

# %%
try:
    df['ROE'] = df['ROE'].map(lambda x: x[:-1])
    df = df[(df['Debt/Eq'].astype(float) < 1) & (df['ROE'].astype(float) > 10)]
except:
    pass

# %% [markdown]
# ### Management having substantial ownership in the business
# * Insider own > 30%

# %%
try:
    df['Insider Own'] = df['Insider Own'].map(lambda x: x[:-1])
    df = df[df['Insider Own'].astype(float) > 30]
except:
    pass

print("Stocks after screening")
df
# Out:
# Stocks after screening
#         P/B     P/E Forward P/E   PEG Debt/Eq EPS (ttm) Dividend %      ROE  \
# AMZN  15.19   82.59       47.32  2.75    0.83     23.02          -   21.10%
# GOOG   4.44   26.41       20.71  1.67       -     49.16          -        -
# AXL    0.59       -        3.28     -    3.73     -4.31          -  -35.40%
# FB     5.11   29.75       16.60  2.25    0.00      6.09          -   20.00%
# TSLA  19.13       -       50.61     -    2.03     -5.01          -  -15.00%
# WMT    4.65   22.59       21.57  3.80    0.76      5.19      1.84%   18.20%
# DIS    2.32   19.43       18.79  4.10    0.54      5.93      1.53%   11.60%
# KO    12.47   26.72       22.59  3.13    2.25      2.07      2.97%   48.80%
# PEP   12.94   26.43       21.65  4.18    2.17      5.19      2.78%   51.30%
#         NaN     NaN         NaN   NaN     NaN       NaN        NaN      NaN
# FICO  43.12   52.31       36.54  2.74    3.84      6.84          -   79.10%
# AMD   19.59  168.13       30.73  4.71    0.17      0.29          -   15.70%
# IBM    5.44   11.90        9.01  1.64    3.02     10.73      5.07%   51.70%
# AAPL  14.25   22.83       18.43  1.88    1.22     12.66      1.07%   60.20%
# LPL    0.40       -       21.32     -    1.03     -1.02          -   -6.50%
#
#          ROI  EPS Q/Q Insider Own
# AMZN  10.70%   12.70%      11.20%
# GOOG       -   19.30%       5.66%
# AXL   -5.40%  -28.00%       1.44%
# FB    17.50%   -7.10%       0.99%
# TSLA  -0.90%  -28.00%       0.10%
# WMT   10.50%  103.20%       0.30%
# DIS    8.40%  -36.10%       0.10%
# KO    12.20%  134.00%       0.74%
# PEP   17.80%  -69.70%       0.10%
#          NaN      NaN         NaN
# FICO  20.60%   38.00%       1.00%
# AMD   12.40%  187.40%       0.60%
# IBM   11.40%   -5.00%       0.10%
# AAPL  26.90%   19.30%       0.10%
# LPL   -0.30%        -      51.10%

# %% [markdown]
# # ALPHA & BETA MARKET ANALYSIS

# %%
start='2019-1-1'
end='2020-1-1'

yf.pdr_override()

df1=pdr.get_data_yahoo("GOOG", start, end)
df2=pdr.get_data_yahoo("SPY", start, end)

df1
#df2
# Out:
#                    High          Low         Open        Close     Volume  \
# Date
# 2019-01-02  1052.319946  1015.710022  1016.570007  1045.849976  1532600.0
# 2019-01-03  1056.979980  1014.070007  1041.000000  1016.059998  1841100.0
# 2019-01-04  1070.839966  1027.417969  1032.589966  1070.709961  2093900.0
# 2019-01-07  1074.000000  1054.760010  1071.500000  1068.390015  1981900.0
# 2019-01-08  1084.560059  1060.530029  1076.109985  1076.280029  1764900.0
# ...                 ...          ...          ...          ...        ...
# 2019-12-26  1361.327026  1344.469971  1346.170044  1360.400024   667500.0
# 2019-12-27  1364.530029  1349.310059  1362.989990  1351.890015  1038400.0
# 2019-12-30  1353.000000  1334.020020  1350.000000  1336.140015  1050900.0
# 2019-12-31  1338.000000  1329.084961  1330.109985  1337.020020   961800.0
# 2020-01-02  1368.140015  1341.550049  1341.550049  1367.369995  1406600.0
#
#               Adj Close
# Date
# 2019-01-02  1045.849976
# 2019-01-03  1016.059998
# 2019-01-04  1070.709961
# 2019-01-07  1068.390015
# 2019-01-08  1076.280029
# ...                 ...
# 2019-12-26  1360.400024
# 2019-12-27  1351.890015
# 2019-12-30  1336.140015
# 2019-12-31  1337.020020
# 2020-01-02  1367.369995
#
# [253 rows x 6 columns]

# %% [markdown]
# ## GOAL = Obtain Percent Change [.pct_change()]
# Also, do NOT want to obtain first (0th) element because that will result in NaN

# %%
return_goog=df1.Close.pct_change()[1:]
return_spy=df2.Close.pct_change()[1:]

# %% [markdown]
# ## PLOT Returns Versus
# We will plot the returns of Google and S&P500 against each other

# %%
plt.figure(figsize=(20,10))
return_goog.plot()
return_spy.plot()
plt.ylabel("Daily Return of GOOG and SPY")
plt.show()

# %% [markdown]
# ## Capital Asset Pricing Model or CAPM (How to Calculate Beta)
# * One of the most common ways to calculate beta is using the Capital Asset Pricing Model or CAPM.
# - Have a look at the CAPM model:
#     - E (Ra) = Rf + Ba [ E (Rm) - Rf]
#
# * CAPM model states that the expected return of an asset ‘E (Ra)’ is equal to the risk-free return in the market plus the difference between the expected return of the market and risk-free rate ‘[E (Rm) - Rf]’ multiplied by the asset’s beta  ‘Ba’.
#
# * If we have all the values except the asset’s beta, we can calculate the beta using:
#        -  Ba = [E (Ra) - Rf] / [ E (Rm) - Rf]
#
# * We can even find beta by performing the ‘regression analysis’.
#
# * When one tries to capture a mathematical relationship between ‘x’ and ‘y’ variables, by fitting a line, polynomial or a curve through scatter plots, such that one can make a reasonably good prediction of  ‘y’ given ‘x’, then the mathematical process of deriving such an equation between x and y is called the regression analysis.This equation can also arrived at by using a machine learning based regression model.
#
# * If we try to fit a ‘line’ through this scatter plot that “best” explains the observed values of ‘y’ in terms of observed values of ‘x’, we get a simple linear regression model.
#
# * Linear regression assumes a linear relationship between the dependent and independent variables.
#
# * The following regression equation describes that relation:
#     - Yi = b0 + b1 Xi + ei
#
# * We refer to the intercept ‘b0’ and slope coefficient ‘b1’ as the regression coefficients and ei as the random error.
#     - Rasset = ex-post alpha + beta of asset *  Rbenchmark  + ei
#
# * To understand the coefficients more intuitively, if we consider the returns for Google vs. S&P 500 index, then the slope coefficient in a regression line is called the stock’s beta, as it measures the relative amount of systematic or undiversifiable risk in Google’s returns.
#
# * If the slope of Google returns is more than 1, its returns tend to increase or decrease more than the market returns. A slope or beta of 1 would have the same level of systematic risk as that of the market on an average, and a slope or beta less than 1 implies that the returns increase or decrease by less than the change in the market returns.
#
# * The intercept term is the ex-post alpha i.e. the measure of excess returns of Google as compared to market index returns. If the intercept term is negative, it means Google has underperformed S&P on a risk adjusted basis and a positive intercept means it has had excess returns on risk adjusted basis.
#
# * All the points on the regression equation line, predict the ‘y’ values for the corresponding ‘x’ values. However, the optimal regression line is the one for which the sum of the squared differences (vertical distances) or the sum of squared errors or SSE between the ‘y’ values predicted by the regression equation/line and the actual ‘y’ values is minimal.
#
# * Thus, the regression line minimizes the SSE. This is the reason why simple linear regression is also called as Ordinary Least Squares or OLS, and the estimated (predicted) values by the regression equation i.e. y predicted are called least squares estimates.
#
# * The slope coefficient ‘b1’ of the regression line is calculated as the covariance of x and y divided by the variance of x (covxy /σ2x ), and the intercept coefficient is the line's intersection with the y axis at x = 0.

# %%
import statsmodels.api as sm
from statsmodels import regression

X=return_spy.values
Y=return_goog.values

def linreg(x,y):
    x=sm.add_constant(x)
    model=regression.linear_model.OLS(y,x).fit()
    
    # REMOVE THE CONSTANT
    x=x[:,1]
    return model.params[0], model.params[1]

alpha, beta = linreg(X,Y)
print('alpha: '+str(alpha))
print('')
print('beta: '+str(beta))
# Out:
# alpha: -0.000187174036974112
#
# beta: 1.279115703665263

# %% [markdown]
# ## LINEAR REGRESSION PLOT

# %%
X2 = np.linspace(X.min(), X.max(), 100)
Y_hat = X2 * beta + alpha

plt.figure(figsize=(10,7))
plt.scatter(X, Y, alpha=0.3) # PLOTS RAW DATA

plt.xlabel('S&P 500 Daily Return')
plt.ylabel('GOOG Daily Return')

plt.plot(X2, Y_hat, 'r', alpha=0.9)

plt.show()
