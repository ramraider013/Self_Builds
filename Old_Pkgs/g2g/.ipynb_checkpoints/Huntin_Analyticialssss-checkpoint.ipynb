# %%
# Importing libraries

import numpy as np
import pandas as pd
import pyexcel
import statsmodels.api as stat
import statsmodels.tsa.stattools as ts
import quandl
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r'C:\Users\gordo\Programming\Data_Bank\HUNTIN\2018_ELK_HARVESTxlsx.xlsx', index_col='Unit', squeeze=True)



df
# Out:
#       Bulls  Cows  Calves  Harvest  Hunters  Success  Rec. Days
# Unit
# 1         7    24       0       31       82       38        336
# 2        25    50       6       81      163       50        812
# 201      26    57       2       85      167       51        668
# 3       295   479      44      818     3624       23      14492
# 301     194   198      27      419     1811       23       7064
# ...     ...   ...     ...      ...      ...      ...        ...
# 110      20    14       3       37       77       48        488
# 111       0     0       0        0        6        0         17
# 112       0     0       0        0        6        0         17
# 114       0     0       0        0        3        0         20
# 115       0     0       0        0        3        0          3
#
# [148 rows x 7 columns]

# %%
df.nlargest(10, ['Harvest'])
# Out:
#       Bulls  Cows  Calves  Harvest  Hunters  Success  Rec. Days
# Unit
# 4       673   592      52     1317     4581       29      20098
# 12      548   592      77     1217     5032       24      20953
# 11      540   529      53     1122     4732       24      19333
# 23      346   478      82      906     4038       22      16125
# 3       295   479      44      818     3624       23      14492
# 70      370   351      22      743     2815       26      13365
# 441     338   348      30      716     1842       39       6487
# 18      304   358      32      694     4576       15      19821
# 62      421   235       9      665     3129       21      14816
# 77      557    87       6      650     2488       26      11379

# %%
df['Ratio']=df['Harvest']/df['Hunters']

df.nlargest(10, ['Harvest'])
# Out:
#       Bulls  Cows  Calves  Harvest  Hunters  Success  Rec. Days     Ratio
# Unit
# 4       673   592      52     1317     4581       29      20098  0.287492
# 12      548   592      77     1217     5032       24      20953  0.241852
# 11      540   529      53     1122     4732       24      19333  0.237109
# 23      346   478      82      906     4038       22      16125  0.224368
# 3       295   479      44      818     3624       23      14492  0.225717
# 70      370   351      22      743     2815       26      13365  0.263943
# 441     338   348      30      716     1842       39       6487  0.388708
# 18      304   358      32      694     4576       15      19821  0.151661
# 62      421   235       9      665     3129       21      14816  0.212528
# 77      557    87       6      650     2488       26      11379  0.261254

# %%
df.nsmallest(10, ['Hunters'])
# Out:
#       Bulls  Cows  Calves  Harvest  Hunters  Success  Rec. Days  Ratio
# Unit
# 88        0     0       0        0        3        0         14    0.0
# 93        0     0       0        0        3        0         29    0.0
# 101       0     0       0        0        3        0         29    0.0
# 114       0     0       0        0        3        0         20    0.0
# 115       0     0       0        0        3        0          3    0.0
# 89        0     0       0        0        6        0         14    0.0
# 95        0     0       0        0        6        0        340    0.0
# 96        0     0       0        0        6        0         46    0.0
# 99        0     0       0        0        6        0         32    0.0
# 107       0     0       0        0        6        0         40    0.0

# %%
df.nlargest(50, ['Success'])
# Out:
#       Bulls  Cows  Calves  Harvest  Hunters  Success  Rec. Days     Ratio
# Unit
# 512       0     4       0        4        7       57         40  0.571429
# 201      26    57       2       85      167       51        668  0.508982
# 40       81    98       5      184      358       51       1482  0.513966
# 2        25    50       6       81      163       50        812  0.496933
# 100       3     0       0        3        6       50         17  0.500000
# 10       29   223      15      267      557       48       2307  0.479354
# 20      104   256      17      377      788       48       8405  0.478426
# 682      39    16       0       55      114       48        176  0.482456
# 110      20    14       3       37       77       48        488  0.480519
# 391      18    88      10      116      247       47       3940  0.469636
# 61      202   205      17      424      920       46       4025  0.460870
# 9        23    50       0       73      163       45        812  0.447853
# ...

# %%
df.Hunters.max=pd.DataFrame(df.nlargest(50, ['Success']))

df.Hunters.max
# Out:
#       Bulls  Cows  Calves  Harvest  Hunters  Success  Rec. Days     Ratio
# Unit
# 512       0     4       0        4        7       57         40  0.571429
# 201      26    57       2       85      167       51        668  0.508982
# 40       81    98       5      184      358       51       1482  0.513966
# 2        25    50       6       81      163       50        812  0.496933
# 100       3     0       0        3        6       50         17  0.500000
# 10       29   223      15      267      557       48       2307  0.479354
# 20      104   256      17      377      788       48       8405  0.478426
# 682      39    16       0       55      114       48        176  0.482456
# 110      20    14       3       37       77       48        488  0.480519
# 391      18    88      10      116      247       47       3940  0.469636
# 61      202   205      17      424      920       46       4025  0.460870
# 9        23    50       0       73      163       45        812  0.447853
# ...

# %%
df.Success.max=pd.DataFrame(df.nlargest(50, ['Hunters']))

df.Success.max
# Out:
#       Bulls  Cows  Calves  Harvest  Hunters  Success  Rec. Days     Ratio
# Unit
# 12      548   592      77     1217     5032       24      20953  0.241852
# 11      540   529      53     1122     4732       24      19333  0.237109
# 4       673   592      52     1317     4581       29      20098  0.287492
# 18      304   358      32      694     4576       15      19821  0.151661
# 23      346   478      82      906     4038       22      16125  0.224368
# 3       295   479      44      818     3624       23      14492  0.225717
# 28      209   275      38      522     3457       15      14112  0.150998
# 24      245   248      30      523     3365       16      13945  0.155423
# 62      421   235       9      665     3129       21      14816  0.212528
# 15      183   226      15      424     2985       14      14281  0.142044
# 70      370   351      22      743     2815       26      13365  0.263943
# 55      208   248      25      481     2699       18      12324  0.178214
# ...

# %%
df[df.Hunters == df.Hunters.max()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-86af14f36d7d> in <module>
# ----> 1 df[df.Hunters == df.Hunters.max()]
#
# TypeError: 'DataFrame' object is not callable

# %%
data =pd.read_excel(r'C:\Users\gordo\Programming\Data_Bank\HUNTIN\2018_ELK_HARVESTxlsx.xlsx')

data
# Out:
#      Unit  Bulls  Cows  Calves  Harvest  Hunters  Success  Rec. Days
# 0       1      7    24       0       31       82       38        336
# 1       2     25    50       6       81      163       50        812
# 2     201     26    57       2       85      167       51        668
# 3       3    295   479      44      818     3624       23      14492
# 4     301    194   198      27      419     1811       23       7064
# ..    ...    ...   ...     ...      ...      ...      ...        ...
# 143   110     20    14       3       37       77       48        488
# 144   111      0     0       0        0        6        0         17
# 145   112      0     0       0        0        6        0         17
# 146   114      0     0       0        0        3        0         20
# 147   115      0     0       0        0        3        0          3
#
# [148 rows x 8 columns]

# %%
import pandas as pd 

data.sort_values('Unit', inplace = True) 

filter = data['Unit']==85

data.where(filter, inplace = True) 

data
# Out:
#      Unit  Bulls  Cows  Calves  Harvest  Hunters  Success  Rec. Days
# 0     NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 1     NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 3     NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 5     NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 7     NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# ..    ...    ...   ...     ...      ...      ...      ...        ...
# 112   NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 115   NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 122   NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 124   NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 131   NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
#
# [148 rows x 8 columns]

# %%
df1.dropna
# Out:
# <bound method DataFrame.dropna of      Unit  Bulls  Cows  Calves  Harvest  Hunters  Success  Rec. Days
# 0     NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 1     NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 3     NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 5     NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 7     NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# ..    ...    ...   ...     ...      ...      ...      ...        ...
# 112   NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 115   NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 122   NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 124   NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
# 131   NaN    NaN   NaN     NaN      NaN      NaN      NaN        NaN
#
# [148 rows x 8 columns]>
